# %% [markdown]
# ### **SETUP:**

# %% [markdown]
# **Add pre-installed package path & load packages:**

# %%
.libPaths(c(.libPaths(), "/exports/eddie3_apps_local/apps/SL7/R/4.3.0/lib64/R/library"))

# %%
#remotes::install_github('MRCIEU/TwoSampleMR')

# %%
library("dplyr", warn.conflicts = F)
library("stringr", warn.conflicts = F)
library("data.table", warn.conflicts = F) 
library("vroom", warn.conflicts = F)
library("ggplot2", warn.conflicts = F)
library("TwoSampleMR")
library("readxl")
# Out:
# TwoSampleMR version 0.5.11
# [>] New: Option to use non-European LD reference panels for clumping etc
# [>] Some studies temporarily quarantined to verify effect allele
# [>] See news(package = 'TwoSampleMR') and https://gwas.mrcieu.ac.uk for further details
#
#
#
# Warning:
# You are running an old version of the TwoSampleMR package.
# This version:   0.5.11
# Latest version: 0.6.15
# Please consider updating using remotes::install_github('MRCIEU/TwoSampleMR')

# %% [markdown]
# **Change working directory:**

# %%
wd = "/exports/cmvm/eddie/smgphs/groups/Quantgen/Users/vasilis/PHD/"
setwd(wd)
getwd()
# Out:
# [1] "/exports/cmvm/eddie/smgphs/groups/Quantgen/Users/vasilis/PHD"

# %% [markdown]
# ### **Extract instruments (non-clumped):**

# %%
## column names to extract
default_2smr_cols    <- c("Phenotype", "SNP", "chr", "position", "effect_allele", "other_allele", "beta", "se", "pval", "eaf", "samplesize")
## all protein exposure names
protein_list <- list.files("SBpQTL_project/SBMR/data/1.GWAS_on_protein/")

# progress bar
pb = txtProgressBar(min = 0, max = length(protein_list), initial = 0) 

## protein loop  
for (i in 1:length(protein_list)){
#for (i in c(1,1172:1175)){
     ## protein name 
    exp_i_name = protein_list[i]
    #cat(paste(exp_i_name, "...\t"))
    ## load protein sumstats
    exp_i_file <- paste0("SBpQTL_project/SBMR/data/1.GWAS_on_protein/", exp_i_name, "/2.Step_2/Step2_", exp_i_name, "_NPX.regenie")
    ## skip proteins with no sumstats
    if (file.exists(exp_i_file)==FALSE) next
    ## filter & reformat
    exp_i <- 
        fread(exp_i_file) %>%
        # make phenotype (protein name) & pvalue column
        mutate(Phenotype = exp_i_name,
               pval = 10^(-LOG10P)) %>%
        # filter pQTL ~ protein associations with pval < 5e-8
        filter(pval <= 5e-8) %>% 
        # rename columns to match 2smr defaults
        rename(Phenotype = Phenotype,
               SNP = ID,
               beta = BETA,
               se = SE,
               effect_allele = ALLELE1,
               other_allele = ALLELE0,
               pval = pval,
               chr = CHROM,
               position = GENPOS,
               eaf = A1FREQ,
               samplesize = N
               ) %>%
        select(all_of(default_2smr_cols)) %>%
        as.data.frame
    #cat(paste(nrow(exp_i), "non-clumped pQTLs\n"))
    # append all sumstats in one df
    if(exp_i_name == protein_list[1]) {
        #cat("... Starting binding all pQTLs ...\n")
        exp_all = exp_i
    }
    else {
        exp_all <- bind_rows(exp_all, exp_i)
        #cat(paste("... ", nrow(exp_all), "pQTLs in total ...\n"))
    }
    # print progress 
    setTxtProgressBar(pb,i)   
    cat(paste0("\rExtracted ", i, " out of ",  length(protein_list), " proteins (", round((i / length(protein_list)*100),2), "%) ..."))
}

# %%
dim(exp_all)
unique(exp_all$Phenotype) %>% length
# Out:
# [1] 339899     11
# [1] 2464

# %%
## save non-clumped pqtls
# system("mkdir -p pQTL_MR_analysis/data", intern=T)
# write.table(exp_all, "pQTL_MR_analysis/data/pQTLs_non_clumped.txt", sep = " ", quote=F, row.names = F)
# Out:
# character(0)

# %% [markdown]
# ### **Liftover pQTLs to hg38 & extract cis-pQTLs:**

# %%
exp_all <- fread("pQTL_MR_analysis/data/pQTLs_non_clumped.txt")

# %%
LIFTOVER  = "/exports/cmvm/eddie/smgphs/groups/Quantgen/Users/vasilis/PHD/software/liftOver"
CHAINFILE = "/exports/cmvm/eddie/smgphs/groups/Quantgen/Users/vasilis/PHD/resources/liftOver_files/hg19ToHg38.over.chain.gz"
OUTDIR    = "/exports/cmvm/eddie/smgphs/groups/Quantgen/Users/vasilis/PHD/pQTL_MR_analysis/data/"
temp_in_file = "/exports/cmvm/eddie/smgphs/groups/Quantgen/Users/vasilis/PHD/pQTL_MR_analysis/data/temp_liftover_in.BED"

#exp_clumped <- fread("pQTL_MR_analysis/data/per_protein/pQTLs_clumped_thres0.2.txt") %>% as.data.frame

# make BED input
temp_in <- exp_all %>% 
#temp_in <- exp_pruned %>% 
#temp_in <- exp_clumped %>%     
    mutate(CHR = paste0("chr", chr), POS0 = position-1) %>% 
    select(CHR, POS0, position, SNP) %>% 
    arrange(SNP) %>% filter(!duplicated(SNP)) # select only unique SNPs
write.table(temp_in, temp_in_file, quote=F, row.names = F, col.names = F)
# run liftOver
system(paste0(
    LIFTOVER,
    " -bedPlus=3 ", 
    temp_in_file, " ",
    CHAINFILE, " ",
    OUTDIR, "temp_liftover_out.BED ",
    OUTDIR, "temp_liftover_unmapped.BED "),
       intern = T
      )
# load hg38 positions (excludes unmapped)
temp_hg38 <- fread("pQTL_MR_analysis/data/temp_liftover_out.BED")

exp_all_hg38 <-
    left_join(x=exp_all, y=temp_hg38[,c("V1","V3","V4")], by=c("SNP"="V4")) %>% 
# exp_pruned_hg38 <-
#     left_join(x=exp_pruned, y=temp_hg38[,c("V1","V3","V4")], by=c("SNP"="V4")) %>% 
# exp_clumped_hg38 <-
#    left_join(x=exp_clumped, y=temp_hg38[,c("V1","V3","V4")], by=c("SNP"="V4")) %>% 
    rename(position_hg38 = V3) %>%
    mutate(chr38 = gsub("chr", "", V1)) %>%
    filter(chr==chr38) %>%
    select(-c(V1, chr38))
# remove temp data
system("rm pQTL_MR_analysis/data/temp_*", intern=T)
# Out:
# character(0)
# character(0)

# %% [markdown]
# *Load metadata:*

# %%
# assay table 
file <- "/exports/cmvm/eddie/smgphs/groups/Quantgen/Users/ukb_data/ukb44986/proteomics/olink_assay.dat"
assay <- fread(file)
# replace "-" with "_" in assay (protein) names
assay <- assay %>% mutate(Assay = gsub("-", "_", Assay))

# %%
# genomic positions table
file <- "/exports/cmvm/eddie/smgphs/groups/Quantgen/Users/vasilis/PHD/proteomics/Resource/Proteome/Sun_etal_sup/proteins_positions.txt"
pos  <- fread(file)

# %%
pos <-
pos %>% 
    mutate(UniProt = gsub(";.*","",UniProt)) %>%
    mutate(Gene_CHROM = gsub(";.*","",Gene_CHROM)) %>%
    mutate(Gene_start = gsub(";.*","",Gene_start))%>% 
    mutate(Gene_end = gsub(";.*","",Gene_end)) %>%
    filter(!duplicated(UniProt))

# %%
# merge protein (gene) info with exposure table & define cis pQTLs : within 1 Mb from the gene encoding the protein
exp_all_annot <- 
inner_join(x=exp_all_hg38, y=assay, by=c("Phenotype"="Assay")) %>% 
#exp_pruned_annot <- 
#inner_join(x=exp_pruned_hg38, y=assay, by=c("Phenotype"="Assay")) %>% 
#exp_clumped_annot <- 
#inner_join(x=exp_clumped_hg38, y=assay, by=c("Phenotype"="Assay")) %>% 
    mutate(UniProt2 = gsub("-.*","", UniProt)) %>% 
    mutate(UniProt2 = gsub("_.*","", UniProt2)) %>%
    left_join(x=., y=pos[,-c("Assay_Target","Gene_symbol")], by=c("UniProt2"="UniProt")) %>% 
    mutate(Gene_CHROM = gsub("X","23",Gene_CHROM),
           Gene_CHROM = as.numeric(Gene_CHROM),
           Gene_start = as.numeric(Gene_start),
           Gene_end = as.numeric(Gene_end)
          ) %>%
    # define cis (<= 1Mb of the gene); otherwise trans
    mutate(IsCis = case_when( chr == Gene_CHROM & (position_hg38 >= Gene_start-1e6) &  (position_hg38 <= Gene_end+1e6) ~ 1,
                              TRUE ~ 0
                            )
          )

# %%
## extract cis-pQTLs
exp_all_annot_cis <- exp_all_annot[exp_all_annot$IsCis==1,]
nrow(exp_all_annot_cis)
#write.table(exp_all_annot_cis, "pQTL_MR_analysis/data/pQTLs_non_clumped_cis.txt", sep = " ", quote=T, row.names = F)
# Out:
# [1] 87331

# %% [markdown]
# ### **LD pruning:**

# %%
exp_all <- fread("pQTL_MR_analysis/data/pQTLs_non_clumped.txt")

# %%
# extract unique SNP ids for pruning
system("cat pQTL_MR_analysis/data/pQTLs_non_clumped.txt | awk 'NR > 1 {print $2}' | sort | uniq > pQTL_MR_analysis/data/pQTLs_non_clumped_uniq.txt", intern=T)
# Out:
# character(0)

# %%
# load plink 
system("module load igmm/apps/plink/1.90b7.2", intern = T)
system("/gpfs/igmmfs01/software-rl9/apps/plink/1.90b7.2/plink --indep-pairwise --help | head", intern = T)
# Out:
# character(0)
#  [1] "PLINK v1.90b7.2 64-bit (11 Dec 2023)           www.cog-genomics.org/plink/1.9/" "(C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3"
#  [3] "--help present, ignoring other flags."                                          ""
#  [5] "--indep <window size>['kb'] <step size (variant ct)> <VIF threshold>"           "--indep-pairwise <window size>['kb'] <step size (variant ct)> <r^2 threshold>"
#  [7] "--indep-pairphase <window size>['kb'] <step size (variant ct)> <r^2 thresh>"    "  Generate a list of markers in approximate linkage equilibrium.  With the"
#  [9] "  'kb' modifier, the window size is in kilobase instead of variant count"       "  units.  (Pre-'kb' space is optional, i.e. \"--indep-pairwise 500 kb 5 0.5\""

# %%
## run pruning
plink    = "/gpfs/igmmfs01/software-rl9/apps/plink/1.90b7.2/plink"
bedfile  = "/exports/cmvm/eddie/smgphs/groups/Quantgen/Users/ybhak/Projects/AIM-CISC/Analysis/Second_Mockup/Result/0.Genotype/unrelated_qc_array_genotypes_XY"
pQTLs_in = "pQTL_MR_analysis/data/pQTLs_non_clumped_uniq.txt"
pQTLs_out= "pQTL_MR_analysis/data/pQTLs"
r2 = 0.1
system(paste0(
    plink,
    " --bfile ", bedfile,
    " --extract ", pQTLs_in,
    " --indep-pairwise 500kb 1 ", r2, # r2=0.05 maybe too low 
    " --out ", paste0(pQTLs_out,r2),
    " --threads $(nproc)"),
    intern = F
      )

# %%
## load pruned SNPs
file   <- paste0(pQTLs_out, r2, ".prune.in")
pruned <- fread(file, header=F)$V1
pruned %>% length
# Out:
# [1] 19419

# %%
## extract pruned SNPs 
exp_pruned <- exp_all %>% filter(SNP %in% pruned) %>% as.data.frame
## check proteins that lose all pQTLs after pruning 
prots.rm <- setdiff(exp_all$Phenotype ,exp_pruned$Phenotype)
cat(paste0(length(prots.rm), " proteins with no pruned pQTLs:\n\n"), prots.rm)
# Out:
# 223 proteins with no pruned pQTLs:
#
#  ACOX1 ACSL1 AHSA1 AIF1 AIFM1 AK2 ALDH2 ANXA10 AP2B1 AP3B1 AP3S2 ARF6 ARL13B ARNT ATP6V1D ATP6V1F AZI2 BAG4 BAMBI BAP18 BCL2 BCL2L1 BIRC2 BLOC1S3 BNIP2 CALB2 CAMSAP1 CAPN3 CASP2 CCT5 CD2 CDC37 CDC42BPB CEBPA CEP170 CEP290 CERT CHM CLPP CLSTN1 CMIP COMMD9 COX6B1 CRKL CSRP3 CTF1 DARS1 DCN DCTN2 DCTN6 DDX25 DECR1 DEFB116 DENR DFFA DHPS DLG4 DNAJA2 DNAJB14 DNAJC9 DOK1 DTX2 EDNRB EIF4E EIF5 ENOX2 ESR1 EVI5 FEN1 FKBP7 FKBPL FNTA FOSB FOXJ3 FOXO3 FUS GABARAPL1 GAPDH GATD3 GCC1 GFER GH2 GIT1 GOPC GPI GRAP2 GRSF1 GUCY2C HARS1 HDAC8 HIP1 HNRNPK HTRA2 IGFBP1 IL11 IL1A IL36A ILKAP IMPACT IMPG1 ING1 INPPL1 IRAG2 IRAK1 KCTD5 KIF1C KLHL41 KRT8 LARP1 LAT2 LATS1 LETM1 M6PR MAP1LC3B2 MARS1 MITD1 MMUT MYCBP2 MYLPF MZT1 NAA10 NACC1 NAMPT NARS1 NBN NDUFB7 NEO1 NFX1 NOS3 NRGN OTUD6B OTUD7B P4HB PAIP2B PAK4 PARD3 PBXIP1 PCBP2 PDP1 PEBP1 PGA4 PITHD1 PLCB1 PLIN1 PPIF PPM1B PPM1F PPP1CC PPP1R14D PRDX3 PRKD2 PSMD1 PTK7 PTPN1 PTPRR RAB39B RAD23B RALY RCC1 RCOR1 RGS10 RNF4 RNF41 RPL14 RPS10 RRAS SCP2 SEMA6C SERPINB5 SHD SIRT1 SLMAP SMAD1 SMAD2 SMPD3 SMS SNAPIN SNRPB2 SORBS1 SPART SPRED2 SSH3 ST13 ST8SIA1 STAMBP STK11 STK24 STX4 STX6 SUGT1 SYT1 TAB2 TADA3 TARBP2 TBC1D5 TEF TET2 TGFB2 TIMM8A TMPRSS11B TNFAIP8L2 TPBGL TPPP3 TRIM21 TSC1 TSC22D1 TSNAX TSPAN1 TSPAN7 TXK UBE2B UBE2Z USO1 USP28 VASP VPS37A VPS53 WASL WWP2 XIAP YOD1 YTHDF3 ZPR1

# %% [markdown]
# ### **LD clumping:**

# %% [markdown]
# Steps:
# 1. **UPDATE (14.03.25):** Start with cis-pQTLs
# 2. make per protein non-clumped sumstats files
# 3. thin down reference plink files; use proteomics ids and pQTLs_non_clumped_uniq.txt
# 4. run clumping with plink -> per protein files prot.clumped
# 5. combine all prot.clumped snplists (some will overlap - its fine i guess)

# %%
# non-pruned cis pQTLs
exp_all_annot_cis <- fread("pQTL_MR_analysis/data/pQTLs_non_clumped_cis.txt")
# list of exposures
exp_prots <- unique(exp_all_annot_cis$Phenotype)
length(exp_prots)
# make output dir
out_dir = "pQTL_MR_analysis/data/per_protein/non_clumped/cis"
cmd = paste0("mkdir -p ", out_dir)
system(cmd)
# Out:
# [1] 1860

# %%
## make per-protein non-clumped files (for plink --clump)

# progress bar
pb = txtProgressBar(min = 0, max = length(exp_prots), initial = 0) 

# loop each protein
for (i in 1:length(exp_prots)){
    exp_i_name = exp_prots[i]
    # extract & write per-protein non-pruned pQTLs table
    exp_i <- exp_all_annot_cis[exp_all_annot_cis$Phenotype==exp_i_name,]
    out_i = paste0(out_dir,"/", exp_i_name, "_CIS_nonclumped_for_plink.txt")
    write.table(exp_i, file = out_i, row.names=F, quote=F, sep=" ")
    # print progress 
    setTxtProgressBar(pb,i)   
}
# Out:
# ========================================================================================================================================================================================================

# %%
# load plink 
system("module load igmm/apps/plink/1.90b7.2", intern = T)
system("/gpfs/igmmfs01/software-rl9/apps/plink/1.90b7.2/plink --clump --help | head", intern = T)
# Out:
# character(0)
#  [1] "PLINK v1.90b7.2 64-bit (11 Dec 2023)           www.cog-genomics.org/plink/1.9/" "(C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3"
#  [3] "--help present, ignoring other flags."                                          ""
#  [5] "--clump <PLINK report filename(s)...>"                                          "  Process association analysis report(s) with 'SNP' and p-value columns,"
#  [7] "  organizing results by LD-based clumps.  Multiple filenames can be separated"  "  by spaces or commas."
#  [9] ""                                                                               "--clump-p1 <pval> : Set --clump index var. p-value ceiling (default 1e-4)."

# %%
# ids to keep for reference plink files 
keepfile = "pQTL_MR_analysis/data/ids.to.keep"
keep <- fread("/exports/cmvm/eddie/smgphs/groups/Quantgen/Users/vasilis/PHD/proteomics/delirium/data/data_int_clean.csv", select = "IID") %>% mutate(FID=IID)
write.table(keep, file=keepfile, row.names=F, quote=F, col.names=F, sep=" ")

# %%
## thin down reference plink files
plink    = "/gpfs/igmmfs01/software-rl9/apps/plink/1.90b7.2/plink"
bedfile  = "/exports/cmvm/eddie/smgphs/groups/Quantgen/Users/ybhak/Projects/AIM-CISC/Analysis/Second_Mockup/Result/0.Genotype/unrelated_qc_array_genotypes_XY"
keepfile = "pQTL_MR_analysis/data/ids.to.keep"
extract  = "pQTL_MR_analysis/data/pQTLs_non_clumped_uniq.txt"
outdir   = "pQTL_MR_analysis/data/plink"

cmd = paste0("mkdir -p ", outdir)
system(cmd)

system(paste0(
    plink,
    " --bfile ", bedfile,
    " --extract ", extract,
    " --keep ", keepfile,
    " --out ", paste0(outdir, "/ref"),
    " --make-bed ",
    " --threads $(nproc)"),
    intern = F
      )

# %%
## run clumping 
r2 = 0.2
plink    = "/gpfs/igmmfs01/software-rl9/apps/plink/1.90b7.2/plink"
bedfile  = "pQTL_MR_analysis/data/plink/ref" # use thinned down from above
pQTLs_in = "pQTL_MR_analysis/data/per_protein/non_clumped/cis/" # dir
pQTLs_out= paste0("pQTL_MR_analysis/data/per_protein/clumped/cis/", r2, "/") # dir
p1 = 5e-8 # clump-p1
pname = "pval" 

# make output dir
system(paste0("mkdir -p ", pQTLs_out, "logs/"))

# locate each protein input
for (i in 1:length(exp_prots)){
    prot = exp_prots[i]
    clumpfile = paste0(pQTLs_in, prot, "_CIS_nonclumped_for_plink.txt")
    # run plink clumping
    system(paste0(
        plink,
        " --bfile ", bedfile,
        " --clump ", clumpfile,
        " --clump-p1 ", p1,
        " --clump-r2 ", r2,
        " --clump-snp-field SNP ",
        " --clump-field ", pname,
        " --out ", paste0(pQTLs_out, prot),
        " --threads $(nproc)"),
        intern = F
          )
}
cmd = paste0('mv ', pQTLs_out, '*log ', pQTLs_out, 'logs')
system(cmd)

# %%
## make table with all clumped pQTLs
r2 = 0.2
plink    = "/gpfs/igmmfs01/software-rl9/apps/plink/1.90b7.2/plink"
bedfile  = "pQTL_MR_analysis/data/plink/ref" # use thinned down from above
pQTLs_in = "pQTL_MR_analysis/data/per_protein/non_clumped/cis/" # dir
pQTLs_out= paste0("pQTL_MR_analysis/data/per_protein/clumped/cis/", r2, "/") # dir

# progress bar
pb = txtProgressBar(min = 0, max = length(exp_prots), initial = 0) 

for (i in 1:length(exp_prots)){
    prot = exp_prots[i]
    # extract the index clumped SNPs for protein i
    clumped_file = paste0(pQTLs_out, prot, ".clumped")
    clumped_snplist <- fread(clumped_file) %>% pull(SNP)
    # extract from non-clumped table
    exp_i = exp_all_annot_cis %>% filter(Phenotype == prot & SNP %in% clumped_snplist)
    # append all sumstats in one df
    if(prot == exp_prots[1]) {
        exp_clumped_cis = exp_i
    }
    else {
        exp_clumped_cis <- bind_rows(exp_clumped_cis, exp_i)
    }
    # print progress 
    setTxtProgressBar(pb,i)   
}
# Out:
# ========================================================================================================================================================================================================

# %%
exp_clumped_cis %>% nrow
exp_all_annot_cis %>%  nrow
# Out:
# [1] 33747
# [1] 87331

# %%
# save clumped pQTLs table
cfile = paste0("pQTL_MR_analysis/data/per_protein/pQTLs_clumped_cis_thres", r2, '.csv')
fwrite(exp_clumped_cis, file=cfile)

# %% [markdown]
# ### **Stricter MR for APOE & PVR (r2 = 0.001):**

# %% [markdown]
# #### ld-clumping

# %%
# load plink 
system("module load igmm/apps/plink/1.90b7.2", intern = T)
system("/gpfs/igmmfs01/software-rl9/apps/plink/1.90b7.2/plink --clump --help | head", intern = T)
# Out:
# character(0)
#  [1] "PLINK v1.90b7.2 64-bit (11 Dec 2023)           www.cog-genomics.org/plink/1.9/" "(C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3"
#  [3] "--help present, ignoring other flags."                                          ""
#  [5] "--clump <PLINK report filename(s)...>"                                          "  Process association analysis report(s) with 'SNP' and p-value columns,"
#  [7] "  organizing results by LD-based clumps.  Multiple filenames can be separated"  "  by spaces or commas."
#  [9] ""                                                                               "--clump-p1 <pval> : Set --clump index var. p-value ceiling (default 1e-4)."

# %%
## set protein names 
exp_prots = c('APOE', 'PVR')
## run clumping 
r2 = 0.0001
plink    = "/gpfs/igmmfs01/software-rl9/apps/plink/1.90b7.2/plink"
bedfile  = "pQTL_MR_analysis/data/plink/ref" # use thinned down from above
pQTLs_in = "pQTL_MR_analysis/data/per_protein/non_clumped/cis/" # dir
pQTLs_out= paste0("pQTL_MR_analysis/data/per_protein/clumped/cis/", r2, "/") # dir
p1 = 5e-8 # clump-p1
pname = "pval" 

# make output dir
system(paste0("mkdir -p ", pQTLs_out, "logs/"))

# locate each protein input
for (i in 1:length(exp_prots)){
    prot = exp_prots[i]
    clumpfile = paste0(pQTLs_in, prot, "_CIS_nonclumped_for_plink.txt")
    # run plink clumping
    system(paste0(
        plink,
        " --bfile ", bedfile,
        " --clump ", clumpfile,
        " --clump-p1 ", p1,
        " --clump-r2 ", r2,
        " --clump-snp-field SNP ",
        " --clump-field ", pname,
        " --out ", paste0(pQTLs_out, prot),
        " --threads $(nproc)"),
        intern = F
          )
}
cmd = paste0('mv ', pQTLs_out, '*log ', pQTLs_out, 'logs')
system(cmd)

# %%
# non-pruned cis pQTLs
exp_all_annot_cis <- fread("pQTL_MR_analysis/data/pQTLs_non_clumped_cis.txt")

# %%
## make table with all clumped pQTLs
r2 = 0.0001
plink    = "/gpfs/igmmfs01/software-rl9/apps/plink/1.90b7.2/plink"
bedfile  = "pQTL_MR_analysis/data/plink/ref" # use thinned down from above
pQTLs_in = "pQTL_MR_analysis/data/per_protein/non_clumped/cis/" # dir
pQTLs_out= paste0("pQTL_MR_analysis/data/per_protein/clumped/cis/", r2, "/") # dir

# progress bar
pb = txtProgressBar(min = 0, max = length(exp_prots), initial = 0) 

for (i in 1:length(exp_prots)){
    prot = exp_prots[i]
    # extract the index clumped SNPs for protein i
    clumped_file = paste0(pQTLs_out, prot, ".clumped")
    clumped_snplist <- fread(clumped_file) %>% pull(SNP)
    # extract from non-clumped table
    exp_i = exp_all_annot_cis %>% filter(Phenotype == prot & SNP %in% clumped_snplist)
    # append all sumstats in one df
    if(prot == exp_prots[1]) {
        exp_clumped_cis = exp_i
    }
    else {
        exp_clumped_cis <- bind_rows(exp_clumped_cis, exp_i)
    }
    # print progress 
    setTxtProgressBar(pb,i)   
}
# Out:
# ========================================================================================================================================================================================================

# %%
exp_clumped_cis %>% nrow
# Out:
# [1] 11

# %%
# save clumped pQTLs table
 cfile = paste0("pQTL_MR_analysis/data/per_protein/pQTLs_clumped_cis_thres", r2, '.csv')
 fwrite(exp_clumped_cis, file=cfile)

# %% [markdown]
# #### outcome

# %%
### clumped cis instruments
r2=0.0001
cfile = paste0("pQTL_MR_analysis/data/per_protein/pQTLs_clumped_cis_thres", r2, '.csv')
exp_clumped_cis <- fread(cfile) %>% as.data.frame
cat(paste0('# of cis instruments: ', length(unique(exp_clumped_cis$SNP))))
# Out:
# # of cis instruments: 11

# %%
### extract pQTLs associated with >= 5 proteins
pleio_snps <- exp_clumped_cis %>% group_by(SNP) %>% summarise(n=n()) %>% filter(n >=5) %>% pull(SNP)
cat(paste0('# of instruments with >=5 protein associations: ', length(unique(pleio_snps))))
# Out:
# # of instruments with >=5 protein associations: 0

# %%
## columns to extract
default_2smr_cols    <- c("Phenotype", "SNP", "chr", "position", "effect_allele", "other_allele", "beta", "se", "pval", "eaf", "samplesize")
## load outcome
delirium_ukb <- 
    # read delirium sumstats (UKB EXCL. PROTEOMICS SET)
    fread('meta_analysis/ukb_nonprot_eur_fgQC_all_hg38_final.txt') %>% 
            filter(ID %in% exp_clumped_cis$SNP) %>% # extract only snps in exposure df
            ### IMPORTANT UPDATE: FILTER sbpqtl ~ disorder associations with pval > 5e-8
            # filter(pval > 5e-8) %>%
            mutate(Phenotype = "delirium_ukb", # name of outcome phenotype
                   N= '360901') %>% # sample size (from .log files)
            rename("SNP" = "ID",
                   "beta" = "BETA",
                   "se" = "SE",
                   "effect_allele" = "ALLELE1",
                   "other_allele" = "ALLELE0",
                   "chr" = "CHROM",
                   "position" = "GENPOS",
                   "pval" = "P",
                   "eaf" = "A1FREQ", 
                   "samplesize" = "N") %>%
            select(all_of(default_2smr_cols)) %>% 
            ## duplicated SNPs: keep the highest EAF
            arrange(SNP,desc(eaf)) %>% filter(!duplicated(SNP)) %>%
            as.data.frame
dim(delirium_ukb)
head(delirium_ukb,3)
# Out:
# [1] 14 11
#   Phenotype    SNP        chr position effect_allele other_allele beta        se        pval         eaf       samplesize
# 1 delirium_ukb rs10417602 19  45157381 T             C             0.11981800 0.0322432 0.0002023392 0.0759807 360901
# 2 delirium_ukb rs1594895  19  44376201 C             T            -0.01708520 0.0220435 0.4382995250 0.2004730 360901
# 3 delirium_ukb rs1625502  19  44540845 C             G             0.00893038 0.0289286 0.7575459837 0.1048600 360901

# %%
## make outcome df in TwoSampleMR format
delirium_ukb$samplesize <- as.numeric(delirium_ukb$samplesize)
out_2smr <- format_data(delirium_ukb, type = "outcome")
dim(out_2smr)
head(out_2smr, 3)
# Out:
# [1] 14 13
#   SNP        chr.outcome effect_allele.outcome other_allele.outcome beta.outcome se.outcome pval.outcome eaf.outcome samplesize.outcome outcome      mr_keep.outcome pval_origin.outcome id.outcome
# 1 rs10417602 19          T                     C                     0.11981800  0.0322432  0.0002023392 0.0759807   360901             delirium_ukb TRUE            reported            nMDNFM
# 2 rs1594895  19          C                     T                    -0.01708520  0.0220435  0.4382995250 0.2004730   360901             delirium_ukb TRUE            reported            nMDNFM
# 3 rs1625502  19          C                     G                     0.00893038  0.0289286  0.7575459837 0.1048600   360901             delirium_ukb TRUE            reported            nMDNFM

# %% [markdown]
# #### MR

# %%
## make exposure df in TwoSampleMR format
exp_2smr <- format_data(exp_clumped_cis, type = "exposure")
## harmonise exposure i and outcome j data
harmon <-
harmonise_data(
    exposure_dat = exp_2smr,
    outcome_dat = out_2smr)
# Out:
# Harmonising APOE (vM1cSX) and delirium_ukb (nMDNFM)
#
# Harmonising PVR (KCkbHE) and delirium_ukb (nMDNFM)

# %%
harmon_cis_nopleio <-
harmon %>% 
    filter(!(SNP %in% pleio_snps) & SNP %in% exp_clumped_cis$SNP)
harmon_nopleio <- 
harmon %>% 
    filter(!(SNP %in% pleio_snps))

length(unique(harmon$SNP))
length(unique(harmon_nopleio$SNP))
length(unique(harmon_cis_nopleio$SNP))
# Out:
# [1] 14
# [1] 14
# [1] 9

# %%
## perform 2sampleMR:
mr_all_cis <- mr(harmon_cis_nopleio, method_list = c("mr_ivw", "mr_weighted_median", "mr_egger_regression", "mr_two_sample_ml"))
# Out:
# Analysing 'KCkbHE' on 'nMDNFM'
#
# Analysing 'vM1cSX' on 'nMDNFM'

# %%
## pleiotropy test
mr_all_cis_pleio <- mr_pleiotropy_test(harmon_cis_nopleio)
# heterogeneity test
mr_all_cis_het <- mr_heterogeneity(harmon_cis_nopleio, method_list = c("mr_ivw"))

# %%
## make pretty
mr_all_cis2     <- 
    mr_all_cis %>% 
    mutate(method = case_when(method == "Inverse variance weighted" ~ "IVW",
                              method == "Maximum likelihood" ~ "ML",
                              method == "Weighted median" ~ "WM",
                              method == "MR Egger" ~ "MR_Egger",
                              TRUE ~ method)
          ) %>%
    select(-c('id.exposure','id.outcome'))
mr_all_cis_het2 <-
    mr_all_cis_het %>% 
    mutate(method = ifelse(method=="Inverse variance weighted", "IVW", method)) %>%
    select(-c('id.exposure','id.outcome'))

mr_all_cis_pleio2 <-
    mr_all_cis_pleio %>%
    select(-c('id.exposure','id.outcome'))

# %%
mr_all_cis2
mr_all_cis_het2
mr_all_cis_pleio2
# Out:
#   outcome      exposure method   nsnp b           se         pval
# 1 delirium_ukb PVR      IVW      5     0.05718643 0.06009085 3.412663e-01
# 2 delirium_ukb PVR      WM       5     0.01901123 0.04195805 6.504761e-01
# 3 delirium_ukb PVR      MR_Egger 5    -0.12391348 0.14462984 4.545612e-01
# 4 delirium_ukb PVR      ML       5     0.05734284 0.03773139 1.285702e-01
# 5 delirium_ukb APOE     IVW      4    -0.57498307 0.03061874 1.126069e-78
# 6 delirium_ukb APOE     WM       4    -0.57608070 0.03178312 2.009940e-73
# 7 delirium_ukb APOE     MR_Egger 4    -0.56522157 0.05184114 8.307558e-03
# 8 delirium_ukb APOE     ML       4    -0.57536740 0.03123808 9.286909e-76
#   outcome      exposure method Q         Q_df Q_pval
# 1 delirium_ukb PVR      IVW    10.182867 4    0.03745744
# 2 delirium_ukb APOE     IVW     3.119473 3    0.37356909
#   outcome      exposure egger_intercept se         pval
# 1 delirium_ukb PVR       0.070968769    0.05246911 0.2691058
# 2 delirium_ukb APOE     -0.005370591    0.02006374 0.8140261

# %%
# forrest plot
library(patchwork)
mr_apoe <- mr_singlesnp(harmon_cis_nopleio[harmon_cis_nopleio$exposure=="APOE",])
p1 <- mr_forest_plot(mr_apoe)[[1]]
# leave one out (MR excluding each pQLT one by one)
mr_loo_apoe <- mr_leaveoneout(harmon_cis_nopleio[harmon_cis_nopleio$exposure=="APOE",])
p2 <- mr_leaveoneout_plot(mr_loo_apoe)[[1]]
# funnel plot
p3 <- mr_funnel_plot(mr_apoe)
p1
p2
p3
# Out:
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_errorbarh()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_errorbarh()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_point()`).”
# plot without title
# $vM1cSX.nMDNFM
#
# attr(,"split_type")
# [1] "data.frame"
# attr(,"split_labels")
#   id.exposure id.outcome
# 1      vM1cSX     nMDNFM
# plot without title
# plot without title

# %%
mr_scatter_plot(mr_all_cis[mr_all_cis$exposure=="APOE",], harmon_cis_nopleio[harmon_cis_nopleio$exposure=="APOE",])[[1]]
mr_scatter_plot(mr_all_cis[mr_all_cis$exposure=="PVR",], harmon_cis_nopleio[harmon_cis_nopleio$exposure=="PVR",])[[1]]
# Out:
# plot without title
# plot without title

# %% [markdown]
# ### **START HERE: Outcome:**
#
# For discovery   -> UKB <br>
# For replication -> 1. in AoU EUR delirium GWAS 2. in FG-r10

# %%
nc <- fread('pQTL_MR_analysis/data/pQTLs_non_clumped.txt')
nc$Phenotype %>% unique %>% length
# Out:
# [1] 2464

# %%
### clumped cis+trans instruments

r2=0.2
cfile = paste0("pQTL_MR_analysis/data/per_protein/pQTLs_clumped_thres", r2, '.txt')
exp_clumped <- fread(cfile) %>% as.data.frame
cat(paste0('# of cis+trans instruments: ', length(unique(exp_clumped$SNP))))
# Out:
# # of cis+trans instruments: 41446

# %%
### clumped cis instruments

r2=0.2
cfile = paste0("pQTL_MR_analysis/data/per_protein/pQTLs_clumped_cis_thres", r2, '.csv')
exp_clumped_cis <- fread(cfile) %>% as.data.frame
cat(paste0('# of cis instruments: ', length(unique(exp_clumped_cis$SNP))))
# Out:
# # of cis instruments: 29370

# %%
### extract pQTLs associated with >= 5 proteins
pleio_snps <- exp_clumped %>% group_by(SNP) %>% summarise(n=n()) %>% filter(n >=5) %>% pull(SNP)
cat(paste0('# of instruments with >=5 protein associations: ', length(unique(pleio_snps))))
# Out:
# # of instruments with >=5 protein associations: 1969

# %% [markdown]
# #### Discovery (UKB)

# %%
## columns to extract
default_2smr_cols    <- c("Phenotype", "SNP", "chr", "position", "effect_allele", "other_allele", "beta", "se", "pval", "eaf", "samplesize")
## load outcome
delirium_ukb <- 
    # read delirium sumstats (UKB EXCL. PROTEOMICS SET)
    fread('meta_analysis/ukb_nonprot_eur_fgQC_all_hg38_final.txt') %>% 
            filter(ID %in% exp_clumped$SNP) %>% # extract only snps in exposure df
            ### IMPORTANT UPDATE: FILTER sbpqtl ~ disorder associations with pval > 5e-8
            # filter(pval > 5e-8) %>%
            mutate(Phenotype = "delirium_ukb", # name of outcome phenotype
                   N= '360901') %>% # sample size (from .log files)
            rename("SNP" = "ID",
                   "beta" = "BETA",
                   "se" = "SE",
                   "effect_allele" = "ALLELE1",
                   "other_allele" = "ALLELE0",
                   "chr" = "CHROM",
                   "position" = "GENPOS",
                   "pval" = "P",
                   "eaf" = "A1FREQ", 
                   "samplesize" = "N") %>%
            select(all_of(default_2smr_cols)) %>% 
            ## duplicated SNPs: keep the highest EAF
            arrange(SNP,desc(eaf)) %>% filter(!duplicated(SNP)) %>%
            as.data.frame
dim(delirium_ukb)
head(delirium_ukb,3)
# Out:
# [1] 40693    11
#   Phenotype    SNP           chr position  effect_allele other_allele beta        se        pval      eaf      samplesize
# 1 delirium_ukb Affx-52334201 19     831815 G             GT           -0.03930490 0.0841427 0.6404128 0.011136 360901
# 2 delirium_ukb Affx-52334718 20    3231072 A             AT            0.02079960 0.0177456 0.2411587 0.463883 360901
# 3 delirium_ukb rs1000110      9  115146442 T             C            -0.00464618 0.0194082 0.8108009 0.294212 360901

# %%
## make outcome df in TwoSampleMR format
delirium_ukb$samplesize <- as.numeric(delirium_ukb$samplesize)
out_2smr <- format_data(delirium_ukb, type = "outcome")
dim(out_2smr)
head(out_2smr, 3)
# Out:
# [1] 40693    13
#   SNP           chr.outcome effect_allele.outcome other_allele.outcome beta.outcome se.outcome pval.outcome eaf.outcome samplesize.outcome outcome      mr_keep.outcome pval_origin.outcome id.outcome
# 1 affx-52334201 19          G                     GT                   -0.03930490  0.0841427  0.6404128    0.011136    360901             delirium_ukb TRUE            reported            iTeu6x
# 2 affx-52334718 20          A                     AT                    0.02079960  0.0177456  0.2411587    0.463883    360901             delirium_ukb TRUE            reported            iTeu6x
# 3 rs1000110      9          T                     C                    -0.00464618  0.0194082  0.8108009    0.294212    360901             delirium_ukb TRUE            reported            iTeu6x

# %% [markdown]
# ### **MR:**

# %% [markdown]
# *harmonise (all pQTLs):*

# %%
## make exposure df in TwoSampleMR format
exp_2smr <- format_data(exp_clumped, type = "exposure")
## harmonise exposure i and outcome j data
harmon <-
harmonise_data(
    exposure_dat = exp_2smr,
    outcome_dat = out_2smr)
# Out:
# Harmonising AZU1 (eeoZIx) and delirium_ukb (lQ5Klx)
#
# Harmonising ATRN (VG0AzR) and delirium_ukb (lQ5Klx)
#
# Harmonising ITPA (pugwxD) and delirium_ukb (lQ5Klx)
#
# Harmonising MATN2 (fmabJS) and delirium_ukb (lQ5Klx)
#
# Harmonising TNC (oIbtsh) and delirium_ukb (lQ5Klx)
#
# Harmonising VSTM2L (wilxvr) and delirium_ukb (lQ5Klx)
#
# Harmonising LRPAP1 (nPzFZV) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2071465, rs2395004
#
# Harmonising HGF (iEwcLJ) and delirium_ukb (lQ5Klx)
#
# Harmonising LRP1 (4j8mCz) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1632854, rs2071465, rs2395004
#
# Harmonising BST1 (wDGi8x) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs4802188
#
# Harmonising FGFBP2 (IRh7JV) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs3857149
#
# Harmonising CD38 (cHB1FM) and delirium_ukb (lQ5Klx)
#
# Harmonising AREG (OgsJFL) and delirium_ukb (lQ5Klx)
#
# Harmonising IDI2 (VqFIhA) and delirium_ukb (lQ5Klx)
#
# Harmonising PYDC1 (ZxyjD8) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10030941
#
# Harmonising GC (slN243) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10030941
#
# Harmonising NAAA (hpT8mN) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1935, rs6571912
#
# Harmonising C1QL2 (9UJL0T) and delirium_ukb (lQ5Klx)
#
# Harmonising QDPR (jMsv2B) and delirium_ukb (lQ5Klx)
#
# Harmonising TLR1 (oWnJCx) and delirium_ukb (lQ5Klx)
#
# Harmonising PDE5A (hctZo7) and delirium_ukb (lQ5Klx)
#
# Harmonising SCARA5 (sU0ric) and delirium_ukb (lQ5Klx)
#
# Harmonising FGF2 (pERLfJ) and delirium_ukb (lQ5Klx)
#
# Harmonising CLGN (R6BOqj) and delirium_ukb (lQ5Klx)
#
# Harmonising SPARCL1 (TfLOPg) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10793964
#
# Harmonising CELA2A (B4GBZR) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2842895
#
# Harmonising AHSP (jsiGDR) and delirium_ukb (lQ5Klx)
#
# Harmonising NAP1L4 (cixGQc) and delirium_ukb (lQ5Klx)
#
# Harmonising CRNN (EeiXzR) and delirium_ukb (lQ5Klx)
#
# Harmonising FABP9 (q9kl76) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs12083211, rs2977299
#
# Harmonising TACC3 (5s6fOQ) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs6831006
#
# Harmonising ACP6 (jeuvS4) and delirium_ukb (lQ5Klx)
#
# Harmonising DKK4 (pDLzfN) and delirium_ukb (lQ5Klx)
#
# Harmonising GNPDA2 (4glLc1) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2130643
#
# Harmonising CCL4 (FutuCJ) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs57815892
#
# Harmonising SPINK8 (m7Hwai) and delirium_ukb (lQ5Klx)
#
# Harmonising COL2A1 (KDqFnd) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs154507, rs1565933
#
# Harmonising CCL5 (k2kbyQ) and delirium_ukb (lQ5Klx)
#
# Harmonising NID1 (Xy0qhF) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs342293
#
# Harmonising TMEM106A (ujUqQl) and delirium_ukb (lQ5Klx)
#
# Harmonising CCER2 (IqaOqn) and delirium_ukb (lQ5Klx)
#
# Harmonising ENPP6 (ReguTv) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2524082
#
# Harmonising EFCAB2 (oJSc7h) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs61844237
#
# Harmonising BTC (sj6asQ) and delirium_ukb (lQ5Klx)
#
# Harmonising CXCL1 (xM5Be6) and delirium_ukb (lQ5Klx)
#
# Harmonising C7 (wNM2CB) and delirium_ukb (lQ5Klx)
#
# Harmonising SERPINI2 (KwcmSt) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs9491696
#
# Harmonising SEMA3G (uBlaJR) and delirium_ukb (lQ5Klx)
#
# Harmonising CLPS (BfbL8t) and delirium_ukb (lQ5Klx)
#
# Harmonising IGFBP7 (oWVgGx) and delirium_ukb (lQ5Klx)
#
# Harmonising SPINK2 (plAATr) and delirium_ukb (lQ5Klx)
#
# Harmonising HGFAC (YCIltx) and delirium_ukb (lQ5Klx)
#
# Harmonising SEPTIN8 (2mRutA) and delirium_ukb (lQ5Klx)
#
# Harmonising ITGB1BP2 (5TUWs4) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs342293
#
# Harmonising TNFRSF10A (FKhOUu) and delirium_ukb (lQ5Klx)
#
# Harmonising CXCL5 (w1gIVi) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs4073
#
# Harmonising OLFM4 (Vh5pbm) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs7982351
#
# Harmonising SORCS2 (W3RgwW) and delirium_ukb (lQ5Klx)
#
# Harmonising AGRN (WtpR1e) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2444239
#
# Harmonising SGSH (Y5DSu5) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs11150849, rs1632854, rs3131785
#
# Harmonising PSAPL1 (jnHSOk) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10099059, rs4234824
#
# Harmonising KDR (IXmpts) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10793964
#
# Harmonising TCN1 (J3IJ2H) and delirium_ukb (lQ5Klx)
#
# Harmonising ODAM (S9L2Po) and delirium_ukb (lQ5Klx)
#
# Harmonising FAM20A (HAd1Ma) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1935
#
# Harmonising TFF2 (nHrLCY) and delirium_ukb (lQ5Klx)
#
# Harmonising HPSE (zTVtU0) and delirium_ukb (lQ5Klx)
#
# Harmonising HLA-A (pCBdIR) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs150359, rs2395153, rs2844503, rs3131785, rs986522
#
# Harmonising F11 (oVhuQH) and delirium_ukb (lQ5Klx)
#
# Harmonising KLKB1 (4RCRf6) and delirium_ukb (lQ5Klx)
#
# Harmonising VNN1 (FV6S8p) and delirium_ukb (lQ5Klx)
#
# Harmonising CYTL1 (8W70yX) and delirium_ukb (lQ5Klx)
#
# Harmonising DPEP1 (fPSSqY) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs16966671
#
# Harmonising CDSN (HRhfom) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs150359, rs1632854, rs2073717, rs2395153, rs3094132, rs3131785
#
# Harmonising CAPG (o75PvE) and delirium_ukb (lQ5Klx)
#
# Harmonising TNXB (HjuXwu) and delirium_ukb (lQ5Klx)
#
# Harmonising MSR1 (Q2j7OQ) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1383264
#
# Harmonising TIMD4 (rbacCT) and delirium_ukb (lQ5Klx)
#
# Harmonising TMPRSS11D (od3eOZ) and delirium_ukb (lQ5Klx)
#
# Harmonising NCR1 (QMfDNK) and delirium_ukb (lQ5Klx)
#
# Harmonising IDUA (Gkd4ji) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs6571912
#
# Harmonising FGFR4 (0XUd0t) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs13177957, rs2524082
#
# Harmonising CPVL (3CEf2E) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1029239, rs130066, rs245894, rs2844503, rs9268560
#
# Harmonising CFP (AmuJyO) and delirium_ukb (lQ5Klx)
#
# Harmonising CFI (vlzZRn) and delirium_ukb (lQ5Klx)
#
# Harmonising CFB (iehtGS) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2395004
#
# Harmonising PAMR1 (IEi9jm) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1383264, rs3021304
#
# Harmonising KIR2DL2 (DkPv5G) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1383264, rs2524082, rs9268560
#
# Harmonising GZMA (W1EXVI) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1383264, rs2844503
#
# Harmonising MICB_MICA (XV30CT) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1003582
#
# Harmonising KLRF1 (qC3E44) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2736155
#
# Harmonising HLA-DRA (XOe5Pl) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2844503, rs6457620
#
# Harmonising GP1BB (jLIj06) and delirium_ukb (lQ5Klx)
#
# Harmonising KIR2DL3 (0wJVok) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1383264, rs2844503
#
# Harmonising TNFRSF8 (ZuR8NS) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1003582, rs2517529, rs3095307
#
# Harmonising IL12B (SPkXro) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1003582
#
# Harmonising LILRB1 (fDRYPm) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1003582, rs1383264, rs2294477, rs9268560
#
# Harmonising TNFRSF9 (cGtfBq) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1003582
#
# Harmonising IL12A_IL12B (YdQKsz) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1003582
#
# Harmonising B2M (IswXha) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1003582, rs9268560
#
# Harmonising HLA-E (rqkj1o) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1003582, rs1029239, rs2294477
#
# Harmonising PDIA5 (TLtqQi) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1003582, rs1383264, rs3021304, rs805293, rs994379
#
# Harmonising SFTPD (djtx8V) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1003582, rs130066, rs3095307
#
# Harmonising SPINK5 (qa3xt9) and delirium_ukb (lQ5Klx)
#
# Harmonising GSTT2B (xbcv42) and delirium_ukb (lQ5Klx)
#
# Harmonising MIF (kPKZLp) and delirium_ukb (lQ5Klx)
#
# Harmonising DDT (9TvFVM) and delirium_ukb (lQ5Klx)
#
# Harmonising ITGA2 (EXP98L) and delirium_ukb (lQ5Klx)
#
# Harmonising CAPS (nBtrjo) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs150359, rs2517529, rs2844503
#
# Harmonising TIE1 (YzkNXh) and delirium_ukb (lQ5Klx)
#
# Harmonising CD74 (EZQUzP) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2524082, rs2736155
#
# Harmonising S100P (eST8Us) and delirium_ukb (lQ5Klx)
#
# Harmonising TYRP1 (wtLNbu) and delirium_ukb (lQ5Klx)
#
# Harmonising CD7 (G9mUtm) and delirium_ukb (lQ5Klx)
#
# Harmonising MLN (VNHYQa) and delirium_ukb (lQ5Klx)
#
# Harmonising PDGFRB (Sh7DDu) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10040588
#
# Harmonising EREG (DZ053G) and delirium_ukb (lQ5Klx)
#
# Harmonising RGMB (N7L8Ry) and delirium_ukb (lQ5Klx)
#
# Harmonising TXNDC15 (dFDtu4) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1383264
#
# Harmonising CEACAM16 (zKhIRe) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2965156
#
# Harmonising PAM (S9tAkL) and delirium_ukb (lQ5Klx)
#
# Harmonising YAP1 (CjeYOv) and delirium_ukb (lQ5Klx)
#
# Harmonising SCGN (hGP47n) and delirium_ukb (lQ5Klx)
#
# Harmonising VASH1 (LyaMKO) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1935
#
# Harmonising CRISP2 (IrOUEj) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs283566
#
# Harmonising HSD11B1 (OzHjAN) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs380390
#
# Harmonising NPHS1 (ygeFEk) and delirium_ukb (lQ5Klx)
#
# Harmonising MTHFSD (q3IhO8) and delirium_ukb (lQ5Klx)
#
# Harmonising CD226 (akYwev) and delirium_ukb (lQ5Klx)
#
# Harmonising PDCD1LG2 (LxOpPP) and delirium_ukb (lQ5Klx)
#
# Harmonising TYRO3 (V5MY4w) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10152546, rs10793964
#
# Harmonising IL1R1 (obEppR) and delirium_ukb (lQ5Klx)
#
# Harmonising ICAM2 (MpEJyZ) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10793964
#
# Harmonising CD200R1 (sqW36h) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs3930154
#
# Harmonising NCR3LG1 (ByoxRA) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10793964
#
# Harmonising SIGLEC9 (xLu1XK) and delirium_ukb (lQ5Klx)
#
# Harmonising LRRC25 (smQWfb) and delirium_ukb (lQ5Klx)
#
# Harmonising FLT4 (7xlRF9) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10793964
#
# Harmonising CRH (9o2Yiw) and delirium_ukb (lQ5Klx)
#
# Harmonising CEACAM8 (BZCE5K) and delirium_ukb (lQ5Klx)
#
# Harmonising CSTB (dhx8zV) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2838362
#
# Harmonising KIRREL2 (DeiZJV) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2842895
#
# Harmonising PRSS27 (Bf5Be6) and delirium_ukb (lQ5Klx)
#
# Harmonising PCDH12 (Pckala) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10793964
#
# Harmonising S100A3 (LSPFim) and delirium_ukb (lQ5Klx)
#
# Harmonising LACRT (Qg5usp) and delirium_ukb (lQ5Klx)
#
# Harmonising CDH6 (ljOwWx) and delirium_ukb (lQ5Klx)
#
# Harmonising PSG1 (xxh8WH) and delirium_ukb (lQ5Klx)
#
# Harmonising ANGPT2 (IMDJoS) and delirium_ukb (lQ5Klx)
#
# Harmonising ARSB (CcoxyA) and delirium_ukb (lQ5Klx)
#
# Harmonising SH2B3 (JXhwIn) and delirium_ukb (lQ5Klx)
#
# Harmonising PGLYRP2 (gPmco4) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2886789
#
# Harmonising GALNT10 (zWoFZj) and delirium_ukb (lQ5Klx)
#
# Harmonising VCAN (avlXBi) and delirium_ukb (lQ5Klx)
#
# Harmonising ADA2 (Oyo7P5) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1029239, rs2844503
#
# Harmonising TNFSF8 (m273jg) and delirium_ukb (lQ5Klx)
#
# Harmonising EGFLAM (N0jvFw) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2561142
#
# Harmonising GHR (3DX42W) and delirium_ukb (lQ5Klx)
#
# Harmonising FAM172A (jfu5Dl) and delirium_ukb (lQ5Klx)
#
# Harmonising SRPX (3ywNKD) and delirium_ukb (lQ5Klx)
#
# Harmonising OMG (9VEX7Y) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10067364
#
# Harmonising RGMA (rkuDN1) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10067364
#
# Harmonising MEGF10 (OIPRHx) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10067364, rs961764
#
# Harmonising IL31RA (Q8a24U) and delirium_ukb (lQ5Klx)
#
# Harmonising EDA2R (WzOhgl) and delirium_ukb (lQ5Klx)
#
# Harmonising MAPK9 (Sn77bT) and delirium_ukb (lQ5Klx)
#
# Harmonising L1CAM (Nweq0Q) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10793964
#
# Harmonising C1QTNF1 (EK8Rv1) and delirium_ukb (lQ5Klx)
#
# Harmonising LGALS3BP (Rb3euR) and delirium_ukb (lQ5Klx)
#
# Harmonising COL4A1 (JqgHMW) and delirium_ukb (lQ5Klx)
#
# Harmonising TSHB (JoJEml) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2439302
#
# Harmonising TG (mAZDTG) and delirium_ukb (lQ5Klx)
#
# Harmonising OSMR (jCaFyz) and delirium_ukb (lQ5Klx)
#
# Harmonising TFPI2 (pBbqC8) and delirium_ukb (lQ5Klx)
#
# Harmonising FCRL6 (4W1vb3) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1383264
#
# Harmonising PPY (XPUKCN) and delirium_ukb (lQ5Klx)
#
# Harmonising APOL1 (D87qEI) and delirium_ukb (lQ5Klx)
#
# Harmonising SERPINA5 (6FNl4o) and delirium_ukb (lQ5Klx)
#
# Harmonising GM2A (0znmXG) and delirium_ukb (lQ5Klx)
#
# Harmonising B4GALT1 (SfeSaz) and delirium_ukb (lQ5Klx)
#
# Harmonising CILP (m4xhiw) and delirium_ukb (lQ5Klx)
#
# Harmonising COL15A1 (QCm7Rb) and delirium_ukb (lQ5Klx)
#
# Harmonising IL7R (ZLzzRn) and delirium_ukb (lQ5Klx)
#
# Harmonising CSF1R (ZwJorf) and delirium_ukb (lQ5Klx)
#
# Harmonising NUMB (TTl9ql) and delirium_ukb (lQ5Klx)
#
# Harmonising LPA (FEDbDn) and delirium_ukb (lQ5Klx)
#
# Harmonising COL28A1 (hE4v8V) and delirium_ukb (lQ5Klx)
#
# Harmonising ADAMTS15 (NDjan9) and delirium_ukb (lQ5Klx)
#
# Harmonising DSC2 (KvFKxr) and delirium_ukb (lQ5Klx)
#
# Harmonising LYPD3 (KBnl7V) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs4802188
#
# Harmonising CPA2 (MEi0zY) and delirium_ukb (lQ5Klx)
#
# Harmonising RAB6A (iQUf8y) and delirium_ukb (lQ5Klx)
#
# Harmonising SPINT2 (6kvuHW) and delirium_ukb (lQ5Klx)
#
# Harmonising BCL2L11 (QoLX98) and delirium_ukb (lQ5Klx)
#
# Harmonising NPY (40ubsw) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2001945
#
# Harmonising VEGFD (wMhamT) and delirium_ukb (lQ5Klx)
#
# Harmonising TLR3 (72rWA0) and delirium_ukb (lQ5Klx)
#
# Harmonising FGF19 (l4SnOF) and delirium_ukb (lQ5Klx)
#
# Harmonising SCGB3A1 (ohzy9O) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs11765552
#
# Harmonising SCGB1A1 (lrihTG) and delirium_ukb (lQ5Klx)
#
# Harmonising CCL25 (C9IkJD) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10793964
#
# Harmonising QPCT (ijXNKf) and delirium_ukb (lQ5Klx)
#
# Harmonising SFRP1 (oqNJcQ) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs11136269
#
# Harmonising GYS1 (bWORXx) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2244931
#
# Harmonising CTSB (P1aNWa) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2244931
#
# Harmonising KITLG (qpjyaK) and delirium_ukb (lQ5Klx)
#
# Harmonising NCAM2 (QKhTOb) and delirium_ukb (lQ5Klx)
#
# Harmonising BTN3A2 (7TBebS) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1029239, rs150359, rs2395004, rs2734959, rs3021304, rs9268560
#
# Harmonising DKKL1 (rkUDgS) and delirium_ukb (lQ5Klx)
#
# Harmonising NAPRT (kCJE0B) and delirium_ukb (lQ5Klx)
#
# Harmonising NPTX2 (WnAd2k) and delirium_ukb (lQ5Klx)
#
# Harmonising GGH (HWRt5Z) and delirium_ukb (lQ5Klx)
#
# Harmonising TNFRSF13C (0gWqoa) and delirium_ukb (lQ5Klx)
#
# Harmonising DEFB104A_DEFB104B (bUcRPl) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10096194
#
# Harmonising PRND (u0QHxk) and delirium_ukb (lQ5Klx)
#
# Harmonising CCL27 (fz8nhy) and delirium_ukb (lQ5Klx)
#
# Harmonising PXDNL (Z9bYTt) and delirium_ukb (lQ5Klx)
#
# Harmonising ENPP2 (YKZ0FB) and delirium_ukb (lQ5Klx)
#
# Harmonising CD274 (gwVKgR) and delirium_ukb (lQ5Klx)
#
# Harmonising PAG1 (iBEgu5) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs7208422
#
# Harmonising EPHB6 (tHZLUa) and delirium_ukb (lQ5Klx)
#
# Harmonising MASP1 (EPjwfC) and delirium_ukb (lQ5Klx)
#
# Harmonising DPP10 (bYhB9B) and delirium_ukb (lQ5Klx)
#
# Harmonising FGL1 (DETvCH) and delirium_ukb (lQ5Klx)
#
# Harmonising FABP2 (NlXXxU) and delirium_ukb (lQ5Klx)
#
# Harmonising EPPK1 (4SkRQG) and delirium_ukb (lQ5Klx)
#
# Harmonising SPAG1 (dQDogp) and delirium_ukb (lQ5Klx)
#
# Harmonising IMPA1 (4r82OG) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs342293
#
# Harmonising CCN4 (Eukt5A) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs753723
#
# Harmonising IDO1 (9864Ov) and delirium_ukb (lQ5Klx)
#
# Harmonising VEGFA (9NShDR) and delirium_ukb (lQ5Klx)
#
# Harmonising WIF1 (2Fbiwc) and delirium_ukb (lQ5Klx)
#
# Harmonising GPC1 (r2Ue08) and delirium_ukb (lQ5Klx)
#
# Harmonising CRIM1 (C8x0Qw) and delirium_ukb (lQ5Klx)
#
# Harmonising ADAM9 (FK2dgz) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2524082
#
# Harmonising GFRA2 (w9rWi2) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs6586997
#
# Harmonising ESM1 (yknnIJ) and delirium_ukb (lQ5Klx)
#
# Harmonising ENTPD6 (9yLTyo) and delirium_ukb (lQ5Klx)
#
# Harmonising LTBP2 (F73xFD) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2284746
#
# Harmonising NCAM1 (xgl32U) and delirium_ukb (lQ5Klx)
#
# Harmonising FBLN2 (KZGVeI) and delirium_ukb (lQ5Klx)
#
# Harmonising IL15 (WUhGTp) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2736155, rs6934041
#
# Harmonising CD101 (StSDOl) and delirium_ukb (lQ5Klx)
#
# Harmonising CPQ (w3xfiD) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs6571912
#
# Harmonising CRTAC1 (M4VJjL) and delirium_ukb (lQ5Klx)
#
# Harmonising TNFRSF10C (csp8m9) and delirium_ukb (lQ5Klx)
#
# Harmonising ICAM3 (R6TzNv) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1383264, rs2395004, rs2734959, rs2844503, rs2894720, rs3095307
#
# Harmonising DEFA1_DEFA1B (3RPV8O) and delirium_ukb (lQ5Klx)
#
# Harmonising OGN (bQpRI5) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs912260
#
# Harmonising BMP10 (vUS91x) and delirium_ukb (lQ5Klx)
#
# Harmonising GDF2 (EnOb4p) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1935
#
# Harmonising HMCN2 (pJY1jB) and delirium_ukb (lQ5Klx)
#
# Harmonising PALM2 (HhWGC1) and delirium_ukb (lQ5Klx)
#
# Harmonising FCN1 (3NJYIU) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1042464, rs11103612
#
# Harmonising AMIGO2 (S81nQN) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10785887
#
# Harmonising C1QTNF9 (mgBZ2K) and delirium_ukb (lQ5Klx)
#
# Harmonising PIK3IP1 (o2Mlzr) and delirium_ukb (lQ5Klx)
#
# Harmonising CLEC4C (v5TEYW) and delirium_ukb (lQ5Klx)
#
# Harmonising PENK (SjEjjo) and delirium_ukb (lQ5Klx)
#
# Harmonising CTSV (N2CElN) and delirium_ukb (lQ5Klx)
#
# Harmonising IGF2R (wK0tZS) and delirium_ukb (lQ5Klx)
#
# Harmonising CD5 (p2Q1Jh) and delirium_ukb (lQ5Klx)
#
# Harmonising MSLN (c68KkV) and delirium_ukb (lQ5Klx)
#
# Harmonising CSDE1 (JmeTjP) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs3021304
#
# Harmonising SPINK4 (HAZDAt) and delirium_ukb (lQ5Klx)
#
# Harmonising CBLIF (wuOtBw) and delirium_ukb (lQ5Klx)
#
# Harmonising LRIG1 (23U6ch) and delirium_ukb (lQ5Klx)
#
# Harmonising XCL1 (Ffzqnd) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2395004, rs4795406
#
# Harmonising HS3ST3B1 (pSKWkR) and delirium_ukb (lQ5Klx)
#
# Harmonising MAN1A2 (mfEn6Q) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs6457620
#
# Harmonising NRP1 (Vb7x89) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs944824
#
# Harmonising IL1RL2 (ZtJF73) and delirium_ukb (lQ5Klx)
#
# Harmonising LAMA4 (C5Oi3Z) and delirium_ukb (lQ5Klx)
#
# Harmonising GRK5 (EUfG2w) and delirium_ukb (lQ5Klx)
#
# Harmonising CCL17 (eG8BnK) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs671623
#
# Harmonising CRACR2A (kFC9ES) and delirium_ukb (lQ5Klx)
#
# Harmonising TF (GCFF9t) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs6935832, rs994379
#
# Harmonising EDDM3B (zABfVW) and delirium_ukb (lQ5Klx)
#
# Harmonising RNASE6 (ZjIazC) and delirium_ukb (lQ5Klx)
#
# Harmonising TCL1A (cuCxfq) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs11585450
#
# Harmonising RNASE1 (DyfvhC) and delirium_ukb (lQ5Klx)
#
# Harmonising AMN (ERFnxn) and delirium_ukb (lQ5Klx)
#
# Harmonising ARHGAP5 (g61yLo) and delirium_ukb (lQ5Klx)
#
# Harmonising ANG (JHcWxW) and delirium_ukb (lQ5Klx)
#
# Harmonising ADAM23 (C8V7Uh) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10793964
#
# Harmonising PLA2G15 (Q0Gqr2) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1383264
#
# Harmonising RNASET2 (KxGkvZ) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1029239, rs130066, rs9268560
#
# Harmonising ATXN3 (DPRad3) and delirium_ukb (lQ5Klx)
#
# Harmonising SERPINA12 (yo9ZUR) and delirium_ukb (lQ5Klx)
#
# Harmonising SERPINA11 (3PcRac) and delirium_ukb (lQ5Klx)
#
# Harmonising SERPINA3 (nSowWY) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2001945
#
# Harmonising RNASE4 (yI9rcB) and delirium_ukb (lQ5Klx)
#
# Harmonising LEG1 (UlAveM) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs3860300
#
# Harmonising FLRT2 (nQsOoo) and delirium_ukb (lQ5Klx)
#
# Harmonising DLK1 (9K3wjy) and delirium_ukb (lQ5Klx)
#
# Harmonising GUCA2A (NNLs81) and delirium_ukb (lQ5Klx)
#
# Harmonising TNFRSF13B (fNZifE) and delirium_ukb (lQ5Klx)
#
# Harmonising TNFRSF17 (p9YWpc) and delirium_ukb (lQ5Klx)
#
# Harmonising FCRL5 (kYyaW3) and delirium_ukb (lQ5Klx)
#
# Harmonising LTA (WuUA1s) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs3021304
#
# Harmonising IL1R2 (XoXTbO) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2001945
#
# Harmonising SERPINA4 (lJPkd9) and delirium_ukb (lQ5Klx)
#
# Harmonising AHNAK2 (WEqGuR) and delirium_ukb (lQ5Klx)
#
# Harmonising LGALS3 (lyw0cn) and delirium_ukb (lQ5Klx)
#
# Harmonising ACYP1 (wfPOum) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1935
#
# Harmonising TMPRSS5 (J9doUi) and delirium_ukb (lQ5Klx)
#
# Harmonising NID2 (rVMb7V) and delirium_ukb (lQ5Klx)
#
# Harmonising GZMB (kXb4np) and delirium_ukb (lQ5Klx)
#
# Harmonising CCDC50 (vGgQxC) and delirium_ukb (lQ5Klx)
#
# Harmonising RGS8 (LePP9P) and delirium_ukb (lQ5Klx)
#
# Harmonising CD5L (UAOZIy) and delirium_ukb (lQ5Klx)
#
# Harmonising CA13 (YfYptn) and delirium_ukb (lQ5Klx)
#
# Harmonising IL4R (aJEvdq) and delirium_ukb (lQ5Klx)
#
# Harmonising ITM2A (51FcvO) and delirium_ukb (lQ5Klx)
#
# Harmonising B3GNT7 (qQOVAn) and delirium_ukb (lQ5Klx)
#
# Harmonising DHRS4L2 (0sXmj5) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1935
#
# Harmonising MFGE8 (w8rEBG) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2001945
#
# Harmonising NRP2 (kaUebL) and delirium_ukb (lQ5Klx)
#
# Harmonising LILRB4 (0jBSiP) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs809871
#
# Harmonising CRTAP (OCwcP6) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs3021304
#
# Harmonising CD1C (cu3A6P) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1383264, rs2517529, rs9268560, rs994379
#
# Harmonising CD207 (N6gdUD) and delirium_ukb (lQ5Klx)
#
# Harmonising CD22 (QYF2qM) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2395004, rs2844503, rs9268560
#
# Harmonising CCL19 (JXmAC4) and delirium_ukb (lQ5Klx)
#
# Harmonising WARS (kYhWPz) and delirium_ukb (lQ5Klx)
#
# Harmonising PRTG (1uBUpZ) and delirium_ukb (lQ5Klx)
#
# Harmonising FUCA1 (yYi5zr) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs4319261
#
# Harmonising IL18R1 (D81gYC) and delirium_ukb (lQ5Klx)
#
# Harmonising IL1RL1 (ZGgQbp) and delirium_ukb (lQ5Klx)
#
# Harmonising GASK1A (rh31Ta) and delirium_ukb (lQ5Klx)
#
# Harmonising LTB (HGBSha) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2844503, rs9268560
#
# Harmonising FCGR2B (IfWDv5) and delirium_ukb (lQ5Klx)
#
# Harmonising C4BPB (S8Hp9m) and delirium_ukb (lQ5Klx)
#
# Harmonising CDA (mCCzzg) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1042464
#
# Harmonising CTBS (Nyxx1u) and delirium_ukb (lQ5Klx)
#
# Harmonising ANGPTL1 (CpRY6t) and delirium_ukb (lQ5Klx)
#
# Harmonising KIF22 (5tFkpL) and delirium_ukb (lQ5Klx)
#
# Harmonising FCN2 (MMI0OU) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs11103612
#
# Harmonising SEPTIN3 (L3G7Pp) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2844503
#
# Harmonising MANSC4 (FCJlfv) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1383264, rs2844503, rs9268560
#
# Harmonising C1RL (bhy7Hj) and delirium_ukb (lQ5Klx)
#
# Harmonising MFAP5 (MUXra9) and delirium_ukb (lQ5Klx)
#
# Harmonising TNFRSF19 (VtUimu) and delirium_ukb (lQ5Klx)
#
# Harmonising TNFRSF11A (VL2FYg) and delirium_ukb (lQ5Klx)
#
# Harmonising CRYGD (axDRH4) and delirium_ukb (lQ5Klx)
#
# Harmonising MATN3 (2Pjdij) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs12479048
#
# Harmonising PNLIP (2cv1ZX) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs8057031, rs9491696
#
# Harmonising CPA1 (ML1Jkw) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2842895, rs8057031, rs9491696
#
# Harmonising GALNT5 (zKUMCJ) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs7606173
#
# Harmonising TP53I3 (QwrYIf) and delirium_ukb (lQ5Klx)
#
# Harmonising TFF1 (tfSvAE) and delirium_ukb (lQ5Klx)
#
# Harmonising HPCAL1 (TghXsB) and delirium_ukb (lQ5Klx)
#
# Harmonising ENPP7 (wZJ1cu) and delirium_ukb (lQ5Klx)
#
# Harmonising ACP1 (0PWsEn) and delirium_ukb (lQ5Klx)
#
# Harmonising FUT3_FUT5 (SfM8KV) and delirium_ukb (lQ5Klx)
#
# Harmonising LY75 (JmC2ea) and delirium_ukb (lQ5Klx)
#
# Harmonising REG1B (a9edk7) and delirium_ukb (lQ5Klx)
#
# Harmonising EDAR (LFM6m1) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs342293
#
# Harmonising FN1 (SpcXdV) and delirium_ukb (lQ5Klx)
#
# Harmonising FRZB (XbBbn1) and delirium_ukb (lQ5Klx)
#
# Harmonising EFHD1 (YBFSfz) and delirium_ukb (lQ5Klx)
#
# Harmonising NMI (DIPydC) and delirium_ukb (lQ5Klx)
#
# Harmonising CD160 (eENWwy) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs3095307
#
# Harmonising STAB2 (tyPNUq) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10793964
#
# Harmonising POSTN (UzEkBv) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs196197
#
# Harmonising DKK3 (JTOEss) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs196197
#
# Harmonising IL1RN (WgmVa6) and delirium_ukb (lQ5Klx)
#
# Harmonising MERTK (NCMgzF) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs449882
#
# Harmonising NELL1 (Tsksg3) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2157342
#
# Harmonising TGOLN2 (ofbUMN) and delirium_ukb (lQ5Klx)
#
# Harmonising SERPINE2 (5AlWm7) and delirium_ukb (lQ5Klx)
#
# Harmonising GAL (dVIFif) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1884371
#
# Harmonising PRKAR1A (TIcWqd) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs342293
#
# Harmonising COCH (mPkPYr) and delirium_ukb (lQ5Klx)
#
# Harmonising SIGLEC1 (bvCiw7) and delirium_ukb (lQ5Klx)
#
# Harmonising GPRC5C (7kKnY0) and delirium_ukb (lQ5Klx)
#
# Harmonising STX3 (kMTT5d) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs3021304
#
# Harmonising GALNT3 (JkxuuX) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10793964
#
# Harmonising FCRL2 (Kky1fV) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2524082, rs942632
#
# Harmonising GNLY (Rissqb) and delirium_ukb (lQ5Klx)
#
# Harmonising PLB1 (GPynII) and delirium_ukb (lQ5Klx)
#
# Harmonising SIGLEC8 (6jbc2e) and delirium_ukb (lQ5Klx)
#
# Harmonising MARCO (UoKugw) and delirium_ukb (lQ5Klx)
#
# Harmonising CD163 (A9Qd72) and delirium_ukb (lQ5Klx)
#
# Harmonising LILRA3 (a9Nizb) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs36657
#
# Harmonising VIT (JYYRmt) and delirium_ukb (lQ5Klx)
#
# Harmonising CCL28 (4rlDJg) and delirium_ukb (lQ5Klx)
#
# Harmonising LYSMD3 (CADFe6) and delirium_ukb (lQ5Klx)
#
# Harmonising PDGFB (lYLT7S) and delirium_ukb (lQ5Klx)
#
# Harmonising WFDC1 (wV3WcN) and delirium_ukb (lQ5Klx)
#
# Harmonising UXS1 (YYZE89) and delirium_ukb (lQ5Klx)
#
# Harmonising PPP1R12A (hRmaBg) and delirium_ukb (lQ5Klx)
#
# Harmonising INSL5 (s4KdeB) and delirium_ukb (lQ5Klx)
#
# Harmonising CXCL16 (LUVzT3) and delirium_ukb (lQ5Klx)
#
# Harmonising GPR37 (sHGKYU) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2001945
#
# Harmonising MAMDC2 (lKclG4) and delirium_ukb (lQ5Klx)
#
# Harmonising SCGB3A2 (GxPeBk) and delirium_ukb (lQ5Klx)
#
# Harmonising PECR (EtOTbD) and delirium_ukb (lQ5Klx)
#
# Harmonising ITPR1 (DxOB4m) and delirium_ukb (lQ5Klx)
#
# Harmonising STAU1 (yXXb0e) and delirium_ukb (lQ5Klx)
#
# Harmonising PDCD1 (mEb6yk) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs4973668
#
# Harmonising ADGRE1 (fm8qy7) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs382356
#
# Harmonising CD300C (nqeQKz) and delirium_ukb (lQ5Klx)
#
# Harmonising LPL (MVd5L4) and delirium_ukb (lQ5Klx)
#
# Harmonising DNER (QciyAs) and delirium_ukb (lQ5Klx)
#
# Harmonising HEPACAM2 (psbhuf) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10793964, rs6444187, rs7606173
#
# Harmonising CHAC2 (Vay473) and delirium_ukb (lQ5Klx)
#
# Harmonising EFEMP1 (M3K4KK) and delirium_ukb (lQ5Klx)
#
# Harmonising INPP5D (T50V15) and delirium_ukb (lQ5Klx)
#
# Harmonising ERBB4 (EsYci6) and delirium_ukb (lQ5Klx)
#
# Harmonising EBI3_IL27 (g2MDNa) and delirium_ukb (lQ5Klx)
#
# Harmonising VCAM1 (I7W195) and delirium_ukb (lQ5Klx)
#
# Harmonising CR1 (iDmlfW) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs6444187
#
# Harmonising EIF2AK3 (PZMo7R) and delirium_ukb (lQ5Klx)
#
# Harmonising FAM171B (fWqyul) and delirium_ukb (lQ5Klx)
#
# Harmonising BCHE (oWc1zj) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1935
#
# Harmonising PAPPA (LJsIxP) and delirium_ukb (lQ5Klx)
#
# Harmonising HS6ST1 (acQsTE) and delirium_ukb (lQ5Klx)
#
# Harmonising HNMT (ACiFUb) and delirium_ukb (lQ5Klx)
#
# Harmonising FKBP1B (TgOt8y) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1935
#
# Harmonising PI3 (DJHclI) and delirium_ukb (lQ5Klx)
#
# Harmonising PRG2 (4nmh2v) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs449882
#
# Harmonising CLC (vVJlbS) and delirium_ukb (lQ5Klx)
#
# Harmonising RNASE3 (D5Ldie) and delirium_ukb (lQ5Klx)
#
# Harmonising MDH1 (Jx1O4k) and delirium_ukb (lQ5Klx)
#
# Harmonising JCHAIN (lL22NV) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2734959
#
# Harmonising SOST (HffwFJ) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs11995824
#
# Harmonising IL1RAP (MBIKnq) and delirium_ukb (lQ5Klx)
#
# Harmonising SEMA7A (FP9s5D) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs7606173
#
# Harmonising KLB (fE4Kt9) and delirium_ukb (lQ5Klx)
#
# Harmonising PCDHB15 (1SAPMu) and delirium_ukb (lQ5Klx)
#
# Harmonising GUSB (boznKr) and delirium_ukb (lQ5Klx)
#
# Harmonising IGFBP3 (A04jQ9) and delirium_ukb (lQ5Klx)
#
# Harmonising PON1 (Mq8VQ4) and delirium_ukb (lQ5Klx)
#
# Harmonising TSPAN8 (Dr4s2T) and delirium_ukb (lQ5Klx)
#
# Harmonising PCDH9 (ZC9JO9) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs6444187
#
# Harmonising GFRAL (14KFxI) and delirium_ukb (lQ5Klx)
#
# Harmonising HCG22 (WQmH5i) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1029239, rs1383264
#
# Harmonising VWC2 (jsQuok) and delirium_ukb (lQ5Klx)
#
# Harmonising TAFA5 (HgHxpz) and delirium_ukb (lQ5Klx)
#
# Harmonising SCARB2 (bOhyED) and delirium_ukb (lQ5Klx)
#
# Harmonising EFCAB14 (w7KPL3) and delirium_ukb (lQ5Klx)
#
# Harmonising CLMP (QGygkq) and delirium_ukb (lQ5Klx)
#
# Harmonising IGFBP6 (VOdm5g) and delirium_ukb (lQ5Klx)
#
# Harmonising AMBP (BOrJK5) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1560539
#
# Harmonising LAYN (LQfczW) and delirium_ukb (lQ5Klx)
#
# Harmonising NPDC1 (PzRJKY) and delirium_ukb (lQ5Klx)
#
# Harmonising ELN (Ua0jIE) and delirium_ukb (lQ5Klx)
#
# Harmonising LAMB1 (bRqwAn) and delirium_ukb (lQ5Klx)
#
# Harmonising NRCAM (NYfApU) and delirium_ukb (lQ5Klx)
#
# Harmonising SHH (YwmXeb) and delirium_ukb (lQ5Klx)
#
# Harmonising MEP1B (4l2Nlb) and delirium_ukb (lQ5Klx)
#
# Harmonising PLTP (su1p0L) and delirium_ukb (lQ5Klx)
#
# Harmonising MRC1 (gWdq24) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs35771982
#
# Harmonising ERN1 (3HePB5) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2001945
#
# Harmonising CTSF (UqLjKu) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs6571912
#
# Harmonising APOE (i9iJjf) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2965156
#
# Harmonising CD27 (uVYpky) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10228441
#
# Harmonising CLEC10A (6NT6SI) and delirium_ukb (lQ5Klx)
#
# Harmonising PODXL (kOsP0C) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10793964
#
# Harmonising ANGPTL2 (I84SKj) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs28712493, rs6457620, rs9268560
#
# Harmonising ZP3 (WxgrNe) and delirium_ukb (lQ5Klx)
#
# Harmonising PTX3 (15sQFN) and delirium_ukb (lQ5Klx)
#
# Harmonising CCL24 (sI9MAr) and delirium_ukb (lQ5Klx)
#
# Harmonising GPNMB (jvA1LW) and delirium_ukb (lQ5Klx)
#
# Harmonising CNTNAP2 (YILcF5) and delirium_ukb (lQ5Klx)
#
# Harmonising CXCL12 (HanKfs) and delirium_ukb (lQ5Klx)
#
# Harmonising SUMF2 (VfM6x5) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs4388405
#
# Harmonising PTPRZ1 (AADQgn) and delirium_ukb (lQ5Klx)
#
# Harmonising CTRB1 (Qg5cY3) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2842895
#
# Harmonising PNLIPRP1 (T8plkh) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs9491696
#
# Harmonising PON2 (tloaLN) and delirium_ukb (lQ5Klx)
#
# Harmonising FIS1 (Wry6Xj) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1935
#
# Harmonising CD28 (rTn3fv) and delirium_ukb (lQ5Klx)
#
# Harmonising CR2 (4pODHv) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2844503, rs3021304
#
# Harmonising COMP (B1XrrE) and delirium_ukb (lQ5Klx)
#
# Harmonising TPK1 (DdKosi) and delirium_ukb (lQ5Klx)
#
# Harmonising TDGF1 (87lHHe) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs57815892
#
# Harmonising BMPER (sApCOV) and delirium_ukb (lQ5Klx)
#
# Harmonising CA9 (oh7KWe) and delirium_ukb (lQ5Klx)
#
# Harmonising EGFR (8Kldqf) and delirium_ukb (lQ5Klx)
#
# Harmonising CLEC5A (r1pykK) and delirium_ukb (lQ5Klx)
#
# Harmonising PILRA (F4k8X5) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs11766125
#
# Harmonising PILRB (FfN4hh) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs11766125
#
# Harmonising C7orf50 (oY9XcN) and delirium_ukb (lQ5Klx)
#
# Harmonising SFRP4 (227Mt4) and delirium_ukb (lQ5Klx)
#
# Harmonising LCN15 (Ftq520) and delirium_ukb (lQ5Klx)
#
# Harmonising SPON1 (A0SSSA) and delirium_ukb (lQ5Klx)
#
# Harmonising PTPRN2 (PTIPyS) and delirium_ukb (lQ5Klx)
#
# Harmonising SSC5D (CsODYY) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs28712493
#
# Harmonising AOC3 (e2sNvO) and delirium_ukb (lQ5Klx)
#
# Harmonising THBS4 (fPhK9p) and delirium_ukb (lQ5Klx)
#
# Harmonising PON3 (zavTUG) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs961262
#
# Harmonising RTN4IP1 (qyLsXF) and delirium_ukb (lQ5Klx)
#
# Harmonising IL22 (cQY1g2) and delirium_ukb (lQ5Klx)
#
# Harmonising GIMAP7 (5dreLT) and delirium_ukb (lQ5Klx)
#
# Harmonising MET (lEAAjV) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10793964, rs1935
#
# Harmonising ACHE (ku81zN) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs6444187
#
# Harmonising IGSF8 (UDrEOJ) and delirium_ukb (lQ5Klx)
#
# Harmonising MOCS2 (5UtYLV) and delirium_ukb (lQ5Klx)
#
# Harmonising ROBO1 (5IUktc) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2395153
#
# Harmonising EPHA1 (AnjD5E) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1935
#
# Harmonising GAS6 (WDrgy6) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1029239
#
# Harmonising CLSTN3 (ZWpyCq) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs7310539
#
# Harmonising FOLR2 (eXtlnK) and delirium_ukb (lQ5Klx)
#
# Harmonising FOLR3 (hk8rsO) and delirium_ukb (lQ5Klx)
#
# Harmonising BTN1A1 (2FmYzx) and delirium_ukb (lQ5Klx)
#
# Harmonising CD83 (ANpma3) and delirium_ukb (lQ5Klx)
#
# Harmonising CPXM1 (2hRu84) and delirium_ukb (lQ5Klx)
#
# Harmonising KIAA0319 (ELWQUz) and delirium_ukb (lQ5Klx)
#
# Harmonising CD302 (tajeCJ) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1029239
#
# Harmonising BTN2A1 (qu1QbW) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1029239, rs1632854, rs3131785
#
# Harmonising SIGLEC6 (fQWCkC) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1029239, rs2844503, rs805293
#
# Harmonising CA4 (miTgSN) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs4711750, rs4802188
#
# Harmonising MINDY1 (5YwkoG) and delirium_ukb (lQ5Klx)
#
# Harmonising ADAMTSL4 (tRP3B6) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2001945
#
# Harmonising CCL8 (KzsoqF) and delirium_ukb (lQ5Klx)
#
# Harmonising ADGRV1 (7u3g23) and delirium_ukb (lQ5Klx)
#
# Harmonising SCPEP1 (ErQUVq) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs12602586
#
# Harmonising FASLG (dVfa1o) and delirium_ukb (lQ5Klx)
#
# Harmonising MMP3 (0vf9KL) and delirium_ukb (lQ5Klx)
#
# Harmonising LCAT (8yiHKQ) and delirium_ukb (lQ5Klx)
#
# Harmonising OXT (wkoUaL) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1935, rs2001945
#
# Harmonising ADGRB3 (4ByIAk) and delirium_ukb (lQ5Klx)
#
# Harmonising ENDOU (vkruH0) and delirium_ukb (lQ5Klx)
#
# Harmonising CDH17 (W82UGl) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs10793964
#
# Harmonising SCARF2 (kDSF0d) and delirium_ukb (lQ5Klx)
#
# Harmonising LAIR1 (zTFsox) and delirium_ukb (lQ5Klx)
#
# ...
#
# Harmonising IMMT (dUspwM) and delirium_ukb (lQ5Klx)
#
# Harmonising DAAM1 (E8WbGx) and delirium_ukb (lQ5Klx)
#
# Harmonising SRC (jc2hac) and delirium_ukb (lQ5Klx)
#
# Harmonising FGD3 (TTUlZA) and delirium_ukb (lQ5Klx)
#
# Harmonising INPPL1 (ET1tm1) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs342293
#
# Harmonising GATD3 (vDdnAa) and delirium_ukb (lQ5Klx)
#
# Harmonising SERPINB1 (0YVU5Y) and delirium_ukb (lQ5Klx)
#
# Harmonising BLOC1S3 (4pJaui) and delirium_ukb (lQ5Klx)
#
# Harmonising DOK1 (8rDfr6) and delirium_ukb (lQ5Klx)
#
# Harmonising LPP (kAHtHB) and delirium_ukb (lQ5Klx)
#
# Harmonising HNRNPK (rREzpr) and delirium_ukb (lQ5Klx)
#
# Harmonising IRAK1 (qRlIhJ) and delirium_ukb (lQ5Klx)
#
# Harmonising SMAD1 (fpr9Se) and delirium_ukb (lQ5Klx)
#
# Harmonising CMIP (U0tSPq) and delirium_ukb (lQ5Klx)
#
# Harmonising POLR2F (1JeP5y) and delirium_ukb (lQ5Klx)
#
# Harmonising KLK3 (94Piaz) and delirium_ukb (lQ5Klx)
#
# Harmonising RNF43 (hvsg7r) and delirium_ukb (lQ5Klx)
#
# Harmonising CNPY2 (GtQ0Qi) and delirium_ukb (lQ5Klx)
#
# Harmonising SLAMF1 (gNpZFS) and delirium_ukb (lQ5Klx)
#
# Harmonising MAP4K5 (BTikk0) and delirium_ukb (lQ5Klx)
#
# Harmonising TAGLN3 (NTNHgx) and delirium_ukb (lQ5Klx)
#
# Harmonising PSMD9 (5ApZNW) and delirium_ukb (lQ5Klx)
#
# Harmonising C19orf12 (62sQHR) and delirium_ukb (lQ5Klx)
#
# Harmonising TRIM21 (3AeJqw) and delirium_ukb (lQ5Klx)
#
# Harmonising MYBPC2 (Tk1p0i) and delirium_ukb (lQ5Klx)
#
# Harmonising SIL1 (0SZi4z) and delirium_ukb (lQ5Klx)
#
# Harmonising ACTN2 (IMjwkI) and delirium_ukb (lQ5Klx)
#
# Harmonising XRCC4 (kpVd5t) and delirium_ukb (lQ5Klx)
#
# Harmonising MCEE (R5aX5c) and delirium_ukb (lQ5Klx)
#
# Harmonising SPRED2 (6ES4RY) and delirium_ukb (lQ5Klx)
#
# Harmonising RASSF2 (Em3iCO) and delirium_ukb (lQ5Klx)
#
# Harmonising CAT (mHGMVY) and delirium_ukb (lQ5Klx)
#
# Harmonising PPIF (MhYlRX) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1935
#
# Harmonising IRAK4 (EBDJLM) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs1935
#
# Harmonising NPPB (UJjUQh) and delirium_ukb (lQ5Klx)
#
# Harmonising POF1B (qCkhRS) and delirium_ukb (lQ5Klx)
#
# Harmonising GLYR1 (MxuGai) and delirium_ukb (lQ5Klx)
#
# Harmonising HJV (5WW7CH) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs2001945
#
# Harmonising PPP1R14D (dj7q3s) and delirium_ukb (lQ5Klx)
#
# Harmonising AHNAK (lIimxR) and delirium_ukb (lQ5Klx)
#
# Harmonising RPE (DrTHue) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs3021304
#
# Harmonising NOS2 (CmqpcB) and delirium_ukb (lQ5Klx)
#
# Harmonising UNC5D (STq5Dt) and delirium_ukb (lQ5Klx)
#
# Harmonising TEF (n8DHvt) and delirium_ukb (lQ5Klx)
#
# Harmonising TSPAN7 (M1zBed) and delirium_ukb (lQ5Klx)
#
# Harmonising SPINT3 (1OdfRS) and delirium_ukb (lQ5Klx)
#
# Harmonising HMGCL (U83Qhe) and delirium_ukb (lQ5Klx)
#
# Harmonising SEMA4C (ydGZTq) and delirium_ukb (lQ5Klx)
#
# Harmonising TST (v580Gr) and delirium_ukb (lQ5Klx)
#
# Harmonising TNFAIP8 (YbJvYb) and delirium_ukb (lQ5Klx)
#
# Harmonising FARSA (SBXDwF) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs3021304
#
# Harmonising PHOSPHO1 (Yu5L0t) and delirium_ukb (lQ5Klx)
#
# Harmonising TNFRSF14 (TpR14d) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs342293
#
# Harmonising CDK1 (TfWcxW) and delirium_ukb (lQ5Klx)
#
# Harmonising CSRP3 (3YK5eU) and delirium_ukb (lQ5Klx)
#
# Harmonising SLC4A1 (xuWn0Y) and delirium_ukb (lQ5Klx)
#
# Harmonising RALY (X29gJN) and delirium_ukb (lQ5Klx)
#
# Harmonising PAIP2B (3gaVaV) and delirium_ukb (lQ5Klx)
#
# Harmonising RBPMS (I7frKz) and delirium_ukb (lQ5Klx)
#
# Harmonising C1QTNF6 (kd8ATQ) and delirium_ukb (lQ5Klx)
#
# Harmonising DCTN6 (EOQWVO) and delirium_ukb (lQ5Klx)
#
# Harmonising PPIE (17FS5s) and delirium_ukb (lQ5Klx)
#
# Harmonising CAPN3 (UXOY4k) and delirium_ukb (lQ5Klx)
#
# Harmonising MANEAL (9xj9vX) and delirium_ukb (lQ5Klx)
#
# Harmonising SOD1 (mK7t1g) and delirium_ukb (lQ5Klx)
#
# Harmonising TXN (rGBVxR) and delirium_ukb (lQ5Klx)
#
# Harmonising NECAP2 (WPVK0Y) and delirium_ukb (lQ5Klx)
#
# Harmonising ERBIN (gKs5IB) and delirium_ukb (lQ5Klx)
#
# Harmonising PNPT1 (RsYgxU) and delirium_ukb (lQ5Klx)
#
# Harmonising SNX18 (YR3s1o) and delirium_ukb (lQ5Klx)
#
# Harmonising ZNF830 (tqXt2l) and delirium_ukb (lQ5Klx)
#
# Harmonising IQGAP2 (H58KsT) and delirium_ukb (lQ5Klx)
#
# Harmonising SNAPIN (JIaO8H) and delirium_ukb (lQ5Klx)
#
# Harmonising PLSCR3 (GvnQnH) and delirium_ukb (lQ5Klx)
#
# Harmonising KCTD5 (tUC5jc) and delirium_ukb (lQ5Klx)
#
# Harmonising ADRA2A (v5q1Gm) and delirium_ukb (lQ5Klx)
#
# Harmonising SCP2 (H4z91I) and delirium_ukb (lQ5Klx)
#
# Harmonising GABARAPL1 (JIMmT1) and delirium_ukb (lQ5Klx)
#
# Harmonising TRIM25 (vlYhre) and delirium_ukb (lQ5Klx)
#
# Harmonising BAG3 (O2VwE3) and delirium_ukb (lQ5Klx)
#
# Harmonising CLASP1 (DBIY07) and delirium_ukb (lQ5Klx)
#
# Harmonising CLEC2L (SmD66P) and delirium_ukb (lQ5Klx)
#
# Harmonising MORF4L2 (lQccpU) and delirium_ukb (lQ5Klx)
#
# Harmonising RAB39B (QkVAN7) and delirium_ukb (lQ5Klx)
#
# Harmonising MINK1 (2zeiuv) and delirium_ukb (lQ5Klx)
#
# Harmonising TEX101 (bHiy5Z) and delirium_ukb (lQ5Klx)
#
# Harmonising LMNB2 (WtPdRZ) and delirium_ukb (lQ5Klx)
#
# Harmonising CASP3 (nM40Ci) and delirium_ukb (lQ5Klx)
#
# Harmonising FDX1 (ccRpIi) and delirium_ukb (lQ5Klx)
#
# Harmonising DTX2 (CxeTGa) and delirium_ukb (lQ5Klx)
#
# Harmonising TIMP2 (bumzxr) and delirium_ukb (lQ5Klx)
#
# Harmonising GART (inZwp3) and delirium_ukb (lQ5Klx)
#
# Harmonising NEDD4L (c03goK) and delirium_ukb (lQ5Klx)
#
# Harmonising CWC15 (FG5Hbp) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs3021304
#
# Harmonising UBE2B (pGrWRP) and delirium_ukb (lQ5Klx)
#
# Harmonising KIAA2013 (qhzTjg) and delirium_ukb (lQ5Klx)
#
# Harmonising UBE2Z (EK9mxu) and delirium_ukb (lQ5Klx)
#
# Harmonising TSC1 (lsYkzr) and delirium_ukb (lQ5Klx)
#
# Harmonising GKN1 (c7slV9) and delirium_ukb (lQ5Klx)
#
# Harmonising FGR (cKakWV) and delirium_ukb (lQ5Klx)
#
# Harmonising TXK (DV510x) and delirium_ukb (lQ5Klx)
#
# Harmonising ATP2B4 (noeJXz) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs3021304
#
# Harmonising PDIA3 (ZJ1XkW) and delirium_ukb (lQ5Klx)
#
# Harmonising TCOF1 (9M37YU) and delirium_ukb (lQ5Klx)
#
# Harmonising CEBPA (mFovWK) and delirium_ukb (lQ5Klx)
#
# Harmonising HTRA2 (J7nzMp) and delirium_ukb (lQ5Klx)
#
# Harmonising SELENOP (NrmunQ) and delirium_ukb (lQ5Klx)
#
# Harmonising PPL (ibhMP9) and delirium_ukb (lQ5Klx)
#
# Harmonising STOML2 (6GAGcs) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs3021304
#
# Harmonising IL31 (snnY8m) and delirium_ukb (lQ5Klx)
#
# Harmonising ANK2 (qMh6b1) and delirium_ukb (lQ5Klx)
#
# Harmonising EIF2S2 (TuKejj) and delirium_ukb (lQ5Klx)
#
# Harmonising IL10RA (C7rr4g) and delirium_ukb (lQ5Klx)
#
# Harmonising CSF2RA (XO0gSc) and delirium_ukb (lQ5Klx)
#
# Harmonising GRSF1 (q4gcAl) and delirium_ukb (lQ5Klx)
#
# Harmonising ELOA (mJBFNI) and delirium_ukb (lQ5Klx)
#
# Harmonising SERPINB9 (jY1rrk) and delirium_ukb (lQ5Klx)
#
# Harmonising TIGAR (b2jcCU) and delirium_ukb (lQ5Klx)
#
# Harmonising ENPEP (k97EIb) and delirium_ukb (lQ5Klx)
#
# Harmonising HMOX2 (VPynnd) and delirium_ukb (lQ5Klx)
#
# Harmonising DNAJC9 (dBBCIL) and delirium_ukb (lQ5Klx)
#
# Harmonising OXCT1 (tc6sh6) and delirium_ukb (lQ5Klx)
#
# Harmonising DOK2 (3ioEm9) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs342293
#
# Harmonising STX6 (cKpFqf) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs342293
#
# Harmonising NAMPT (p74mfX) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs342293
#
# Harmonising RRAS (XpYXdo) and delirium_ukb (lQ5Klx)
#
# Harmonising DNAJA2 (6UApoR) and delirium_ukb (lQ5Klx)
#
# Harmonising SNX9 (163BzS) and delirium_ukb (lQ5Klx)
#
# Harmonising RNF41 (GSBACF) and delirium_ukb (lQ5Klx)
#
# Harmonising DNAJB6 (BYJeP1) and delirium_ukb (lQ5Klx)
#
# Harmonising AMBN (fVoLOz) and delirium_ukb (lQ5Klx)
#
# Harmonising SMNDC1 (uXqiZF) and delirium_ukb (lQ5Klx)
#
# Harmonising ANXA1 (nU9jBc) and delirium_ukb (lQ5Klx)
#
# Harmonising FEN1 (iod9Ep) and delirium_ukb (lQ5Klx)
#
# Harmonising KLF4 (lVxZuK) and delirium_ukb (lQ5Klx)
#
# Harmonising TRAF3 (Zy6m6M) and delirium_ukb (lQ5Klx)
#
# Harmonising PRUNE2 (sRXyOD) and delirium_ukb (lQ5Klx)
#
# Harmonising VGF (p6qM4v) and delirium_ukb (lQ5Klx)
#
# Harmonising ZPR1 (P1gxIC) and delirium_ukb (lQ5Klx)
#
# Harmonising CEP290 (xBogXR) and delirium_ukb (lQ5Klx)
#
# Harmonising GCG (jhxBga) and delirium_ukb (lQ5Klx)
#
# Harmonising ANXA5 (JQS6zb) and delirium_ukb (lQ5Klx)
#
# Harmonising GP5 (Zh9M0I) and delirium_ukb (lQ5Klx)
#
# Harmonising KIR3DL2 (CGLPRh) and delirium_ukb (lQ5Klx)
#
# Harmonising DNAJB8 (IeTkBq) and delirium_ukb (lQ5Klx)
#
# Harmonising GBP2 (qR1W5j) and delirium_ukb (lQ5Klx)
#
# Harmonising ATP6V1D (5HFf2s) and delirium_ukb (lQ5Klx)
#
# Harmonising VAMP5 (LydvKx) and delirium_ukb (lQ5Klx)
#
# Harmonising CLIC5 (m1Qx3J) and delirium_ukb (lQ5Klx)
#
# Harmonising PSME2 (gXV0IY) and delirium_ukb (lQ5Klx)
#
# Harmonising DOC2B (uPCA8H) and delirium_ukb (lQ5Klx)
#
# Harmonising LHB (1LKuFV) and delirium_ukb (lQ5Klx)
#
# Harmonising RCC1 (LZZoXm) and delirium_ukb (lQ5Klx)
#
# Harmonising IL36A (gyAz8y) and delirium_ukb (lQ5Klx)
#
# Harmonising LPCAT2 (VxIyer) and delirium_ukb (lQ5Klx)
#
# Harmonising RFC4 (rGEP9n) and delirium_ukb (lQ5Klx)
#
# Harmonising CIT (SeYl4T) and delirium_ukb (lQ5Klx)
#
# Harmonising TSPYL1 (bWOlQx) and delirium_ukb (lQ5Klx)
#
# Harmonising OCLN (F9FOSD) and delirium_ukb (lQ5Klx)
#
# Harmonising NACC1 (mhlORg) and delirium_ukb (lQ5Klx)
#
# Harmonising NGF (awxt0x) and delirium_ukb (lQ5Klx)
#
# Harmonising RUVBL1 (bIFSNf) and delirium_ukb (lQ5Klx)
#
# Harmonising BCR (op22mQ) and delirium_ukb (lQ5Klx)
#
# Harmonising DDI2 (cd6aUZ) and delirium_ukb (lQ5Klx)
#
# Harmonising ITIH5 (B0QG26) and delirium_ukb (lQ5Klx)
#
# Harmonising ARHGAP25 (8CK2o2) and delirium_ukb (lQ5Klx)
#
# Harmonising CXCL14 (TdRnrb) and delirium_ukb (lQ5Klx)
#
# Harmonising CALB2 (M6lFjV) and delirium_ukb (lQ5Klx)
#
# Harmonising GAS2 (zhsRSB) and delirium_ukb (lQ5Klx)
#
# Harmonising MYLPF (bNr8PW) and delirium_ukb (lQ5Klx)
#
# Harmonising CEND1 (E6fBl2) and delirium_ukb (lQ5Klx)
#
# Harmonising PBXIP1 (rR8t7o) and delirium_ukb (lQ5Klx)
#
# Harmonising HHEX (gTUuZj) and delirium_ukb (lQ5Klx)
#
# Harmonising OTOA (N2VIsW) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs4783413
#
# Harmonising ZBTB17 (PjKMkW) and delirium_ukb (lQ5Klx)
#
# Harmonising CEBPB (ERkIyX) and delirium_ukb (lQ5Klx)
#
# Harmonising TMCO5A (KVXwYR) and delirium_ukb (lQ5Klx)
#
# Harmonising ACRV1 (mcUGdt) and delirium_ukb (lQ5Klx)
#
# Harmonising ALDH2 (SBbztx) and delirium_ukb (lQ5Klx)
#
# Harmonising HADH (Mdv0dV) and delirium_ukb (lQ5Klx)
#
# Harmonising PSMG3 (lo8o15) and delirium_ukb (lQ5Klx)
#
# Harmonising PSMG4 (1rPRY5) and delirium_ukb (lQ5Klx)
#
# Harmonising DLL4 (t9SXxj) and delirium_ukb (lQ5Klx)
#
# Harmonising CLSTN1 (LeMVYh) and delirium_ukb (lQ5Klx)
#
# Harmonising YJU2 (n7oceS) and delirium_ukb (lQ5Klx)
#
# Harmonising CLIP2 (LJjtAe) and delirium_ukb (lQ5Klx)
#
# Harmonising TCP11 (ZJAu7M) and delirium_ukb (lQ5Klx)
#
# Harmonising NEFL (f515vk) and delirium_ukb (lQ5Klx)
#
# Harmonising MMUT (HZNJ8f) and delirium_ukb (lQ5Klx)
#
# Harmonising TIMM8A (BNQ1G4) and delirium_ukb (lQ5Klx)
#
# Harmonising MED18 (0Mdc0v) and delirium_ukb (lQ5Klx)
#
# Harmonising MAP3K5 (07LBNK) and delirium_ukb (lQ5Klx)
#
# Harmonising DAND5 (IclFsn) and delirium_ukb (lQ5Klx)
#
# Harmonising UROS (iJObwf) and delirium_ukb (lQ5Klx)
#
# Harmonising RALB (Cgpjf1) and delirium_ukb (lQ5Klx)
#
# Harmonising SPACA5_SPACA5B (wF2kZz) and delirium_ukb (lQ5Klx)
#
# Removing the following SNPs for being palindromic with intermediate allele frequencies:
# rs5905647
#
# Harmonising DNAJB2 (Ug2Ddq) and delirium_ukb (lQ5Klx)
#
# Harmonising SLIT2 (bdwQIm) and delirium_ukb (lQ5Klx)
#
# Harmonising PLIN1 (xizz7s) and delirium_ukb (lQ5Klx)
#
# Harmonising KRT19 (B4H1K4) and delirium_ukb (lQ5Klx)
#
# Harmonising IL11 (Yg90dn) and delirium_ukb (lQ5Klx)
#
# Harmonising TET2 (OUQ4SC) and delirium_ukb (lQ5Klx)
#
# Harmonising RPGR (p4RJpb) and delirium_ukb (lQ5Klx)
#
# Harmonising IL5 (uZjSXq) and delirium_ukb (lQ5Klx)
#
# Harmonising MTHFD2 (rKohaO) and delirium_ukb (lQ5Klx)
#
# Harmonising NTF4 (1RvQNc) and delirium_ukb (lQ5Klx)
#
# Harmonising C2CD2L (BzBF1Z) and delirium_ukb (lQ5Klx)
#
# Harmonising TMPRSS11B (W6Ubpx) and delirium_ukb (lQ5Klx)
#
# Harmonising SNRPB2 (ZkLd1U) and delirium_ukb (lQ5Klx)
#
# Harmonising SF3B4 (Wvb3oJ) and delirium_ukb (lQ5Klx)
#
# Harmonising CA7 (3VsGgI) and delirium_ukb (lQ5Klx)
#
# Harmonising GFER (UmlCeS) and delirium_ukb (lQ5Klx)
#
# Harmonising BNIP2 (FLDK0K) and delirium_ukb (lQ5Klx)
#
# Harmonising RAD23B (lmZykj) and delirium_ukb (lQ5Klx)
#
# Harmonising CRKL (AqZtZ8) and delirium_ukb (lQ5Klx)
#
# Harmonising GRAP2 (8brcW4) and delirium_ukb (lQ5Klx)
#
# Harmonising PLIN3 (nYXBGE) and delirium_ukb (lQ5Klx)
#
# Harmonising MTSS1 (AjpmFU) and delirium_ukb (lQ5Klx)
#
# Harmonising AK2 (YUORyB) and delirium_ukb (lQ5Klx)
#
# Harmonising ING1 (ZYqf5S) and delirium_ukb (lQ5Klx)
#
# Harmonising CLPP (jLzj69) and delirium_ukb (lQ5Klx)
#
# Harmonising DECR1 (h3QeZ4) and delirium_ukb (lQ5Klx)
#
# Harmonising PDP1 (Vob2pJ) and delirium_ukb (lQ5Klx)
#
# Harmonising TSNAX (aE3LpC) and delirium_ukb (lQ5Klx)
#
# Harmonising PPP1CC (A8HmfF) and delirium_ukb (lQ5Klx)
#
# Harmonising SMS (g2FyEi) and delirium_ukb (lQ5Klx)
#
# Harmonising CCT5 (hI3rhz) and delirium_ukb (lQ5Klx)
#
# Harmonising IRAG2 (DpxIHH) and delirium_ukb (lQ5Klx)
#
# Harmonising H2AP (hSnr0y) and delirium_ukb (lQ5Klx)
#
# Harmonising EPHX2 (rTD3dn) and delirium_ukb (lQ5Klx)
#
# Harmonising MYO9B (VSNle8) and delirium_ukb (lQ5Klx)
#
# Harmonising NEO1 (7QaiDR) and delirium_ukb (lQ5Klx)
#
# Harmonising NPR1 (FSsepv) and delirium_ukb (lQ5Klx)
#
# Harmonising ATF2 (ElHaza) and delirium_ukb (lQ5Klx)
#
# Harmonising CACNB1 (Cm3Zyb) and delirium_ukb (lQ5Klx)
#
# Harmonising MAP1LC3B2 (GJBQtV) and delirium_ukb (lQ5Klx)
#
# Harmonising GH2 (9rjtGH) and delirium_ukb (lQ5Klx)
#
# Harmonising KRT8 (tffD48) and delirium_ukb (lQ5Klx)
#
# Harmonising FAM171A2 (Glq559) and delirium_ukb (lQ5Klx)
#
# Harmonising PITHD1 (8RHYo9) and delirium_ukb (lQ5Klx)
#
# Harmonising GUCY2C (Mn76rw) and delirium_ukb (lQ5Klx)
#
# Harmonising DEFB116 (ebVSRp) and delirium_ukb (lQ5Klx)
#
# Harmonising RCOR1 (pmT4Es) and delirium_ukb (lQ5Klx)
#
# Harmonising TPBGL (Ien01g) and delirium_ukb (lQ5Klx)
#
# Harmonising PRKD2 (gwamSY) and delirium_ukb (lQ5Klx)
#
# Harmonising ACSL1 (mznb5U) and delirium_ukb (lQ5Klx)
#
# Harmonising FKBP7 (NPCKCw) and delirium_ukb (lQ5Klx)
#
# Harmonising ANXA10 (Ui0u5N) and delirium_ukb (lQ5Klx)
#
# Harmonising EVPL (jGLiab) and delirium_ukb (lQ5Klx)
#
# Harmonising SYT1 (fZZnxP) and delirium_ukb (lQ5Klx)
#
# Harmonising CEP152 (FyQ9CB) and delirium_ukb (lQ5Klx)
#
# Harmonising FZD10 (hSIKlb) and delirium_ukb (lQ5Klx)
#
# Harmonising SIGLEC15 (VgxeHB) and delirium_ukb (lQ5Klx)
#
# Harmonising HIP1 (IUnG6y) and delirium_ukb (lQ5Klx)
#
# Harmonising RAPGEF2 (O1h0BM) and delirium_ukb (lQ5Klx)
#
# Harmonising IMPG1 (T2dEpt) and delirium_ukb (lQ5Klx)
#
# Harmonising TP53INP1 (OhJpI3) and delirium_ukb (lQ5Klx)
#
# Harmonising ARNT (ZVVscs) and delirium_ukb (lQ5Klx)
#
# Harmonising PLCB1 (Pn0LIk) and delirium_ukb (lQ5Klx)
#
# Harmonising RNF4 (LPxDHF) and delirium_ukb (lQ5Klx)
#
# Harmonising LRP2BP (z7ZEGd) and delirium_ukb (lQ5Klx)
#
# Harmonising IGF2BP3 (XFao13) and delirium_ukb (lQ5Klx)
#
# Harmonising BCL7B (9SoLGo) and delirium_ukb (lQ5Klx)
#
# Harmonising ARHGAP30 (jybUYc) and delirium_ukb (lQ5Klx)
#
# Harmonising SPRR1B (TNswkY) and delirium_ukb (lQ5Klx)
#
# Harmonising TMED1 (PBqtP5) and delirium_ukb (lQ5Klx)
#
# Harmonising INPP5J (wvSZNb) and delirium_ukb (lQ5Klx)
#
# Harmonising SORBS1 (OxFCzQ) and delirium_ukb (lQ5Klx)

# %% [markdown]
# *exclude pleiotropic pQTLs & extract cis-pQTLs*:

# %%
harmon_cis_nopleio <-
harmon %>% 
    filter(!(SNP %in% pleio_snps) & SNP %in% exp_clumped_cis$SNP)
harmon_nopleio <- 
harmon %>% 
    filter(!(SNP %in% pleio_snps))

length(unique(harmon$SNP))
length(unique(harmon_nopleio$SNP))
length(unique(harmon_cis_nopleio$SNP))
# Out:
# [1] 40693
# [1] 38775
# [1] 27948

# %% [markdown]
# #### **cis-pQTLs MR:**

# %%
## perform 2sampleMR:
mr_all_cis <- mr(harmon_cis_nopleio, method_list = c("mr_ivw", "mr_weighted_median", "mr_egger_regression", "mr_two_sample_ml"))
# Out:
# Analysing '01vuod' on 'PLoTSQ'
#
# Analysing '04aDX7' on 'PLoTSQ'
#
# Analysing '05ki0T' on 'PLoTSQ'
#
# Analysing '07SKi0' on 'PLoTSQ'
#
# Analysing '08jku6' on 'PLoTSQ'
#
# Analysing '09d5Mb' on 'PLoTSQ'
#
# Analysing '0C2yuA' on 'PLoTSQ'
#
# Analysing '0d4VvH' on 'PLoTSQ'
#
# Analysing '0E9FJQ' on 'PLoTSQ'
#
# Analysing '0eZC0L' on 'PLoTSQ'
#
# Analysing '0i3obs' on 'PLoTSQ'
#
# Analysing '0IGBwp' on 'PLoTSQ'
#
# Analysing '0IZDi9' on 'PLoTSQ'
#
# Analysing '0jf5ZC' on 'PLoTSQ'
#
# Analysing '0jY1yH' on 'PLoTSQ'
#
# Analysing '0KVBr5' on 'PLoTSQ'
#
# Analysing '0L041e' on 'PLoTSQ'
#
# Analysing '0L34h1' on 'PLoTSQ'
#
# Analysing '0LT5pW' on 'PLoTSQ'
#
# Analysing '0MBR7O' on 'PLoTSQ'
#
# Analysing '0Nh02f' on 'PLoTSQ'
#
# Analysing '0OaLlq' on 'PLoTSQ'
#
# Analysing '0RfYRo' on 'PLoTSQ'
#
# Analysing '0s0iUd' on 'PLoTSQ'
#
# Analysing '0Sncbb' on 'PLoTSQ'
#
# Analysing '0trdb3' on 'PLoTSQ'
#
# Analysing '0tuqOC' on 'PLoTSQ'
#
# Analysing '0TXiCT' on 'PLoTSQ'
#
# Analysing '0UNvpI' on 'PLoTSQ'
#
# Analysing '103si1' on 'PLoTSQ'
#
# Analysing '109XZz' on 'PLoTSQ'
#
# Analysing '14rBhX' on 'PLoTSQ'
#
# Analysing '17h0z0' on 'PLoTSQ'
#
# Analysing '18JUaw' on 'PLoTSQ'
#
# Analysing '1ASHm3' on 'PLoTSQ'
#
# Analysing '1bRol9' on 'PLoTSQ'
#
# Analysing '1bT0e6' on 'PLoTSQ'
#
# Analysing '1F2PrG' on 'PLoTSQ'
#
# Analysing '1FTXjc' on 'PLoTSQ'
#
# Analysing '1gbYdB' on 'PLoTSQ'
#
# Analysing '1HndBg' on 'PLoTSQ'
#
# Analysing '1hPkaS' on 'PLoTSQ'
#
# Analysing '1km18d' on 'PLoTSQ'
#
# Analysing '1MdigH' on 'PLoTSQ'
#
# Analysing '1mEKVG' on 'PLoTSQ'
#
# Analysing '1MG2Qc' on 'PLoTSQ'
#
# Analysing '1MMcYr' on 'PLoTSQ'
#
# Analysing '1NB1CW' on 'PLoTSQ'
#
# Analysing '1NZrPj' on 'PLoTSQ'
#
# Analysing '1Qd8Mv' on 'PLoTSQ'
#
# Analysing '1RH1An' on 'PLoTSQ'
#
# Analysing '1RTQVE' on 'PLoTSQ'
#
# Analysing '1ryfGs' on 'PLoTSQ'
#
# Analysing '1S4Lq0' on 'PLoTSQ'
#
# Analysing '1WGu2D' on 'PLoTSQ'
#
# Analysing '1yAi1j' on 'PLoTSQ'
#
# Analysing '1ZxUCX' on 'PLoTSQ'
#
# Analysing '21ReDd' on 'PLoTSQ'
#
# Analysing '245PJF' on 'PLoTSQ'
#
# Analysing '248WnJ' on 'PLoTSQ'
#
# Analysing '2ajmuJ' on 'PLoTSQ'
#
# Analysing '2enqVO' on 'PLoTSQ'
#
# Analysing '2eRYVX' on 'PLoTSQ'
#
# Analysing '2etG6i' on 'PLoTSQ'
#
# Analysing '2EZezz' on 'PLoTSQ'
#
# Analysing '2FQlOC' on 'PLoTSQ'
#
# Analysing '2FYmfe' on 'PLoTSQ'
#
# Analysing '2gpHVC' on 'PLoTSQ'
#
# Analysing '2GZv6R' on 'PLoTSQ'
#
# Analysing '2ic2XR' on 'PLoTSQ'
#
# Analysing '2NT6Sq' on 'PLoTSQ'
#
# Analysing '2rpY3D' on 'PLoTSQ'
#
# Analysing '2SixLs' on 'PLoTSQ'
#
# Analysing '2t0bCc' on 'PLoTSQ'
#
# Analysing '2uJ9DG' on 'PLoTSQ'
#
# Analysing '2vYbUG' on 'PLoTSQ'
#
# Analysing '2WFjTj' on 'PLoTSQ'
#
# Analysing '2XcH97' on 'PLoTSQ'
#
# Analysing '2zwrtf' on 'PLoTSQ'
#
# Analysing '30IJn9' on 'PLoTSQ'
#
# Analysing '30q0vW' on 'PLoTSQ'
#
# Analysing '30TfEr' on 'PLoTSQ'
#
# Analysing '342hTX' on 'PLoTSQ'
#
# Analysing '38EL4W' on 'PLoTSQ'
#
# Analysing '3AMDz9' on 'PLoTSQ'
#
# Analysing '3ApVv6' on 'PLoTSQ'
#
# Analysing '3AYVop' on 'PLoTSQ'
#
# Analysing '3BBZRN' on 'PLoTSQ'
#
# Analysing '3EovFX' on 'PLoTSQ'
#
# Analysing '3Fj9oy' on 'PLoTSQ'
#
# Analysing '3GGU42' on 'PLoTSQ'
#
# Analysing '3GyFy8' on 'PLoTSQ'
#
# Analysing '3HGrcB' on 'PLoTSQ'
#
# Analysing '3hrREK' on 'PLoTSQ'
#
# Analysing '3hWG2h' on 'PLoTSQ'
#
# Analysing '3i4t4m' on 'PLoTSQ'
#
# Analysing '3jCFq8' on 'PLoTSQ'
#
# Analysing '3jK0XT' on 'PLoTSQ'
#
# Analysing '3Lw7Cd' on 'PLoTSQ'
#
# Analysing '3M6UzD' on 'PLoTSQ'
#
# Analysing '3oNO0e' on 'PLoTSQ'
#
# Analysing '3qfrqs' on 'PLoTSQ'
#
# Analysing '3Qh5FJ' on 'PLoTSQ'
#
# Analysing '3qIpDD' on 'PLoTSQ'
#
# Analysing '3qkJvR' on 'PLoTSQ'
#
# Analysing '3r3bYO' on 'PLoTSQ'
#
# Analysing '3rycmO' on 'PLoTSQ'
#
# Analysing '3snY4C' on 'PLoTSQ'
#
# Analysing '3sYq8T' on 'PLoTSQ'
#
# Analysing '3t82aY' on 'PLoTSQ'
#
# Analysing '3uKzRg' on 'PLoTSQ'
#
# Analysing '3wt8II' on 'PLoTSQ'
#
# Analysing '3xVfmo' on 'PLoTSQ'
#
# Analysing '3YHdot' on 'PLoTSQ'
#
# Analysing '402hJR' on 'PLoTSQ'
#
# Analysing '40cVU2' on 'PLoTSQ'
#
# Analysing '40znNm' on 'PLoTSQ'
#
# Analysing '46otZi' on 'PLoTSQ'
#
# Analysing '48Trux' on 'PLoTSQ'
#
# Analysing '4anNop' on 'PLoTSQ'
#
# Analysing '4bc9Bl' on 'PLoTSQ'
#
# Analysing '4BH5Ph' on 'PLoTSQ'
#
# Analysing '4c6t0C' on 'PLoTSQ'
#
# Analysing '4ckYpd' on 'PLoTSQ'
#
# Analysing '4CMDw6' on 'PLoTSQ'
#
# Analysing '4cYxfC' on 'PLoTSQ'
#
# Analysing '4DpPqx' on 'PLoTSQ'
#
# Analysing '4EAMyA' on 'PLoTSQ'
#
# Analysing '4EY2kv' on 'PLoTSQ'
#
# Analysing '4H5nLa' on 'PLoTSQ'
#
# Analysing '4OFGWn' on 'PLoTSQ'
#
# Analysing '4S8ZQ8' on 'PLoTSQ'
#
# Analysing '4U9KUq' on 'PLoTSQ'
#
# Analysing '4v1b4d' on 'PLoTSQ'
#
# Analysing '4yzHEh' on 'PLoTSQ'
#
# Analysing '4ZOfO2' on 'PLoTSQ'
#
# Analysing '527QLX' on 'PLoTSQ'
#
# Analysing '53lb2J' on 'PLoTSQ'
#
# Analysing '53oKz4' on 'PLoTSQ'
#
# Analysing '56M8LH' on 'PLoTSQ'
#
# Analysing '58cKz9' on 'PLoTSQ'
#
# Analysing '59mV5y' on 'PLoTSQ'
#
# Analysing '5a5f6V' on 'PLoTSQ'
#
# Analysing '5ax0cA' on 'PLoTSQ'
#
# Analysing '5aZm2J' on 'PLoTSQ'
#
# Analysing '5b82JJ' on 'PLoTSQ'
#
# Analysing '5HMiue' on 'PLoTSQ'
#
# Analysing '5Ho86r' on 'PLoTSQ'
#
# Analysing '5hQxLm' on 'PLoTSQ'
#
# Analysing '5jlU4b' on 'PLoTSQ'
#
# Analysing '5kDtgE' on 'PLoTSQ'
#
# Analysing '5MFCKO' on 'PLoTSQ'
#
# Analysing '5nzPXq' on 'PLoTSQ'
#
# Analysing '5OEpsM' on 'PLoTSQ'
#
# Analysing '5onXqI' on 'PLoTSQ'
#
# Analysing '5PGy0C' on 'PLoTSQ'
#
# Analysing '5pJFtX' on 'PLoTSQ'
#
# Analysing '5pkxXu' on 'PLoTSQ'
#
# Analysing '5POcGK' on 'PLoTSQ'
#
# Analysing '5QtNq3' on 'PLoTSQ'
#
# Analysing '5s3vE0' on 'PLoTSQ'
#
# Analysing '5S3YMf' on 'PLoTSQ'
#
# Analysing '5ShC4r' on 'PLoTSQ'
#
# Analysing '5thHat' on 'PLoTSQ'
#
# Analysing '5u63qu' on 'PLoTSQ'
#
# Analysing '5UWGNV' on 'PLoTSQ'
#
# Analysing '5V21jX' on 'PLoTSQ'
#
# Analysing '5vCGnL' on 'PLoTSQ'
#
# Analysing '5W6Ya7' on 'PLoTSQ'
#
# Analysing '5WBNWV' on 'PLoTSQ'
#
# Analysing '5yYSKu' on 'PLoTSQ'
#
# Analysing '5Zx8aK' on 'PLoTSQ'
#
# Analysing '61H1eh' on 'PLoTSQ'
#
# Analysing '67GpWz' on 'PLoTSQ'
#
# Analysing '6AjeKB' on 'PLoTSQ'
#
# Analysing '6b6PeB' on 'PLoTSQ'
#
# Analysing '6cDi3Y' on 'PLoTSQ'
#
# Analysing '6fBl8Q' on 'PLoTSQ'
#
# Analysing '6gopPV' on 'PLoTSQ'
#
# Analysing '6GR1qC' on 'PLoTSQ'
#
# Analysing '6iW2gU' on 'PLoTSQ'
#
# Analysing '6IWlFa' on 'PLoTSQ'
#
# Analysing '6j8ANh' on 'PLoTSQ'
#
# Analysing '6JXBrq' on 'PLoTSQ'
#
# Analysing '6lNTSp' on 'PLoTSQ'
#
# Analysing '6M5e79' on 'PLoTSQ'
#
# Analysing '6mj6bW' on 'PLoTSQ'
#
# Analysing '6MUq6I' on 'PLoTSQ'
#
# Analysing '6OdZub' on 'PLoTSQ'
#
# Analysing '6QJXCb' on 'PLoTSQ'
#
# Analysing '6r9o02' on 'PLoTSQ'
#
# Analysing '6rEleR' on 'PLoTSQ'
#
# Analysing '6RlMnV' on 'PLoTSQ'
#
# Analysing '6Rqlka' on 'PLoTSQ'
#
# Analysing '6uJdXY' on 'PLoTSQ'
#
# Analysing '6UqMSy' on 'PLoTSQ'
#
# Analysing '70wqke' on 'PLoTSQ'
#
# Analysing '71aQjZ' on 'PLoTSQ'
#
# Analysing '78BoD3' on 'PLoTSQ'
#
# Analysing '7A4JBN' on 'PLoTSQ'
#
# Analysing '7AM7sq' on 'PLoTSQ'
#
# Analysing '7APsOy' on 'PLoTSQ'
#
# Analysing '7AsvcK' on 'PLoTSQ'
#
# Analysing '7DrnXF' on 'PLoTSQ'
#
# Analysing '7FMiMl' on 'PLoTSQ'
#
# Analysing '7FR7Fe' on 'PLoTSQ'
#
# Analysing '7fsE2W' on 'PLoTSQ'
#
# Analysing '7fZugq' on 'PLoTSQ'
#
# Analysing '7GgABD' on 'PLoTSQ'
#
# Analysing '7hBXLV' on 'PLoTSQ'
#
# Analysing '7Hvjht' on 'PLoTSQ'
#
# Analysing '7iOZom' on 'PLoTSQ'
#
# Analysing '7j44ZZ' on 'PLoTSQ'
#
# Analysing '7kxXTI' on 'PLoTSQ'
#
# Analysing '7LsY7g' on 'PLoTSQ'
#
# Analysing '7lvmXC' on 'PLoTSQ'
#
# Analysing '7NkHYS' on 'PLoTSQ'
#
# Analysing '7O7D5w' on 'PLoTSQ'
#
# Analysing '7p6vDZ' on 'PLoTSQ'
#
# Analysing '7qBP8f' on 'PLoTSQ'
#
# Analysing '7Re6ij' on 'PLoTSQ'
#
# Analysing '7rWr5w' on 'PLoTSQ'
#
# Analysing '7se4jB' on 'PLoTSQ'
#
# Analysing '7t4LUX' on 'PLoTSQ'
#
# Analysing '7UE9jD' on 'PLoTSQ'
#
# Analysing '7VdcrI' on 'PLoTSQ'
#
# Analysing '7wblPl' on 'PLoTSQ'
#
# Analysing '7wYXGR' on 'PLoTSQ'
#
# Analysing '7XvfhZ' on 'PLoTSQ'
#
# Analysing '87Pe1f' on 'PLoTSQ'
#
# Analysing '88EPQd' on 'PLoTSQ'
#
# Analysing '8aBfeX' on 'PLoTSQ'
#
# Analysing '8auBAz' on 'PLoTSQ'
#
# Analysing '8bVM1F' on 'PLoTSQ'
#
# Analysing '8BW2Kw' on 'PLoTSQ'
#
# Analysing '8cT51l' on 'PLoTSQ'
#
# Analysing '8E3zRC' on 'PLoTSQ'
#
# Analysing '8euSt7' on 'PLoTSQ'
#
# Analysing '8GHCyR' on 'PLoTSQ'
#
# Analysing '8IhiOm' on 'PLoTSQ'
#
# Analysing '8jI0UW' on 'PLoTSQ'
#
# Analysing '8jxfS3' on 'PLoTSQ'
#
# Analysing '8kOS8d' on 'PLoTSQ'
#
# Analysing '8lFtoW' on 'PLoTSQ'
#
# Analysing '8mSMg6' on 'PLoTSQ'
#
# Analysing '8RDAWU' on 'PLoTSQ'
#
# Analysing '8RTOOJ' on 'PLoTSQ'
#
# Analysing '8S8S9d' on 'PLoTSQ'
#
# Analysing '8temwQ' on 'PLoTSQ'
#
# Analysing '8uqsc0' on 'PLoTSQ'
#
# Analysing '8WbcYg' on 'PLoTSQ'
#
# Analysing '8Wlhwj' on 'PLoTSQ'
#
# Analysing '8XwJh1' on 'PLoTSQ'
#
# Analysing '8Yatbm' on 'PLoTSQ'
#
# Analysing '8YgwcK' on 'PLoTSQ'
#
# Analysing '8YNnuA' on 'PLoTSQ'
#
# Analysing '8ZOmj9' on 'PLoTSQ'
#
# Analysing '8ZZUQ3' on 'PLoTSQ'
#
# Analysing '93sEDg' on 'PLoTSQ'
#
# Analysing '94aAig' on 'PLoTSQ'
#
# Analysing '96LDpu' on 'PLoTSQ'
#
# Analysing '96o3Ui' on 'PLoTSQ'
#
# Analysing '98vUek' on 'PLoTSQ'
#
# Analysing '9C7B9n' on 'PLoTSQ'
#
# Analysing '9fekE9' on 'PLoTSQ'
#
# Analysing '9fiJVg' on 'PLoTSQ'
#
# Analysing '9GraHd' on 'PLoTSQ'
#
# Analysing '9jk3pD' on 'PLoTSQ'
#
# Analysing '9lEvK1' on 'PLoTSQ'
#
# Analysing '9MMici' on 'PLoTSQ'
#
# Analysing '9PdwKu' on 'PLoTSQ'
#
# Analysing '9Pgz55' on 'PLoTSQ'
#
# Analysing '9q3dCL' on 'PLoTSQ'
#
# Analysing '9rpM1H' on 'PLoTSQ'
#
# Analysing '9sQ1dq' on 'PLoTSQ'
#
# Analysing '9SR6iu' on 'PLoTSQ'
#
# Analysing '9UiEW1' on 'PLoTSQ'
#
# Analysing '9v0FuW' on 'PLoTSQ'
#
# Analysing '9wlTAG' on 'PLoTSQ'
#
# Analysing '9y5UX9' on 'PLoTSQ'
#
# Analysing '9yPZEP' on 'PLoTSQ'
#
# Analysing '9YzCrs' on 'PLoTSQ'
#
# Analysing '9ZgqY8' on 'PLoTSQ'
#
# Analysing '9zUwZs' on 'PLoTSQ'
#
# Analysing 'A2mDiM' on 'PLoTSQ'
#
# Analysing 'A3joHP' on 'PLoTSQ'
#
# Analysing 'A40C8L' on 'PLoTSQ'
#
# Analysing 'a4IdYK' on 'PLoTSQ'
#
# Analysing 'a5W7kq' on 'PLoTSQ'
#
# Analysing 'A8dO0u' on 'PLoTSQ'
#
# Analysing 'A9LRCP' on 'PLoTSQ'
#
# Analysing 'A9TfO4' on 'PLoTSQ'
#
# Analysing 'AAVBZu' on 'PLoTSQ'
#
# Analysing 'abFUPI' on 'PLoTSQ'
#
# Analysing 'abnRhD' on 'PLoTSQ'
#
# Analysing 'aC0Wjk' on 'PLoTSQ'
#
# Analysing 'AcgWjX' on 'PLoTSQ'
#
# Analysing 'AcnOgp' on 'PLoTSQ'
#
# Analysing 'AD6lLM' on 'PLoTSQ'
#
# Analysing 'aDlIYq' on 'PLoTSQ'
#
# Analysing 'aDNVRd' on 'PLoTSQ'
#
# Analysing 'afwk4X' on 'PLoTSQ'
#
# Analysing 'agTbOA' on 'PLoTSQ'
#
# Analysing 'ah43Si' on 'PLoTSQ'
#
# Analysing 'ahHAvO' on 'PLoTSQ'
#
# Analysing 'ahl81k' on 'PLoTSQ'
#
# Analysing 'AhQJBM' on 'PLoTSQ'
#
# Analysing 'aI2mkd' on 'PLoTSQ'
#
# Analysing 'AIECtS' on 'PLoTSQ'
#
# Analysing 'AIWbb6' on 'PLoTSQ'
#
# Analysing 'AJ6e38' on 'PLoTSQ'
#
# Analysing 'aJ84yO' on 'PLoTSQ'
#
# Analysing 'ajHoge' on 'PLoTSQ'
#
# Analysing 'AKNREu' on 'PLoTSQ'
#
# Analysing 'aKtXBG' on 'PLoTSQ'
#
# Analysing 'AkyK30' on 'PLoTSQ'
#
# Analysing 'AL32GU' on 'PLoTSQ'
#
# Analysing 'al6JAy' on 'PLoTSQ'
#
# Analysing 'alWpml' on 'PLoTSQ'
#
# Analysing 'amJciV' on 'PLoTSQ'
#
# Analysing 'AMkHZM' on 'PLoTSQ'
#
# Analysing 'Amp1vr' on 'PLoTSQ'
#
# Analysing 'AMR7pA' on 'PLoTSQ'
#
# Analysing 'amT9XI' on 'PLoTSQ'
#
# Analysing 'aNd5x9' on 'PLoTSQ'
#
# Analysing 'aNgabn' on 'PLoTSQ'
#
# Analysing 'Angv0K' on 'PLoTSQ'
#
# Analysing 'ANui2J' on 'PLoTSQ'
#
# Analysing 'aODBoK' on 'PLoTSQ'
#
# Analysing 'AodGF9' on 'PLoTSQ'
#
# Analysing 'aouvE0' on 'PLoTSQ'
#
# Analysing 'ApBZcx' on 'PLoTSQ'
#
# Analysing 'apt1oB' on 'PLoTSQ'
#
# Analysing 'APyXou' on 'PLoTSQ'
#
# Analysing 'aqBsbZ' on 'PLoTSQ'
#
# Analysing 'AQcba9' on 'PLoTSQ'
#
# Analysing 'AQQOpV' on 'PLoTSQ'
#
# Analysing 'aRBEC1' on 'PLoTSQ'
#
# Analysing 'aSIbTK' on 'PLoTSQ'
#
# Analysing 'AtEBfN' on 'PLoTSQ'
#
# Analysing 'au7MQc' on 'PLoTSQ'
#
# Analysing 'AuoCRn' on 'PLoTSQ'
#
# Analysing 'AuSRvO' on 'PLoTSQ'
#
# Analysing 'auxJhF' on 'PLoTSQ'
#
# Analysing 'Av0wk9' on 'PLoTSQ'
#
# Analysing 'aVKvsB' on 'PLoTSQ'
#
# Analysing 'AvyVKa' on 'PLoTSQ'
#
# Analysing 'aw3JlE' on 'PLoTSQ'
#
# Analysing 'AW7E6w' on 'PLoTSQ'
#
# Analysing 'AwWwRt' on 'PLoTSQ'
#
# Analysing 'AwY6X6' on 'PLoTSQ'
#
# Analysing 'aYu7cO' on 'PLoTSQ'
#
# Analysing 'AZ9o1L' on 'PLoTSQ'
#
# Analysing 'AZdGIW' on 'PLoTSQ'
#
# Analysing 'B0ai7P' on 'PLoTSQ'
#
# Analysing 'B0HbaB' on 'PLoTSQ'
#
# Analysing 'B2V1bh' on 'PLoTSQ'
#
# Analysing 'B3HPcK' on 'PLoTSQ'
#
# Analysing 'B53DUz' on 'PLoTSQ'
#
# Analysing 'B7cpGl' on 'PLoTSQ'
#
# Analysing 'B7ft72' on 'PLoTSQ'
#
# Analysing 'B7vTLV' on 'PLoTSQ'
#
# Analysing 'b883QL' on 'PLoTSQ'
#
# Analysing 'BauA9E' on 'PLoTSQ'
#
# Analysing 'bb62rx' on 'PLoTSQ'
#
# Analysing 'Bb7h1T' on 'PLoTSQ'
#
# Analysing 'BBT20p' on 'PLoTSQ'
#
# Analysing 'BBVjXR' on 'PLoTSQ'
#
# Analysing 'BC5LGW' on 'PLoTSQ'
#
# Analysing 'bc6VGj' on 'PLoTSQ'
#
# Analysing 'BCtGH0' on 'PLoTSQ'
#
# Analysing 'bCyF8j' on 'PLoTSQ'
#
# Analysing 'Bd1FsJ' on 'PLoTSQ'
#
# Analysing 'BdilD7' on 'PLoTSQ'
#
# Analysing 'Bdm1Tz' on 'PLoTSQ'
#
# Analysing 'Be30iU' on 'PLoTSQ'
#
# Analysing 'bEnUGa' on 'PLoTSQ'
#
# Analysing 'beZ34Y' on 'PLoTSQ'
#
# Analysing 'BfP0WT' on 'PLoTSQ'
#
# Analysing 'BfYenS' on 'PLoTSQ'
#
# Analysing 'bGAPjK' on 'PLoTSQ'
#
# Analysing 'bGFd8a' on 'PLoTSQ'
#
# Analysing 'BgtIDz' on 'PLoTSQ'
#
# Analysing 'BGtZHV' on 'PLoTSQ'
#
# Analysing 'bHgdQA' on 'PLoTSQ'
#
# Analysing 'BHQMBI' on 'PLoTSQ'
#
# Analysing 'bHrWy4' on 'PLoTSQ'
#
# Analysing 'BiYeNw' on 'PLoTSQ'
#
# Analysing 'BJ06tx' on 'PLoTSQ'
#
# Analysing 'bJ4CB3' on 'PLoTSQ'
#
# Analysing 'bjXeMo' on 'PLoTSQ'
#
# Analysing 'BJXXV5' on 'PLoTSQ'
#
# Analysing 'BkPpDG' on 'PLoTSQ'
#
# Analysing 'bkRnij' on 'PLoTSQ'
#
# Analysing 'bKYCi7' on 'PLoTSQ'
#
# Analysing 'BlgYXj' on 'PLoTSQ'
#
# Analysing 'BLUzpU' on 'PLoTSQ'
#
# Analysing 'bMk3hF' on 'PLoTSQ'
#
# Analysing 'bnGiyP' on 'PLoTSQ'
#
# Analysing 'BNQBTg' on 'PLoTSQ'
#
# Analysing 'bNUAkQ' on 'PLoTSQ'
#
# Analysing 'BNVDLk' on 'PLoTSQ'
#
# Analysing 'Bnw6lR' on 'PLoTSQ'
#
# Analysing 'BOub1z' on 'PLoTSQ'
#
# Analysing 'BPaKVD' on 'PLoTSQ'
#
# Analysing 'bPdQ9J' on 'PLoTSQ'
#
# Analysing 'bPJylz' on 'PLoTSQ'
#
# Analysing 'bq8t0j' on 'PLoTSQ'
#
# Analysing 'BQEyyc' on 'PLoTSQ'
#
# Analysing 'BqFgog' on 'PLoTSQ'
#
# Analysing 'BrPNPl' on 'PLoTSQ'
#
# Analysing 'bS9rRc' on 'PLoTSQ'
#
# Analysing 'bScRFw' on 'PLoTSQ'
#
# Analysing 'BSDitt' on 'PLoTSQ'
#
# Analysing 'BSNccI' on 'PLoTSQ'
#
# Analysing 'bSVfzt' on 'PLoTSQ'
#
# Analysing 'bTe61e' on 'PLoTSQ'
#
# Analysing 'btGVAf' on 'PLoTSQ'
#
# Analysing 'bTrOvp' on 'PLoTSQ'
#
# Analysing 'bTwcnG' on 'PLoTSQ'
#
# Analysing 'BTzAun' on 'PLoTSQ'
#
# Analysing 'BU78qP' on 'PLoTSQ'
#
# Analysing 'BuKaaK' on 'PLoTSQ'
#
# Analysing 'BuLuw2' on 'PLoTSQ'
#
# Analysing 'BurFCs' on 'PLoTSQ'
#
# Analysing 'BVBGWw' on 'PLoTSQ'
#
# Analysing 'bvPaq2' on 'PLoTSQ'
#
# Analysing 'bvvv0D' on 'PLoTSQ'
#
# Analysing 'BWibyW' on 'PLoTSQ'
#
# Analysing 'bwuXWF' on 'PLoTSQ'
#
# Analysing 'BX47TD' on 'PLoTSQ'
#
# Analysing 'bXgRJE' on 'PLoTSQ'
#
# Analysing 'BxhdM0' on 'PLoTSQ'
#
# Analysing 'bxwz91' on 'PLoTSQ'
#
# Analysing 'ByDE7W' on 'PLoTSQ'
#
# Analysing 'ByFsfC' on 'PLoTSQ'
#
# Analysing 'BZ7YRY' on 'PLoTSQ'
#
# Analysing 'bZPSIn' on 'PLoTSQ'
#
# Analysing 'c1phzW' on 'PLoTSQ'
#
# Analysing 'C1se1L' on 'PLoTSQ'
#
# Analysing 'C2pyrZ' on 'PLoTSQ'
#
# Analysing 'C4E6Tz' on 'PLoTSQ'
#
# Analysing 'c6SvbG' on 'PLoTSQ'
#
# Analysing 'C9ByyF' on 'PLoTSQ'
#
# Analysing 'ca81w5' on 'PLoTSQ'
#
# Analysing 'cACgs1' on 'PLoTSQ'
#
# Analysing 'CAjdVm' on 'PLoTSQ'
#
# Analysing 'Casr0l' on 'PLoTSQ'
#
# Analysing 'cbx9s9' on 'PLoTSQ'
#
# Analysing 'cC4StV' on 'PLoTSQ'
#
# Analysing 'cce6FC' on 'PLoTSQ'
#
# Analysing 'ccnngi' on 'PLoTSQ'
#
# Analysing 'CCr5sy' on 'PLoTSQ'
#
# Analysing 'CcS25Z' on 'PLoTSQ'
#
# Analysing 'cCsajo' on 'PLoTSQ'
#
# Analysing 'cDClCX' on 'PLoTSQ'
#
# Analysing 'cdQIlo' on 'PLoTSQ'
#
# Analysing 'CE1iMo' on 'PLoTSQ'
#
# Analysing 'ceC1Lz' on 'PLoTSQ'
#
# Analysing 'CeoGwr' on 'PLoTSQ'
#
# Analysing 'CfdsVH' on 'PLoTSQ'
#
# Analysing 'Cfz7oN' on 'PLoTSQ'
#
# Analysing 'Cg3cpf' on 'PLoTSQ'
#
# Analysing 'Cg7VFY' on 'PLoTSQ'
#
# Analysing 'ChOB6P' on 'PLoTSQ'
#
# Analysing 'ChZiaL' on 'PLoTSQ'
#
# Analysing 'ciIBux' on 'PLoTSQ'
#
# Analysing 'cJ6XoB' on 'PLoTSQ'
#
# Analysing 'cJMLuy' on 'PLoTSQ'
#
# Analysing 'CkoA6i' on 'PLoTSQ'
#
# Analysing 'ckrUQO' on 'PLoTSQ'
#
# Analysing 'clPC4O' on 'PLoTSQ'
#
# Analysing 'cmeP9m' on 'PLoTSQ'
#
# Analysing 'CmiZdW' on 'PLoTSQ'
#
# Analysing 'CmpoA1' on 'PLoTSQ'
#
# Analysing 'CMQTMJ' on 'PLoTSQ'
#
# Analysing 'cMSNuj' on 'PLoTSQ'
#
# Analysing 'cOJIOf' on 'PLoTSQ'
#
# Analysing 'CoMuql' on 'PLoTSQ'
#
# Analysing 'coSk8n' on 'PLoTSQ'
#
# Analysing 'cp7ICr' on 'PLoTSQ'
#
# Analysing 'cpAdvD' on 'PLoTSQ'
#
# Analysing 'CpBmC6' on 'PLoTSQ'
#
# Analysing 'CpFfr5' on 'PLoTSQ'
#
# Analysing 'CpvJYn' on 'PLoTSQ'
#
# Analysing 'cPyA3r' on 'PLoTSQ'
#
# Analysing 'Cqf6H2' on 'PLoTSQ'
#
# Analysing 'cqH2wn' on 'PLoTSQ'
#
# No SNPs available for MR analysis of 'CR668A' on 'PLoTSQ'
#
# Analysing 'cRxjA1' on 'PLoTSQ'
#
# Analysing 'cs4xpc' on 'PLoTSQ'
#
# Analysing 'cS9kAg' on 'PLoTSQ'
#
# Analysing 'csiy02' on 'PLoTSQ'
#
# Analysing 'CsNCfY' on 'PLoTSQ'
#
# Analysing 'ctF30A' on 'PLoTSQ'
#
# Analysing 'cUnXJq' on 'PLoTSQ'
#
# Analysing 'CUpg2p' on 'PLoTSQ'
#
# Analysing 'CVTJDh' on 'PLoTSQ'
#
# Analysing 'CVzseg' on 'PLoTSQ'
#
# Analysing 'Cw2UA2' on 'PLoTSQ'
#
# Analysing 'Cw3quT' on 'PLoTSQ'
#
# Analysing 'Cw991h' on 'PLoTSQ'
#
# Analysing 'cwkKN5' on 'PLoTSQ'
#
# Analysing 'cwNVSd' on 'PLoTSQ'
#
# Analysing 'CxEGqK' on 'PLoTSQ'
#
# Analysing 'cxgf12' on 'PLoTSQ'
#
# Analysing 'cXJm7u' on 'PLoTSQ'
#
# Analysing 'CXryLC' on 'PLoTSQ'
#
# Analysing 'Cy0GOT' on 'PLoTSQ'
#
# Analysing 'cZgJnr' on 'PLoTSQ'
#
# Analysing 'CZViuU' on 'PLoTSQ'
#
# Analysing 'd036V1' on 'PLoTSQ'
#
# Analysing 'D0Ov1T' on 'PLoTSQ'
#
# Analysing 'D0PiS4' on 'PLoTSQ'
#
# Analysing 'd1Hm7A' on 'PLoTSQ'
#
# Analysing 'D1Svel' on 'PLoTSQ'
#
# Analysing 'd2XScE' on 'PLoTSQ'
#
# Analysing 'D4L6QL' on 'PLoTSQ'
#
# Analysing 'D7uf4d' on 'PLoTSQ'
#
# Analysing 'd7y4HE' on 'PLoTSQ'
#
# Analysing 'D8WPN4' on 'PLoTSQ'
#
# Analysing 'd8Z3zu' on 'PLoTSQ'
#
# Analysing 'D9blEl' on 'PLoTSQ'
#
# Analysing 'D9CqeV' on 'PLoTSQ'
#
# Analysing 'D9f6kZ' on 'PLoTSQ'
#
# Analysing 'D9nvi7' on 'PLoTSQ'
#
# Analysing 'dAhI8v' on 'PLoTSQ'
#
# Analysing 'DAJGfd' on 'PLoTSQ'
#
# Analysing 'dAQNaB' on 'PLoTSQ'
#
# Analysing 'dauagA' on 'PLoTSQ'
#
# Analysing 'Db5oJG' on 'PLoTSQ'
#
# Analysing 'dbNG4F' on 'PLoTSQ'
#
# Analysing 'DcgV3X' on 'PLoTSQ'
#
# Analysing 'dDjHPy' on 'PLoTSQ'
#
# Analysing 'DFBCMT' on 'PLoTSQ'
#
# Analysing 'dhNo5H' on 'PLoTSQ'
#
# Analysing 'di8SrN' on 'PLoTSQ'
#
# Analysing 'DIwblZ' on 'PLoTSQ'
#
# Analysing 'DiwS2p' on 'PLoTSQ'
#
# Analysing 'diypE8' on 'PLoTSQ'
#
# Analysing 'dJ8lbW' on 'PLoTSQ'
#
# Analysing 'dJY2CU' on 'PLoTSQ'
#
# Analysing 'DmBN9c' on 'PLoTSQ'
#
# Analysing 'dn7Dop' on 'PLoTSQ'
#
# Analysing 'dnqNfT' on 'PLoTSQ'
#
# Analysing 'DnVAaQ' on 'PLoTSQ'
#
# Analysing 'dNYGI4' on 'PLoTSQ'
#
# Analysing 'doFOkH' on 'PLoTSQ'
#
# Analysing 'DqJtdy' on 'PLoTSQ'
#
# Analysing 'dQze3t' on 'PLoTSQ'
#
# Analysing 'dRTSwU' on 'PLoTSQ'
#
# Analysing 'ds0Bvo' on 'PLoTSQ'
#
# Analysing 'dsKPBl' on 'PLoTSQ'
#
# Analysing 'dSplbJ' on 'PLoTSQ'
#
# Analysing 'dTjOva' on 'PLoTSQ'
#
# Analysing 'dUgaDZ' on 'PLoTSQ'
#
# Analysing 'dUwghb' on 'PLoTSQ'
#
# Analysing 'dwPL1q' on 'PLoTSQ'
#
# Analysing 'DWUSVc' on 'PLoTSQ'
#
# Analysing 'DYsvnP' on 'PLoTSQ'
#
# Analysing 'e0jKC4' on 'PLoTSQ'
#
# Analysing 'E0jMcj' on 'PLoTSQ'
#
# Analysing 'E1MSOJ' on 'PLoTSQ'
#
# Analysing 'e1VqiE' on 'PLoTSQ'
#
# Analysing 'E2avcM' on 'PLoTSQ'
#
# Analysing 'e2QATy' on 'PLoTSQ'
#
# Analysing 'e3alYa' on 'PLoTSQ'
#
# Analysing 'E3VCkQ' on 'PLoTSQ'
#
# Analysing 'E4LPJL' on 'PLoTSQ'
#
# Analysing 'e5j9UE' on 'PLoTSQ'
#
# Analysing 'E68JYm' on 'PLoTSQ'
#
# Analysing 'E7wMB7' on 'PLoTSQ'
#
# Analysing 'E7ZW1n' on 'PLoTSQ'
#
# Analysing 'E8xrPm' on 'PLoTSQ'
#
# Analysing 'EB69Xu' on 'PLoTSQ'
#
# Analysing 'eBPca7' on 'PLoTSQ'
#
# Analysing 'EbUFrw' on 'PLoTSQ'
#
# Analysing 'EbYN4s' on 'PLoTSQ'
#
# Analysing 'EcFiVW' on 'PLoTSQ'
#
# Analysing 'ecUHLX' on 'PLoTSQ'
#
# Analysing 'EDEsZh' on 'PLoTSQ'
#
# Analysing 'eDNenN' on 'PLoTSQ'
#
# Analysing 'eDoJrK' on 'PLoTSQ'
#
# Analysing 'eE9bfp' on 'PLoTSQ'
#
# Analysing 'EebxcR' on 'PLoTSQ'
#
# Analysing 'eEDKYL' on 'PLoTSQ'
#
# Analysing 'EEJXMT' on 'PLoTSQ'
#
# Analysing 'Eevvoi' on 'PLoTSQ'
#
# Analysing 'EeyExq' on 'PLoTSQ'
#
# Analysing 'efZLpH' on 'PLoTSQ'
#
# Analysing 'EGji6u' on 'PLoTSQ'
#
# Analysing 'EgXbFt' on 'PLoTSQ'
#
# Analysing 'egxCbJ' on 'PLoTSQ'
#
# Analysing 'EgYQvH' on 'PLoTSQ'
#
# Analysing 'ehCiOj' on 'PLoTSQ'
#
# Analysing 'Ehv9O4' on 'PLoTSQ'
#
# Analysing 'ehVUuA' on 'PLoTSQ'
#
# Analysing 'eJN9jm' on 'PLoTSQ'
#
# Analysing 'eLaBdU' on 'PLoTSQ'
#
# Analysing 'ElDplR' on 'PLoTSQ'
#
# Analysing 'ElKdq9' on 'PLoTSQ'
#
# Analysing 'embsiK' on 'PLoTSQ'
#
# Analysing 'EnRKTN' on 'PLoTSQ'
#
# Analysing 'eP2mG4' on 'PLoTSQ'
#
# Analysing 'eqlkDr' on 'PLoTSQ'
#
# Analysing 'eqoYt4' on 'PLoTSQ'
#
# Analysing 'eQwGr5' on 'PLoTSQ'
#
# Analysing 'eqXmsc' on 'PLoTSQ'
#
# Analysing 'ErCLVr' on 'PLoTSQ'
#
# Analysing 'ErgMwz' on 'PLoTSQ'
#
# Analysing 'ErjvZB' on 'PLoTSQ'
#
# Analysing 'ERqsAC' on 'PLoTSQ'
#
# Analysing 'eTHelb' on 'PLoTSQ'
#
# Analysing 'ETk4XI' on 'PLoTSQ'
#
# Analysing 'ETlYUB' on 'PLoTSQ'
#
# Analysing 'ETUETJ' on 'PLoTSQ'
#
# Analysing 'EtWRX4' on 'PLoTSQ'
#
# Analysing 'eUp2vr' on 'PLoTSQ'
#
# Analysing 'EV85mm' on 'PLoTSQ'
#
# Analysing 'EVnU4i' on 'PLoTSQ'
#
# Analysing 'EwJSxd' on 'PLoTSQ'
#
# Analysing 'ex6www' on 'PLoTSQ'
#
# Analysing 'eXBgXn' on 'PLoTSQ'
#
# Analysing 'eyCOzl' on 'PLoTSQ'
#
# Analysing 'eZD09K' on 'PLoTSQ'
#
# Analysing 'EZtKkY' on 'PLoTSQ'
#
# Analysing 'f0BUjj' on 'PLoTSQ'
#
# Analysing 'F0QCQ3' on 'PLoTSQ'
#
# Analysing 'f83zKU' on 'PLoTSQ'
#
# Analysing 'F8c53B' on 'PLoTSQ'
#
# Analysing 'f8QtJT' on 'PLoTSQ'
#
# Analysing 'f9fNUB' on 'PLoTSQ'
#
# Analysing 'F9jRf0' on 'PLoTSQ'
#
# Analysing 'Fa3XFz' on 'PLoTSQ'
#
# Analysing 'FAEizE' on 'PLoTSQ'
#
# Analysing 'faiBMZ' on 'PLoTSQ'
#
# Analysing 'FAJJhg' on 'PLoTSQ'
#
# Analysing 'faqhET' on 'PLoTSQ'
#
# Analysing 'FarNqE' on 'PLoTSQ'
#
# Analysing 'FBt3fZ' on 'PLoTSQ'
#
# Analysing 'FBtVJ7' on 'PLoTSQ'
#
# Analysing 'FBWmOp' on 'PLoTSQ'
#
# Analysing 'fCcjca' on 'PLoTSQ'
#
# Analysing 'FcNdrr' on 'PLoTSQ'
#
# Analysing 'FCPijG' on 'PLoTSQ'
#
# Analysing 'FCsYGG' on 'PLoTSQ'
#
# Analysing 'fDeAz6' on 'PLoTSQ'
#
# Analysing 'feWbgF' on 'PLoTSQ'
#
# Analysing 'FfHf0e' on 'PLoTSQ'
#
# Analysing 'ffPU2w' on 'PLoTSQ'
#
# Analysing 'FfVxYe' on 'PLoTSQ'
#
# Analysing 'FGuy9x' on 'PLoTSQ'
#
# Analysing 'fHSWGg' on 'PLoTSQ'
#
# Analysing 'FISBmm' on 'PLoTSQ'
#
# Analysing 'fIxcRa' on 'PLoTSQ'
#
# Analysing 'Fj2DmE' on 'PLoTSQ'
#
# Analysing 'FJDsgL' on 'PLoTSQ'
#
# Analysing 'fJHh4k' on 'PLoTSQ'
#
# Analysing 'FK5Ccc' on 'PLoTSQ'
#
# Analysing 'fM3Fxc' on 'PLoTSQ'
#
# Analysing 'fm973x' on 'PLoTSQ'
#
# Analysing 'FMc8FH' on 'PLoTSQ'
#
# Analysing 'fMs83b' on 'PLoTSQ'
#
# Analysing 'fMYTjL' on 'PLoTSQ'
#
# Analysing 'FnhD9x' on 'PLoTSQ'
#
# Analysing 'FNliVc' on 'PLoTSQ'
#
# Analysing 'fnNwWs' on 'PLoTSQ'
#
# Analysing 'fo4L4d' on 'PLoTSQ'
#
# Analysing 'fopBrm' on 'PLoTSQ'
#
# Analysing 'FoQicc' on 'PLoTSQ'
#
# Analysing 'FpdZCI' on 'PLoTSQ'
#
# Analysing 'fpoUXg' on 'PLoTSQ'
#
# Analysing 'FS4oDW' on 'PLoTSQ'
#
# Analysing 'FsHUf0' on 'PLoTSQ'
#
# Analysing 'ftt0dF' on 'PLoTSQ'
#
# Analysing 'FuFqZo' on 'PLoTSQ'
#
# Analysing 'FUQFGN' on 'PLoTSQ'
#
# Analysing 'fuQUbK' on 'PLoTSQ'
#
# Analysing 'FWapPV' on 'PLoTSQ'
#
# Analysing 'fwj3YF' on 'PLoTSQ'
#
# Analysing 'FWjngg' on 'PLoTSQ'
#
# Analysing 'FWToxk' on 'PLoTSQ'
#
# Analysing 'FxE55l' on 'PLoTSQ'
#
# Analysing 'fXeG3h' on 'PLoTSQ'
#
# Analysing 'fXqelB' on 'PLoTSQ'
#
# Analysing 'fxzQGX' on 'PLoTSQ'
#
# Analysing 'Fy5YaQ' on 'PLoTSQ'
#
# Analysing 'fzLdpy' on 'PLoTSQ'
#
# Analysing 'g0BJLf' on 'PLoTSQ'
#
# Analysing 'g0bxQk' on 'PLoTSQ'
#
# Analysing 'G1ujjP' on 'PLoTSQ'
#
# Analysing 'g2shHC' on 'PLoTSQ'
#
# Analysing 'G3N1PY' on 'PLoTSQ'
#
# Analysing 'g46I0v' on 'PLoTSQ'
#
# Analysing 'g4hAIY' on 'PLoTSQ'
#
# Analysing 'g548tf' on 'PLoTSQ'
#
# Analysing 'g7wSGO' on 'PLoTSQ'
#
# Analysing 'g7wYoa' on 'PLoTSQ'
#
# Analysing 'G8YQCG' on 'PLoTSQ'
#
# Analysing 'g9bJm9' on 'PLoTSQ'
#
# Analysing 'g9gsPq' on 'PLoTSQ'
#
# Analysing 'Ga47ud' on 'PLoTSQ'
#
# Analysing 'gANXmT' on 'PLoTSQ'
#
# Analysing 'GAPcba' on 'PLoTSQ'
#
# Analysing 'gAV6Au' on 'PLoTSQ'
#
# Analysing 'GaVrbW' on 'PLoTSQ'
#
# Analysing 'gD2Jbm' on 'PLoTSQ'
#
# Analysing 'gF55Vv' on 'PLoTSQ'
#
# Analysing 'gFSiVR' on 'PLoTSQ'
#
# Analysing 'gh1mqj' on 'PLoTSQ'
#
# Analysing 'GHJAw9' on 'PLoTSQ'
#
# Analysing 'ghsr9q' on 'PLoTSQ'
#
# Analysing 'gI3NHx' on 'PLoTSQ'
#
# Analysing 'gImeQo' on 'PLoTSQ'
#
# Analysing 'gjCqJh' on 'PLoTSQ'
#
# Analysing 'GjMlUA' on 'PLoTSQ'
#
# Analysing 'Gkbk3z' on 'PLoTSQ'
#
# Analysing 'Gkd4Rh' on 'PLoTSQ'
#
# Analysing 'Gl4usQ' on 'PLoTSQ'
#
# Analysing 'gLhz1z' on 'PLoTSQ'
#
# Analysing 'GlM00J' on 'PLoTSQ'
#
# Analysing 'gMZcIX' on 'PLoTSQ'
#
# Analysing 'gnCrKI' on 'PLoTSQ'
#
# Analysing 'go7DnQ' on 'PLoTSQ'
#
# Analysing 'gohTqy' on 'PLoTSQ'
#
# Analysing 'GpHmzO' on 'PLoTSQ'
#
# Analysing 'gPMXzH' on 'PLoTSQ'
#
# Analysing 'gQAdds' on 'PLoTSQ'
#
# Analysing 'GR4T2M' on 'PLoTSQ'
#
# Analysing 'grcjIh' on 'PLoTSQ'
#
# Analysing 'gRutjj' on 'PLoTSQ'
#
# Analysing 'GSnrHq' on 'PLoTSQ'
#
# Analysing 'gtgKK4' on 'PLoTSQ'
#
# Analysing 'gTHdt7' on 'PLoTSQ'
#
# Analysing 'gtqeHE' on 'PLoTSQ'
#
# Analysing 'GTyfj7' on 'PLoTSQ'
#
# Analysing 'GUiffj' on 'PLoTSQ'
#
# Analysing 'GutzhP' on 'PLoTSQ'
#
# Analysing 'gUvWlF' on 'PLoTSQ'
#
# Analysing 'GVE4dT' on 'PLoTSQ'
#
# Analysing 'GVfeRZ' on 'PLoTSQ'
#
# Analysing 'gVyQfu' on 'PLoTSQ'
#
# Analysing 'gwI1LH' on 'PLoTSQ'
#
# Analysing 'GWYFhW' on 'PLoTSQ'
#
# Analysing 'GY1LXs' on 'PLoTSQ'
#
# Analysing 'Gyeqen' on 'PLoTSQ'
#
# Analysing 'H0zfXS' on 'PLoTSQ'
#
# Analysing 'H2DCRt' on 'PLoTSQ'
#
# Analysing 'H4E5hc' on 'PLoTSQ'
#
# Analysing 'H4kHeZ' on 'PLoTSQ'
#
# Analysing 'h4wAcs' on 'PLoTSQ'
#
# Analysing 'H4yOuX' on 'PLoTSQ'
#
# Analysing 'H55Pcd' on 'PLoTSQ'
#
# Analysing 'h5IaqD' on 'PLoTSQ'
#
# Analysing 'H6ymze' on 'PLoTSQ'
#
# Analysing 'H7w51Y' on 'PLoTSQ'
#
# Analysing 'h8Wgcs' on 'PLoTSQ'
#
# Analysing 'hAMyKh' on 'PLoTSQ'
#
# Analysing 'hAy5NO' on 'PLoTSQ'
#
# Analysing 'HB1jUZ' on 'PLoTSQ'
#
# Analysing 'HBtFzV' on 'PLoTSQ'
#
# Analysing 'hCaVU8' on 'PLoTSQ'
#
# Analysing 'hDTvAf' on 'PLoTSQ'
#
# Analysing 'hECw6j' on 'PLoTSQ'
#
# Analysing 'HffE5T' on 'PLoTSQ'
#
# Analysing 'HFLOOD' on 'PLoTSQ'
#
# Analysing 'Hfo8IY' on 'PLoTSQ'
#
# Analysing 'HGN7CO' on 'PLoTSQ'
#
# Analysing 'hhQJ9p' on 'PLoTSQ'
#
# Analysing 'HHuugr' on 'PLoTSQ'
#
# Analysing 'hIC7Vs' on 'PLoTSQ'
#
# Analysing 'hj1M6s' on 'PLoTSQ'
#
# Analysing 'Hjab34' on 'PLoTSQ'
#
# Analysing 'hKFLND' on 'PLoTSQ'
#
# Analysing 'HkodEy' on 'PLoTSQ'
#
# Analysing 'hM260K' on 'PLoTSQ'
#
# Analysing 'hM3HoO' on 'PLoTSQ'
#
# Analysing 'HmA7Vk' on 'PLoTSQ'
#
# Analysing 'hMgsx8' on 'PLoTSQ'
#
# Analysing 'HN2WRz' on 'PLoTSQ'
#
# Analysing 'hNcLoe' on 'PLoTSQ'
#
# Analysing 'HNEgtA' on 'PLoTSQ'
#
# Analysing 'HNzQI1' on 'PLoTSQ'
#
# Analysing 'hO0xwH' on 'PLoTSQ'
#
# Analysing 'hpuGSX' on 'PLoTSQ'
#
# Analysing 'hq39tI' on 'PLoTSQ'
#
# Analysing 'HqMtqJ' on 'PLoTSQ'
#
# Analysing 'hqqAqL' on 'PLoTSQ'
#
# Analysing 'hR8LXw' on 'PLoTSQ'
#
# Analysing 'hSeNXR' on 'PLoTSQ'
#
# Analysing 'hsNGLN' on 'PLoTSQ'
#
# Analysing 'hSy9JB' on 'PLoTSQ'
#
# Analysing 'HSZeAx' on 'PLoTSQ'
#
# Analysing 'hSZuDr' on 'PLoTSQ'
#
# Analysing 'htOtj4' on 'PLoTSQ'
#
# Analysing 'hULbOv' on 'PLoTSQ'
#
# Analysing 'HvdgeC' on 'PLoTSQ'
#
# Analysing 'hVhBvj' on 'PLoTSQ'
#
# Analysing 'hVT3BL' on 'PLoTSQ'
#
# Analysing 'HwPQ1G' on 'PLoTSQ'
#
# Analysing 'Hxi4Aj' on 'PLoTSQ'
#
# Analysing 'HxPiBy' on 'PLoTSQ'
#
# Analysing 'HXvJ7h' on 'PLoTSQ'
#
# Analysing 'hYEDj2' on 'PLoTSQ'
#
# Analysing 'HYviYN' on 'PLoTSQ'
#
# Analysing 'HzQ2VA' on 'PLoTSQ'
#
# Analysing 'I11sIU' on 'PLoTSQ'
#
# Analysing 'I1mrRi' on 'PLoTSQ'
#
# Analysing 'I20WwX' on 'PLoTSQ'
#
# Analysing 'I2a6YL' on 'PLoTSQ'
#
# Analysing 'i2DZzf' on 'PLoTSQ'
#
# Analysing 'i2eRuM' on 'PLoTSQ'
#
# Analysing 'I2o4EG' on 'PLoTSQ'
#
# Analysing 'I5afYY' on 'PLoTSQ'
#
# Analysing 'I697kF' on 'PLoTSQ'
#
# Analysing 'I6AWwL' on 'PLoTSQ'
#
# Analysing 'I7ygqa' on 'PLoTSQ'
#
# Analysing 'i8Dnlq' on 'PLoTSQ'
#
# Analysing 'i8PJx5' on 'PLoTSQ'
#
# Analysing 'i9jphF' on 'PLoTSQ'
#
# Analysing 'iaKaLX' on 'PLoTSQ'
#
# Analysing 'IAMJx5' on 'PLoTSQ'
#
# Analysing 'IB7Sxp' on 'PLoTSQ'
#
# Analysing 'IbEAbv' on 'PLoTSQ'
#
# Analysing 'IcATbB' on 'PLoTSQ'
#
# Analysing 'iDgohi' on 'PLoTSQ'
#
# Analysing 'IduuvH' on 'PLoTSQ'
#
# Analysing 'idVFUh' on 'PLoTSQ'
#
# Analysing 'iDZ8US' on 'PLoTSQ'
#
# Analysing 'IE30hK' on 'PLoTSQ'
#
# Analysing 'ieBnmr' on 'PLoTSQ'
#
# Analysing 'ieUbzF' on 'PLoTSQ'
#
# Analysing 'iexsqA' on 'PLoTSQ'
#
# Analysing 'IfGOLy' on 'PLoTSQ'
#
# Analysing 'ifTQSn' on 'PLoTSQ'
#
# Analysing 'Ig1JcA' on 'PLoTSQ'
#
# Analysing 'IGiQ3M' on 'PLoTSQ'
#
# Analysing 'IgS86I' on 'PLoTSQ'
#
# Analysing 'iHk1SB' on 'PLoTSQ'
#
# Analysing 'IHkBgo' on 'PLoTSQ'
#
# Analysing 'iHkzuC' on 'PLoTSQ'
#
# Analysing 'ihLlMy' on 'PLoTSQ'
#
# Analysing 'ihUaDi' on 'PLoTSQ'
#
# Analysing 'IjGwKt' on 'PLoTSQ'
#
# Analysing 'IjUHiL' on 'PLoTSQ'
#
# Analysing 'ik8N46' on 'PLoTSQ'
#
# Analysing 'ikrmVC' on 'PLoTSQ'
#
# Analysing 'ikZFpj' on 'PLoTSQ'
#
# Analysing 'ILmhmX' on 'PLoTSQ'
#
# Analysing 'IN66Ze' on 'PLoTSQ'
#
# Analysing 'InZ5yC' on 'PLoTSQ'
#
# Analysing 'iOEGcD' on 'PLoTSQ'
#
# Analysing 'iot4zl' on 'PLoTSQ'
#
# Analysing 'IOTO8W' on 'PLoTSQ'
#
# Analysing 'IOY1VY' on 'PLoTSQ'
#
# Analysing 'iPF9JT' on 'PLoTSQ'
#
# Analysing 'iPFIG1' on 'PLoTSQ'
#
# Analysing 'iPO8qY' on 'PLoTSQ'
#
# Analysing 'ipTLr0' on 'PLoTSQ'
#
# Analysing 'iqDhhC' on 'PLoTSQ'
#
# Analysing 'IrfjLC' on 'PLoTSQ'
#
# Analysing 'IRhTcN' on 'PLoTSQ'
#
# Analysing 'IS9P7y' on 'PLoTSQ'
#
# Analysing 'iSOBa3' on 'PLoTSQ'
#
# Analysing 'itltlK' on 'PLoTSQ'
#
# Analysing 'ITqWUA' on 'PLoTSQ'
#
# Analysing 'Ivb8BF' on 'PLoTSQ'
#
# Analysing 'IvsoeD' on 'PLoTSQ'
#
# Analysing 'IWixcS' on 'PLoTSQ'
#
# Analysing 'iwZnWO' on 'PLoTSQ'
#
# Analysing 'IxISQQ' on 'PLoTSQ'
#
# Analysing 'iXR6J6' on 'PLoTSQ'
#
# Analysing 'iyW9VO' on 'PLoTSQ'
#
# Analysing 'iZK3Vr' on 'PLoTSQ'
#
# Analysing 'iZyPJm' on 'PLoTSQ'
#
# Analysing 'j4hr78' on 'PLoTSQ'
#
# Analysing 'j5c6tp' on 'PLoTSQ'
#
# Analysing 'j7TCRX' on 'PLoTSQ'
#
# Analysing 'j8JKZM' on 'PLoTSQ'
#
# Analysing 'j8zd0W' on 'PLoTSQ'
#
# Analysing 'J9CCGf' on 'PLoTSQ'
#
# Analysing 'jbcorK' on 'PLoTSQ'
#
# Analysing 'JBtj7m' on 'PLoTSQ'
#
# Analysing 'jCJZwH' on 'PLoTSQ'
#
# Analysing 'jDzW2k' on 'PLoTSQ'
#
# Analysing 'JE2QBa' on 'PLoTSQ'
#
# Analysing 'JEVLBF' on 'PLoTSQ'
#
# Analysing 'JfAHbz' on 'PLoTSQ'
#
# Analysing 'jfQtzl' on 'PLoTSQ'
#
# Analysing 'jFwaWI' on 'PLoTSQ'
#
# Analysing 'jgbxkP' on 'PLoTSQ'
#
# Analysing 'jGPZys' on 'PLoTSQ'
#
# Analysing 'JH1AZG' on 'PLoTSQ'
#
# Analysing 'jHnQPS' on 'PLoTSQ'
#
# Analysing 'JiBkXD' on 'PLoTSQ'
#
# Analysing 'JiXjvm' on 'PLoTSQ'
#
# Analysing 'jJ0aNW' on 'PLoTSQ'
#
# Analysing 'JjYTlO' on 'PLoTSQ'
#
# Analysing 'jK5YWb' on 'PLoTSQ'
#
# Analysing 'JKbouG' on 'PLoTSQ'
#
# Analysing 'Jl81M0' on 'PLoTSQ'
#
# Analysing 'jLe3v2' on 'PLoTSQ'
#
# Analysing 'JLiAMe' on 'PLoTSQ'
#
# Analysing 'JltWeG' on 'PLoTSQ'
#
# Analysing 'jLxtMO' on 'PLoTSQ'
#
# Analysing 'jmBBvx' on 'PLoTSQ'
#
# Analysing 'jN5Tp2' on 'PLoTSQ'
#
# Analysing 'jn6UUO' on 'PLoTSQ'
#
# Analysing 'JNCJ8K' on 'PLoTSQ'
#
# Analysing 'jNuUNf' on 'PLoTSQ'
#
# Analysing 'JOerAJ' on 'PLoTSQ'
#
# Analysing 'JpCE2v' on 'PLoTSQ'
#
# Analysing 'jqA4Ob' on 'PLoTSQ'
#
# Analysing 'JQrFLU' on 'PLoTSQ'
#
# Analysing 'Jr8qT8' on 'PLoTSQ'
#
# Analysing 'Jrm9uZ' on 'PLoTSQ'
#
# Analysing 'jSONy7' on 'PLoTSQ'
#
# Analysing 'JSRO3N' on 'PLoTSQ'
#
# Analysing 'JSvtBL' on 'PLoTSQ'
#
# Analysing 'jt302L' on 'PLoTSQ'
#
# Analysing 'jT35NP' on 'PLoTSQ'
#
# Analysing 'JtQ6eC' on 'PLoTSQ'
#
# Analysing 'JU1m50' on 'PLoTSQ'
#
# Analysing 'jU3aul' on 'PLoTSQ'
#
# Analysing 'jUxjmd' on 'PLoTSQ'
#
# Analysing 'jVpaOU' on 'PLoTSQ'
#
# Analysing 'JW69ia' on 'PLoTSQ'
#
# Analysing 'jWlFIK' on 'PLoTSQ'
#
# Analysing 'JWU0He' on 'PLoTSQ'
#
# Analysing 'jX06dZ' on 'PLoTSQ'
#
# Analysing 'JXBEGq' on 'PLoTSQ'
#
# Analysing 'jxZorL' on 'PLoTSQ'
#
# Analysing 'JYZn6E' on 'PLoTSQ'
#
# Analysing 'k0oVUn' on 'PLoTSQ'
#
# Analysing 'k0VsTs' on 'PLoTSQ'
#
# Analysing 'k19XGv' on 'PLoTSQ'
#
# Analysing 'K2vdzY' on 'PLoTSQ'
#
# Analysing 'K3lqMM' on 'PLoTSQ'
#
# Analysing 'K3P2Dg' on 'PLoTSQ'
#
# Analysing 'k7gmXf' on 'PLoTSQ'
#
# Analysing 'K9B0lS' on 'PLoTSQ'
#
# Analysing 'k9yQRN' on 'PLoTSQ'
#
# Analysing 'kAHiW9' on 'PLoTSQ'
#
# Analysing 'Kbtoae' on 'PLoTSQ'
#
# Analysing 'kBYCFu' on 'PLoTSQ'
#
# Analysing 'kcKaZm' on 'PLoTSQ'
#
# Analysing 'KcO8Hf' on 'PLoTSQ'
#
# Analysing 'kcohnx' on 'PLoTSQ'
#
# Analysing 'KF1d7g' on 'PLoTSQ'
#
# Analysing 'kf7l6r' on 'PLoTSQ'
#
# Analysing 'KGNpGd' on 'PLoTSQ'
#
# Analysing 'KGoWvQ' on 'PLoTSQ'
#
# Analysing 'kgWzVK' on 'PLoTSQ'
#
# Analysing 'KhI3SR' on 'PLoTSQ'
#
# Analysing 'KhJ51n' on 'PLoTSQ'
#
# Analysing 'KhU2rq' on 'PLoTSQ'
#
# Analysing 'kinL9V' on 'PLoTSQ'
#
# Analysing 'kJiKVE' on 'PLoTSQ'
#
# Analysing 'KjUcY5' on 'PLoTSQ'
#
# Analysing 'kKkqHH' on 'PLoTSQ'
#
# Analysing 'kKxbI5' on 'PLoTSQ'
#
# Analysing 'Kldcqm' on 'PLoTSQ'
#
# Analysing 'kLFTSz' on 'PLoTSQ'
#
# Analysing 'KmLeFN' on 'PLoTSQ'
#
# Analysing 'kmOjMn' on 'PLoTSQ'
#
# Analysing 'kMorVU' on 'PLoTSQ'
#
# Analysing 'kmwOFA' on 'PLoTSQ'
#
# Analysing 'KnmAiu' on 'PLoTSQ'
#
# Analysing 'KnnaDi' on 'PLoTSQ'
#
# Analysing 'KnWltg' on 'PLoTSQ'
#
# Analysing 'KnXVIB' on 'PLoTSQ'
#
# Analysing 'kOgbyP' on 'PLoTSQ'
#
# Analysing 'korAAj' on 'PLoTSQ'
#
# Analysing 'KoWAcc' on 'PLoTSQ'
#
# Analysing 'kpbaKS' on 'PLoTSQ'
#
# Analysing 'KPgIIf' on 'PLoTSQ'
#
# Analysing 'kPkKz1' on 'PLoTSQ'
#
# Analysing 'KPn5Ar' on 'PLoTSQ'
#
# Analysing 'kpwrxk' on 'PLoTSQ'
#
# Analysing 'Kq0WjF' on 'PLoTSQ'
#
# Analysing 'krKZS7' on 'PLoTSQ'
#
# Analysing 'ktpgPw' on 'PLoTSQ'
#
# Analysing 'KUoKFf' on 'PLoTSQ'
#
# Analysing 'KUolTX' on 'PLoTSQ'
#
# Analysing 'kUwNyP' on 'PLoTSQ'
#
# Analysing 'kVI5HQ' on 'PLoTSQ'
#
# Analysing 'KVKp48' on 'PLoTSQ'
#
# Analysing 'KvoBfj' on 'PLoTSQ'
#
# Analysing 'Kw6B7Z' on 'PLoTSQ'
#
# Analysing 'kWSJ9n' on 'PLoTSQ'
#
# Analysing 'Kx8KAD' on 'PLoTSQ'
#
# Analysing 'KxiMoE' on 'PLoTSQ'
#
# Analysing 'KXPr8H' on 'PLoTSQ'
#
# Analysing 'l0DrBX' on 'PLoTSQ'
#
# Analysing 'L0EwfP' on 'PLoTSQ'
#
# Analysing 'L0SmDa' on 'PLoTSQ'
#
# Analysing 'l1YLek' on 'PLoTSQ'
#
# Analysing 'L233qR' on 'PLoTSQ'
#
# Analysing 'l2KpX1' on 'PLoTSQ'
#
# Analysing 'l2WcZI' on 'PLoTSQ'
#
# Analysing 'L3asYh' on 'PLoTSQ'
#
# Analysing 'L3ylbB' on 'PLoTSQ'
#
# Analysing 'L3ylLh' on 'PLoTSQ'
#
# Analysing 'l4VUyt' on 'PLoTSQ'
#
# Analysing 'l5mOza' on 'PLoTSQ'
#
# Analysing 'l5UrJF' on 'PLoTSQ'
#
# Analysing 'l5wsBD' on 'PLoTSQ'
#
# Analysing 'l6RLve' on 'PLoTSQ'
#
# Analysing 'l7icdg' on 'PLoTSQ'
#
# Analysing 'LbFYmx' on 'PLoTSQ'
#
# Analysing 'lc7TYa' on 'PLoTSQ'
#
# Analysing 'lcvX1w' on 'PLoTSQ'
#
# Analysing 'lcYAw3' on 'PLoTSQ'
#
# Analysing 'Ld8OJf' on 'PLoTSQ'
#
# Analysing 'LDaBMG' on 'PLoTSQ'
#
# Analysing 'LDAnCS' on 'PLoTSQ'
#
# Analysing 'LdOJ9B' on 'PLoTSQ'
#
# Analysing 'LDSa6r' on 'PLoTSQ'
#
# Analysing 'lEigjY' on 'PLoTSQ'
#
# Analysing 'LeIOpp' on 'PLoTSQ'
#
# Analysing 'LEVkLl' on 'PLoTSQ'
#
# Analysing 'lEYx2W' on 'PLoTSQ'
#
# Analysing 'LF5IXe' on 'PLoTSQ'
#
# Analysing 'lffOPx' on 'PLoTSQ'
#
# Analysing 'LfR4mn' on 'PLoTSQ'
#
# Analysing 'lGnap8' on 'PLoTSQ'
#
# Analysing 'lHTd7l' on 'PLoTSQ'
#
# Analysing 'liuUub' on 'PLoTSQ'
#
# Analysing 'lJ42bV' on 'PLoTSQ'
#
# Analysing 'ljABh9' on 'PLoTSQ'
#
# Analysing 'lJimSa' on 'PLoTSQ'
#
# Analysing 'LjOW0h' on 'PLoTSQ'
#
# Analysing 'lJSglM' on 'PLoTSQ'
#
# Analysing 'LkCXd0' on 'PLoTSQ'
#
# Analysing 'lL2KP9' on 'PLoTSQ'
#
# Analysing 'LLbYs4' on 'PLoTSQ'
#
# Analysing 'LlQZUD' on 'PLoTSQ'
#
# Analysing 'lN3qp7' on 'PLoTSQ'
#
# Analysing 'lNMxgb' on 'PLoTSQ'
#
# Analysing 'lNpI5e' on 'PLoTSQ'
#
# Analysing 'lnRXdv' on 'PLoTSQ'
#
# Analysing 'lNxnHz' on 'PLoTSQ'
#
# Analysing 'LO6GjJ' on 'PLoTSQ'
#
# Analysing 'LPU6aU' on 'PLoTSQ'
#
# Analysing 'lq3sQq' on 'PLoTSQ'
#
# Analysing 'lqDeoY' on 'PLoTSQ'
#
# Analysing 'LqfyRb' on 'PLoTSQ'
#
# Analysing 'Lr6QEU' on 'PLoTSQ'
#
# Analysing 'lrAqbA' on 'PLoTSQ'
#
# Analysing 'lRDFO9' on 'PLoTSQ'
#
# Analysing 'LSjdg5' on 'PLoTSQ'
#
# Analysing 'LsZ8Kx' on 'PLoTSQ'
#
# Analysing 'lTckH1' on 'PLoTSQ'
#
# Analysing 'ltfZOr' on 'PLoTSQ'
#
# Analysing 'ltGw8F' on 'PLoTSQ'
#
# Analysing 'LTJQT2' on 'PLoTSQ'
#
# Analysing 'Ltu1EI' on 'PLoTSQ'
#
# Analysing 'lu2XCm' on 'PLoTSQ'
#
# Analysing 'lVPyon' on 'PLoTSQ'
#
# Analysing 'LWuoPF' on 'PLoTSQ'
#
# Analysing 'LWWGrk' on 'PLoTSQ'
#
# Analysing 'lxYc8T' on 'PLoTSQ'
#
# Analysing 'LYQWOW' on 'PLoTSQ'
#
# Analysing 'lyREd3' on 'PLoTSQ'
#
# Analysing 'lZaXba' on 'PLoTSQ'
#
# Analysing 'LZazv8' on 'PLoTSQ'
#
# Analysing 'lzJTR8' on 'PLoTSQ'
#
# Analysing 'LZTkrj' on 'PLoTSQ'
#
# Analysing 'm0RoAg' on 'PLoTSQ'
#
# Analysing 'M3jLmP' on 'PLoTSQ'
#
# Analysing 'M46El7' on 'PLoTSQ'
#
# Analysing 'm49fzx' on 'PLoTSQ'
#
# Analysing 'M4XfVa' on 'PLoTSQ'
#
# Analysing 'M5iBzh' on 'PLoTSQ'
#
# Analysing 'm5wsEy' on 'PLoTSQ'
#
# Analysing 'M7haz4' on 'PLoTSQ'
#
# Analysing 'M9n4TY' on 'PLoTSQ'
#
# Analysing 'mahnjI' on 'PLoTSQ'
#
# Analysing 'mALHhr' on 'PLoTSQ'
#
# Analysing 'MARyLu' on 'PLoTSQ'
#
# Analysing 'maxQhc' on 'PLoTSQ'
#
# Analysing 'mB057h' on 'PLoTSQ'
#
# Analysing 'mB4Jtb' on 'PLoTSQ'
#
# Analysing 'mb6cCi' on 'PLoTSQ'
#
# Analysing 'mBc1a8' on 'PLoTSQ'
#
# Analysing 'MBCHjx' on 'PLoTSQ'
#
# Analysing 'MbfeoU' on 'PLoTSQ'
#
# Analysing 'MbLKGi' on 'PLoTSQ'
#
# Analysing 'mbnksR' on 'PLoTSQ'
#
# Analysing 'mBpoMh' on 'PLoTSQ'
#
# Analysing 'MBWHqJ' on 'PLoTSQ'
#
# Analysing 'Mc57gc' on 'PLoTSQ'
#
# Analysing 'mCcdNM' on 'PLoTSQ'
#
# Analysing 'mckfMB' on 'PLoTSQ'
#
# Analysing 'mCRetA' on 'PLoTSQ'
#
# Analysing 'mcSSUR' on 'PLoTSQ'
#
# Analysing 'McUt1p' on 'PLoTSQ'
#
# Analysing 'Md4jQB' on 'PLoTSQ'
#
# Analysing 'MdaCSG' on 'PLoTSQ'
#
# Analysing 'mdu87y' on 'PLoTSQ'
#
# Analysing 'mDUWDd' on 'PLoTSQ'
#
# Analysing 'MEbz6W' on 'PLoTSQ'
#
# Analysing 'mFAhLf' on 'PLoTSQ'
#
# Analysing 'mFXBN0' on 'PLoTSQ'
#
# Analysing 'MG3PtL' on 'PLoTSQ'
#
# Analysing 'mG5T8P' on 'PLoTSQ'
#
# Analysing 'mGy0rn' on 'PLoTSQ'
#
# Analysing 'Mhx6cb' on 'PLoTSQ'
#
# Analysing 'Mi4AdG' on 'PLoTSQ'
#
# Analysing 'MI7WFg' on 'PLoTSQ'
#
# Analysing 'MICy89' on 'PLoTSQ'
#
# Analysing 'MIPIPI' on 'PLoTSQ'
#
# Analysing 'miZgXT' on 'PLoTSQ'
#
# Analysing 'mj5XnV' on 'PLoTSQ'
#
# Analysing 'mKOYE7' on 'PLoTSQ'
#
# Analysing 'MKVEuQ' on 'PLoTSQ'
#
# Analysing 'MKY0Wr' on 'PLoTSQ'
#
# Analysing 'mLVq5X' on 'PLoTSQ'
#
# Analysing 'mM86hy' on 'PLoTSQ'
#
# Analysing 'mNGzG4' on 'PLoTSQ'
#
# Analysing 'mnMjyE' on 'PLoTSQ'
#
# Analysing 'mo834B' on 'PLoTSQ'
#
# Analysing 'MoAwNY' on 'PLoTSQ'
#
# Analysing 'mOC3Q8' on 'PLoTSQ'
#
# Analysing 'mp9Df3' on 'PLoTSQ'
#
# Analysing 'mpbqxS' on 'PLoTSQ'
#
# Analysing 'MpCqbe' on 'PLoTSQ'
#
# Analysing 'mPovEK' on 'PLoTSQ'
#
# Analysing 'mpTgWC' on 'PLoTSQ'
#
# Analysing 'MqiYhM' on 'PLoTSQ'
#
# Analysing 'mqtpED' on 'PLoTSQ'
#
# Analysing 'MRuXmO' on 'PLoTSQ'
#
# Analysing 'MSSTJt' on 'PLoTSQ'
#
# Analysing 'MT8EOU' on 'PLoTSQ'
#
# Analysing 'mtA4ic' on 'PLoTSQ'
#
# Analysing 'Mtt3QD' on 'PLoTSQ'
#
# Analysing 'MuRG9Y' on 'PLoTSQ'
#
# Analysing 'MusRmW' on 'PLoTSQ'
#
# Analysing 'MUSW36' on 'PLoTSQ'
#
# Analysing 'MV9hH2' on 'PLoTSQ'
#
# Analysing 'MVHttk' on 'PLoTSQ'
#
# Analysing 'mvqGvG' on 'PLoTSQ'
#
# Analysing 'mWEQ51' on 'PLoTSQ'
#
# Analysing 'MwTM6O' on 'PLoTSQ'
#
# Analysing 'mWxL0e' on 'PLoTSQ'
#
# Analysing 'mxghOQ' on 'PLoTSQ'
#
# Analysing 'MypK3o' on 'PLoTSQ'
#
# Analysing 'MyuaNa' on 'PLoTSQ'
#
# Analysing 'mZ4AlA' on 'PLoTSQ'
#
# Analysing 'n35Rx1' on 'PLoTSQ'
#
# Analysing 'N3fowT' on 'PLoTSQ'
#
# Analysing 'N3had1' on 'PLoTSQ'
#
# Analysing 'N4Guhg' on 'PLoTSQ'
#
# Analysing 'N4uWHS' on 'PLoTSQ'
#
# Analysing 'n5B63a' on 'PLoTSQ'
#
# Analysing 'N7cIDR' on 'PLoTSQ'
#
# Analysing 'n8pzs6' on 'PLoTSQ'
#
# Analysing 'n9GYuG' on 'PLoTSQ'
#
# Analysing 'NAfULe' on 'PLoTSQ'
#
# Analysing 'NASbd5' on 'PLoTSQ'
#
# Analysing 'NBhNQx' on 'PLoTSQ'
#
# Analysing 'NbUamy' on 'PLoTSQ'
#
# Analysing 'NC8wtu' on 'PLoTSQ'
#
# Analysing 'ncNWVa' on 'PLoTSQ'
#
# Analysing 'NCVZVo' on 'PLoTSQ'
#
# Analysing 'nDVE3o' on 'PLoTSQ'
#
# Analysing 'NEnAR0' on 'PLoTSQ'
#
# Analysing 'nETOMT' on 'PLoTSQ'
#
# Analysing 'nf20M2' on 'PLoTSQ'
#
# Analysing 'nh4opt' on 'PLoTSQ'
#
# Analysing 'Nh5KQc' on 'PLoTSQ'
#
# Analysing 'nhdSSK' on 'PLoTSQ'
#
# Analysing 'NiceDQ' on 'PLoTSQ'
#
# Analysing 'nin4US' on 'PLoTSQ'
#
# Analysing 'niXefp' on 'PLoTSQ'
#
# Analysing 'NJaceY' on 'PLoTSQ'
#
# Analysing 'NkYZqH' on 'PLoTSQ'
#
# Analysing 'nLjSdQ' on 'PLoTSQ'
#
# Analysing 'NLY9su' on 'PLoTSQ'
#
# Analysing 'NMFILw' on 'PLoTSQ'
#
# Analysing 'nnd2U3' on 'PLoTSQ'
#
# Analysing 'NNjC5G' on 'PLoTSQ'
#
# Analysing 'nOrOuI' on 'PLoTSQ'
#
# Analysing 'npdP2h' on 'PLoTSQ'
#
# Analysing 'NpkX7q' on 'PLoTSQ'
#
# Analysing 'NpvUkZ' on 'PLoTSQ'
#
# Analysing 'NqdBYh' on 'PLoTSQ'
#
# Analysing 'nS1fg1' on 'PLoTSQ'
#
# Analysing 'nSHUil' on 'PLoTSQ'
#
# Analysing 'NsI4ok' on 'PLoTSQ'
#
# Analysing 'nSKMSG' on 'PLoTSQ'
#
# Analysing 'NTqYew' on 'PLoTSQ'
#
# Analysing 'NtY5mX' on 'PLoTSQ'
#
# Analysing 'Nujmno' on 'PLoTSQ'
#
# Analysing 'NVVyzX' on 'PLoTSQ'
#
# Analysing 'NxAJeZ' on 'PLoTSQ'
#
# Analysing 'nXeinv' on 'PLoTSQ'
#
# Analysing 'nY8cUo' on 'PLoTSQ'
#
# Analysing 'nYbhX5' on 'PLoTSQ'
#
# Analysing 'NyIiSo' on 'PLoTSQ'
#
# Analysing 'NYoDB5' on 'PLoTSQ'
#
# Analysing 'nyZX9U' on 'PLoTSQ'
#
# Analysing 'nz63RY' on 'PLoTSQ'
#
# Analysing 'nZd4dE' on 'PLoTSQ'
#
# Analysing 'nZJB2m' on 'PLoTSQ'
#
# Analysing 'NZLwQA' on 'PLoTSQ'
#
# Analysing 'nZpHck' on 'PLoTSQ'
#
# Analysing 'NZRjAB' on 'PLoTSQ'
#
# Analysing 'NzTFZ3' on 'PLoTSQ'
#
# Analysing 'o0KoZW' on 'PLoTSQ'
#
# Analysing 'o14FrP' on 'PLoTSQ'
#
# Analysing 'o1hq2d' on 'PLoTSQ'
#
# Analysing 'o2OSkx' on 'PLoTSQ'
#
# Analysing 'O3dLJF' on 'PLoTSQ'
#
# Analysing 'o3SEF2' on 'PLoTSQ'
#
# Analysing 'o4k6iL' on 'PLoTSQ'
#
# Analysing 'O5CtMU' on 'PLoTSQ'
#
# Analysing 'o5EHm4' on 'PLoTSQ'
#
# Analysing 'O6PcJF' on 'PLoTSQ'
#
# Analysing 'o7jjxk' on 'PLoTSQ'
#
# Analysing 'o8CDpn' on 'PLoTSQ'
#
# Analysing 'oaqLH8' on 'PLoTSQ'
#
# Analysing 'OAvXDK' on 'PLoTSQ'
#
# Analysing 'oBKt93' on 'PLoTSQ'
#
# Analysing 'oByxWr' on 'PLoTSQ'
#
# Analysing 'ocRUkM' on 'PLoTSQ'
#
# Analysing 'OcYjk4' on 'PLoTSQ'
#
# Analysing 'od3uIc' on 'PLoTSQ'
#
# Analysing 'Odmmb4' on 'PLoTSQ'
#
# Analysing 'oeAJQy' on 'PLoTSQ'
#
# Analysing 'OEjiab' on 'PLoTSQ'
#
# Analysing 'OEODQk' on 'PLoTSQ'
#
# Analysing 'oEqoRL' on 'PLoTSQ'
#
# Analysing 'OFgPPk' on 'PLoTSQ'
#
# Analysing 'OFGQqx' on 'PLoTSQ'
#
# Analysing 'oFWO2K' on 'PLoTSQ'
#
# Analysing 'og5tCw' on 'PLoTSQ'
#
# Analysing 'OHHevK' on 'PLoTSQ'
#
# Analysing 'OHy8OK' on 'PLoTSQ'
#
# Analysing 'OI4L1X' on 'PLoTSQ'
#
# Analysing 'oIscmS' on 'PLoTSQ'
#
# Analysing 'okEKOX' on 'PLoTSQ'
#
# Analysing 'oKyGHB' on 'PLoTSQ'
#
# Analysing 'oLBBSN' on 'PLoTSQ'
#
# Analysing 'oM0mVz' on 'PLoTSQ'
#
# Analysing 'OmApRs' on 'PLoTSQ'
#
# Analysing 'OMI4xA' on 'PLoTSQ'
#
# Analysing 'On34f3' on 'PLoTSQ'
#
# Analysing 'Onlvpc' on 'PLoTSQ'
#
# No SNPs available for MR analysis of 'oO9tkB' on 'PLoTSQ'
#
# Analysing 'oOtgc1' on 'PLoTSQ'
#
# Analysing 'OoV7bC' on 'PLoTSQ'
#
# Analysing 'Oox5dY' on 'PLoTSQ'
#
# Analysing 'oP4CgV' on 'PLoTSQ'
#
# Analysing 'oprFGq' on 'PLoTSQ'
#
# Analysing 'oQ3eG1' on 'PLoTSQ'
#
# Analysing 'oRLYZM' on 'PLoTSQ'
#
# Analysing 'orN0sW' on 'PLoTSQ'
#
# Analysing 'Os2vkv' on 'PLoTSQ'
#
# Analysing 'OSQQAV' on 'PLoTSQ'
#
# Analysing 'ot4AOG' on 'PLoTSQ'
#
# Analysing 'otAepK' on 'PLoTSQ'
#
# Analysing 'oUn5IM' on 'PLoTSQ'
#
# Analysing 'OVTic4' on 'PLoTSQ'
#
# Analysing 'OvZwBE' on 'PLoTSQ'
#
# Analysing 'owexMy' on 'PLoTSQ'
#
# Analysing 'ox2SPs' on 'PLoTSQ'
#
# Analysing 'oX9ca5' on 'PLoTSQ'
#
# Analysing 'OXGqPz' on 'PLoTSQ'
#
# Analysing 'oXgXzv' on 'PLoTSQ'
#
# Analysing 'OXJeH1' on 'PLoTSQ'
#
# Analysing 'oXLh5d' on 'PLoTSQ'
#
# Analysing 'OYGcR2' on 'PLoTSQ'
#
# Analysing 'oYubmk' on 'PLoTSQ'
#
# Analysing 'p01mnN' on 'PLoTSQ'
#
# Analysing 'p08V8O' on 'PLoTSQ'
#
# Analysing 'P2mwpn' on 'PLoTSQ'
#
# Analysing 'p5ryfp' on 'PLoTSQ'
#
# Analysing 'p6gFKy' on 'PLoTSQ'
#
# Analysing 'p6YUMA' on 'PLoTSQ'
#
# Analysing 'p9UGJm' on 'PLoTSQ'
#
# Analysing 'paAchd' on 'PLoTSQ'
#
# Analysing 'PaIdxT' on 'PLoTSQ'
#
# Analysing 'paQFbA' on 'PLoTSQ'
#
# Analysing 'pc4EVT' on 'PLoTSQ'
#
# Analysing 'PCv8dH' on 'PLoTSQ'
#
# Analysing 'pCvc0h' on 'PLoTSQ'
#
# Analysing 'Pd7Juo' on 'PLoTSQ'
#
# Analysing 'PDn9Gj' on 'PLoTSQ'
#
# Analysing 'PDSyLX' on 'PLoTSQ'
#
# Analysing 'pEvBHO' on 'PLoTSQ'
#
# Analysing 'pFasXe' on 'PLoTSQ'
#
# Analysing 'PGFUaU' on 'PLoTSQ'
#
# Analysing 'PH43Xl' on 'PLoTSQ'
#
# Analysing 'PhF62i' on 'PLoTSQ'
#
# Analysing 'PHXsUf' on 'PLoTSQ'
#
# Analysing 'PHy4vE' on 'PLoTSQ'
#
# Analysing 'PI5HGs' on 'PLoTSQ'
#
# Analysing 'Pjj8kQ' on 'PLoTSQ'
#
# Analysing 'PJsz4B' on 'PLoTSQ'
#
# Analysing 'pJUdhi' on 'PLoTSQ'
#
# Analysing 'pjxV7V' on 'PLoTSQ'
#
# Analysing 'PkkIXU' on 'PLoTSQ'
#
# Analysing 'PktAgJ' on 'PLoTSQ'
#
# Analysing 'plcnlC' on 'PLoTSQ'
#
# Analysing 'PMi2G5' on 'PLoTSQ'
#
# Analysing 'pmU15B' on 'PLoTSQ'
#
# Analysing 'PMv4eL' on 'PLoTSQ'
#
# Analysing 'PNcNNU' on 'PLoTSQ'
#
# Analysing 'PnkCaz' on 'PLoTSQ'
#
# Analysing 'PNSo2t' on 'PLoTSQ'
#
# Analysing 'pnZSUn' on 'PLoTSQ'
#
# Analysing 'Po6BFm' on 'PLoTSQ'
#
# Analysing 'poQTez' on 'PLoTSQ'
#
# Analysing 'ppGGcF' on 'PLoTSQ'
#
# Analysing 'PpxSVV' on 'PLoTSQ'
#
# Analysing 'pPZeph' on 'PLoTSQ'
#
# Analysing 'pQarDs' on 'PLoTSQ'
#
# Analysing 'pQIRXo' on 'PLoTSQ'
#
# Analysing 'PR4opd' on 'PLoTSQ'
#
# Analysing 'pre64f' on 'PLoTSQ'
#
# Analysing 'PRGgQ2' on 'PLoTSQ'
#
# Analysing 'Prk8oI' on 'PLoTSQ'
#
# Analysing 'PRMS3P' on 'PLoTSQ'
#
# Analysing 'ps4cyM' on 'PLoTSQ'
#
# Analysing 'PSxYQs' on 'PLoTSQ'
#
# Analysing 'pT7R02' on 'PLoTSQ'
#
# Analysing 'PT8lNs' on 'PLoTSQ'
#
# Analysing 'PTblyN' on 'PLoTSQ'
#
# Analysing 'pTdhee' on 'PLoTSQ'
#
# Analysing 'PTKjjt' on 'PLoTSQ'
#
# Analysing 'PUkgqn' on 'PLoTSQ'
#
# Analysing 'PVSooW' on 'PLoTSQ'
#
# Analysing 'pVWXtS' on 'PLoTSQ'
#
# Analysing 'Pvy5iC' on 'PLoTSQ'
#
# Analysing 'pW94tr' on 'PLoTSQ'
#
# Analysing 'PWdXLB' on 'PLoTSQ'
#
# Analysing 'pWe2Ob' on 'PLoTSQ'
#
# Analysing 'PwPRw4' on 'PLoTSQ'
#
# Analysing 'pWZu2O' on 'PLoTSQ'
#
# Analysing 'pxFHyH' on 'PLoTSQ'
#
# Analysing 'PXhLxX' on 'PLoTSQ'
#
# Analysing 'pY2KEz' on 'PLoTSQ'
#
# Analysing 'pz50lo' on 'PLoTSQ'
#
# Analysing 'pZbYEk' on 'PLoTSQ'
#
# Analysing 'PZC3Bg' on 'PLoTSQ'
#
# Analysing 'q0IAlI' on 'PLoTSQ'
#
# Analysing 'q0UIaM' on 'PLoTSQ'
#
# Analysing 'Q1kioD' on 'PLoTSQ'
#
# Analysing 'Q1supL' on 'PLoTSQ'
#
# Analysing 'Q2AFJw' on 'PLoTSQ'
#
# Analysing 'Q4tFib' on 'PLoTSQ'
#
# Analysing 'Q4uJh6' on 'PLoTSQ'
#
# Analysing 'Q74VTd' on 'PLoTSQ'
#
# Analysing 'Q7MjOe' on 'PLoTSQ'
#
# Analysing 'q9dp4J' on 'PLoTSQ'
#
# Analysing 'Q9hKOR' on 'PLoTSQ'
#
# Analysing 'Q9RRlH' on 'PLoTSQ'
#
# Analysing 'QaiD2E' on 'PLoTSQ'
#
# Analysing 'qB4zrt' on 'PLoTSQ'
#
# Analysing 'QBf0Qs' on 'PLoTSQ'
#
# Analysing 'QCDfxt' on 'PLoTSQ'
#
# Analysing 'QCZPj6' on 'PLoTSQ'
#
# Analysing 'qDAoaU' on 'PLoTSQ'
#
# Analysing 'qDgxiY' on 'PLoTSQ'
#
# Analysing 'QDj6hO' on 'PLoTSQ'
#
# Analysing 'qdRDu5' on 'PLoTSQ'
#
# Analysing 'QdseXZ' on 'PLoTSQ'
#
# Analysing 'qebgXO' on 'PLoTSQ'
#
# Analysing 'QeYKES' on 'PLoTSQ'
#
# Analysing 'qfDV5t' on 'PLoTSQ'
#
# Analysing 'qfhSkR' on 'PLoTSQ'
#
# Analysing 'qgHKKc' on 'PLoTSQ'
#
# Analysing 'QGYMDG' on 'PLoTSQ'
#
# Analysing 'QHNtTd' on 'PLoTSQ'
#
# Analysing 'QJB5Ad' on 'PLoTSQ'
#
# Analysing 'qjTiMb' on 'PLoTSQ'
#
# Analysing 'QKdWUG' on 'PLoTSQ'
#
# Analysing 'qkJGIP' on 'PLoTSQ'
#
# Analysing 'QKmuGe' on 'PLoTSQ'
#
# Analysing 'QlBTEh' on 'PLoTSQ'
#
# Analysing 'QLIPHB' on 'PLoTSQ'
#
# Analysing 'QLIvjM' on 'PLoTSQ'
#
# Analysing 'qlKNYQ' on 'PLoTSQ'
#
# Analysing 'QLpLtE' on 'PLoTSQ'
#
# Analysing 'qNBAS8' on 'PLoTSQ'
#
# Analysing 'QnH1v2' on 'PLoTSQ'
#
# Analysing 'QNJFrX' on 'PLoTSQ'
#
# Analysing 'qnWFtp' on 'PLoTSQ'
#
# Analysing 'qNzObu' on 'PLoTSQ'
#
# Analysing 'Qo335U' on 'PLoTSQ'
#
# Analysing 'qO6rSG' on 'PLoTSQ'
#
# Analysing 'qofKrD' on 'PLoTSQ'
#
# Analysing 'QPFZWn' on 'PLoTSQ'
#
# Analysing 'QqPBHo' on 'PLoTSQ'
#
# Analysing 'QraSuN' on 'PLoTSQ'
#
# Analysing 'QrbMme' on 'PLoTSQ'
#
# Analysing 'qsiigW' on 'PLoTSQ'
#
# Analysing 'QSPwvw' on 'PLoTSQ'
#
# Analysing 'QsqJUm' on 'PLoTSQ'
#
# Analysing 'qucBLo' on 'PLoTSQ'
#
# Analysing 'QUYmHs' on 'PLoTSQ'
#
# Analysing 'qVFTxO' on 'PLoTSQ'
#
# Analysing 'QvZszR' on 'PLoTSQ'
#
# Analysing 'qWA3C0' on 'PLoTSQ'
#
# Analysing 'QxgGrl' on 'PLoTSQ'
#
# Analysing 'qZ2QdN' on 'PLoTSQ'
#
# Analysing 'R00YbG' on 'PLoTSQ'
#
# Analysing 'r0limX' on 'PLoTSQ'
#
# Analysing 'R12Mlg' on 'PLoTSQ'
#
# Analysing 'r1D8I7' on 'PLoTSQ'
#
# Analysing 'R1gwtF' on 'PLoTSQ'
#
# Analysing 'r1RqQW' on 'PLoTSQ'
#
# Analysing 'R2xKfU' on 'PLoTSQ'
#
# Analysing 'r373Ey' on 'PLoTSQ'
#
# Analysing 'r3pkbJ' on 'PLoTSQ'
#
# Analysing 'R4qNyl' on 'PLoTSQ'
#
# Analysing 'R5cuaC' on 'PLoTSQ'
#
# Analysing 'r5QZTi' on 'PLoTSQ'
#
# Analysing 'R5Y1oD' on 'PLoTSQ'
#
# Analysing 'r5zl3o' on 'PLoTSQ'
#
# Analysing 'R64KLh' on 'PLoTSQ'
#
# Analysing 'R6zwzf' on 'PLoTSQ'
#
# Analysing 'R9Brea' on 'PLoTSQ'
#
# Analysing 'rApdt5' on 'PLoTSQ'
#
# Analysing 'RC0RtK' on 'PLoTSQ'
#
# No SNPs available for MR analysis of 'rc5woD' on 'PLoTSQ'
#
# Analysing 'RCmVxT' on 'PLoTSQ'
#
# Analysing 'rCvsYt' on 'PLoTSQ'
#
# Analysing 'rdOl6k' on 'PLoTSQ'
#
# Analysing 'rDR6sp' on 'PLoTSQ'
#
# Analysing 'rFBdzz' on 'PLoTSQ'
#
# Analysing 'RgPKLT' on 'PLoTSQ'
#
# Analysing 'rHeTZf' on 'PLoTSQ'
#
# Analysing 'ridxnW' on 'PLoTSQ'
#
# Analysing 'riW994' on 'PLoTSQ'
#
# Analysing 'rj8Vvk' on 'PLoTSQ'
#
# Analysing 'rjgJPG' on 'PLoTSQ'
#
# Analysing 'RJvDQC' on 'PLoTSQ'
#
# Analysing 'RJXvVJ' on 'PLoTSQ'
#
# Analysing 'RkaFad' on 'PLoTSQ'
#
# Analysing 'rkTRAi' on 'PLoTSQ'
#
# Analysing 'RL0f6K' on 'PLoTSQ'
#
# Analysing 'RlB4H0' on 'PLoTSQ'
#
# Analysing 'RlSR3R' on 'PLoTSQ'
#
# Analysing 'rLVf8p' on 'PLoTSQ'
#
# Analysing 'RLzSF7' on 'PLoTSQ'
#
# Analysing 'rMkcdo' on 'PLoTSQ'
#
# Analysing 'rmkPwG' on 'PLoTSQ'
#
# Analysing 'rmP2eY' on 'PLoTSQ'
#
# Analysing 'RMypcg' on 'PLoTSQ'
#
# Analysing 'RNeku5' on 'PLoTSQ'
#
# Analysing 'rnim0d' on 'PLoTSQ'
#
# Analysing 'RnYuMA' on 'PLoTSQ'
#
# Analysing 'RO61zw' on 'PLoTSQ'
#
# Analysing 'ROvz0F' on 'PLoTSQ'
#
# Analysing 'rPghmB' on 'PLoTSQ'
#
# Analysing 'RpTues' on 'PLoTSQ'
#
# Analysing 'rpXeRi' on 'PLoTSQ'
#
# Analysing 'rr4qYj' on 'PLoTSQ'
#
# Analysing 'rRZWKM' on 'PLoTSQ'
#
# Analysing 'rSF4qR' on 'PLoTSQ'
#
# Analysing 'rsMDX1' on 'PLoTSQ'
#
# Analysing 'rTG2HB' on 'PLoTSQ'
#
# Analysing 'RTUvDE' on 'PLoTSQ'
#
# Analysing 'rujYv6' on 'PLoTSQ'
#
# Analysing 'RuyTKX' on 'PLoTSQ'
#
# Analysing 'rVbENC' on 'PLoTSQ'
#
# Analysing 'rVwhLZ' on 'PLoTSQ'
#
# Analysing 'RWGr7x' on 'PLoTSQ'
#
# Analysing 'RwQkxV' on 'PLoTSQ'
#
# Analysing 'rwyZh6' on 'PLoTSQ'
#
# Analysing 'rX3eOg' on 'PLoTSQ'
#
# Analysing 'rxc1tY' on 'PLoTSQ'
#
# Analysing 'rxdVkD' on 'PLoTSQ'
#
# Analysing 'rXLo8L' on 'PLoTSQ'
#
# Analysing 'RXSLoU' on 'PLoTSQ'
#
# Analysing 'rxYOrz' on 'PLoTSQ'
#
# Analysing 'RyjjEy' on 'PLoTSQ'
#
# Analysing 'ryjycc' on 'PLoTSQ'
#
# Analysing 'ryZk7G' on 'PLoTSQ'
#
# Analysing 'RyZP7V' on 'PLoTSQ'
#
# Analysing 'rZFlOK' on 'PLoTSQ'
#
# Analysing 's09TqZ' on 'PLoTSQ'
#
# Analysing 's0IsWZ' on 'PLoTSQ'
#
# Analysing 's0qTIp' on 'PLoTSQ'
#
# Analysing 'S10DJb' on 'PLoTSQ'
#
# Analysing 's3MQUv' on 'PLoTSQ'
#
# Analysing 'S41M35' on 'PLoTSQ'
#
# Analysing 'S4GRPH' on 'PLoTSQ'
#
# Analysing 'S5PgNg' on 'PLoTSQ'
#
# Analysing 'S6V0Dk' on 'PLoTSQ'
#
# Analysing 's6VVWI' on 'PLoTSQ'
#
# Analysing 's7BetG' on 'PLoTSQ'
#
# Analysing 'S8sJIo' on 'PLoTSQ'
#
# Analysing 'SaNJTi' on 'PLoTSQ'
#
# Analysing 'sAzZpK' on 'PLoTSQ'
#
# Analysing 'sb2n02' on 'PLoTSQ'
#
# Analysing 'SBv4hK' on 'PLoTSQ'
#
# Analysing 'sc4pXE' on 'PLoTSQ'
#
# Analysing 'sCePQX' on 'PLoTSQ'
#
# Analysing 'sct1Ck' on 'PLoTSQ'
#
# Analysing 'SD9bJD' on 'PLoTSQ'
#
# Analysing 'sDDy0T' on 'PLoTSQ'
#
# Analysing 'sdSyW0' on 'PLoTSQ'
#
# Analysing 'SdWeRQ' on 'PLoTSQ'
#
# Analysing 'SeJBNa' on 'PLoTSQ'
#
# Analysing 'sEsqRU' on 'PLoTSQ'
#
# Analysing 'setK4Q' on 'PLoTSQ'
#
# Analysing 'sexWQy' on 'PLoTSQ'
#
# Analysing 'SGC9OO' on 'PLoTSQ'
#
# Analysing 'SGeqXb' on 'PLoTSQ'
#
# Analysing 'sgNgHR' on 'PLoTSQ'
#
# Analysing 'ShS6WW' on 'PLoTSQ'
#
# Analysing 'SHSwkC' on 'PLoTSQ'
#
# Analysing 'shvG4z' on 'PLoTSQ'
#
# Analysing 'sJ9uj2' on 'PLoTSQ'
#
# Analysing 'SJsrHZ' on 'PLoTSQ'
#
# Analysing 'SkAco0' on 'PLoTSQ'
#
# Analysing 'Skb3nu' on 'PLoTSQ'
#
# Analysing 'sL9o50' on 'PLoTSQ'
#
# Analysing 'SLwzdH' on 'PLoTSQ'
#
# Analysing 'SlxeiF' on 'PLoTSQ'
#
# Analysing 'SmbA6Q' on 'PLoTSQ'
#
# Analysing 'SMDD80' on 'PLoTSQ'
#
# Analysing 'SMUlCA' on 'PLoTSQ'
#
# Analysing 'sMx9P8' on 'PLoTSQ'
#
# Analysing 'sN68fZ' on 'PLoTSQ'
#
# Analysing 'SNy6Gu' on 'PLoTSQ'
#
# Analysing 'So75qJ' on 'PLoTSQ'
#
# Analysing 'sou4WW' on 'PLoTSQ'
#
# Analysing 'SPud9Z' on 'PLoTSQ'
#
# Analysing 'SqIm18' on 'PLoTSQ'
#
# Analysing 'SQvRmw' on 'PLoTSQ'
#
# Analysing 'SR8ayE' on 'PLoTSQ'
#
# Analysing 'srDStB' on 'PLoTSQ'
#
# Analysing 'SrMwrl' on 'PLoTSQ'
#
# Analysing 'srN529' on 'PLoTSQ'
#
# Analysing 'sRYPVU' on 'PLoTSQ'
#
# Analysing 'SsUUFB' on 'PLoTSQ'
#
# Analysing 'stRbtU' on 'PLoTSQ'
#
# Analysing 'SUEfUU' on 'PLoTSQ'
#
# Analysing 'SuJJPg' on 'PLoTSQ'
#
# Analysing 'sUsQ3b' on 'PLoTSQ'
#
# Analysing 'Suxan0' on 'PLoTSQ'
#
# Analysing 'sVAxSw' on 'PLoTSQ'
#
# Analysing 'SvbjDu' on 'PLoTSQ'
#
# Analysing 'svpdp8' on 'PLoTSQ'
#
# Analysing 'sw6wsx' on 'PLoTSQ'
#
# Analysing 'swauzY' on 'PLoTSQ'
#
# Analysing 'SxpU5Z' on 'PLoTSQ'
#
# Analysing 'sYBo2b' on 'PLoTSQ'
#
# Analysing 'SyPost' on 'PLoTSQ'
#
# Analysing 'szc4Fl' on 'PLoTSQ'
#
# Analysing 'SZg3uH' on 'PLoTSQ'
#
# Analysing 'szsB8C' on 'PLoTSQ'
#
# Analysing 'sztIgl' on 'PLoTSQ'
#
# Analysing 'SZzOny' on 'PLoTSQ'
#
# Analysing 'T06b0s' on 'PLoTSQ'
#
# Analysing 'T0D4A6' on 'PLoTSQ'
#
# Analysing 't3h7jI' on 'PLoTSQ'
#
# Analysing 't498yN' on 'PLoTSQ'
#
# Analysing 'T4xRfj' on 'PLoTSQ'
#
# Analysing 't5FhsQ' on 'PLoTSQ'
#
# Analysing 'T7E4eD' on 'PLoTSQ'
#
# Analysing 'T93ePk' on 'PLoTSQ'
#
# Analysing 'tBufVK' on 'PLoTSQ'
#
# Analysing 'TCcYI2' on 'PLoTSQ'
#
# Analysing 'TcfLjG' on 'PLoTSQ'
#
# Analysing 'tCkKO3' on 'PLoTSQ'
#
# Analysing 'TDnyTM' on 'PLoTSQ'
#
# Analysing 'tdXXoa' on 'PLoTSQ'
#
# Analysing 'TeNpGf' on 'PLoTSQ'
#
# Analysing 'teQHCC' on 'PLoTSQ'
#
# Analysing 'tFrpjZ' on 'PLoTSQ'
#
# Analysing 'tFXCm0' on 'PLoTSQ'
#
# Analysing 'tGE7TS' on 'PLoTSQ'
#
# Analysing 'tH6ZR9' on 'PLoTSQ'
#
# Analysing 'tHeLLp' on 'PLoTSQ'
#
# Analysing 'THGbhu' on 'PLoTSQ'
#
# Analysing 'tHYloM' on 'PLoTSQ'
#
# Analysing 'tIJUrC' on 'PLoTSQ'
#
# Analysing 'tiRquh' on 'PLoTSQ'
#
# Analysing 'tirtg6' on 'PLoTSQ'
#
# Analysing 'tJK98j' on 'PLoTSQ'
#
# Analysing 'TKsr2J' on 'PLoTSQ'
#
# Analysing 'tL0KB2' on 'PLoTSQ'
#
# Analysing 'TlCxs7' on 'PLoTSQ'
#
# Analysing 'tlICUP' on 'PLoTSQ'
#
# Analysing 'TLOYsq' on 'PLoTSQ'
#
# Analysing 'TLPso1' on 'PLoTSQ'
#
# Analysing 'TLTsK0' on 'PLoTSQ'
#
# Analysing 'tMpgtx' on 'PLoTSQ'
#
# Analysing 'tmYjyV' on 'PLoTSQ'
#
# Analysing 'tMYoI0' on 'PLoTSQ'
#
# Analysing 'Tpy9hg' on 'PLoTSQ'
#
# Analysing 'tqL48m' on 'PLoTSQ'
#
# Analysing 'tqr0U3' on 'PLoTSQ'
#
# Analysing 'TQTuny' on 'PLoTSQ'
#
# Analysing 'TR0FHX' on 'PLoTSQ'
#
# Analysing 'trvrZu' on 'PLoTSQ'
#
# Analysing 'TrzdmE' on 'PLoTSQ'
#
# Analysing 'Ts8vPK' on 'PLoTSQ'
#
# Analysing 'tTyEb4' on 'PLoTSQ'
#
# Analysing 'TU3EEa' on 'PLoTSQ'
#
# Analysing 'tU9Q15' on 'PLoTSQ'
#
# Analysing 'tUMqiT' on 'PLoTSQ'
#
# Analysing 'TV3aL2' on 'PLoTSQ'
#
# Analysing 'tV7rir' on 'PLoTSQ'
#
# Analysing 'TvcKCf' on 'PLoTSQ'
#
# Analysing 'TvjTMc' on 'PLoTSQ'
#
# Analysing 'tVPQT7' on 'PLoTSQ'
#
# Analysing 'tWLGrb' on 'PLoTSQ'
#
# Analysing 'TwxX62' on 'PLoTSQ'
#
# Analysing 'TX2KOJ' on 'PLoTSQ'
#
# Analysing 'txRivJ' on 'PLoTSQ'
#
# Analysing 'txRRUe' on 'PLoTSQ'
#
# Analysing 'txW6nU' on 'PLoTSQ'
#
# Analysing 'tZUY6K' on 'PLoTSQ'
#
# Analysing 'tZyTFi' on 'PLoTSQ'
#
# Analysing 'U1RILF' on 'PLoTSQ'
#
# Analysing 'u1rItA' on 'PLoTSQ'
#
# Analysing 'u3zOez' on 'PLoTSQ'
#
# Analysing 'u48jto' on 'PLoTSQ'
#
# Analysing 'U4SwSQ' on 'PLoTSQ'
#
# Analysing 'u6ohj4' on 'PLoTSQ'
#
# Analysing 'U7aq39' on 'PLoTSQ'
#
# Analysing 'u7RIcp' on 'PLoTSQ'
#
# Analysing 'u7WJ8w' on 'PLoTSQ'
#
# Analysing 'u8Js0h' on 'PLoTSQ'
#
# Analysing 'U97U1h' on 'PLoTSQ'
#
# Analysing 'u9Th2Z' on 'PLoTSQ'
#
# Analysing 'UA8aif' on 'PLoTSQ'
#
# Analysing 'UAbahF' on 'PLoTSQ'
#
# Analysing 'UaG1sc' on 'PLoTSQ'
#
# Analysing 'UBAzY6' on 'PLoTSQ'
#
# Analysing 'ucCrbY' on 'PLoTSQ'
#
# Analysing 'uCoKen' on 'PLoTSQ'
#
# Analysing 'Ud94ia' on 'PLoTSQ'
#
# Analysing 'ueNYC8' on 'PLoTSQ'
#
# Analysing 'UFDaXM' on 'PLoTSQ'
#
# Analysing 'uFrPk0' on 'PLoTSQ'
#
# Analysing 'uhaybA' on 'PLoTSQ'
#
# Analysing 'UhDNCw' on 'PLoTSQ'
#
# Analysing 'Uhg8XI' on 'PLoTSQ'
#
# Analysing 'Uhj46u' on 'PLoTSQ'
#
# Analysing 'uhkVKU' on 'PLoTSQ'
#
# Analysing 'UiMxYD' on 'PLoTSQ'
#
# Analysing 'uj9tIZ' on 'PLoTSQ'
#
# Analysing 'uJKMDn' on 'PLoTSQ'
#
# Analysing 'UK138u' on 'PLoTSQ'
#
# Analysing 'Ulh6DR' on 'PLoTSQ'
#
# Analysing 'uLvDDz' on 'PLoTSQ'
#
# Analysing 'UMm4Qe' on 'PLoTSQ'
#
# Analysing 'UmRY5v' on 'PLoTSQ'
#
# Analysing 'UN90zz' on 'PLoTSQ'
#
# Analysing 'UNJzbt' on 'PLoTSQ'
#
# Analysing 'uODC9A' on 'PLoTSQ'
#
# Analysing 'uoTjXg' on 'PLoTSQ'
#
# Analysing 'uPUhEK' on 'PLoTSQ'
#
# Analysing 'UPx0wI' on 'PLoTSQ'
#
# Analysing 'uqCAfi' on 'PLoTSQ'
#
# Analysing 'UQFP87' on 'PLoTSQ'
#
# Analysing 'UQMLmS' on 'PLoTSQ'
#
# Analysing 'uqn29L' on 'PLoTSQ'
#
# Analysing 'uqnmI0' on 'PLoTSQ'
#
# Analysing 'UQZfgk' on 'PLoTSQ'
#
# Analysing 'UR5IQr' on 'PLoTSQ'
#
# Analysing 'urHP6g' on 'PLoTSQ'
#
# Analysing 'URQFXm' on 'PLoTSQ'
#
# Analysing 'urQQd2' on 'PLoTSQ'
#
# Analysing 'USFA05' on 'PLoTSQ'
#
# Analysing 'usIC9e' on 'PLoTSQ'
#
# Analysing 'usJ0jw' on 'PLoTSQ'
#
# Analysing 'ut3rze' on 'PLoTSQ'
#
# Analysing 'uUQRYz' on 'PLoTSQ'
#
# Analysing 'UuZC6S' on 'PLoTSQ'
#
# Analysing 'uwJgpZ' on 'PLoTSQ'
#
# Analysing 'uWP5Xe' on 'PLoTSQ'
#
# Analysing 'uWtCRc' on 'PLoTSQ'
#
# Analysing 'uWzfpU' on 'PLoTSQ'
#
# Analysing 'uxzcPm' on 'PLoTSQ'
#
# Analysing 'UyjmCH' on 'PLoTSQ'
#
# Analysing 'uzvcJr' on 'PLoTSQ'
#
# Analysing 'v0d2VH' on 'PLoTSQ'
#
# Analysing 'v3owQE' on 'PLoTSQ'
#
# Analysing 'v4Ynvp' on 'PLoTSQ'
#
# Analysing 'v5pizh' on 'PLoTSQ'
#
# Analysing 'V5q5pG' on 'PLoTSQ'
#
# Analysing 'V5twBn' on 'PLoTSQ'
#
# Analysing 'VA2fzz' on 'PLoTSQ'
#
# Analysing 'VAdKNl' on 'PLoTSQ'
#
# Analysing 'VAjfzi' on 'PLoTSQ'
#
# Analysing 'VAPwcw' on 'PLoTSQ'
#
# Analysing 'vAPYjU' on 'PLoTSQ'
#
# Analysing 'VArFPa' on 'PLoTSQ'
#
# Analysing 'VCMubN' on 'PLoTSQ'
#
# Analysing 'VCYZcU' on 'PLoTSQ'
#
# Analysing 'VD0fKM' on 'PLoTSQ'
#
# Analysing 'VdeuR3' on 'PLoTSQ'
#
# Analysing 'vdnrnh' on 'PLoTSQ'
#
# Analysing 'VdQbSA' on 'PLoTSQ'
#
# Analysing 'vFDOgb' on 'PLoTSQ'
#
# Analysing 'VfFxvW' on 'PLoTSQ'
#
# Analysing 'VgcNZM' on 'PLoTSQ'
#
# Analysing 'vGlmD8' on 'PLoTSQ'
#
# Analysing 'VH3UvW' on 'PLoTSQ'
#
# Analysing 'VhhUN5' on 'PLoTSQ'
#
# Analysing 'VHVFEQ' on 'PLoTSQ'
#
# Analysing 'viXE8h' on 'PLoTSQ'
#
# Analysing 'vJ421L' on 'PLoTSQ'
#
# Analysing 'VjdgqD' on 'PLoTSQ'
#
# Analysing 'VJgBtA' on 'PLoTSQ'
#
# Analysing 'VjYw6g' on 'PLoTSQ'
#
# Analysing 'vkdLhB' on 'PLoTSQ'
#
# Analysing 'vLdB89' on 'PLoTSQ'
#
# Analysing 'VlMtfE' on 'PLoTSQ'
#
# Analysing 'vmBJUm' on 'PLoTSQ'
#
# Analysing 'vMxf6Q' on 'PLoTSQ'
#
# Analysing 'vnVMbP' on 'PLoTSQ'
#
# Analysing 'VnwJVv' on 'PLoTSQ'
#
# Analysing 'vomPaY' on 'PLoTSQ'
#
# Analysing 'VpcUNS' on 'PLoTSQ'
#
# Analysing 'VQlDf0' on 'PLoTSQ'
#
# Analysing 'VqMdFx' on 'PLoTSQ'
#
# Analysing 'vrD3n1' on 'PLoTSQ'
#
# Analysing 'vRNAg6' on 'PLoTSQ'
#
# Analysing 'VRwuIS' on 'PLoTSQ'
#
# Analysing 'vRzFwW' on 'PLoTSQ'
#
# Analysing 'Vs1dPa' on 'PLoTSQ'
#
# Analysing 'Vt0340' on 'PLoTSQ'
#
# Analysing 'vt1pea' on 'PLoTSQ'
#
# Analysing 'vTASOO' on 'PLoTSQ'
#
# Analysing 'vTcBUJ' on 'PLoTSQ'
#
# Analysing 'vtdTrV' on 'PLoTSQ'
#
# Analysing 'vTqn1H' on 'PLoTSQ'
#
# Analysing 'Vuf7MN' on 'PLoTSQ'
#
# Analysing 'vuGSO0' on 'PLoTSQ'
#
# Analysing 'VujLWV' on 'PLoTSQ'
#
# Analysing 'vvg2Nd' on 'PLoTSQ'
#
# Analysing 'vVm7Wz' on 'PLoTSQ'
#
# Analysing 'VWaVKS' on 'PLoTSQ'
#
# Analysing 'vwrbOZ' on 'PLoTSQ'
#
# Analysing 'vWY8qJ' on 'PLoTSQ'
#
# Analysing 'vx1VtS' on 'PLoTSQ'
#
# Analysing 'vXQyoI' on 'PLoTSQ'
#
# Analysing 'VXTVcm' on 'PLoTSQ'
#
# Analysing 'vXXX2v' on 'PLoTSQ'
#
# Analysing 'vxxX9W' on 'PLoTSQ'
#
# Analysing 'vYhKcw' on 'PLoTSQ'
#
# Analysing 'VyPVnh' on 'PLoTSQ'
#
# Analysing 'VZKChX' on 'PLoTSQ'
#
# Analysing 'W1TzpI' on 'PLoTSQ'
#
# Analysing 'W1ygrS' on 'PLoTSQ'
#
# Analysing 'w44tzB' on 'PLoTSQ'
#
# Analysing 'w4xVCK' on 'PLoTSQ'
#
# Analysing 'w5lvet' on 'PLoTSQ'
#
# Analysing 'w6FaAv' on 'PLoTSQ'
#
# Analysing 'w8Bc6y' on 'PLoTSQ'
#
# Analysing 'W9UFQu' on 'PLoTSQ'
#
# Analysing 'wa8qwF' on 'PLoTSQ'
#
# Analysing 'WBP8XW' on 'PLoTSQ'
#
# Analysing 'wbQ8FV' on 'PLoTSQ'
#
# Analysing 'wbu7Bk' on 'PLoTSQ'
#
# Analysing 'WbVkjR' on 'PLoTSQ'
#
# Analysing 'wcSh2A' on 'PLoTSQ'
#
# Analysing 'WDcofO' on 'PLoTSQ'
#
# Analysing 'wDxfJb' on 'PLoTSQ'
#
# Analysing 'we5BkK' on 'PLoTSQ'
#
# Analysing 'WEtAkc' on 'PLoTSQ'
#
# Analysing 'WfMfqh' on 'PLoTSQ'
#
# Analysing 'wGcML3' on 'PLoTSQ'
#
# Analysing 'whCzsX' on 'PLoTSQ'
#
# Analysing 'wHfVrk' on 'PLoTSQ'
#
# Analysing 'wIOGc6' on 'PLoTSQ'
#
# Analysing 'WIrhhO' on 'PLoTSQ'
#
# Analysing 'WJJIXO' on 'PLoTSQ'
#
# Analysing 'wJqdwg' on 'PLoTSQ'
#
# Analysing 'WKAPkV' on 'PLoTSQ'
#
# Analysing 'wLGe80' on 'PLoTSQ'
#
# Analysing 'wnJHdd' on 'PLoTSQ'
#
# Analysing 'WnlXXT' on 'PLoTSQ'
#
# Analysing 'WOJqNt' on 'PLoTSQ'
#
# Analysing 'wqyoW9' on 'PLoTSQ'
#
# Analysing 'wricjk' on 'PLoTSQ'
#
# Analysing 'WsJ50M' on 'PLoTSQ'
#
# Analysing 'wT4d47' on 'PLoTSQ'
#
# Analysing 'WtlMWD' on 'PLoTSQ'
#
# Analysing 'WU9mNS' on 'PLoTSQ'
#
# Analysing 'wuegjA' on 'PLoTSQ'
#
# Analysing 'WUrSmg' on 'PLoTSQ'
#
# Analysing 'WVD77V' on 'PLoTSQ'
#
# Analysing 'WVSS9O' on 'PLoTSQ'
#
# Analysing 'wVyMbU' on 'PLoTSQ'
#
# Analysing 'WwgIS3' on 'PLoTSQ'
#
# Analysing 'WWZV13' on 'PLoTSQ'
#
# Analysing 'wwzYJ9' on 'PLoTSQ'
#
# Analysing 'wxQDMu' on 'PLoTSQ'
#
# Analysing 'WyeOO1' on 'PLoTSQ'
#
# Analysing 'WYg6uO' on 'PLoTSQ'
#
# Analysing 'WyriIY' on 'PLoTSQ'
#
# Analysing 'WZlGGz' on 'PLoTSQ'
#
# Analysing 'WZLKhv' on 'PLoTSQ'
#
# Analysing 'WZozGR' on 'PLoTSQ'
#
# Analysing 'x0I562' on 'PLoTSQ'
#
# Analysing 'x39vjx' on 'PLoTSQ'
#
# Analysing 'x3CIan' on 'PLoTSQ'
#
# Analysing 'x3iTHo' on 'PLoTSQ'
#
# Analysing 'X4fLbA' on 'PLoTSQ'
#
# Analysing 'x9tYOM' on 'PLoTSQ'
#
# Analysing 'X9VXAa' on 'PLoTSQ'
#
# Analysing 'xA4XQM' on 'PLoTSQ'
#
# Analysing 'XB6fXc' on 'PLoTSQ'
#
# Analysing 'xbIRSF' on 'PLoTSQ'
#
# Analysing 'xDceLl' on 'PLoTSQ'
#
# Analysing 'XDjX7P' on 'PLoTSQ'
#
# Analysing 'XDut5Z' on 'PLoTSQ'
#
# Analysing 'XdwKHY' on 'PLoTSQ'
#
# Analysing 'xEIf9R' on 'PLoTSQ'
#
# Analysing 'xeUgjN' on 'PLoTSQ'
#
# Analysing 'XFA2Fx' on 'PLoTSQ'
#
# Analysing 'xfn53O' on 'PLoTSQ'
#
# Analysing 'xFTtCp' on 'PLoTSQ'
#
# Analysing 'Xg2n6E' on 'PLoTSQ'
#
# Analysing 'XggvXk' on 'PLoTSQ'
#
# Analysing 'xHeWO6' on 'PLoTSQ'
#
# Analysing 'XHhh9n' on 'PLoTSQ'
#
# Analysing 'XHWdf2' on 'PLoTSQ'
#
# Analysing 'XHYwxt' on 'PLoTSQ'
#
# Analysing 'xHZuZc' on 'PLoTSQ'
#
# Analysing 'Xid2LP' on 'PLoTSQ'
#
# Analysing 'XjacM6' on 'PLoTSQ'
#
# Analysing 'xJaJKi' on 'PLoTSQ'
#
# Analysing 'XK1fFj' on 'PLoTSQ'
#
# Analysing 'XlyNBC' on 'PLoTSQ'
#
# Analysing 'XMGDVn' on 'PLoTSQ'
#
# Analysing 'xmreRt' on 'PLoTSQ'
#
# Analysing 'xNBRip' on 'PLoTSQ'
#
# Analysing 'xNLlYE' on 'PLoTSQ'
#
# Analysing 'XNsErT' on 'PLoTSQ'
#
# Analysing 'xNtgXo' on 'PLoTSQ'
#
# Analysing 'Xo6avZ' on 'PLoTSQ'
#
# Analysing 'xoDCcu' on 'PLoTSQ'
#
# Analysing 'xOGzHj' on 'PLoTSQ'
#
# Analysing 'xOuvw4' on 'PLoTSQ'
#
# Analysing 'xpWolM' on 'PLoTSQ'
#
# Analysing 'XQKp2N' on 'PLoTSQ'
#
# Analysing 'XQMbAq' on 'PLoTSQ'
#
# Analysing 'xRBaZr' on 'PLoTSQ'
#
# Analysing 'XRD7Fd' on 'PLoTSQ'
#
# Analysing 'XRIqHf' on 'PLoTSQ'
#
# Analysing 'xssCVn' on 'PLoTSQ'
#
# Analysing 'xTcUOv' on 'PLoTSQ'
#
# Analysing 'XtOfXA' on 'PLoTSQ'
#
# Analysing 'xUaPTb' on 'PLoTSQ'
#
# Analysing 'xuDTzw' on 'PLoTSQ'
#
# Analysing 'XvBpLV' on 'PLoTSQ'
#
# Analysing 'xVNqXz' on 'PLoTSQ'
#
# Analysing 'XVQA6O' on 'PLoTSQ'
#
# Analysing 'XvSnls' on 'PLoTSQ'
#
# Analysing 'XWhBaD' on 'PLoTSQ'
#
# Analysing 'xWMHLf' on 'PLoTSQ'
#
# Analysing 'xWZUxQ' on 'PLoTSQ'
#
# Analysing 'XXkb5K' on 'PLoTSQ'
#
# Analysing 'xYTPds' on 'PLoTSQ'
#
# Analysing 'xyupfX' on 'PLoTSQ'
#
# Analysing 'XZ1bHB' on 'PLoTSQ'
#
# Analysing 'XZtqi3' on 'PLoTSQ'
#
# Analysing 'Y2fr64' on 'PLoTSQ'
#
# Analysing 'Y2klz8' on 'PLoTSQ'
#
# Analysing 'Y2xLbr' on 'PLoTSQ'
#
# Analysing 'y4PMh7' on 'PLoTSQ'
#
# Analysing 'y4q6G7' on 'PLoTSQ'
#
# Analysing 'y56cXb' on 'PLoTSQ'
#
# Analysing 'y6Lv9w' on 'PLoTSQ'
#
# Analysing 'Y6PRpG' on 'PLoTSQ'
#
# Analysing 'y9Pim2' on 'PLoTSQ'
#
# Analysing 'yAr3kt' on 'PLoTSQ'
#
# Analysing 'yaTGKT' on 'PLoTSQ'
#
# Analysing 'YBlc0g' on 'PLoTSQ'
#
# Analysing 'Ybw2tj' on 'PLoTSQ'
#
# Analysing 'YCgNiI' on 'PLoTSQ'
#
# Analysing 'YCYrdJ' on 'PLoTSQ'
#
# Analysing 'YdExHn' on 'PLoTSQ'
#
# Analysing 'YDRzRv' on 'PLoTSQ'
#
# Analysing 'yE9TZr' on 'PLoTSQ'
#
# Analysing 'YEyWRx' on 'PLoTSQ'
#
# Analysing 'yfB5y7' on 'PLoTSQ'
#
# Analysing 'YFHzQc' on 'PLoTSQ'
#
# Analysing 'yfU0IB' on 'PLoTSQ'
#
# Analysing 'Ygf3Pg' on 'PLoTSQ'
#
# Analysing 'YHp68E' on 'PLoTSQ'
#
# Analysing 'yhT2wl' on 'PLoTSQ'
#
# Analysing 'YicM8x' on 'PLoTSQ'
#
# Analysing 'YIF5EA' on 'PLoTSQ'
#
# Analysing 'yiz06S' on 'PLoTSQ'
#
# Analysing 'Yj9roc' on 'PLoTSQ'
#
# Analysing 'YjCKLC' on 'PLoTSQ'
#
# Analysing 'YJcklm' on 'PLoTSQ'
#
# Analysing 'yjQyb2' on 'PLoTSQ'
#
# Analysing 'yJVCkO' on 'PLoTSQ'
#
# Analysing 'ykjunE' on 'PLoTSQ'
#
# Analysing 'yKp5Yy' on 'PLoTSQ'
#
# Analysing 'YKQy7t' on 'PLoTSQ'
#
# Analysing 'YKZbW0' on 'PLoTSQ'
#
# Analysing 'YMl3jD' on 'PLoTSQ'
#
# Analysing 'ynbhtz' on 'PLoTSQ'
#
# Analysing 'yneP7G' on 'PLoTSQ'
#
# Analysing 'YoepGK' on 'PLoTSQ'
#
# Analysing 'yOjFzf' on 'PLoTSQ'
#
# Analysing 'YpmnVN' on 'PLoTSQ'
#
# Analysing 'YQ9434' on 'PLoTSQ'
#
# Analysing 'yTqJiO' on 'PLoTSQ'
#
# Analysing 'yujlDP' on 'PLoTSQ'
#
# Analysing 'yUvjnj' on 'PLoTSQ'
#
# Analysing 'YuYxux' on 'PLoTSQ'
#
# Analysing 'YWfekl' on 'PLoTSQ'
#
# Analysing 'Ywjaqt' on 'PLoTSQ'
#
# Analysing 'Ywp8Vq' on 'PLoTSQ'
#
# Analysing 'yxbV4e' on 'PLoTSQ'
#
# Analysing 'yXE5ff' on 'PLoTSQ'
#
# Analysing 'yXfU3M' on 'PLoTSQ'
#
# Analysing 'yyVenC' on 'PLoTSQ'
#
# Analysing 'yZg3w9' on 'PLoTSQ'
#
# Analysing 'YZtDxv' on 'PLoTSQ'
#
# Analysing 'YZUZRc' on 'PLoTSQ'
#
# Analysing 'YzXXob' on 'PLoTSQ'
#
# Analysing 'Z0TOpp' on 'PLoTSQ'
#
# Analysing 'Z1BWjM' on 'PLoTSQ'
#
# Analysing 'z1uJP9' on 'PLoTSQ'
#
# Analysing 'z4nlkQ' on 'PLoTSQ'
#
# Analysing 'z5A9cL' on 'PLoTSQ'
#
# Analysing 'z5IZJZ' on 'PLoTSQ'
#
# Analysing 'Z5snjk' on 'PLoTSQ'
#
# Analysing 'z6NOvZ' on 'PLoTSQ'
#
# Analysing 'z78wPi' on 'PLoTSQ'
#
# Analysing 'Z7Nbz3' on 'PLoTSQ'
#
# Analysing 'Z82KQW' on 'PLoTSQ'
#
# Analysing 'Z8TYHt' on 'PLoTSQ'
#
# Analysing 'zamZtr' on 'PLoTSQ'
#
# Analysing 'ZB1MH5' on 'PLoTSQ'
#
# Analysing 'zBAjbB' on 'PLoTSQ'
#
# Analysing 'zBD5mb' on 'PLoTSQ'
#
# Analysing 'ZboMaK' on 'PLoTSQ'
#
# Analysing 'zCNl1W' on 'PLoTSQ'
#
# Analysing 'zcXbrx' on 'PLoTSQ'
#
# Analysing 'zDUOCe' on 'PLoTSQ'
#
# Analysing 'ZE3cxL' on 'PLoTSQ'
#
# Analysing 'ZgyHbo' on 'PLoTSQ'
#
# Analysing 'ZGzhtu' on 'PLoTSQ'
#
# Analysing 'Zh1r3W' on 'PLoTSQ'
#
# Analysing 'zHi2iG' on 'PLoTSQ'
#
# Analysing 'zhK6r2' on 'PLoTSQ'
#
# Analysing 'ZhS1P2' on 'PLoTSQ'
#
# Analysing 'ZJ8fqE' on 'PLoTSQ'
#
# Analysing 'ZjCxWk' on 'PLoTSQ'
#
# Analysing 'Zjg0OM' on 'PLoTSQ'
#
# Analysing 'ZJN3LT' on 'PLoTSQ'
#
# Analysing 'zJzbeq' on 'PLoTSQ'
#
# Analysing 'ZkXJ5t' on 'PLoTSQ'
#
# Analysing 'zLQkIW' on 'PLoTSQ'
#
# Analysing 'ZLscj6' on 'PLoTSQ'
#
# Analysing 'ZLV761' on 'PLoTSQ'
#
# Analysing 'ZMFgN9' on 'PLoTSQ'
#
# Analysing 'zMnwde' on 'PLoTSQ'
#
# Analysing 'ZmnzFX' on 'PLoTSQ'
#
# Analysing 'zms3Th' on 'PLoTSQ'
#
# Analysing 'ZnHOAs' on 'PLoTSQ'
#
# Analysing 'zoOmvf' on 'PLoTSQ'
#
# Analysing 'ZP5DMI' on 'PLoTSQ'
#
# Analysing 'zpEzhh' on 'PLoTSQ'
#
# Analysing 'ZpGUKm' on 'PLoTSQ'
#
# Analysing 'zq3jjJ' on 'PLoTSQ'
#
# Analysing 'zQGpe5' on 'PLoTSQ'
#
# Analysing 'zQjWMb' on 'PLoTSQ'
#
# Analysing 'Zrc2SX' on 'PLoTSQ'
#
# Analysing 'ZRJNqm' on 'PLoTSQ'
#
# Analysing 'ZrXlIY' on 'PLoTSQ'
#
# Analysing 'zTRD10' on 'PLoTSQ'
#
# Analysing 'ZuXXBB' on 'PLoTSQ'
#
# Analysing 'ZV8N30' on 'PLoTSQ'
#
# Analysing 'ZVgOej' on 'PLoTSQ'
#
# Analysing 'ZvUuyY' on 'PLoTSQ'
#
# Analysing 'zvYkyq' on 'PLoTSQ'
#
# Analysing 'ZWj7lo' on 'PLoTSQ'
#
# Analysing 'zxDZ8z' on 'PLoTSQ'
#
# Analysing 'zydwNA' on 'PLoTSQ'
#
# Analysing 'zyE3X0' on 'PLoTSQ'
#
# Analysing 'zyfGnq' on 'PLoTSQ'
#
# Analysing 'ZZKl9w' on 'PLoTSQ'

# %%
## pleiotropy test
mr_all_cis_pleio <- mr_pleiotropy_test(harmon_cis_nopleio)
# heterogeneity test
mr_all_cis_het <- mr_heterogeneity(harmon_cis_nopleio, method_list = c("mr_ivw"))
# Out:
# Not enough SNPs available for pleiotropy analysis of '08jku6' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '0C2yuA' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '0IGBwp' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '0tuqOC' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '2ajmuJ' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '2vYbUG' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '2XcH97' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '2zwrtf' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '3AYVop' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '3hrREK' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '3oNO0e' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '3Qh5FJ' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '3YHdot' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '4v1b4d' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '4yzHEh' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '56M8LH' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '5S3YMf' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '5u63qu' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '67GpWz' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '6IWlFa' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '6uJdXY' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '7DrnXF' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '8aBfeX' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '8IhiOm' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '8temwQ' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '93sEDg' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '9fekE9' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '9Pgz55' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '9q3dCL' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '9rpM1H' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '9UiEW1' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '9wlTAG' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '9zUwZs' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'A40C8L' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'A9LRCP' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'abnRhD' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'aDNVRd' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'AJ6e38' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'aKtXBG' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'aNgabn' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'ApBZcx' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'aw3JlE' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'AwY6X6' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'BiYeNw' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'BJXXV5' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'bNUAkQ' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'bS9rRc' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'BSNccI' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'BuLuw2' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'bvPaq2' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'BZ7YRY' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'bZPSIn' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'cdQIlo' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'ChZiaL' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'cJMLuy' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'CkoA6i' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'cPyA3r' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'CR668A' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'CVTJDh' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'CXryLC' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'd1Hm7A' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'dnqNfT' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'dNYGI4' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'dsKPBl' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'dUgaDZ' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'dUwghb' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'dwPL1q' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'E1MSOJ' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'E8xrPm' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'EbYN4s' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'eQwGr5' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'ErgMwz' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'eXBgXn' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'F8c53B' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'FAEizE' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'FAJJhg' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'FCsYGG' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'fDeAz6' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'FISBmm' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'fm973x' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'FnhD9x' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'fnNwWs' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'fo4L4d' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'FxE55l' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'fxzQGX' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'g2shHC' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'g7wSGO' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'gANXmT' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'gFSiVR' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Gkbk3z' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'gohTqy' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'GpHmzO' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'GUiffj' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'gUvWlF' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'H0zfXS' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'HBtFzV' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'hCaVU8' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Hfo8IY' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'hIC7Vs' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Hjab34' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'HmA7Vk' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'hqqAqL' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'hULbOv' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'HYviYN' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'i2eRuM' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'iaKaLX' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'idVFUh' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'ieUbzF' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Ig1JcA' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'itltlK' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'j8JKZM' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'JU1m50' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'JW69ia' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'k19XGv' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'K3P2Dg' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Kbtoae' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'kBYCFu' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'kgWzVK' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'kinL9V' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'KjUcY5' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'kKxbI5' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'KnmAiu' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'KoWAcc' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'KUolTX' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'kWSJ9n' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'KXPr8H' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'liuUub' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'lNpI5e' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Lr6QEU' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'lTckH1' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Ltu1EI' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'LWWGrk' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'LZazv8' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'm49fzx' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'MbfeoU' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'mCRetA' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'mDUWDd' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'mFAhLf' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'MoAwNY' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'mPovEK' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'mqtpED' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'mvqGvG' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'nhdSSK' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'NkYZqH' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'nSHUil' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'NYoDB5' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'nyZX9U' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'NZRjAB' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'oBKt93' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'oFWO2K' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'oIscmS' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'okEKOX' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'OmApRs' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'OMI4xA' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Onlvpc' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'oO9tkB' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'oOtgc1' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'ot4AOG' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'otAepK' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'oXLh5d' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'p6gFKy' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'PDSyLX' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'PhF62i' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'pmU15B' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'poQTez' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'PpxSVV' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'pPZeph' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'PRGgQ2' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Prk8oI' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'PRMS3P' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'PTblyN' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'PTKjjt' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'PwPRw4' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Q1kioD' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'QeYKES' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'QGYMDG' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'QKmuGe' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'QNJFrX' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'qnWFtp' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'qucBLo' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'QxgGrl' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'r0limX' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'R9Brea' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'rApdt5' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'rc5woD' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'RlB4H0' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'rpXeRi' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'rujYv6' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'rVwhLZ' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'S6V0Dk' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'sct1Ck' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'sDDy0T' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'sdSyW0' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'SeJBNa' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'sEsqRU' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'SMDD80' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'sou4WW' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'srN529' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'sRYPVU' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'swauzY' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'szc4Fl' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'T06b0s' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 't5FhsQ' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'TcfLjG' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'tCkKO3' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'tJK98j' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'tL0KB2' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'u3zOez' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'uhaybA' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'UK138u' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'UQZfgk' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'urHP6g' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'urQQd2' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'usIC9e' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'uWP5Xe' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'uWzfpU' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'uzvcJr' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'VA2fzz' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'VArFPa' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'vmBJUm' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'vnVMbP' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'vomPaY' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'vTASOO' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'VujLWV' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'vvg2Nd' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'VZKChX' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'W9UFQu' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'WBP8XW' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'WJJIXO' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'WOJqNt' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'xA4XQM' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'XHhh9n' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'xJaJKi' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'xNLlYE' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'xOuvw4' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'xRBaZr' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'XRIqHf' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'xVNqXz' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'XWhBaD' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Ybw2tj' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'yE9TZr' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'YFHzQc' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'yfU0IB' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'yiz06S' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Yj9roc' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'YuYxux' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'yyVenC' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'z4nlkQ' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'ZjCxWk' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'zJzbeq' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'zq3jjJ' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'zvYkyq' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '08jku6' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '0C2yuA' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '0IGBwp' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '0tuqOC' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '2ajmuJ' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '2vYbUG' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '2XcH97' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '2zwrtf' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '3AYVop' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '3hrREK' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '3oNO0e' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '3Qh5FJ' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '3YHdot' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '4v1b4d' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '4yzHEh' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '56M8LH' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '5S3YMf' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '5u63qu' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '67GpWz' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '6IWlFa' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '6uJdXY' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '7DrnXF' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '8aBfeX' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '8IhiOm' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '8temwQ' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '93sEDg' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '9fekE9' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '9Pgz55' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '9q3dCL' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '9rpM1H' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '9UiEW1' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '9wlTAG' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '9zUwZs' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'A40C8L' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'A9LRCP' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'abnRhD' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'aDNVRd' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'AJ6e38' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'aKtXBG' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'aNgabn' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'ApBZcx' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'aw3JlE' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'AwY6X6' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'BiYeNw' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'BJXXV5' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'bNUAkQ' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'bS9rRc' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'BSNccI' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'BuLuw2' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'bvPaq2' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'BZ7YRY' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'bZPSIn' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'cdQIlo' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'ChZiaL' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'cJMLuy' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'CkoA6i' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'cPyA3r' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'CR668A' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'CVTJDh' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'CXryLC' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'd1Hm7A' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'dnqNfT' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'dNYGI4' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'dsKPBl' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'dUgaDZ' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'dUwghb' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'dwPL1q' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'E1MSOJ' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'E8xrPm' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'EbYN4s' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'eQwGr5' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'ErgMwz' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'eXBgXn' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'F8c53B' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'FAEizE' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'FAJJhg' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'FCsYGG' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'fDeAz6' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'FISBmm' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'fm973x' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'FnhD9x' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'fnNwWs' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'fo4L4d' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'FxE55l' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'fxzQGX' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'g2shHC' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'g7wSGO' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'gANXmT' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'gFSiVR' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Gkbk3z' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'gohTqy' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'GpHmzO' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'GUiffj' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'gUvWlF' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'H0zfXS' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'HBtFzV' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'hCaVU8' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Hfo8IY' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'hIC7Vs' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Hjab34' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'HmA7Vk' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'hqqAqL' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'hULbOv' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'HYviYN' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'i2eRuM' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'iaKaLX' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'idVFUh' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'ieUbzF' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Ig1JcA' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'itltlK' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'j8JKZM' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'JU1m50' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'JW69ia' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'k19XGv' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'K3P2Dg' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Kbtoae' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'kBYCFu' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'kgWzVK' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'kinL9V' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'KjUcY5' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'kKxbI5' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'KnmAiu' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'KoWAcc' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'KUolTX' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'kWSJ9n' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'KXPr8H' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'liuUub' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'lNpI5e' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Lr6QEU' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'lTckH1' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Ltu1EI' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'LWWGrk' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'LZazv8' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'm49fzx' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'MbfeoU' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'mCRetA' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'mDUWDd' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'mFAhLf' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'MoAwNY' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'mPovEK' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'mqtpED' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'mvqGvG' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'nhdSSK' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'NkYZqH' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'nSHUil' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'NYoDB5' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'nyZX9U' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'NZRjAB' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'oBKt93' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'oFWO2K' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'oIscmS' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'okEKOX' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'OmApRs' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'OMI4xA' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Onlvpc' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'oO9tkB' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'oOtgc1' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'ot4AOG' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'otAepK' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'oXLh5d' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'p6gFKy' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'PDSyLX' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'PhF62i' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'pmU15B' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'poQTez' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'PpxSVV' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'pPZeph' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'PRGgQ2' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Prk8oI' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'PRMS3P' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'PTblyN' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'PTKjjt' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'PwPRw4' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Q1kioD' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'QeYKES' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'QGYMDG' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'QKmuGe' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'QNJFrX' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'qnWFtp' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'qucBLo' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'QxgGrl' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'r0limX' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'R9Brea' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'rApdt5' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'rc5woD' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'RlB4H0' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'rpXeRi' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'rujYv6' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'rVwhLZ' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'S6V0Dk' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'sct1Ck' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'sDDy0T' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'sdSyW0' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'SeJBNa' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'sEsqRU' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'SMDD80' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'sou4WW' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'srN529' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'sRYPVU' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'swauzY' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'szc4Fl' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'T06b0s' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 't5FhsQ' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'TcfLjG' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'tCkKO3' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'tJK98j' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'tL0KB2' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'u3zOez' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'uhaybA' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'UK138u' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'UQZfgk' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'urHP6g' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'urQQd2' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'usIC9e' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'uWP5Xe' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'uWzfpU' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'uzvcJr' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'VA2fzz' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'VArFPa' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'vmBJUm' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'vnVMbP' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'vomPaY' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'vTASOO' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'VujLWV' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'vvg2Nd' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'VZKChX' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'W9UFQu' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'WBP8XW' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'WJJIXO' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'WOJqNt' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'xA4XQM' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'XHhh9n' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'xJaJKi' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'xNLlYE' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'xOuvw4' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'xRBaZr' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'XRIqHf' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'xVNqXz' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'XWhBaD' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Ybw2tj' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'yE9TZr' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'YFHzQc' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'yfU0IB' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'yiz06S' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Yj9roc' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'YuYxux' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'yyVenC' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'z4nlkQ' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'ZjCxWk' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'zJzbeq' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'zq3jjJ' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'zvYkyq' on 'PLoTSQ'

# %%
## make pretty
mr_all_cis2     <- 
    mr_all_cis %>% 
    mutate(method = case_when(method == "Inverse variance weighted" ~ "IVW",
                              method == "Maximum likelihood" ~ "ML",
                              method == "Weighted median" ~ "WM",
                              method == "MR Egger" ~ "MR_Egger",
                              TRUE ~ method)
          ) %>%
    select(-c('id.exposure','id.outcome'))
mr_all_cis_het2 <-
    mr_all_cis_het %>% 
    mutate(method = ifelse(method=="Inverse variance weighted", "IVW", method)) %>%
    select(-c('id.exposure','id.outcome'))

mr_all_cis_pleio2 <-
    mr_all_cis_pleio %>%
    select(-c('id.exposure','id.outcome'))

# %%
ivw <-
mr_all_cis2 %>% 
    filter(method=='IVW') %>%
    mutate(fdr = p.adjust(pval, 'fdr'))
nrow(ivw)
ivw %>% filter(fdr < 0.05) %>% arrange(b)
# Out:
# [1] 1738
#    outcome      exposure method nsnp b           se         pval         fdr
# 1  delirium_ukb CALB1    IVW     2   -0.77304279 0.17927089 1.616754e-05 2.554472e-03
# 2  delirium_ukb APOE     IVW    36   -0.52557330 0.03683868 3.519371e-46 6.116667e-43
# 3  delirium_ukb RILPL2   IVW     4   -0.50202694 0.14973587 8.001291e-04 3.311010e-02
# 4  delirium_ukb NUDT16   IVW     3   -0.47704221 0.11161357 1.919520e-05 2.566251e-03
# 5  delirium_ukb CEACAM19 IVW    15   -0.44630169 0.09166163 1.121568e-06 4.873212e-04
# 6  delirium_ukb RAB44    IVW     6   -0.35639027 0.09516844 1.805113e-04 1.120459e-02
# 7  delirium_ukb CNPY4    IVW    16   -0.35188509 0.06694478 1.469440e-07 8.512953e-05
# 8  delirium_ukb WARS     IVW    16   -0.24582811 0.05249233 2.825348e-06 6.138069e-04
# 9  delirium_ukb DSG2     IVW    18   -0.20358519 0.05638040 3.051114e-04 1.710592e-02
# 10 delirium_ukb IL1R1    IVW    28   -0.17550211 0.05171260 6.893057e-04 3.135926e-02
# 11 delirium_ukb MPO      IVW    14   -0.16976845 0.04208865 5.493061e-05 4.546162e-03
# 12 delirium_ukb CHRDL2   IVW    14   -0.16621115 0.05117292 1.162072e-03 4.301636e-02
# 13 delirium_ukb RNF149   IVW    18   -0.15894576 0.04862988 1.081270e-03 4.176104e-02
# 14 delirium_ukb MEGF9    IVW    32   -0.13408916 0.03491186 1.226386e-04 7.894290e-03
# 15 delirium_ukb PON3     IVW    21   -0.12161977 0.03747462 1.172896e-03 4.301636e-02
# 16 delirium_ukb VASN     IVW    20   -0.11648916 0.02869835 4.926461e-05 4.506416e-03
# 17 delirium_ukb ACE      IVW    39   -0.11581461 0.02995459 1.104814e-04 7.894290e-03
# 18 delirium_ukb IL12RB1  IVW    23   -0.11394537 0.02939004 1.057499e-04 7.894290e-03
# 19 delirium_ukb HNMT     IVW    36   -0.10974965 0.02292210 1.685017e-06 5.857118e-04
# 20 delirium_ukb CD80     IVW    23   -0.10503142 0.03286001 1.391878e-03 4.573645e-02
# 21 delirium_ukb LGALS9   IVW    43   -0.09087776 0.02621480 5.269707e-04 2.475338e-02
# 22 delirium_ukb FOLR3    IVW    35   -0.08137565 0.01960885 3.325551e-05 3.211005e-03
# 23 delirium_ukb SFTPD    IVW    70   -0.05137193 0.01597595 1.301818e-03 4.525121e-02
# 24 delirium_ukb CD33     IVW    45    0.04096865 0.01212487 7.277781e-04 3.162196e-02
# 25 delirium_ukb PILRA    IVW    92    0.04356412 0.01353410 1.287097e-03 4.525121e-02
# 26 delirium_ukb IL17RB   IVW    57    0.06039486 0.01684307 3.361231e-04 1.825569e-02
# 27 delirium_ukb CCL25    IVW    46    0.06213242 0.01759711 4.142553e-04 2.181745e-02
# 28 delirium_ukb TOR1AIP1 IVW    60    0.07232893 0.01644575 1.092372e-05 1.970318e-03
# 29 delirium_ukb PXN      IVW    48    0.07366412 0.02305072 1.394725e-03 4.573645e-02
# 30 delirium_ukb GNLY     IVW    30    0.07475503 0.02131234 4.521796e-04 2.245395e-02
# 31 delirium_ukb LECT2    IVW    58    0.07510126 0.01777009 2.375923e-05 2.876705e-03
# 32 delirium_ukb SFTPA2   IVW    35    0.07630565 0.01738182 1.133670e-05 1.970318e-03
# 33 delirium_ukb PVR      IVW    45    0.08540393 0.02461121 5.202209e-04 2.475338e-02
# 34 delirium_ukb SPINK5   IVW    27    0.08696317 0.02607815 8.538707e-04 3.372789e-02
# 35 delirium_ukb HPGDS    IVW    27    0.08853020 0.02445439 2.943552e-04 1.705298e-02
# 36 delirium_ukb FCGR3B   IVW    67    0.08911838 0.02209088 5.479567e-05 4.546162e-03
# 37 delirium_ukb GGH      IVW    36    0.08929917 0.02541272 4.414863e-04 2.245395e-02
# 38 delirium_ukb IL1R2    IVW    46    0.10080662 0.02600373 1.059170e-04 7.894290e-03
# 39 delirium_ukb ADAM8    IVW    22    0.10310541 0.03180558 1.188024e-03 4.301636e-02
# 40 delirium_ukb LAYN     IVW    31    0.11837855 0.03231289 2.487843e-04 1.490990e-02
# 41 delirium_ukb DPP10    IVW    35    0.13604936 0.03534930 1.187392e-04 7.894290e-03
# 42 delirium_ukb SPINK6   IVW    28    0.16061200 0.03757005 1.911369e-05 2.566251e-03
# 43 delirium_ukb F11      IVW    30    0.17200003 0.05144699 8.280400e-04 3.346822e-02
# 44 delirium_ukb SSC4D    IVW    17    0.17585156 0.04214086 3.006847e-05 3.211005e-03
# 45 delirium_ukb DSC2     IVW    18    0.19762806 0.05129216 1.166852e-04 7.894290e-03
# 46 delirium_ukb GPNMB    IVW    22    0.20875345 0.04431348 2.467046e-06 6.138069e-04
# 47 delirium_ukb TGFBR3   IVW    11    0.27519487 0.08607228 1.387431e-03 4.573645e-02
# 48 delirium_ukb CEACAM20 IVW     7    0.35813927 0.07623484 2.629245e-06 6.138069e-04
# 49 delirium_ukb MMP13    IVW     8    0.38398685 0.09230556 3.183119e-05 3.211005e-03
# 50 delirium_ukb RNF43    IVW    10    0.39073305 0.09267070 2.482772e-05 2.876705e-03
# 51 delirium_ukb NT5C1A   IVW     3    0.48436858 0.14296012 7.036889e-04 3.135926e-02
# 52 delirium_ukb SH2B3    IVW     4    0.75209340 0.22372911 7.748523e-04 3.284618e-02
# 53 delirium_ukb MENT     IVW     9    0.93032664 0.10631812 2.125877e-18 1.847387e-15

# %%
mr_all_cis2fdr <- left_join(mr_all_cis2, ivw[,c('exposure','method','outcome', 'fdr')], by=c('exposure', 'outcome', 'method'))

# %%
# save results (cis-pqtls)
resultsdir = paste0("pQTL_MR_analysis/results/with_clumped", "/thres", r2, '/ukb_nopleio')
system(paste0("mkdir -p ", resultsdir), intern=T)
fwrite(mr_all_cis2fdr, paste0(resultsdir, "/mr_pQTLs_delirium_1by1_thres", r2, "_cis_main.csv"))     # main table
fwrite(mr_all_cis_pleio2, paste0(resultsdir, "/mr_pQTLs_delirium_1by1_thres", r2, "_cis_pleio.csv")) # plei test
fwrite(mr_all_cis_het2, paste0(resultsdir, "/mr_pQTLs_delirium_1by1_thres", r2, "_cis_het.csv"))     # heterogeneity test
# save dfs (for ploting)
saveRDS(mr_all_cis, paste0(resultsdir, "/mr_all_cis.rds"))                  # original MR df
saveRDS(harmon_cis_nopleio, paste0(resultsdir, "/harmon_cis_nopleio.rds"))  # original harmon df
# Out:
# character(0)

# %% [markdown]
# #### **cis+trans pQTLs MR:**

# %%
## perform 2sampleMR:
mr_all <- mr(harmon_nopleio, method_list = c("mr_ivw", "mr_weighted_median", "mr_egger_regression", "mr_two_sample_ml"))
# Out:
# Analysing '01vuod' on 'PLoTSQ'
#
# Analysing '04aDX7' on 'PLoTSQ'
#
# Analysing '05ki0T' on 'PLoTSQ'
#
# Analysing '07SKi0' on 'PLoTSQ'
#
# Analysing '08jku6' on 'PLoTSQ'
#
# Analysing '09d5Mb' on 'PLoTSQ'
#
# Analysing '0C2yuA' on 'PLoTSQ'
#
# Analysing '0d4VvH' on 'PLoTSQ'
#
# Analysing '0E9FJQ' on 'PLoTSQ'
#
# Analysing '0eZC0L' on 'PLoTSQ'
#
# Analysing '0i3obs' on 'PLoTSQ'
#
# Analysing '0IGBwp' on 'PLoTSQ'
#
# Analysing '0IZDi9' on 'PLoTSQ'
#
# Analysing '0jf5ZC' on 'PLoTSQ'
#
# Analysing '0jY1yH' on 'PLoTSQ'
#
# Analysing '0KVBr5' on 'PLoTSQ'
#
# Analysing '0L041e' on 'PLoTSQ'
#
# Analysing '0L34h1' on 'PLoTSQ'
#
# Analysing '0LT5pW' on 'PLoTSQ'
#
# Analysing '0MBR7O' on 'PLoTSQ'
#
# Analysing '0NCbGM' on 'PLoTSQ'
#
# Analysing '0Nh02f' on 'PLoTSQ'
#
# Analysing '0OaLlq' on 'PLoTSQ'
#
# Analysing '0RfYRo' on 'PLoTSQ'
#
# Analysing '0rlQuw' on 'PLoTSQ'
#
# Analysing '0s0iUd' on 'PLoTSQ'
#
# Analysing '0Sncbb' on 'PLoTSQ'
#
# Analysing '0trdb3' on 'PLoTSQ'
#
# Analysing '0tuqOC' on 'PLoTSQ'
#
# Analysing '0TXiCT' on 'PLoTSQ'
#
# Analysing '0U5mcr' on 'PLoTSQ'
#
# Analysing '0UNvpI' on 'PLoTSQ'
#
# Analysing '103si1' on 'PLoTSQ'
#
# Analysing '109XZz' on 'PLoTSQ'
#
# Analysing '11ab6G' on 'PLoTSQ'
#
# Analysing '12S01x' on 'PLoTSQ'
#
# Analysing '14rBhX' on 'PLoTSQ'
#
# Analysing '17h0z0' on 'PLoTSQ'
#
# Analysing '18JUaw' on 'PLoTSQ'
#
# Analysing '1ASHm3' on 'PLoTSQ'
#
# Analysing '1bRol9' on 'PLoTSQ'
#
# Analysing '1bT0e6' on 'PLoTSQ'
#
# Analysing '1F2PrG' on 'PLoTSQ'
#
# Analysing '1FTXjc' on 'PLoTSQ'
#
# Analysing '1gbYdB' on 'PLoTSQ'
#
# Analysing '1HndBg' on 'PLoTSQ'
#
# Analysing '1hPkaS' on 'PLoTSQ'
#
# Analysing '1kjSq6' on 'PLoTSQ'
#
# Analysing '1km18d' on 'PLoTSQ'
#
# Analysing '1MdigH' on 'PLoTSQ'
#
# Analysing '1mEKVG' on 'PLoTSQ'
#
# Analysing '1MG2Qc' on 'PLoTSQ'
#
# Analysing '1MMcYr' on 'PLoTSQ'
#
# Analysing '1NB1CW' on 'PLoTSQ'
#
# Analysing '1NZrPj' on 'PLoTSQ'
#
# Analysing '1Qd8Mv' on 'PLoTSQ'
#
# Analysing '1RH1An' on 'PLoTSQ'
#
# Analysing '1RTQVE' on 'PLoTSQ'
#
# Analysing '1ryfGs' on 'PLoTSQ'
#
# Analysing '1S4Lq0' on 'PLoTSQ'
#
# Analysing '1WGu2D' on 'PLoTSQ'
#
# Analysing '1yAi1j' on 'PLoTSQ'
#
# Analysing '1ZxUCX' on 'PLoTSQ'
#
# Analysing '21ReDd' on 'PLoTSQ'
#
# Analysing '23yYuS' on 'PLoTSQ'
#
# Analysing '245PJF' on 'PLoTSQ'
#
# Analysing '248WnJ' on 'PLoTSQ'
#
# Analysing '26S0cE' on 'PLoTSQ'
#
# Analysing '2ajmuJ' on 'PLoTSQ'
#
# Analysing '2enqVO' on 'PLoTSQ'
#
# Analysing '2eRYVX' on 'PLoTSQ'
#
# Analysing '2etG6i' on 'PLoTSQ'
#
# Analysing '2EZezz' on 'PLoTSQ'
#
# Analysing '2FbUgr' on 'PLoTSQ'
#
# Analysing '2FQlOC' on 'PLoTSQ'
#
# Analysing '2FYmfe' on 'PLoTSQ'
#
# Analysing '2gpHVC' on 'PLoTSQ'
#
# Analysing '2GZv6R' on 'PLoTSQ'
#
# Analysing '2ic2XR' on 'PLoTSQ'
#
# Analysing '2NT6Sq' on 'PLoTSQ'
#
# Analysing '2rpY3D' on 'PLoTSQ'
#
# Analysing '2SixLs' on 'PLoTSQ'
#
# Analysing '2t0bCc' on 'PLoTSQ'
#
# Analysing '2txnCT' on 'PLoTSQ'
#
# Analysing '2uJ9DG' on 'PLoTSQ'
#
# Analysing '2vYbUG' on 'PLoTSQ'
#
# Analysing '2WFjTj' on 'PLoTSQ'
#
# Analysing '2XcH97' on 'PLoTSQ'
#
# Analysing '2zwrtf' on 'PLoTSQ'
#
# Analysing '30IJn9' on 'PLoTSQ'
#
# Analysing '30q0vW' on 'PLoTSQ'
#
# Analysing '30TfEr' on 'PLoTSQ'
#
# Analysing '342hTX' on 'PLoTSQ'
#
# Analysing '38EL4W' on 'PLoTSQ'
#
# Analysing '3AMDz9' on 'PLoTSQ'
#
# Analysing '3ApVv6' on 'PLoTSQ'
#
# Analysing '3AYVop' on 'PLoTSQ'
#
# Analysing '3BBZRN' on 'PLoTSQ'
#
# Analysing '3EovFX' on 'PLoTSQ'
#
# Analysing '3Fj9oy' on 'PLoTSQ'
#
# Analysing '3GGU42' on 'PLoTSQ'
#
# Analysing '3GyFy8' on 'PLoTSQ'
#
# Analysing '3HGrcB' on 'PLoTSQ'
#
# Analysing '3hrREK' on 'PLoTSQ'
#
# Analysing '3hWG2h' on 'PLoTSQ'
#
# Analysing '3i4t4m' on 'PLoTSQ'
#
# Analysing '3i6RDH' on 'PLoTSQ'
#
# Analysing '3jCFq8' on 'PLoTSQ'
#
# Analysing '3JIWmi' on 'PLoTSQ'
#
# Analysing '3jK0XT' on 'PLoTSQ'
#
# Analysing '3Lw7Cd' on 'PLoTSQ'
#
# Analysing '3M6UzD' on 'PLoTSQ'
#
# Analysing '3oNO0e' on 'PLoTSQ'
#
# Analysing '3pdMaf' on 'PLoTSQ'
#
# Analysing '3qfrqs' on 'PLoTSQ'
#
# Analysing '3Qh5FJ' on 'PLoTSQ'
#
# Analysing '3qIpDD' on 'PLoTSQ'
#
# Analysing '3qkJvR' on 'PLoTSQ'
#
# Analysing '3r3bYO' on 'PLoTSQ'
#
# Analysing '3rycmO' on 'PLoTSQ'
#
# Analysing '3snY4C' on 'PLoTSQ'
#
# Analysing '3sYq8T' on 'PLoTSQ'
#
# Analysing '3t82aY' on 'PLoTSQ'
#
# Analysing '3TlOcC' on 'PLoTSQ'
#
# Analysing '3uKzRg' on 'PLoTSQ'
#
# Analysing '3wt8II' on 'PLoTSQ'
#
# Analysing '3xVfmo' on 'PLoTSQ'
#
# Analysing '3YHdot' on 'PLoTSQ'
#
# Analysing '402hJR' on 'PLoTSQ'
#
# Analysing '40cVU2' on 'PLoTSQ'
#
# Analysing '40znNm' on 'PLoTSQ'
#
# Analysing '44SfHs' on 'PLoTSQ'
#
# Analysing '46otZi' on 'PLoTSQ'
#
# Analysing '48Trux' on 'PLoTSQ'
#
# Analysing '4anNop' on 'PLoTSQ'
#
# Analysing '4bc9Bl' on 'PLoTSQ'
#
# Analysing '4BH5Ph' on 'PLoTSQ'
#
# Analysing '4BxSpI' on 'PLoTSQ'
#
# Analysing '4c6t0C' on 'PLoTSQ'
#
# Analysing '4ckYpd' on 'PLoTSQ'
#
# Analysing '4CMDw6' on 'PLoTSQ'
#
# Analysing '4cYxfC' on 'PLoTSQ'
#
# Analysing '4DpPqx' on 'PLoTSQ'
#
# Analysing '4EAMyA' on 'PLoTSQ'
#
# Analysing '4EY2kv' on 'PLoTSQ'
#
# Analysing '4H5nLa' on 'PLoTSQ'
#
# Analysing '4OFGWn' on 'PLoTSQ'
#
# Analysing '4S8ZQ8' on 'PLoTSQ'
#
# Analysing '4U9KUq' on 'PLoTSQ'
#
# Analysing '4v1b4d' on 'PLoTSQ'
#
# Analysing '4Y8AoH' on 'PLoTSQ'
#
# Analysing '4yzHEh' on 'PLoTSQ'
#
# Analysing '4ZOfO2' on 'PLoTSQ'
#
# Analysing '521YOu' on 'PLoTSQ'
#
# Analysing '527QLX' on 'PLoTSQ'
#
# Analysing '53lb2J' on 'PLoTSQ'
#
# Analysing '53oKz4' on 'PLoTSQ'
#
# Analysing '53yNiS' on 'PLoTSQ'
#
# Analysing '56M8LH' on 'PLoTSQ'
#
# Analysing '58cKz9' on 'PLoTSQ'
#
# Analysing '59mV5y' on 'PLoTSQ'
#
# Analysing '5a5f6V' on 'PLoTSQ'
#
# Analysing '5aeb2d' on 'PLoTSQ'
#
# Analysing '5ax0cA' on 'PLoTSQ'
#
# Analysing '5aZm2J' on 'PLoTSQ'
#
# Analysing '5b82JJ' on 'PLoTSQ'
#
# Analysing '5HMiue' on 'PLoTSQ'
#
# Analysing '5Ho86r' on 'PLoTSQ'
#
# Analysing '5hQxLm' on 'PLoTSQ'
#
# Analysing '5jlU4b' on 'PLoTSQ'
#
# Analysing '5kDtgE' on 'PLoTSQ'
#
# Analysing '5MFCKO' on 'PLoTSQ'
#
# Analysing '5MfhUv' on 'PLoTSQ'
#
# Analysing '5nzPXq' on 'PLoTSQ'
#
# Analysing '5OEpsM' on 'PLoTSQ'
#
# Analysing '5onXqI' on 'PLoTSQ'
#
# Analysing '5PGy0C' on 'PLoTSQ'
#
# Analysing '5pJFtX' on 'PLoTSQ'
#
# Analysing '5pkxXu' on 'PLoTSQ'
#
# Analysing '5POcGK' on 'PLoTSQ'
#
# Analysing '5QtNq3' on 'PLoTSQ'
#
# Analysing '5s3vE0' on 'PLoTSQ'
#
# Analysing '5S3YMf' on 'PLoTSQ'
#
# Analysing '5ShC4r' on 'PLoTSQ'
#
# Analysing '5thHat' on 'PLoTSQ'
#
# Analysing '5u63qu' on 'PLoTSQ'
#
# Analysing '5ulzlM' on 'PLoTSQ'
#
# Analysing '5UWGNV' on 'PLoTSQ'
#
# Analysing '5V21jX' on 'PLoTSQ'
#
# Analysing '5vCGnL' on 'PLoTSQ'
#
# Analysing '5W6Ya7' on 'PLoTSQ'
#
# Analysing '5WBNWV' on 'PLoTSQ'
#
# Analysing '5yYSKu' on 'PLoTSQ'
#
# Analysing '5Zx8aK' on 'PLoTSQ'
#
# Analysing '61H1eh' on 'PLoTSQ'
#
# Analysing '67GpWz' on 'PLoTSQ'
#
# Analysing '6AjeKB' on 'PLoTSQ'
#
# Analysing '6b6PeB' on 'PLoTSQ'
#
# Analysing '6cDi3Y' on 'PLoTSQ'
#
# Analysing '6eFJAA' on 'PLoTSQ'
#
# Analysing '6fBl8Q' on 'PLoTSQ'
#
# Analysing '6gopPV' on 'PLoTSQ'
#
# Analysing '6GR1qC' on 'PLoTSQ'
#
# Analysing '6isSS2' on 'PLoTSQ'
#
# Analysing '6iW2gU' on 'PLoTSQ'
#
# Analysing '6IWlFa' on 'PLoTSQ'
#
# Analysing '6j8ANh' on 'PLoTSQ'
#
# Analysing '6JXBrq' on 'PLoTSQ'
#
# Analysing '6lNTSp' on 'PLoTSQ'
#
# Analysing '6M5e79' on 'PLoTSQ'
#
# Analysing '6mj6bW' on 'PLoTSQ'
#
# Analysing '6MUq6I' on 'PLoTSQ'
#
# Analysing '6OdZub' on 'PLoTSQ'
#
# Analysing '6q7soC' on 'PLoTSQ'
#
# Analysing '6QJXCb' on 'PLoTSQ'
#
# Analysing '6r9o02' on 'PLoTSQ'
#
# Analysing '6rEleR' on 'PLoTSQ'
#
# Analysing '6RlMnV' on 'PLoTSQ'
#
# Analysing '6Rqlka' on 'PLoTSQ'
#
# Analysing '6uJdXY' on 'PLoTSQ'
#
# Analysing '6UqMSy' on 'PLoTSQ'
#
# Analysing '6UXSlI' on 'PLoTSQ'
#
# Analysing '70wqke' on 'PLoTSQ'
#
# Analysing '71aQjZ' on 'PLoTSQ'
#
# Analysing '76p0lP' on 'PLoTSQ'
#
# Analysing '78BoD3' on 'PLoTSQ'
#
# Analysing '7A4JBN' on 'PLoTSQ'
#
# Analysing '7AM7sq' on 'PLoTSQ'
#
# Analysing '7APsOy' on 'PLoTSQ'
#
# Analysing '7AsvcK' on 'PLoTSQ'
#
# Analysing '7C5YhW' on 'PLoTSQ'
#
# Analysing '7DrnXF' on 'PLoTSQ'
#
# Analysing '7FMiMl' on 'PLoTSQ'
#
# Analysing '7FR7Fe' on 'PLoTSQ'
#
# Analysing '7fsE2W' on 'PLoTSQ'
#
# Analysing '7fZugq' on 'PLoTSQ'
#
# Analysing '7GgABD' on 'PLoTSQ'
#
# Analysing '7H8CLk' on 'PLoTSQ'
#
# Analysing '7hBXLV' on 'PLoTSQ'
#
# Analysing '7Hvjht' on 'PLoTSQ'
#
# Analysing '7iOZom' on 'PLoTSQ'
#
# Analysing '7j44ZZ' on 'PLoTSQ'
#
# Analysing '7kxXTI' on 'PLoTSQ'
#
# Analysing '7LsY7g' on 'PLoTSQ'
#
# Analysing '7lvmXC' on 'PLoTSQ'
#
# Analysing '7NkHYS' on 'PLoTSQ'
#
# Analysing '7O7D5w' on 'PLoTSQ'
#
# Analysing '7p6vDZ' on 'PLoTSQ'
#
# Analysing '7pyzc9' on 'PLoTSQ'
#
# Analysing '7qBP8f' on 'PLoTSQ'
#
# Analysing '7qvCLy' on 'PLoTSQ'
#
# Analysing '7Re6ij' on 'PLoTSQ'
#
# Analysing '7rWr5w' on 'PLoTSQ'
#
# Analysing '7rXpZX' on 'PLoTSQ'
#
# Analysing '7se4jB' on 'PLoTSQ'
#
# Analysing '7t4LUX' on 'PLoTSQ'
#
# Analysing '7UE9jD' on 'PLoTSQ'
#
# Analysing '7VdcrI' on 'PLoTSQ'
#
# Analysing '7wblPl' on 'PLoTSQ'
#
# Analysing '7wYXGR' on 'PLoTSQ'
#
# Analysing '7XvfhZ' on 'PLoTSQ'
#
# Analysing '806rh8' on 'PLoTSQ'
#
# Analysing '87Pe1f' on 'PLoTSQ'
#
# Analysing '88EPQd' on 'PLoTSQ'
#
# Analysing '8aBfeX' on 'PLoTSQ'
#
# Analysing '8auBAz' on 'PLoTSQ'
#
# Analysing '8bVM1F' on 'PLoTSQ'
#
# Analysing '8BW2Kw' on 'PLoTSQ'
#
# Analysing '8cT51l' on 'PLoTSQ'
#
# Analysing '8E3zRC' on 'PLoTSQ'
#
# Analysing '8e4QNT' on 'PLoTSQ'
#
# Analysing '8euSt7' on 'PLoTSQ'
#
# Analysing '8GHCyR' on 'PLoTSQ'
#
# Analysing '8IhiOm' on 'PLoTSQ'
#
# Analysing '8jI0UW' on 'PLoTSQ'
#
# Analysing '8jxfS3' on 'PLoTSQ'
#
# Analysing '8kOS8d' on 'PLoTSQ'
#
# Analysing '8lFtoW' on 'PLoTSQ'
#
# Analysing '8mSMg6' on 'PLoTSQ'
#
# Analysing '8RDAWU' on 'PLoTSQ'
#
# Analysing '8RTOOJ' on 'PLoTSQ'
#
# Analysing '8S8S9d' on 'PLoTSQ'
#
# Analysing '8temwQ' on 'PLoTSQ'
#
# Analysing '8uqsc0' on 'PLoTSQ'
#
# Analysing '8WbcYg' on 'PLoTSQ'
#
# Analysing '8Wlhwj' on 'PLoTSQ'
#
# Analysing '8XwJh1' on 'PLoTSQ'
#
# Analysing '8Yatbm' on 'PLoTSQ'
#
# Analysing '8YgwcK' on 'PLoTSQ'
#
# Analysing '8YNnuA' on 'PLoTSQ'
#
# Analysing '8ZOmj9' on 'PLoTSQ'
#
# Analysing '8ZZUQ3' on 'PLoTSQ'
#
# Analysing '93sEDg' on 'PLoTSQ'
#
# Analysing '94aAig' on 'PLoTSQ'
#
# Analysing '96LDpu' on 'PLoTSQ'
#
# Analysing '96o3Ui' on 'PLoTSQ'
#
# Analysing '98vUek' on 'PLoTSQ'
#
# Analysing '9C7B9n' on 'PLoTSQ'
#
# Analysing '9fekE9' on 'PLoTSQ'
#
# Analysing '9fiJVg' on 'PLoTSQ'
#
# Analysing '9GraHd' on 'PLoTSQ'
#
# Analysing '9jk3pD' on 'PLoTSQ'
#
# Analysing '9JsNzR' on 'PLoTSQ'
#
# Analysing '9lEvK1' on 'PLoTSQ'
#
# Analysing '9MMici' on 'PLoTSQ'
#
# Analysing '9O0fL2' on 'PLoTSQ'
#
# Analysing '9PdwKu' on 'PLoTSQ'
#
# Analysing '9Pgz55' on 'PLoTSQ'
#
# Analysing '9q3dCL' on 'PLoTSQ'
#
# Analysing '9rpM1H' on 'PLoTSQ'
#
# Analysing '9sQ1dq' on 'PLoTSQ'
#
# Analysing '9SR6iu' on 'PLoTSQ'
#
# Analysing '9UiEW1' on 'PLoTSQ'
#
# Analysing '9v0FuW' on 'PLoTSQ'
#
# Analysing '9wlTAG' on 'PLoTSQ'
#
# Analysing '9xfmfA' on 'PLoTSQ'
#
# Analysing '9y5UX9' on 'PLoTSQ'
#
# Analysing '9yPZEP' on 'PLoTSQ'
#
# Analysing '9Yt0pA' on 'PLoTSQ'
#
# Analysing '9YzCrs' on 'PLoTSQ'
#
# Analysing '9ZgqY8' on 'PLoTSQ'
#
# Analysing '9zUwZs' on 'PLoTSQ'
#
# Analysing 'A2mDiM' on 'PLoTSQ'
#
# Analysing 'A3joHP' on 'PLoTSQ'
#
# Analysing 'A40C8L' on 'PLoTSQ'
#
# Analysing 'a4IdYK' on 'PLoTSQ'
#
# Analysing 'a5W7kq' on 'PLoTSQ'
#
# Analysing 'A8CZ0I' on 'PLoTSQ'
#
# Analysing 'A8dO0u' on 'PLoTSQ'
#
# Analysing 'A9LRCP' on 'PLoTSQ'
#
# Analysing 'A9TfO4' on 'PLoTSQ'
#
# Analysing 'AAVBZu' on 'PLoTSQ'
#
# Analysing 'ab52KV' on 'PLoTSQ'
#
# Analysing 'abFUPI' on 'PLoTSQ'
#
# Analysing 'abnRhD' on 'PLoTSQ'
#
# Analysing 'aC0Wjk' on 'PLoTSQ'
#
# Analysing 'AcgWjX' on 'PLoTSQ'
#
# Analysing 'AcnOgp' on 'PLoTSQ'
#
# Analysing 'AD6lLM' on 'PLoTSQ'
#
# Analysing 'aDlIYq' on 'PLoTSQ'
#
# Analysing 'aDNVRd' on 'PLoTSQ'
#
# Analysing 'afwk4X' on 'PLoTSQ'
#
# Analysing 'agGIoB' on 'PLoTSQ'
#
# Analysing 'agTbOA' on 'PLoTSQ'
#
# Analysing 'AgXDaZ' on 'PLoTSQ'
#
# Analysing 'ah43Si' on 'PLoTSQ'
#
# Analysing 'ahHAvO' on 'PLoTSQ'
#
# Analysing 'ahl81k' on 'PLoTSQ'
#
# Analysing 'AhQJBM' on 'PLoTSQ'
#
# Analysing 'aI2mkd' on 'PLoTSQ'
#
# Analysing 'AIECtS' on 'PLoTSQ'
#
# Analysing 'AIWbb6' on 'PLoTSQ'
#
# Analysing 'AJ6e38' on 'PLoTSQ'
#
# Analysing 'aJ84yO' on 'PLoTSQ'
#
# Analysing 'ajHoge' on 'PLoTSQ'
#
# Analysing 'AKNREu' on 'PLoTSQ'
#
# Analysing 'aKtXBG' on 'PLoTSQ'
#
# Analysing 'akxcFz' on 'PLoTSQ'
#
# Analysing 'AkyK30' on 'PLoTSQ'
#
# Analysing 'AL32GU' on 'PLoTSQ'
#
# Analysing 'al6JAy' on 'PLoTSQ'
#
# Analysing 'alWpml' on 'PLoTSQ'
#
# Analysing 'AmgwPv' on 'PLoTSQ'
#
# Analysing 'amJciV' on 'PLoTSQ'
#
# Analysing 'AMkHZM' on 'PLoTSQ'
#
# Analysing 'Amp1vr' on 'PLoTSQ'
#
# Analysing 'AMR7pA' on 'PLoTSQ'
#
# Analysing 'amT9XI' on 'PLoTSQ'
#
# Analysing 'aNd5x9' on 'PLoTSQ'
#
# Analysing 'aNgabn' on 'PLoTSQ'
#
# Analysing 'Angv0K' on 'PLoTSQ'
#
# Analysing 'AnNENP' on 'PLoTSQ'
#
# Analysing 'ANui2J' on 'PLoTSQ'
#
# Analysing 'aODBoK' on 'PLoTSQ'
#
# Analysing 'AodGF9' on 'PLoTSQ'
#
# Analysing 'aouvE0' on 'PLoTSQ'
#
# Analysing 'ApBZcx' on 'PLoTSQ'
#
# Analysing 'apt1oB' on 'PLoTSQ'
#
# Analysing 'APyXou' on 'PLoTSQ'
#
# Analysing 'aqBsbZ' on 'PLoTSQ'
#
# Analysing 'AQcba9' on 'PLoTSQ'
#
# Analysing 'AQQOpV' on 'PLoTSQ'
#
# Analysing 'aRBEC1' on 'PLoTSQ'
#
# Analysing 'aSIbTK' on 'PLoTSQ'
#
# Analysing 'AtEBfN' on 'PLoTSQ'
#
# Analysing 'au7MQc' on 'PLoTSQ'
#
# Analysing 'AuoCRn' on 'PLoTSQ'
#
# Analysing 'AuSRvO' on 'PLoTSQ'
#
# Analysing 'auxJhF' on 'PLoTSQ'
#
# Analysing 'aUxlJ7' on 'PLoTSQ'
#
# Analysing 'Av0wk9' on 'PLoTSQ'
#
# Analysing 'av6rx7' on 'PLoTSQ'
#
# Analysing 'aVKvsB' on 'PLoTSQ'
#
# Analysing 'AvyVKa' on 'PLoTSQ'
#
# Analysing 'aw3JlE' on 'PLoTSQ'
#
# Analysing 'AW7E6w' on 'PLoTSQ'
#
# Analysing 'AwWwRt' on 'PLoTSQ'
#
# Analysing 'AwY6X6' on 'PLoTSQ'
#
# Analysing 'AxzQHF' on 'PLoTSQ'
#
# Analysing 'aYu7cO' on 'PLoTSQ'
#
# Analysing 'AZ9o1L' on 'PLoTSQ'
#
# Analysing 'AZdGIW' on 'PLoTSQ'
#
# Analysing 'B0ai7P' on 'PLoTSQ'
#
# Analysing 'B0HbaB' on 'PLoTSQ'
#
# Analysing 'B2V1bh' on 'PLoTSQ'
#
# Analysing 'B3HPcK' on 'PLoTSQ'
#
# Analysing 'B53DUz' on 'PLoTSQ'
#
# Analysing 'B5xZYc' on 'PLoTSQ'
#
# Analysing 'B7cpGl' on 'PLoTSQ'
#
# Analysing 'B7ft72' on 'PLoTSQ'
#
# Analysing 'B7vTLV' on 'PLoTSQ'
#
# Analysing 'b81Ng1' on 'PLoTSQ'
#
# Analysing 'b883QL' on 'PLoTSQ'
#
# Analysing 'BauA9E' on 'PLoTSQ'
#
# Analysing 'bb62rx' on 'PLoTSQ'
#
# Analysing 'Bb7h1T' on 'PLoTSQ'
#
# Analysing 'BBT20p' on 'PLoTSQ'
#
# Analysing 'BBVjXR' on 'PLoTSQ'
#
# Analysing 'BC5LGW' on 'PLoTSQ'
#
# Analysing 'bc6VGj' on 'PLoTSQ'
#
# Analysing 'BCtGH0' on 'PLoTSQ'
#
# Analysing 'bCyF8j' on 'PLoTSQ'
#
# Analysing 'Bd1FsJ' on 'PLoTSQ'
#
# Analysing 'BdilD7' on 'PLoTSQ'
#
# Analysing 'Bdm1Tz' on 'PLoTSQ'
#
# Analysing 'Be30iU' on 'PLoTSQ'
#
# Analysing 'bEnUGa' on 'PLoTSQ'
#
# Analysing 'beZ34Y' on 'PLoTSQ'
#
# Analysing 'BfP0WT' on 'PLoTSQ'
#
# Analysing 'BfYenS' on 'PLoTSQ'
#
# Analysing 'bGAPjK' on 'PLoTSQ'
#
# Analysing 'bGFd8a' on 'PLoTSQ'
#
# Analysing 'BgtIDz' on 'PLoTSQ'
#
# Analysing 'BGtZHV' on 'PLoTSQ'
#
# Analysing 'bHgdQA' on 'PLoTSQ'
#
# Analysing 'BHQMBI' on 'PLoTSQ'
#
# Analysing 'bHrWy4' on 'PLoTSQ'
#
# Analysing 'BiYeNw' on 'PLoTSQ'
#
# Analysing 'BJ06tx' on 'PLoTSQ'
#
# Analysing 'bJ4CB3' on 'PLoTSQ'
#
# Analysing 'bjXeMo' on 'PLoTSQ'
#
# Analysing 'BJXXV5' on 'PLoTSQ'
#
# Analysing 'BkPpDG' on 'PLoTSQ'
#
# Analysing 'bkRnij' on 'PLoTSQ'
#
# Analysing 'bKYCi7' on 'PLoTSQ'
#
# Analysing 'BlgYXj' on 'PLoTSQ'
#
# Analysing 'BLUzpU' on 'PLoTSQ'
#
# Analysing 'bMk3hF' on 'PLoTSQ'
#
# Analysing 'bNDHQR' on 'PLoTSQ'
#
# Analysing 'bnGiyP' on 'PLoTSQ'
#
# Analysing 'BNQBTg' on 'PLoTSQ'
#
# Analysing 'bNUAkQ' on 'PLoTSQ'
#
# Analysing 'BNVDLk' on 'PLoTSQ'
#
# Analysing 'Bnw6lR' on 'PLoTSQ'
#
# Analysing 'BOub1z' on 'PLoTSQ'
#
# Analysing 'BPaKVD' on 'PLoTSQ'
#
# Analysing 'bPdQ9J' on 'PLoTSQ'
#
# Analysing 'bPJylz' on 'PLoTSQ'
#
# Analysing 'bq8t0j' on 'PLoTSQ'
#
# Analysing 'BQEyyc' on 'PLoTSQ'
#
# Analysing 'BqFgog' on 'PLoTSQ'
#
# Analysing 'BrPNPl' on 'PLoTSQ'
#
# Analysing 'bS9rRc' on 'PLoTSQ'
#
# Analysing 'bScRFw' on 'PLoTSQ'
#
# Analysing 'BSDitt' on 'PLoTSQ'
#
# Analysing 'BSNccI' on 'PLoTSQ'
#
# Analysing 'bSVfzt' on 'PLoTSQ'
#
# Analysing 'bTe61e' on 'PLoTSQ'
#
# Analysing 'btGVAf' on 'PLoTSQ'
#
# Analysing 'bTrOvp' on 'PLoTSQ'
#
# Analysing 'bTwcnG' on 'PLoTSQ'
#
# Analysing 'BTzAun' on 'PLoTSQ'
#
# Analysing 'BU78qP' on 'PLoTSQ'
#
# Analysing 'BuKaaK' on 'PLoTSQ'
#
# Analysing 'BuLuw2' on 'PLoTSQ'
#
# Analysing 'BurFCs' on 'PLoTSQ'
#
# Analysing 'BVBGWw' on 'PLoTSQ'
#
# Analysing 'bvPaq2' on 'PLoTSQ'
#
# Analysing 'bvvv0D' on 'PLoTSQ'
#
# Analysing 'BWibyW' on 'PLoTSQ'
#
# Analysing 'bwuXWF' on 'PLoTSQ'
#
# Analysing 'BX47TD' on 'PLoTSQ'
#
# Analysing 'bXgRJE' on 'PLoTSQ'
#
# Analysing 'BxhdM0' on 'PLoTSQ'
#
# Analysing 'BXs71A' on 'PLoTSQ'
#
# Analysing 'bxwz91' on 'PLoTSQ'
#
# Analysing 'ByDE7W' on 'PLoTSQ'
#
# Analysing 'ByFsfC' on 'PLoTSQ'
#
# Analysing 'BYUbCE' on 'PLoTSQ'
#
# Analysing 'BZ7YRY' on 'PLoTSQ'
#
# Analysing 'bZPSIn' on 'PLoTSQ'
#
# Analysing 'bzu2kA' on 'PLoTSQ'
#
# Analysing 'c1phzW' on 'PLoTSQ'
#
# Analysing 'C1se1L' on 'PLoTSQ'
#
# Analysing 'C2pyrZ' on 'PLoTSQ'
#
# Analysing 'C4E6Tz' on 'PLoTSQ'
#
# Analysing 'c6SvbG' on 'PLoTSQ'
#
# Analysing 'c780sq' on 'PLoTSQ'
#
# Analysing 'c8pkqo' on 'PLoTSQ'
#
# Analysing 'C9ByyF' on 'PLoTSQ'
#
# Analysing 'ca81w5' on 'PLoTSQ'
#
# Analysing 'cACgs1' on 'PLoTSQ'
#
# Analysing 'CAjdVm' on 'PLoTSQ'
#
# Analysing 'Casr0l' on 'PLoTSQ'
#
# Analysing 'cbx9s9' on 'PLoTSQ'
#
# Analysing 'cC4StV' on 'PLoTSQ'
#
# Analysing 'cce6FC' on 'PLoTSQ'
#
# Analysing 'ccnngi' on 'PLoTSQ'
#
# Analysing 'CCr5sy' on 'PLoTSQ'
#
# Analysing 'CcS25Z' on 'PLoTSQ'
#
# Analysing 'cCsajo' on 'PLoTSQ'
#
# Analysing 'cDClCX' on 'PLoTSQ'
#
# Analysing 'cdQIlo' on 'PLoTSQ'
#
# Analysing 'CE1iMo' on 'PLoTSQ'
#
# Analysing 'ceC1Lz' on 'PLoTSQ'
#
# Analysing 'CeoGwr' on 'PLoTSQ'
#
# Analysing 'CfdsVH' on 'PLoTSQ'
#
# Analysing 'Cfz7oN' on 'PLoTSQ'
#
# Analysing 'Cg3cpf' on 'PLoTSQ'
#
# Analysing 'cG7rkN' on 'PLoTSQ'
#
# Analysing 'Cg7VFY' on 'PLoTSQ'
#
# Analysing 'cgbcWN' on 'PLoTSQ'
#
# Analysing 'ChOB6P' on 'PLoTSQ'
#
# Analysing 'ChZiaL' on 'PLoTSQ'
#
# Analysing 'ciIBux' on 'PLoTSQ'
#
# Analysing 'cJ6XoB' on 'PLoTSQ'
#
# Analysing 'cJMLuy' on 'PLoTSQ'
#
# Analysing 'CkoA6i' on 'PLoTSQ'
#
# Analysing 'ckrUQO' on 'PLoTSQ'
#
# Analysing 'clPC4O' on 'PLoTSQ'
#
# Analysing 'cmeP9m' on 'PLoTSQ'
#
# Analysing 'CmiZdW' on 'PLoTSQ'
#
# Analysing 'CmpoA1' on 'PLoTSQ'
#
# Analysing 'CMQTMJ' on 'PLoTSQ'
#
# Analysing 'cMSNuj' on 'PLoTSQ'
#
# Analysing 'cOJIOf' on 'PLoTSQ'
#
# Analysing 'CoMuql' on 'PLoTSQ'
#
# Analysing 'coSk8n' on 'PLoTSQ'
#
# Analysing 'cp7ICr' on 'PLoTSQ'
#
# Analysing 'cpAdvD' on 'PLoTSQ'
#
# Analysing 'CpBmC6' on 'PLoTSQ'
#
# Analysing 'CpFfr5' on 'PLoTSQ'
#
# Analysing 'CpvJYn' on 'PLoTSQ'
#
# Analysing 'cPyA3r' on 'PLoTSQ'
#
# Analysing 'Cqf6H2' on 'PLoTSQ'
#
# Analysing 'cqH2wn' on 'PLoTSQ'
#
# No SNPs available for MR analysis of 'CR668A' on 'PLoTSQ'
#
# Analysing 'cRxjA1' on 'PLoTSQ'
#
# Analysing 'cs4xpc' on 'PLoTSQ'
#
# Analysing 'cS9kAg' on 'PLoTSQ'
#
# Analysing 'CsfOOD' on 'PLoTSQ'
#
# Analysing 'csiy02' on 'PLoTSQ'
#
# Analysing 'CsNCfY' on 'PLoTSQ'
#
# Analysing 'ctF30A' on 'PLoTSQ'
#
# Analysing 'cUnXJq' on 'PLoTSQ'
#
# Analysing 'CUpg2p' on 'PLoTSQ'
#
# Analysing 'CVTJDh' on 'PLoTSQ'
#
# Analysing 'CVzseg' on 'PLoTSQ'
#
# Analysing 'Cw2UA2' on 'PLoTSQ'
#
# Analysing 'Cw3quT' on 'PLoTSQ'
#
# Analysing 'Cw991h' on 'PLoTSQ'
#
# Analysing 'cwkKN5' on 'PLoTSQ'
#
# Analysing 'Cwlphs' on 'PLoTSQ'
#
# Analysing 'cwNVSd' on 'PLoTSQ'
#
# Analysing 'CxEGqK' on 'PLoTSQ'
#
# Analysing 'cxgf12' on 'PLoTSQ'
#
# Analysing 'cXJm7u' on 'PLoTSQ'
#
# Analysing 'CXryLC' on 'PLoTSQ'
#
# Analysing 'cXUyKd' on 'PLoTSQ'
#
# Analysing 'Cy0GOT' on 'PLoTSQ'
#
# Analysing 'cZgJnr' on 'PLoTSQ'
#
# Analysing 'CZViuU' on 'PLoTSQ'
#
# Analysing 'd036V1' on 'PLoTSQ'
#
# Analysing 'D06Xpb' on 'PLoTSQ'
#
# Analysing 'D0Ov1T' on 'PLoTSQ'
#
# Analysing 'D0PiS4' on 'PLoTSQ'
#
# Analysing 'd1Hm7A' on 'PLoTSQ'
#
# Analysing 'D1Svel' on 'PLoTSQ'
#
# Analysing 'd2XScE' on 'PLoTSQ'
#
# Analysing 'D4L6QL' on 'PLoTSQ'
#
# Analysing 'D7uf4d' on 'PLoTSQ'
#
# Analysing 'd7y4HE' on 'PLoTSQ'
#
# Analysing 'D8cMv7' on 'PLoTSQ'
#
# Analysing 'D8omWN' on 'PLoTSQ'
#
# Analysing 'D8WPN4' on 'PLoTSQ'
#
# Analysing 'd8Z3zu' on 'PLoTSQ'
#
# Analysing 'D9blEl' on 'PLoTSQ'
#
# Analysing 'D9CqeV' on 'PLoTSQ'
#
# Analysing 'D9f6kZ' on 'PLoTSQ'
#
# Analysing 'd9fmtC' on 'PLoTSQ'
#
# Analysing 'D9nvi7' on 'PLoTSQ'
#
# Analysing 'dAhI8v' on 'PLoTSQ'
#
# Analysing 'DAJGfd' on 'PLoTSQ'
#
# Analysing 'dAQNaB' on 'PLoTSQ'
#
# Analysing 'dauagA' on 'PLoTSQ'
#
# Analysing 'Db5oJG' on 'PLoTSQ'
#
# Analysing 'dbNG4F' on 'PLoTSQ'
#
# Analysing 'DcgV3X' on 'PLoTSQ'
#
# Analysing 'dDjHPy' on 'PLoTSQ'
#
# Analysing 'DFBCMT' on 'PLoTSQ'
#
# Analysing 'dhNo5H' on 'PLoTSQ'
#
# Analysing 'di8SrN' on 'PLoTSQ'
#
# Analysing 'DIwblZ' on 'PLoTSQ'
#
# Analysing 'DiwS2p' on 'PLoTSQ'
#
# Analysing 'diypE8' on 'PLoTSQ'
#
# Analysing 'dJ8lbW' on 'PLoTSQ'
#
# Analysing 'dJY2CU' on 'PLoTSQ'
#
# Analysing 'dl1DRz' on 'PLoTSQ'
#
# Analysing 'DmBN9c' on 'PLoTSQ'
#
# Analysing 'DMPOxn' on 'PLoTSQ'
#
# Analysing 'dn7Dop' on 'PLoTSQ'
#
# Analysing 'dnqNfT' on 'PLoTSQ'
#
# Analysing 'DnVAaQ' on 'PLoTSQ'
#
# Analysing 'dNYGI4' on 'PLoTSQ'
#
# Analysing 'doFOkH' on 'PLoTSQ'
#
# Analysing 'dOfZpw' on 'PLoTSQ'
#
# Analysing 'DqJtdy' on 'PLoTSQ'
#
# Analysing 'dQze3t' on 'PLoTSQ'
#
# Analysing 'dRTSwU' on 'PLoTSQ'
#
# Analysing 'ds0Bvo' on 'PLoTSQ'
#
# Analysing 'dsKPBl' on 'PLoTSQ'
#
# Analysing 'dSplbJ' on 'PLoTSQ'
#
# Analysing 'dTjOva' on 'PLoTSQ'
#
# Analysing 'dUgaDZ' on 'PLoTSQ'
#
# Analysing 'dUwghb' on 'PLoTSQ'
#
# Analysing 'dwPL1q' on 'PLoTSQ'
#
# Analysing 'DWUSVc' on 'PLoTSQ'
#
# Analysing 'DYsvnP' on 'PLoTSQ'
#
# Analysing 'DztFqf' on 'PLoTSQ'
#
# Analysing 'e0jKC4' on 'PLoTSQ'
#
# Analysing 'E0jMcj' on 'PLoTSQ'
#
# Analysing 'E1MSOJ' on 'PLoTSQ'
#
# Analysing 'e1VqiE' on 'PLoTSQ'
#
# Analysing 'E2avcM' on 'PLoTSQ'
#
# Analysing 'e2QATy' on 'PLoTSQ'
#
# Analysing 'e3alYa' on 'PLoTSQ'
#
# Analysing 'E3VCkQ' on 'PLoTSQ'
#
# Analysing 'E4LPJL' on 'PLoTSQ'
#
# Analysing 'e514lC' on 'PLoTSQ'
#
# Analysing 'e5j9UE' on 'PLoTSQ'
#
# Analysing 'E68JYm' on 'PLoTSQ'
#
# Analysing 'E7wMB7' on 'PLoTSQ'
#
# Analysing 'E7ZW1n' on 'PLoTSQ'
#
# Analysing 'E8xrPm' on 'PLoTSQ'
#
# Analysing 'e9mu6C' on 'PLoTSQ'
#
# Analysing 'EAQGdd' on 'PLoTSQ'
#
# Analysing 'EB69Xu' on 'PLoTSQ'
#
# Analysing 'eBPca7' on 'PLoTSQ'
#
# Analysing 'EbUFrw' on 'PLoTSQ'
#
# Analysing 'EbYN4s' on 'PLoTSQ'
#
# Analysing 'EcFiVW' on 'PLoTSQ'
#
# Analysing 'ecUHLX' on 'PLoTSQ'
#
# Analysing 'EDEsZh' on 'PLoTSQ'
#
# Analysing 'eDNenN' on 'PLoTSQ'
#
# Analysing 'eDoJrK' on 'PLoTSQ'
#
# Analysing 'EdvUD3' on 'PLoTSQ'
#
# Analysing 'eE9bfp' on 'PLoTSQ'
#
# Analysing 'EebxcR' on 'PLoTSQ'
#
# Analysing 'eEDKYL' on 'PLoTSQ'
#
# Analysing 'EEJXMT' on 'PLoTSQ'
#
# Analysing 'Eevvoi' on 'PLoTSQ'
#
# Analysing 'EeyExq' on 'PLoTSQ'
#
# Analysing 'efZLpH' on 'PLoTSQ'
#
# Analysing 'EGji6u' on 'PLoTSQ'
#
# Analysing 'EgXbFt' on 'PLoTSQ'
#
# Analysing 'egxCbJ' on 'PLoTSQ'
#
# Analysing 'EgYQvH' on 'PLoTSQ'
#
# Analysing 'ehCiOj' on 'PLoTSQ'
#
# Analysing 'Ehv9O4' on 'PLoTSQ'
#
# Analysing 'ehVUuA' on 'PLoTSQ'
#
# Analysing 'eJN9jm' on 'PLoTSQ'
#
# Analysing 'eLaBdU' on 'PLoTSQ'
#
# Analysing 'ElDplR' on 'PLoTSQ'
#
# Analysing 'ElKdq9' on 'PLoTSQ'
#
# Analysing 'embsiK' on 'PLoTSQ'
#
# Analysing 'EnRKTN' on 'PLoTSQ'
#
# Analysing 'eP2mG4' on 'PLoTSQ'
#
# Analysing 'eP9ZbS' on 'PLoTSQ'
#
# Analysing 'eqlkDr' on 'PLoTSQ'
#
# Analysing 'eqoYt4' on 'PLoTSQ'
#
# Analysing 'eQwGr5' on 'PLoTSQ'
#
# Analysing 'eqXmsc' on 'PLoTSQ'
#
# Analysing 'ErCLVr' on 'PLoTSQ'
#
# Analysing 'ErgMwz' on 'PLoTSQ'
#
# Analysing 'ErjvZB' on 'PLoTSQ'
#
# Analysing 'ERqsAC' on 'PLoTSQ'
#
# Analysing 'eTHelb' on 'PLoTSQ'
#
# Analysing 'ETk4XI' on 'PLoTSQ'
#
# Analysing 'ETlYUB' on 'PLoTSQ'
#
# Analysing 'ETUETJ' on 'PLoTSQ'
#
# Analysing 'EtWRX4' on 'PLoTSQ'
#
# Analysing 'eUp2vr' on 'PLoTSQ'
#
# Analysing 'EV85mm' on 'PLoTSQ'
#
# Analysing 'EVnU4i' on 'PLoTSQ'
#
# Analysing 'EwJSxd' on 'PLoTSQ'
#
# Analysing 'ex6www' on 'PLoTSQ'
#
# Analysing 'eXBgXn' on 'PLoTSQ'
#
# Analysing 'eyCOzl' on 'PLoTSQ'
#
# Analysing 'EykUHA' on 'PLoTSQ'
#
# Analysing 'eYtqQR' on 'PLoTSQ'
#
# Analysing 'eZD09K' on 'PLoTSQ'
#
# Analysing 'EZtKkY' on 'PLoTSQ'
#
# Analysing 'f0BUjj' on 'PLoTSQ'
#
# Analysing 'F0QCQ3' on 'PLoTSQ'
#
# Analysing 'f83zKU' on 'PLoTSQ'
#
# Analysing 'F8c53B' on 'PLoTSQ'
#
# Analysing 'f8QtJT' on 'PLoTSQ'
#
# Analysing 'f9fNUB' on 'PLoTSQ'
#
# Analysing 'F9jRf0' on 'PLoTSQ'
#
# Analysing 'Fa3XFz' on 'PLoTSQ'
#
# Analysing 'FAEizE' on 'PLoTSQ'
#
# Analysing 'faiBMZ' on 'PLoTSQ'
#
# Analysing 'FAJJhg' on 'PLoTSQ'
#
# Analysing 'faqhET' on 'PLoTSQ'
#
# Analysing 'FarNqE' on 'PLoTSQ'
#
# Analysing 'FBt3fZ' on 'PLoTSQ'
#
# Analysing 'FBtVJ7' on 'PLoTSQ'
#
# Analysing 'fbvh5h' on 'PLoTSQ'
#
# Analysing 'FBWmOp' on 'PLoTSQ'
#
# Analysing 'fCcjca' on 'PLoTSQ'
#
# Analysing 'FcNdrr' on 'PLoTSQ'
#
# Analysing 'FCPijG' on 'PLoTSQ'
#
# Analysing 'FCsYGG' on 'PLoTSQ'
#
# Analysing 'fD4h6g' on 'PLoTSQ'
#
# Analysing 'fDeAz6' on 'PLoTSQ'
#
# Analysing 'FDL0cD' on 'PLoTSQ'
#
# Analysing 'feWbgF' on 'PLoTSQ'
#
# Analysing 'FfHf0e' on 'PLoTSQ'
#
# Analysing 'ffPU2w' on 'PLoTSQ'
#
# Analysing 'FfVxYe' on 'PLoTSQ'
#
# Analysing 'FGuy9x' on 'PLoTSQ'
#
# Analysing 'fHSWGg' on 'PLoTSQ'
#
# Analysing 'FISBmm' on 'PLoTSQ'
#
# Analysing 'fIxcRa' on 'PLoTSQ'
#
# Analysing 'Fj2DmE' on 'PLoTSQ'
#
# Analysing 'FJDsgL' on 'PLoTSQ'
#
# Analysing 'fJHh4k' on 'PLoTSQ'
#
# Analysing 'FJzJC6' on 'PLoTSQ'
#
# Analysing 'FK5Ccc' on 'PLoTSQ'
#
# Analysing 'Fklmb1' on 'PLoTSQ'
#
# Analysing 'fM3Fxc' on 'PLoTSQ'
#
# Analysing 'fm973x' on 'PLoTSQ'
#
# Analysing 'FMc8FH' on 'PLoTSQ'
#
# Analysing 'fMs83b' on 'PLoTSQ'
#
# Analysing 'fMYTjL' on 'PLoTSQ'
#
# Analysing 'FnhD9x' on 'PLoTSQ'
#
# Analysing 'FNliVc' on 'PLoTSQ'
#
# Analysing 'fnNwWs' on 'PLoTSQ'
#
# Analysing 'fo4L4d' on 'PLoTSQ'
#
# Analysing 'fopBrm' on 'PLoTSQ'
#
# Analysing 'FoQicc' on 'PLoTSQ'
#
# Analysing 'FpdZCI' on 'PLoTSQ'
#
# Analysing 'fpoUXg' on 'PLoTSQ'
#
# Analysing 'FqeFQh' on 'PLoTSQ'
#
# Analysing 'fR2HTf' on 'PLoTSQ'
#
# Analysing 'FS4oDW' on 'PLoTSQ'
#
# Analysing 'fsgvK4' on 'PLoTSQ'
#
# Analysing 'FsHUf0' on 'PLoTSQ'
#
# Analysing 'ftt0dF' on 'PLoTSQ'
#
# Analysing 'fucJHm' on 'PLoTSQ'
#
# Analysing 'FuFqZo' on 'PLoTSQ'
#
# Analysing 'FUQFGN' on 'PLoTSQ'
#
# Analysing 'fuQUbK' on 'PLoTSQ'
#
# Analysing 'FWapPV' on 'PLoTSQ'
#
# Analysing 'fwj3YF' on 'PLoTSQ'
#
# Analysing 'FWjngg' on 'PLoTSQ'
#
# Analysing 'FWToxk' on 'PLoTSQ'
#
# Analysing 'FxE55l' on 'PLoTSQ'
#
# Analysing 'fXeG3h' on 'PLoTSQ'
#
# Analysing 'fXqelB' on 'PLoTSQ'
#
# Analysing 'fxzQGX' on 'PLoTSQ'
#
# Analysing 'Fy5YaQ' on 'PLoTSQ'
#
# Analysing 'fzLdpy' on 'PLoTSQ'
#
# Analysing 'g0BJLf' on 'PLoTSQ'
#
# Analysing 'g0bxQk' on 'PLoTSQ'
#
# Analysing 'G1ujjP' on 'PLoTSQ'
#
# Analysing 'g2shHC' on 'PLoTSQ'
#
# Analysing 'g2umQL' on 'PLoTSQ'
#
# Analysing 'G3N1PY' on 'PLoTSQ'
#
# Analysing 'g46I0v' on 'PLoTSQ'
#
# Analysing 'g4hAIY' on 'PLoTSQ'
#
# Analysing 'g548tf' on 'PLoTSQ'
#
# Analysing 'g7wSGO' on 'PLoTSQ'
#
# Analysing 'g7wYoa' on 'PLoTSQ'
#
# Analysing 'G8YQCG' on 'PLoTSQ'
#
# Analysing 'g9bJm9' on 'PLoTSQ'
#
# Analysing 'g9gsPq' on 'PLoTSQ'
#
# Analysing 'Ga47ud' on 'PLoTSQ'
#
# Analysing 'gANXmT' on 'PLoTSQ'
#
# Analysing 'GAPcba' on 'PLoTSQ'
#
# Analysing 'gAV6Au' on 'PLoTSQ'
#
# Analysing 'GaVrbW' on 'PLoTSQ'
#
# Analysing 'GcP5tl' on 'PLoTSQ'
#
# Analysing 'gD2Jbm' on 'PLoTSQ'
#
# Analysing 'gF55Vv' on 'PLoTSQ'
#
# Analysing 'gFSiVR' on 'PLoTSQ'
#
# Analysing 'GG94fb' on 'PLoTSQ'
#
# Analysing 'gGC6vx' on 'PLoTSQ'
#
# Analysing 'gh1mqj' on 'PLoTSQ'
#
# Analysing 'GHJAw9' on 'PLoTSQ'
#
# Analysing 'ghsr9q' on 'PLoTSQ'
#
# Analysing 'gI3NHx' on 'PLoTSQ'
#
# Analysing 'gImeQo' on 'PLoTSQ'
#
# Analysing 'gjCqJh' on 'PLoTSQ'
#
# Analysing 'GjMlUA' on 'PLoTSQ'
#
# Analysing 'Gkbk3z' on 'PLoTSQ'
#
# Analysing 'Gkd4Rh' on 'PLoTSQ'
#
# Analysing 'Gl4usQ' on 'PLoTSQ'
#
# Analysing 'gLhz1z' on 'PLoTSQ'
#
# Analysing 'GlM00J' on 'PLoTSQ'
#
# Analysing 'gMZcIX' on 'PLoTSQ'
#
# Analysing 'gnCrKI' on 'PLoTSQ'
#
# Analysing 'go7DnQ' on 'PLoTSQ'
#
# Analysing 'gohTqy' on 'PLoTSQ'
#
# Analysing 'GpHmzO' on 'PLoTSQ'
#
# Analysing 'gPMXzH' on 'PLoTSQ'
#
# Analysing 'gQAdds' on 'PLoTSQ'
#
# Analysing 'GqFS7v' on 'PLoTSQ'
#
# Analysing 'GR4T2M' on 'PLoTSQ'
#
# Analysing 'grcjIh' on 'PLoTSQ'
#
# Analysing 'gRutjj' on 'PLoTSQ'
#
# Analysing 'GSnrHq' on 'PLoTSQ'
#
# Analysing 'gtgKK4' on 'PLoTSQ'
#
# Analysing 'gTHdt7' on 'PLoTSQ'
#
# Analysing 'gtqeHE' on 'PLoTSQ'
#
# Analysing 'GTyfj7' on 'PLoTSQ'
#
# Analysing 'GUiffj' on 'PLoTSQ'
#
# Analysing 'GutzhP' on 'PLoTSQ'
#
# Analysing 'gUvWlF' on 'PLoTSQ'
#
# Analysing 'GVE4dT' on 'PLoTSQ'
#
# Analysing 'GVfeRZ' on 'PLoTSQ'
#
# Analysing 'gVyQfu' on 'PLoTSQ'
#
# Analysing 'gwI1LH' on 'PLoTSQ'
#
# Analysing 'GWYFhW' on 'PLoTSQ'
#
# Analysing 'GY1LXs' on 'PLoTSQ'
#
# Analysing 'Gyeqen' on 'PLoTSQ'
#
# Analysing 'H0NTTM' on 'PLoTSQ'
#
# Analysing 'H0zfXS' on 'PLoTSQ'
#
# Analysing 'h14Zib' on 'PLoTSQ'
#
# Analysing 'H2DCRt' on 'PLoTSQ'
#
# Analysing 'H2E17v' on 'PLoTSQ'
#
# Analysing 'H4E5hc' on 'PLoTSQ'
#
# Analysing 'H4kHeZ' on 'PLoTSQ'
#
# Analysing 'h4wAcs' on 'PLoTSQ'
#
# Analysing 'H4yOuX' on 'PLoTSQ'
#
# Analysing 'H55Pcd' on 'PLoTSQ'
#
# Analysing 'h5IaqD' on 'PLoTSQ'
#
# Analysing 'H6ymze' on 'PLoTSQ'
#
# Analysing 'H7w51Y' on 'PLoTSQ'
#
# Analysing 'h8Wgcs' on 'PLoTSQ'
#
# Analysing 'hAMyKh' on 'PLoTSQ'
#
# Analysing 'hAy5NO' on 'PLoTSQ'
#
# Analysing 'HB1jUZ' on 'PLoTSQ'
#
# Analysing 'HBtFzV' on 'PLoTSQ'
#
# Analysing 'hCaVU8' on 'PLoTSQ'
#
# Analysing 'HcIfCJ' on 'PLoTSQ'
#
# Analysing 'hDTvAf' on 'PLoTSQ'
#
# Analysing 'hECw6j' on 'PLoTSQ'
#
# Analysing 'HffE5T' on 'PLoTSQ'
#
# Analysing 'HFLOOD' on 'PLoTSQ'
#
# Analysing 'Hfo8IY' on 'PLoTSQ'
#
# Analysing 'hg53hI' on 'PLoTSQ'
#
# Analysing 'HGN7CO' on 'PLoTSQ'
#
# Analysing 'hhQJ9p' on 'PLoTSQ'
#
# Analysing 'HHuugr' on 'PLoTSQ'
#
# Analysing 'hIC7Vs' on 'PLoTSQ'
#
# Analysing 'HiFAwy' on 'PLoTSQ'
#
# Analysing 'hj1M6s' on 'PLoTSQ'
#
# Analysing 'Hjab34' on 'PLoTSQ'
#
# Analysing 'hKFLND' on 'PLoTSQ'
#
# Analysing 'HkodEy' on 'PLoTSQ'
#
# Analysing 'hM260K' on 'PLoTSQ'
#
# Analysing 'hM3HoO' on 'PLoTSQ'
#
# Analysing 'HmA7Vk' on 'PLoTSQ'
#
# Analysing 'hMgsx8' on 'PLoTSQ'
#
# Analysing 'HN2WRz' on 'PLoTSQ'
#
# Analysing 'hNcLoe' on 'PLoTSQ'
#
# Analysing 'HNEgtA' on 'PLoTSQ'
#
# Analysing 'HNzQI1' on 'PLoTSQ'
#
# Analysing 'hO0xwH' on 'PLoTSQ'
#
# Analysing 'hpuGSX' on 'PLoTSQ'
#
# Analysing 'hq39tI' on 'PLoTSQ'
#
# Analysing 'HqMtqJ' on 'PLoTSQ'
#
# Analysing 'hqqAqL' on 'PLoTSQ'
#
# Analysing 'hR8LXw' on 'PLoTSQ'
#
# Analysing 'hSeNXR' on 'PLoTSQ'
#
# Analysing 'hsNGLN' on 'PLoTSQ'
#
# Analysing 'hSy9JB' on 'PLoTSQ'
#
# Analysing 'HSZeAx' on 'PLoTSQ'
#
# Analysing 'hSZuDr' on 'PLoTSQ'
#
# Analysing 'htOtj4' on 'PLoTSQ'
#
# Analysing 'HTxv7N' on 'PLoTSQ'
#
# Analysing 'hULbOv' on 'PLoTSQ'
#
# Analysing 'HvdgeC' on 'PLoTSQ'
#
# Analysing 'hVhBvj' on 'PLoTSQ'
#
# Analysing 'hVT3BL' on 'PLoTSQ'
#
# Analysing 'HwPQ1G' on 'PLoTSQ'
#
# Analysing 'Hxi4Aj' on 'PLoTSQ'
#
# Analysing 'HxPiBy' on 'PLoTSQ'
#
# Analysing 'HXvJ7h' on 'PLoTSQ'
#
# Analysing 'hYEDj2' on 'PLoTSQ'
#
# Analysing 'HYviYN' on 'PLoTSQ'
#
# Analysing 'hZA5k9' on 'PLoTSQ'
#
# Analysing 'HzQ2VA' on 'PLoTSQ'
#
# Analysing 'I11sIU' on 'PLoTSQ'
#
# Analysing 'I1mrRi' on 'PLoTSQ'
#
# Analysing 'I20WwX' on 'PLoTSQ'
#
# Analysing 'I2a6YL' on 'PLoTSQ'
#
# Analysing 'i2DZzf' on 'PLoTSQ'
#
# Analysing 'i2eRuM' on 'PLoTSQ'
#
# Analysing 'I2o4EG' on 'PLoTSQ'
#
# Analysing 'I5afYY' on 'PLoTSQ'
#
# Analysing 'I697kF' on 'PLoTSQ'
#
# Analysing 'I6AWwL' on 'PLoTSQ'
#
# Analysing 'I7ygqa' on 'PLoTSQ'
#
# Analysing 'i8Dnlq' on 'PLoTSQ'
#
# Analysing 'i8PJx5' on 'PLoTSQ'
#
# Analysing 'i9jphF' on 'PLoTSQ'
#
# Analysing 'iaKaLX' on 'PLoTSQ'
#
# Analysing 'IAMJx5' on 'PLoTSQ'
#
# Analysing 'IB7Sxp' on 'PLoTSQ'
#
# Analysing 'IbEAbv' on 'PLoTSQ'
#
# Analysing 'IcATbB' on 'PLoTSQ'
#
# Analysing 'iDgohi' on 'PLoTSQ'
#
# Analysing 'IdkmcG' on 'PLoTSQ'
#
# Analysing 'IduuvH' on 'PLoTSQ'
#
# Analysing 'idVFUh' on 'PLoTSQ'
#
# Analysing 'iDZ8US' on 'PLoTSQ'
#
# Analysing 'IE30hK' on 'PLoTSQ'
#
# Analysing 'ieBnmr' on 'PLoTSQ'
#
# Analysing 'ieUbzF' on 'PLoTSQ'
#
# Analysing 'iexsqA' on 'PLoTSQ'
#
# Analysing 'IfGOLy' on 'PLoTSQ'
#
# Analysing 'ifTQSn' on 'PLoTSQ'
#
# Analysing 'Ig1JcA' on 'PLoTSQ'
#
# Analysing 'IGiQ3M' on 'PLoTSQ'
#
# Analysing 'IgS86I' on 'PLoTSQ'
#
# Analysing 'IhEisW' on 'PLoTSQ'
#
# Analysing 'iHk1SB' on 'PLoTSQ'
#
# Analysing 'IHkBgo' on 'PLoTSQ'
#
# Analysing 'iHkzuC' on 'PLoTSQ'
#
# Analysing 'ihLlMy' on 'PLoTSQ'
#
# Analysing 'ihUaDi' on 'PLoTSQ'
#
# Analysing 'IjGwKt' on 'PLoTSQ'
#
# Analysing 'IjUHiL' on 'PLoTSQ'
#
# Analysing 'ik8N46' on 'PLoTSQ'
#
# Analysing 'ikrmVC' on 'PLoTSQ'
#
# Analysing 'ikZFpj' on 'PLoTSQ'
#
# Analysing 'ILmhmX' on 'PLoTSQ'
#
# Analysing 'iLsb3a' on 'PLoTSQ'
#
# Analysing 'IN66Ze' on 'PLoTSQ'
#
# Analysing 'InZ5yC' on 'PLoTSQ'
#
# Analysing 'iO0KL2' on 'PLoTSQ'
#
# Analysing 'iOEGcD' on 'PLoTSQ'
#
# Analysing 'iot4zl' on 'PLoTSQ'
#
# Analysing 'IOTO8W' on 'PLoTSQ'
#
# Analysing 'IOY1VY' on 'PLoTSQ'
#
# Analysing 'iPF9JT' on 'PLoTSQ'
#
# Analysing 'iPFIG1' on 'PLoTSQ'
#
# Analysing 'iPO8qY' on 'PLoTSQ'
#
# Analysing 'ipTLr0' on 'PLoTSQ'
#
# Analysing 'iqDhhC' on 'PLoTSQ'
#
# Analysing 'IrfjLC' on 'PLoTSQ'
#
# Analysing 'IRhTcN' on 'PLoTSQ'
#
# Analysing 'IS9P7y' on 'PLoTSQ'
#
# Analysing 'iSOBa3' on 'PLoTSQ'
#
# Analysing 'itltlK' on 'PLoTSQ'
#
# Analysing 'ITqWUA' on 'PLoTSQ'
#
# Analysing 'iTVcg8' on 'PLoTSQ'
#
# Analysing 'Ivb8BF' on 'PLoTSQ'
#
# Analysing 'IvsoeD' on 'PLoTSQ'
#
# Analysing 'IWixcS' on 'PLoTSQ'
#
# Analysing 'iwZnWO' on 'PLoTSQ'
#
# Analysing 'IxISQQ' on 'PLoTSQ'
#
# Analysing 'iXR6J6' on 'PLoTSQ'
#
# Analysing 'iyW9VO' on 'PLoTSQ'
#
# Analysing 'iZK3Vr' on 'PLoTSQ'
#
# Analysing 'iZyPJm' on 'PLoTSQ'
#
# Analysing 'j4hr78' on 'PLoTSQ'
#
# Analysing 'j5c6tp' on 'PLoTSQ'
#
# Analysing 'j5qJP0' on 'PLoTSQ'
#
# Analysing 'j7TCRX' on 'PLoTSQ'
#
# Analysing 'j8JKZM' on 'PLoTSQ'
#
# Analysing 'j8zd0W' on 'PLoTSQ'
#
# Analysing 'J9CCGf' on 'PLoTSQ'
#
# Analysing 'ja9kSn' on 'PLoTSQ'
#
# Analysing 'jbcorK' on 'PLoTSQ'
#
# Analysing 'JBtj7m' on 'PLoTSQ'
#
# Analysing 'jCJZwH' on 'PLoTSQ'
#
# Analysing 'jDzW2k' on 'PLoTSQ'
#
# Analysing 'JE2QBa' on 'PLoTSQ'
#
# Analysing 'JEVLBF' on 'PLoTSQ'
#
# Analysing 'JfAHbz' on 'PLoTSQ'
#
# Analysing 'jfQtzl' on 'PLoTSQ'
#
# Analysing 'jFwaWI' on 'PLoTSQ'
#
# Analysing 'Jg16zo' on 'PLoTSQ'
#
# Analysing 'jgbxkP' on 'PLoTSQ'
#
# Analysing 'jGPZys' on 'PLoTSQ'
#
# Analysing 'jGtXhJ' on 'PLoTSQ'
#
# Analysing 'JH1AZG' on 'PLoTSQ'
#
# Analysing 'Jh2Qc0' on 'PLoTSQ'
#
# Analysing 'jHnQPS' on 'PLoTSQ'
#
# Analysing 'JiBkXD' on 'PLoTSQ'
#
# Analysing 'JiXjvm' on 'PLoTSQ'
#
# Analysing 'jJ0aNW' on 'PLoTSQ'
#
# Analysing 'JjYTlO' on 'PLoTSQ'
#
# Analysing 'jK5YWb' on 'PLoTSQ'
#
# Analysing 'JKbouG' on 'PLoTSQ'
#
# Analysing 'Jl81M0' on 'PLoTSQ'
#
# Analysing 'jLe3v2' on 'PLoTSQ'
#
# Analysing 'JLiAMe' on 'PLoTSQ'
#
# Analysing 'JltWeG' on 'PLoTSQ'
#
# Analysing 'jLxtMO' on 'PLoTSQ'
#
# Analysing 'jmBBvx' on 'PLoTSQ'
#
# Analysing 'jN5Tp2' on 'PLoTSQ'
#
# Analysing 'jn6UUO' on 'PLoTSQ'
#
# Analysing 'JNCJ8K' on 'PLoTSQ'
#
# Analysing 'jNuUNf' on 'PLoTSQ'
#
# Analysing 'JOerAJ' on 'PLoTSQ'
#
# Analysing 'JpCE2v' on 'PLoTSQ'
#
# Analysing 'jqA4Ob' on 'PLoTSQ'
#
# Analysing 'JQrFLU' on 'PLoTSQ'
#
# Analysing 'Jr8qT8' on 'PLoTSQ'
#
# Analysing 'Jrm9uZ' on 'PLoTSQ'
#
# Analysing 'jSONy7' on 'PLoTSQ'
#
# Analysing 'JSRO3N' on 'PLoTSQ'
#
# Analysing 'JSvtBL' on 'PLoTSQ'
#
# Analysing 'jt302L' on 'PLoTSQ'
#
# Analysing 'jT35NP' on 'PLoTSQ'
#
# Analysing 'JtQ6eC' on 'PLoTSQ'
#
# Analysing 'jtXugy' on 'PLoTSQ'
#
# Analysing 'JU1m50' on 'PLoTSQ'
#
# Analysing 'jU3aul' on 'PLoTSQ'
#
# Analysing 'jUxjmd' on 'PLoTSQ'
#
# Analysing 'jVpaOU' on 'PLoTSQ'
#
# Analysing 'JW69ia' on 'PLoTSQ'
#
# Analysing 'jWlFIK' on 'PLoTSQ'
#
# Analysing 'JWU0He' on 'PLoTSQ'
#
# Analysing 'jX06dZ' on 'PLoTSQ'
#
# Analysing 'JXBEGq' on 'PLoTSQ'
#
# Analysing 'JxW4u3' on 'PLoTSQ'
#
# Analysing 'jxZorL' on 'PLoTSQ'
#
# Analysing 'JYZn6E' on 'PLoTSQ'
#
# Analysing 'k0oVUn' on 'PLoTSQ'
#
# Analysing 'k0VsTs' on 'PLoTSQ'
#
# Analysing 'k19XGv' on 'PLoTSQ'
#
# Analysing 'K2vdzY' on 'PLoTSQ'
#
# Analysing 'K3lqMM' on 'PLoTSQ'
#
# Analysing 'K3P2Dg' on 'PLoTSQ'
#
# Analysing 'k7gmXf' on 'PLoTSQ'
#
# Analysing 'K9B0lS' on 'PLoTSQ'
#
# Analysing 'k9yQRN' on 'PLoTSQ'
#
# Analysing 'kAHiW9' on 'PLoTSQ'
#
# Analysing 'Kbtoae' on 'PLoTSQ'
#
# Analysing 'kBYCFu' on 'PLoTSQ'
#
# Analysing 'kcKaZm' on 'PLoTSQ'
#
# Analysing 'KcO8Hf' on 'PLoTSQ'
#
# Analysing 'kcohnx' on 'PLoTSQ'
#
# Analysing 'KF1d7g' on 'PLoTSQ'
#
# Analysing 'kf7l6r' on 'PLoTSQ'
#
# Analysing 'KGNpGd' on 'PLoTSQ'
#
# Analysing 'KGoWvQ' on 'PLoTSQ'
#
# Analysing 'kgWzVK' on 'PLoTSQ'
#
# Analysing 'KhI3SR' on 'PLoTSQ'
#
# Analysing 'KhJ51n' on 'PLoTSQ'
#
# Analysing 'KhU2rq' on 'PLoTSQ'
#
# Analysing 'kinL9V' on 'PLoTSQ'
#
# Analysing 'kJiKVE' on 'PLoTSQ'
#
# Analysing 'KjUcY5' on 'PLoTSQ'
#
# Analysing 'kKkqHH' on 'PLoTSQ'
#
# Analysing 'kKxbI5' on 'PLoTSQ'
#
# Analysing 'Kldcqm' on 'PLoTSQ'
#
# Analysing 'kLFTSz' on 'PLoTSQ'
#
# Analysing 'km8aiJ' on 'PLoTSQ'
#
# Analysing 'KmLeFN' on 'PLoTSQ'
#
# Analysing 'kmOjMn' on 'PLoTSQ'
#
# Analysing 'kMorVU' on 'PLoTSQ'
#
# Analysing 'kmwOFA' on 'PLoTSQ'
#
# Analysing 'KnmAiu' on 'PLoTSQ'
#
# Analysing 'KnnaDi' on 'PLoTSQ'
#
# Analysing 'KnWltg' on 'PLoTSQ'
#
# Analysing 'KnXVIB' on 'PLoTSQ'
#
# Analysing 'kOgbyP' on 'PLoTSQ'
#
# Analysing 'KOGLwN' on 'PLoTSQ'
#
# Analysing 'korAAj' on 'PLoTSQ'
#
# Analysing 'KoWAcc' on 'PLoTSQ'
#
# Analysing 'kpbaKS' on 'PLoTSQ'
#
# Analysing 'KPgIIf' on 'PLoTSQ'
#
# Analysing 'kPkKz1' on 'PLoTSQ'
#
# Analysing 'KPn5Ar' on 'PLoTSQ'
#
# Analysing 'kpwrxk' on 'PLoTSQ'
#
# Analysing 'Kq0WjF' on 'PLoTSQ'
#
# Analysing 'kR1wvS' on 'PLoTSQ'
#
# Analysing 'krKZS7' on 'PLoTSQ'
#
# Analysing 'kSrIgT' on 'PLoTSQ'
#
# Analysing 'ktpgPw' on 'PLoTSQ'
#
# Analysing 'KUoKFf' on 'PLoTSQ'
#
# Analysing 'KUolTX' on 'PLoTSQ'
#
# Analysing 'kUwNyP' on 'PLoTSQ'
#
# Analysing 'kVI5HQ' on 'PLoTSQ'
#
# Analysing 'KVKp48' on 'PLoTSQ'
#
# Analysing 'KvoBfj' on 'PLoTSQ'
#
# Analysing 'Kw6B7Z' on 'PLoTSQ'
#
# Analysing 'kWSJ9n' on 'PLoTSQ'
#
# Analysing 'Kx8KAD' on 'PLoTSQ'
#
# Analysing 'KxiMoE' on 'PLoTSQ'
#
# Analysing 'KXPr8H' on 'PLoTSQ'
#
# Analysing 'l0DrBX' on 'PLoTSQ'
#
# Analysing 'L0EwfP' on 'PLoTSQ'
#
# Analysing 'L0SmDa' on 'PLoTSQ'
#
# Analysing 'l1YLek' on 'PLoTSQ'
#
# Analysing 'L233qR' on 'PLoTSQ'
#
# Analysing 'l2KpX1' on 'PLoTSQ'
#
# Analysing 'l2WcZI' on 'PLoTSQ'
#
# Analysing 'L3asYh' on 'PLoTSQ'
#
# Analysing 'L3ylbB' on 'PLoTSQ'
#
# Analysing 'L3ylLh' on 'PLoTSQ'
#
# Analysing 'l4VUyt' on 'PLoTSQ'
#
# Analysing 'l5mOza' on 'PLoTSQ'
#
# Analysing 'l5UrJF' on 'PLoTSQ'
#
# Analysing 'l5wsBD' on 'PLoTSQ'
#
# Analysing 'l6RLve' on 'PLoTSQ'
#
# Analysing 'l7icdg' on 'PLoTSQ'
#
# Analysing 'laiCr2' on 'PLoTSQ'
#
# Analysing 'LbFYmx' on 'PLoTSQ'
#
# Analysing 'lc7TYa' on 'PLoTSQ'
#
# Analysing 'lcvX1w' on 'PLoTSQ'
#
# Analysing 'lcYAw3' on 'PLoTSQ'
#
# Analysing 'Ld8OJf' on 'PLoTSQ'
#
# Analysing 'LDaBMG' on 'PLoTSQ'
#
# Analysing 'LDAnCS' on 'PLoTSQ'
#
# Analysing 'LdOJ9B' on 'PLoTSQ'
#
# Analysing 'LDSa6r' on 'PLoTSQ'
#
# Analysing 'lEigjY' on 'PLoTSQ'
#
# Analysing 'LeiMDP' on 'PLoTSQ'
#
# Analysing 'LeIOpp' on 'PLoTSQ'
#
# Analysing 'LElig7' on 'PLoTSQ'
#
# Analysing 'LEVkLl' on 'PLoTSQ'
#
# Analysing 'lEYx2W' on 'PLoTSQ'
#
# Analysing 'LF5IXe' on 'PLoTSQ'
#
# Analysing 'lffOPx' on 'PLoTSQ'
#
# Analysing 'LfR4mn' on 'PLoTSQ'
#
# Analysing 'lGnap8' on 'PLoTSQ'
#
# Analysing 'lHTd7l' on 'PLoTSQ'
#
# Analysing 'lhu639' on 'PLoTSQ'
#
# Analysing 'liuUub' on 'PLoTSQ'
#
# Analysing 'lJ42bV' on 'PLoTSQ'
#
# Analysing 'ljABh9' on 'PLoTSQ'
#
# Analysing 'lJimSa' on 'PLoTSQ'
#
# Analysing 'LjOW0h' on 'PLoTSQ'
#
# Analysing 'lJSglM' on 'PLoTSQ'
#
# Analysing 'LkCXd0' on 'PLoTSQ'
#
# Analysing 'LkKtYJ' on 'PLoTSQ'
#
# Analysing 'lL2KP9' on 'PLoTSQ'
#
# Analysing 'LLbYs4' on 'PLoTSQ'
#
# Analysing 'LlQZUD' on 'PLoTSQ'
#
# Analysing 'lN3qp7' on 'PLoTSQ'
#
# Analysing 'lNMxgb' on 'PLoTSQ'
#
# Analysing 'lNpI5e' on 'PLoTSQ'
#
# Analysing 'lnRXdv' on 'PLoTSQ'
#
# Analysing 'lNxnHz' on 'PLoTSQ'
#
# Analysing 'LO6GjJ' on 'PLoTSQ'
#
# Analysing 'LPU6aU' on 'PLoTSQ'
#
# Analysing 'lq3sQq' on 'PLoTSQ'
#
# Analysing 'lqDeoY' on 'PLoTSQ'
#
# Analysing 'LqfyRb' on 'PLoTSQ'
#
# Analysing 'Lr6QEU' on 'PLoTSQ'
#
# Analysing 'lrAqbA' on 'PLoTSQ'
#
# Analysing 'lRDFO9' on 'PLoTSQ'
#
# Analysing 'LrgTjI' on 'PLoTSQ'
#
# Analysing 'LrpeHa' on 'PLoTSQ'
#
# Analysing 'LSjdg5' on 'PLoTSQ'
#
# Analysing 'LsZ8Kx' on 'PLoTSQ'
#
# Analysing 'lTckH1' on 'PLoTSQ'
#
# Analysing 'ltfZOr' on 'PLoTSQ'
#
# Analysing 'ltGw8F' on 'PLoTSQ'
#
# Analysing 'LTJQT2' on 'PLoTSQ'
#
# Analysing 'Ltu1EI' on 'PLoTSQ'
#
# Analysing 'lu2XCm' on 'PLoTSQ'
#
# Analysing 'lVPyon' on 'PLoTSQ'
#
# Analysing 'LWuoPF' on 'PLoTSQ'
#
# Analysing 'LWWGrk' on 'PLoTSQ'
#
# Analysing 'lxYc8T' on 'PLoTSQ'
#
# Analysing 'LYQWOW' on 'PLoTSQ'
#
# Analysing 'lyREd3' on 'PLoTSQ'
#
# Analysing 'lZaXba' on 'PLoTSQ'
#
# Analysing 'LZazv8' on 'PLoTSQ'
#
# Analysing 'lzJTR8' on 'PLoTSQ'
#
# Analysing 'LZTkrj' on 'PLoTSQ'
#
# Analysing 'LzvUdh' on 'PLoTSQ'
#
# Analysing 'm0RoAg' on 'PLoTSQ'
#
# Analysing 'M3jLmP' on 'PLoTSQ'
#
# Analysing 'M46El7' on 'PLoTSQ'
#
# Analysing 'm49fzx' on 'PLoTSQ'
#
# Analysing 'M4XfVa' on 'PLoTSQ'
#
# Analysing 'M5iBzh' on 'PLoTSQ'
#
# Analysing 'm5wsEy' on 'PLoTSQ'
#
# Analysing 'M7haz4' on 'PLoTSQ'
#
# Analysing 'M9n4TY' on 'PLoTSQ'
#
# Analysing 'mahnjI' on 'PLoTSQ'
#
# Analysing 'mALHhr' on 'PLoTSQ'
#
# Analysing 'MARyLu' on 'PLoTSQ'
#
# Analysing 'mAwlth' on 'PLoTSQ'
#
# Analysing 'maxQhc' on 'PLoTSQ'
#
# Analysing 'mB057h' on 'PLoTSQ'
#
# Analysing 'mB4Jtb' on 'PLoTSQ'
#
# Analysing 'mb6cCi' on 'PLoTSQ'
#
# Analysing 'mBc1a8' on 'PLoTSQ'
#
# Analysing 'MBCHjx' on 'PLoTSQ'
#
# Analysing 'MbfeoU' on 'PLoTSQ'
#
# Analysing 'MbLKGi' on 'PLoTSQ'
#
# Analysing 'mbnksR' on 'PLoTSQ'
#
# Analysing 'mBpoMh' on 'PLoTSQ'
#
# Analysing 'MBWHqJ' on 'PLoTSQ'
#
# Analysing 'Mc57gc' on 'PLoTSQ'
#
# Analysing 'mCcdNM' on 'PLoTSQ'
#
# Analysing 'mckfMB' on 'PLoTSQ'
#
# Analysing 'mCRetA' on 'PLoTSQ'
#
# Analysing 'mcSSUR' on 'PLoTSQ'
#
# Analysing 'McUt1p' on 'PLoTSQ'
#
# Analysing 'Md4jQB' on 'PLoTSQ'
#
# Analysing 'MdaCSG' on 'PLoTSQ'
#
# Analysing 'mdu87y' on 'PLoTSQ'
#
# Analysing 'mDUWDd' on 'PLoTSQ'
#
# Analysing 'MEbz6W' on 'PLoTSQ'
#
# Analysing 'mFAhLf' on 'PLoTSQ'
#
# Analysing 'mFXBN0' on 'PLoTSQ'
#
# Analysing 'MG3PtL' on 'PLoTSQ'
#
# Analysing 'mG5T8P' on 'PLoTSQ'
#
# Analysing 'mGy0rn' on 'PLoTSQ'
#
# Analysing 'Mhx6cb' on 'PLoTSQ'
#
# Analysing 'Mi4AdG' on 'PLoTSQ'
#
# Analysing 'MI7WFg' on 'PLoTSQ'
#
# Analysing 'MICy89' on 'PLoTSQ'
#
# Analysing 'MIPIPI' on 'PLoTSQ'
#
# Analysing 'miZgXT' on 'PLoTSQ'
#
# Analysing 'mj5XnV' on 'PLoTSQ'
#
# Analysing 'mKOYE7' on 'PLoTSQ'
#
# Analysing 'MKVEuQ' on 'PLoTSQ'
#
# Analysing 'MKY0Wr' on 'PLoTSQ'
#
# Analysing 'mLVq5X' on 'PLoTSQ'
#
# Analysing 'mM86hy' on 'PLoTSQ'
#
# Analysing 'mNGzG4' on 'PLoTSQ'
#
# Analysing 'mnMjyE' on 'PLoTSQ'
#
# Analysing 'mo834B' on 'PLoTSQ'
#
# Analysing 'MoAwNY' on 'PLoTSQ'
#
# Analysing 'mOC3Q8' on 'PLoTSQ'
#
# Analysing 'mp9Df3' on 'PLoTSQ'
#
# Analysing 'mpbqxS' on 'PLoTSQ'
#
# Analysing 'MpCqbe' on 'PLoTSQ'
#
# Analysing 'mPovEK' on 'PLoTSQ'
#
# Analysing 'mpTgWC' on 'PLoTSQ'
#
# Analysing 'MqiYhM' on 'PLoTSQ'
#
# Analysing 'mqtpED' on 'PLoTSQ'
#
# Analysing 'MRuXmO' on 'PLoTSQ'
#
# Analysing 'MSSTJt' on 'PLoTSQ'
#
# Analysing 'MT8EOU' on 'PLoTSQ'
#
# Analysing 'mtA4ic' on 'PLoTSQ'
#
# Analysing 'Mtt3QD' on 'PLoTSQ'
#
# Analysing 'MuRG9Y' on 'PLoTSQ'
#
# Analysing 'MusRmW' on 'PLoTSQ'
#
# Analysing 'MUSW36' on 'PLoTSQ'
#
# Analysing 'MV9hH2' on 'PLoTSQ'
#
# Analysing 'MVHttk' on 'PLoTSQ'
#
# Analysing 'mvqGvG' on 'PLoTSQ'
#
# Analysing 'mWEQ51' on 'PLoTSQ'
#
# Analysing 'MwTM6O' on 'PLoTSQ'
#
# Analysing 'mWxL0e' on 'PLoTSQ'
#
# Analysing 'mxghOQ' on 'PLoTSQ'
#
# Analysing 'MypK3o' on 'PLoTSQ'
#
# Analysing 'MyuaNa' on 'PLoTSQ'
#
# Analysing 'mZ4AlA' on 'PLoTSQ'
#
# Analysing 'n35Rx1' on 'PLoTSQ'
#
# Analysing 'N3fowT' on 'PLoTSQ'
#
# Analysing 'N3had1' on 'PLoTSQ'
#
# Analysing 'N4Guhg' on 'PLoTSQ'
#
# Analysing 'N4uWHS' on 'PLoTSQ'
#
# Analysing 'n5B63a' on 'PLoTSQ'
#
# Analysing 'N7cIDR' on 'PLoTSQ'
#
# Analysing 'n8pzs6' on 'PLoTSQ'
#
# Analysing 'N8W9Ir' on 'PLoTSQ'
#
# Analysing 'n9GYuG' on 'PLoTSQ'
#
# Analysing 'NAfULe' on 'PLoTSQ'
#
# Analysing 'NASbd5' on 'PLoTSQ'
#
# Analysing 'NBhNQx' on 'PLoTSQ'
#
# Analysing 'NbUamy' on 'PLoTSQ'
#
# Analysing 'NC8wtu' on 'PLoTSQ'
#
# Analysing 'ncNWVa' on 'PLoTSQ'
#
# Analysing 'ncoJL5' on 'PLoTSQ'
#
# Analysing 'NCVZVo' on 'PLoTSQ'
#
# Analysing 'nDVE3o' on 'PLoTSQ'
#
# Analysing 'NEnAR0' on 'PLoTSQ'
#
# Analysing 'nETOMT' on 'PLoTSQ'
#
# Analysing 'nf20M2' on 'PLoTSQ'
#
# Analysing 'NFBYe0' on 'PLoTSQ'
#
# Analysing 'nh4opt' on 'PLoTSQ'
#
# Analysing 'Nh5KQc' on 'PLoTSQ'
#
# Analysing 'nhdSSK' on 'PLoTSQ'
#
# Analysing 'NiceDQ' on 'PLoTSQ'
#
# Analysing 'nin4US' on 'PLoTSQ'
#
# Analysing 'niXefp' on 'PLoTSQ'
#
# Analysing 'NJaceY' on 'PLoTSQ'
#
# Analysing 'NkYZqH' on 'PLoTSQ'
#
# Analysing 'nLjSdQ' on 'PLoTSQ'
#
# Analysing 'NLY9su' on 'PLoTSQ'
#
# Analysing 'NMFILw' on 'PLoTSQ'
#
# Analysing 'nnd2U3' on 'PLoTSQ'
#
# Analysing 'NNjC5G' on 'PLoTSQ'
#
# Analysing 'nOrOuI' on 'PLoTSQ'
#
# Analysing 'npdP2h' on 'PLoTSQ'
#
# Analysing 'NpkX7q' on 'PLoTSQ'
#
# Analysing 'NpvUkZ' on 'PLoTSQ'
#
# Analysing 'NqdBYh' on 'PLoTSQ'
#
# Analysing 'nS1fg1' on 'PLoTSQ'
#
# Analysing 'nSHUil' on 'PLoTSQ'
#
# Analysing 'NsI4ok' on 'PLoTSQ'
#
# Analysing 'nSKMSG' on 'PLoTSQ'
#
# Analysing 'NTqYew' on 'PLoTSQ'
#
# Analysing 'NtY5mX' on 'PLoTSQ'
#
# Analysing 'nU1v1w' on 'PLoTSQ'
#
# Analysing 'Nujmno' on 'PLoTSQ'
#
# Analysing 'NVVyzX' on 'PLoTSQ'
#
# Analysing 'NxAJeZ' on 'PLoTSQ'
#
# Analysing 'nXeinv' on 'PLoTSQ'
#
# Analysing 'NxkbrI' on 'PLoTSQ'
#
# Analysing 'nY8cUo' on 'PLoTSQ'
#
# Analysing 'nYbhX5' on 'PLoTSQ'
#
# Analysing 'NyIiSo' on 'PLoTSQ'
#
# Analysing 'NYoDB5' on 'PLoTSQ'
#
# Analysing 'nyZX9U' on 'PLoTSQ'
#
# Analysing 'nz63RY' on 'PLoTSQ'
#
# Analysing 'nZd4dE' on 'PLoTSQ'
#
# Analysing 'nZJB2m' on 'PLoTSQ'
#
# Analysing 'NZLwQA' on 'PLoTSQ'
#
# Analysing 'nZpHck' on 'PLoTSQ'
#
# Analysing 'NZRjAB' on 'PLoTSQ'
#
# Analysing 'NzTFZ3' on 'PLoTSQ'
#
# Analysing 'o0KoZW' on 'PLoTSQ'
#
# Analysing 'o14FrP' on 'PLoTSQ'
#
# Analysing 'o1hq2d' on 'PLoTSQ'
#
# Analysing 'o2OSkx' on 'PLoTSQ'
#
# Analysing 'O3dLJF' on 'PLoTSQ'
#
# Analysing 'o3SEF2' on 'PLoTSQ'
#
# Analysing 'o4k6iL' on 'PLoTSQ'
#
# Analysing 'O5CtMU' on 'PLoTSQ'
#
# Analysing 'o5EHm4' on 'PLoTSQ'
#
# Analysing 'O6PcJF' on 'PLoTSQ'
#
# Analysing 'o7jjxk' on 'PLoTSQ'
#
# No SNPs available for MR analysis of 'o7LU0G' on 'PLoTSQ'
#
# Analysing 'O7XKwx' on 'PLoTSQ'
#
# Analysing 'o8CDpn' on 'PLoTSQ'
#
# Analysing 'oaqLH8' on 'PLoTSQ'
#
# Analysing 'OAvXDK' on 'PLoTSQ'
#
# Analysing 'oBKt93' on 'PLoTSQ'
#
# Analysing 'oByxWr' on 'PLoTSQ'
#
# Analysing 'ocRUkM' on 'PLoTSQ'
#
# Analysing 'OcYjk4' on 'PLoTSQ'
#
# Analysing 'od3uIc' on 'PLoTSQ'
#
# Analysing 'Odmmb4' on 'PLoTSQ'
#
# Analysing 'oeAJQy' on 'PLoTSQ'
#
# Analysing 'OEjiab' on 'PLoTSQ'
#
# Analysing 'OEODQk' on 'PLoTSQ'
#
# Analysing 'oEqoRL' on 'PLoTSQ'
#
# Analysing 'oeW0Ts' on 'PLoTSQ'
#
# Analysing 'OFgPPk' on 'PLoTSQ'
#
# Analysing 'OFGQqx' on 'PLoTSQ'
#
# Analysing 'oFWO2K' on 'PLoTSQ'
#
# Analysing 'og5tCw' on 'PLoTSQ'
#
# Analysing 'OHdjLX' on 'PLoTSQ'
#
# Analysing 'OHHevK' on 'PLoTSQ'
#
# Analysing 'OHy8OK' on 'PLoTSQ'
#
# Analysing 'OI4L1X' on 'PLoTSQ'
#
# Analysing 'oIscmS' on 'PLoTSQ'
#
# Analysing 'OJN2yX' on 'PLoTSQ'
#
# Analysing 'okEKOX' on 'PLoTSQ'
#
# Analysing 'oKyGHB' on 'PLoTSQ'
#
# Analysing 'oLBBSN' on 'PLoTSQ'
#
# Analysing 'oM0mVz' on 'PLoTSQ'
#
# Analysing 'OmApRs' on 'PLoTSQ'
#
# Analysing 'OMI4xA' on 'PLoTSQ'
#
# Analysing 'On34f3' on 'PLoTSQ'
#
# Analysing 'Onlvpc' on 'PLoTSQ'
#
# No SNPs available for MR analysis of 'oO9tkB' on 'PLoTSQ'
#
# Analysing 'oOtgc1' on 'PLoTSQ'
#
# Analysing 'OoV7bC' on 'PLoTSQ'
#
# Analysing 'Oox5dY' on 'PLoTSQ'
#
# Analysing 'oP4CgV' on 'PLoTSQ'
#
# Analysing 'oprFGq' on 'PLoTSQ'
#
# Analysing 'oQ3eG1' on 'PLoTSQ'
#
# Analysing 'oRLYZM' on 'PLoTSQ'
#
# Analysing 'orN0sW' on 'PLoTSQ'
#
# Analysing 'oRq7Pv' on 'PLoTSQ'
#
# Analysing 'Os2vkv' on 'PLoTSQ'
#
# Analysing 'osJ1vW' on 'PLoTSQ'
#
# Analysing 'OSQQAV' on 'PLoTSQ'
#
# Analysing 'ot4AOG' on 'PLoTSQ'
#
# Analysing 'otAepK' on 'PLoTSQ'
#
# Analysing 'oTsDmv' on 'PLoTSQ'
#
# Analysing 'oUn5IM' on 'PLoTSQ'
#
# Analysing 'ovmso6' on 'PLoTSQ'
#
# Analysing 'OVTic4' on 'PLoTSQ'
#
# Analysing 'OvZwBE' on 'PLoTSQ'
#
# Analysing 'owexMy' on 'PLoTSQ'
#
# Analysing 'ox2SPs' on 'PLoTSQ'
#
# Analysing 'oX9ca5' on 'PLoTSQ'
#
# Analysing 'OXGqPz' on 'PLoTSQ'
#
# Analysing 'oXgXzv' on 'PLoTSQ'
#
# Analysing 'OXJeH1' on 'PLoTSQ'
#
# Analysing 'oXLh5d' on 'PLoTSQ'
#
# Analysing 'OYGcR2' on 'PLoTSQ'
#
# Analysing 'oYubmk' on 'PLoTSQ'
#
# Analysing 'p01mnN' on 'PLoTSQ'
#
# Analysing 'p08V8O' on 'PLoTSQ'
#
# Analysing 'P2mwpn' on 'PLoTSQ'
#
# Analysing 'p5ryfp' on 'PLoTSQ'
#
# Analysing 'p6gFKy' on 'PLoTSQ'
#
# Analysing 'p6YUMA' on 'PLoTSQ'
#
# Analysing 'p8rGBn' on 'PLoTSQ'
#
# Analysing 'p9UGJm' on 'PLoTSQ'
#
# Analysing 'paAchd' on 'PLoTSQ'
#
# Analysing 'PAGdS9' on 'PLoTSQ'
#
# Analysing 'PaIdxT' on 'PLoTSQ'
#
# Analysing 'PAmQtX' on 'PLoTSQ'
#
# Analysing 'paQFbA' on 'PLoTSQ'
#
# Analysing 'pc4EVT' on 'PLoTSQ'
#
# Analysing 'PCv8dH' on 'PLoTSQ'
#
# Analysing 'pCvc0h' on 'PLoTSQ'
#
# Analysing 'Pd7Juo' on 'PLoTSQ'
#
# Analysing 'PDn9Gj' on 'PLoTSQ'
#
# Analysing 'PDSyLX' on 'PLoTSQ'
#
# Analysing 'pEvBHO' on 'PLoTSQ'
#
# Analysing 'pFasXe' on 'PLoTSQ'
#
# Analysing 'PGFUaU' on 'PLoTSQ'
#
# Analysing 'PH43Xl' on 'PLoTSQ'
#
# Analysing 'PhF62i' on 'PLoTSQ'
#
# Analysing 'PHXsUf' on 'PLoTSQ'
#
# Analysing 'PHy4vE' on 'PLoTSQ'
#
# Analysing 'PI5HGs' on 'PLoTSQ'
#
# Analysing 'Pjj8kQ' on 'PLoTSQ'
#
# Analysing 'PJsz4B' on 'PLoTSQ'
#
# Analysing 'pJUdhi' on 'PLoTSQ'
#
# Analysing 'pjxV7V' on 'PLoTSQ'
#
# Analysing 'PkkIXU' on 'PLoTSQ'
#
# Analysing 'PktAgJ' on 'PLoTSQ'
#
# Analysing 'plcnlC' on 'PLoTSQ'
#
# Analysing 'PMi2G5' on 'PLoTSQ'
#
# Analysing 'pmU15B' on 'PLoTSQ'
#
# Analysing 'PMv4eL' on 'PLoTSQ'
#
# Analysing 'PNcNNU' on 'PLoTSQ'
#
# Analysing 'PnkCaz' on 'PLoTSQ'
#
# Analysing 'PNSo2t' on 'PLoTSQ'
#
# Analysing 'pnZSUn' on 'PLoTSQ'
#
# Analysing 'Po6BFm' on 'PLoTSQ'
#
# Analysing 'poQTez' on 'PLoTSQ'
#
# Analysing 'ppGGcF' on 'PLoTSQ'
#
# Analysing 'PpxSVV' on 'PLoTSQ'
#
# Analysing 'pPZeph' on 'PLoTSQ'
#
# Analysing 'pQarDs' on 'PLoTSQ'
#
# Analysing 'pQIRXo' on 'PLoTSQ'
#
# Analysing 'PR4opd' on 'PLoTSQ'
#
# Analysing 'pre64f' on 'PLoTSQ'
#
# Analysing 'PRGgQ2' on 'PLoTSQ'
#
# Analysing 'Prk8oI' on 'PLoTSQ'
#
# Analysing 'PRMS3P' on 'PLoTSQ'
#
# Analysing 'ps4cyM' on 'PLoTSQ'
#
# Analysing 'PSxYQs' on 'PLoTSQ'
#
# Analysing 'pT7R02' on 'PLoTSQ'
#
# Analysing 'PT8lNs' on 'PLoTSQ'
#
# Analysing 'PTblyN' on 'PLoTSQ'
#
# Analysing 'pTdhee' on 'PLoTSQ'
#
# Analysing 'PTKjjt' on 'PLoTSQ'
#
# Analysing 'PUkgqn' on 'PLoTSQ'
#
# Analysing 'PVSooW' on 'PLoTSQ'
#
# Analysing 'pVWXtS' on 'PLoTSQ'
#
# Analysing 'Pvy5iC' on 'PLoTSQ'
#
# Analysing 'pW94tr' on 'PLoTSQ'
#
# Analysing 'PWdXLB' on 'PLoTSQ'
#
# Analysing 'pWe2Ob' on 'PLoTSQ'
#
# Analysing 'PwPRw4' on 'PLoTSQ'
#
# Analysing 'pWZu2O' on 'PLoTSQ'
#
# Analysing 'pxFHyH' on 'PLoTSQ'
#
# Analysing 'PXhLxX' on 'PLoTSQ'
#
# Analysing 'pY2KEz' on 'PLoTSQ'
#
# Analysing 'pz50lo' on 'PLoTSQ'
#
# Analysing 'pZbYEk' on 'PLoTSQ'
#
# Analysing 'PZC3Bg' on 'PLoTSQ'
#
# Analysing 'q0IAlI' on 'PLoTSQ'
#
# Analysing 'q0UIaM' on 'PLoTSQ'
#
# Analysing 'Q1kioD' on 'PLoTSQ'
#
# Analysing 'Q1supL' on 'PLoTSQ'
#
# Analysing 'Q2AFJw' on 'PLoTSQ'
#
# Analysing 'Q4tFib' on 'PLoTSQ'
#
# Analysing 'Q4uJh6' on 'PLoTSQ'
#
# Analysing 'Q74VTd' on 'PLoTSQ'
#
# Analysing 'Q7MjOe' on 'PLoTSQ'
#
# Analysing 'Q8g2Oc' on 'PLoTSQ'
#
# Analysing 'q9dp4J' on 'PLoTSQ'
#
# ...
#
# Analysing 'sN68fZ' on 'PLoTSQ'
#
# Analysing 'SNy6Gu' on 'PLoTSQ'
#
# Analysing 'So75qJ' on 'PLoTSQ'
#
# Analysing 'sou4WW' on 'PLoTSQ'
#
# Analysing 'SPud9Z' on 'PLoTSQ'
#
# Analysing 'SqIm18' on 'PLoTSQ'
#
# Analysing 'SqQifl' on 'PLoTSQ'
#
# Analysing 'SQvRmw' on 'PLoTSQ'
#
# Analysing 'SR8ayE' on 'PLoTSQ'
#
# Analysing 'srDStB' on 'PLoTSQ'
#
# Analysing 'SrMwrl' on 'PLoTSQ'
#
# Analysing 'srN529' on 'PLoTSQ'
#
# Analysing 'sRYPVU' on 'PLoTSQ'
#
# Analysing 'SSLxn9' on 'PLoTSQ'
#
# Analysing 'SsUUFB' on 'PLoTSQ'
#
# Analysing 'stRbtU' on 'PLoTSQ'
#
# Analysing 'SUEfUU' on 'PLoTSQ'
#
# Analysing 'SuJJPg' on 'PLoTSQ'
#
# Analysing 'sUsQ3b' on 'PLoTSQ'
#
# Analysing 'Suxan0' on 'PLoTSQ'
#
# Analysing 'sVAxSw' on 'PLoTSQ'
#
# Analysing 'SvbjDu' on 'PLoTSQ'
#
# Analysing 'svpdp8' on 'PLoTSQ'
#
# Analysing 'sw6wsx' on 'PLoTSQ'
#
# Analysing 'swauzY' on 'PLoTSQ'
#
# Analysing 'SxpU5Z' on 'PLoTSQ'
#
# Analysing 'sYBo2b' on 'PLoTSQ'
#
# Analysing 'SyPost' on 'PLoTSQ'
#
# Analysing 'szc4Fl' on 'PLoTSQ'
#
# Analysing 'SZg3uH' on 'PLoTSQ'
#
# Analysing 'szsB8C' on 'PLoTSQ'
#
# Analysing 'sztIgl' on 'PLoTSQ'
#
# Analysing 'SZzOny' on 'PLoTSQ'
#
# Analysing 'T06b0s' on 'PLoTSQ'
#
# Analysing 'T0D4A6' on 'PLoTSQ'
#
# Analysing 't3h7jI' on 'PLoTSQ'
#
# Analysing 't498yN' on 'PLoTSQ'
#
# Analysing 'T4xRfj' on 'PLoTSQ'
#
# Analysing 't4y9bi' on 'PLoTSQ'
#
# Analysing 't5FhsQ' on 'PLoTSQ'
#
# Analysing 'T7E4eD' on 'PLoTSQ'
#
# Analysing 'T93ePk' on 'PLoTSQ'
#
# Analysing 'tBufVK' on 'PLoTSQ'
#
# Analysing 'TCcYI2' on 'PLoTSQ'
#
# Analysing 'TcDFC1' on 'PLoTSQ'
#
# Analysing 'TcfLjG' on 'PLoTSQ'
#
# Analysing 'tCkKO3' on 'PLoTSQ'
#
# Analysing 'TDnyTM' on 'PLoTSQ'
#
# Analysing 'tdXXoa' on 'PLoTSQ'
#
# Analysing 'TeNpGf' on 'PLoTSQ'
#
# Analysing 'teQHCC' on 'PLoTSQ'
#
# Analysing 'tFrpjZ' on 'PLoTSQ'
#
# Analysing 'tFXCm0' on 'PLoTSQ'
#
# Analysing 'tGE7TS' on 'PLoTSQ'
#
# Analysing 'tH6ZR9' on 'PLoTSQ'
#
# Analysing 'tHeLLp' on 'PLoTSQ'
#
# Analysing 'THGbhu' on 'PLoTSQ'
#
# Analysing 'tHYloM' on 'PLoTSQ'
#
# Analysing 'tIJUrC' on 'PLoTSQ'
#
# Analysing 'tiRquh' on 'PLoTSQ'
#
# Analysing 'tirtg6' on 'PLoTSQ'
#
# Analysing 'tJK98j' on 'PLoTSQ'
#
# Analysing 'TKsr2J' on 'PLoTSQ'
#
# Analysing 'tL0KB2' on 'PLoTSQ'
#
# Analysing 'TlCxs7' on 'PLoTSQ'
#
# Analysing 'tlICUP' on 'PLoTSQ'
#
# Analysing 'TLOYsq' on 'PLoTSQ'
#
# Analysing 'TLPso1' on 'PLoTSQ'
#
# Analysing 'TLTsK0' on 'PLoTSQ'
#
# Analysing 'tMpgtx' on 'PLoTSQ'
#
# Analysing 'tmYjyV' on 'PLoTSQ'
#
# Analysing 'tMYoI0' on 'PLoTSQ'
#
# Analysing 'To404A' on 'PLoTSQ'
#
# Analysing 'Tpy9hg' on 'PLoTSQ'
#
# Analysing 'tqL48m' on 'PLoTSQ'
#
# Analysing 'tqr0U3' on 'PLoTSQ'
#
# Analysing 'TQTuny' on 'PLoTSQ'
#
# Analysing 'TR0FHX' on 'PLoTSQ'
#
# Analysing 'trvrZu' on 'PLoTSQ'
#
# Analysing 'TrzdmE' on 'PLoTSQ'
#
# Analysing 'Ts8vPK' on 'PLoTSQ'
#
# Analysing 'TsYbCY' on 'PLoTSQ'
#
# Analysing 'tTyEb4' on 'PLoTSQ'
#
# Analysing 'TU3EEa' on 'PLoTSQ'
#
# Analysing 'tU9Q15' on 'PLoTSQ'
#
# Analysing 'tUMqiT' on 'PLoTSQ'
#
# Analysing 'TV3aL2' on 'PLoTSQ'
#
# Analysing 'tV7rir' on 'PLoTSQ'
#
# Analysing 'tV9KG4' on 'PLoTSQ'
#
# Analysing 'TvcKCf' on 'PLoTSQ'
#
# Analysing 'TvjTMc' on 'PLoTSQ'
#
# Analysing 'tVPQT7' on 'PLoTSQ'
#
# Analysing 'tWLGrb' on 'PLoTSQ'
#
# Analysing 'TwxX62' on 'PLoTSQ'
#
# Analysing 'TX2KOJ' on 'PLoTSQ'
#
# Analysing 'txRivJ' on 'PLoTSQ'
#
# Analysing 'txRRUe' on 'PLoTSQ'
#
# Analysing 'txW6nU' on 'PLoTSQ'
#
# Analysing 'tZUY6K' on 'PLoTSQ'
#
# Analysing 'tZyTFi' on 'PLoTSQ'
#
# Analysing 'U1RILF' on 'PLoTSQ'
#
# Analysing 'u1rItA' on 'PLoTSQ'
#
# Analysing 'u3zOez' on 'PLoTSQ'
#
# Analysing 'u48jto' on 'PLoTSQ'
#
# Analysing 'U4SwSQ' on 'PLoTSQ'
#
# Analysing 'u6ohj4' on 'PLoTSQ'
#
# Analysing 'U7aq39' on 'PLoTSQ'
#
# Analysing 'u7RIcp' on 'PLoTSQ'
#
# Analysing 'u7WJ8w' on 'PLoTSQ'
#
# Analysing 'u8Js0h' on 'PLoTSQ'
#
# Analysing 'U97U1h' on 'PLoTSQ'
#
# Analysing 'U9T8gs' on 'PLoTSQ'
#
# Analysing 'u9Th2Z' on 'PLoTSQ'
#
# Analysing 'UA8aif' on 'PLoTSQ'
#
# Analysing 'UAbahF' on 'PLoTSQ'
#
# Analysing 'UaG1sc' on 'PLoTSQ'
#
# Analysing 'UAV6Fp' on 'PLoTSQ'
#
# Analysing 'UBAzY6' on 'PLoTSQ'
#
# Analysing 'ucCrbY' on 'PLoTSQ'
#
# Analysing 'uCoKen' on 'PLoTSQ'
#
# Analysing 'Ud94ia' on 'PLoTSQ'
#
# Analysing 'ueNYC8' on 'PLoTSQ'
#
# Analysing 'UFDaXM' on 'PLoTSQ'
#
# Analysing 'uFrPk0' on 'PLoTSQ'
#
# Analysing 'uhaybA' on 'PLoTSQ'
#
# Analysing 'UhDNCw' on 'PLoTSQ'
#
# Analysing 'Uhg8XI' on 'PLoTSQ'
#
# Analysing 'Uhj46u' on 'PLoTSQ'
#
# Analysing 'uhkVKU' on 'PLoTSQ'
#
# Analysing 'UiMxYD' on 'PLoTSQ'
#
# Analysing 'uj9tIZ' on 'PLoTSQ'
#
# Analysing 'uJKMDn' on 'PLoTSQ'
#
# Analysing 'UK138u' on 'PLoTSQ'
#
# Analysing 'Ulh6DR' on 'PLoTSQ'
#
# Analysing 'uLvDDz' on 'PLoTSQ'
#
# Analysing 'UMm4Qe' on 'PLoTSQ'
#
# Analysing 'UmRY5v' on 'PLoTSQ'
#
# Analysing 'UN90zz' on 'PLoTSQ'
#
# Analysing 'UNJzbt' on 'PLoTSQ'
#
# Analysing 'uODC9A' on 'PLoTSQ'
#
# Analysing 'uoTjXg' on 'PLoTSQ'
#
# Analysing 'uPUhEK' on 'PLoTSQ'
#
# Analysing 'UPx0wI' on 'PLoTSQ'
#
# Analysing 'uqCAfi' on 'PLoTSQ'
#
# Analysing 'UQFP87' on 'PLoTSQ'
#
# Analysing 'UQMLmS' on 'PLoTSQ'
#
# Analysing 'uqn29L' on 'PLoTSQ'
#
# Analysing 'uqnmI0' on 'PLoTSQ'
#
# Analysing 'UQZfgk' on 'PLoTSQ'
#
# Analysing 'UR5IQr' on 'PLoTSQ'
#
# Analysing 'uRHJB6' on 'PLoTSQ'
#
# Analysing 'urHP6g' on 'PLoTSQ'
#
# Analysing 'URQFXm' on 'PLoTSQ'
#
# Analysing 'urQQd2' on 'PLoTSQ'
#
# Analysing 'USFA05' on 'PLoTSQ'
#
# Analysing 'usIC9e' on 'PLoTSQ'
#
# Analysing 'usJ0jw' on 'PLoTSQ'
#
# Analysing 'ut3rze' on 'PLoTSQ'
#
# Analysing 'uUQRYz' on 'PLoTSQ'
#
# Analysing 'UuZC6S' on 'PLoTSQ'
#
# Analysing 'uwJgpZ' on 'PLoTSQ'
#
# Analysing 'uWP5Xe' on 'PLoTSQ'
#
# Analysing 'uWtCRc' on 'PLoTSQ'
#
# Analysing 'uWzfpU' on 'PLoTSQ'
#
# Analysing 'uxzcPm' on 'PLoTSQ'
#
# Analysing 'UyjmCH' on 'PLoTSQ'
#
# Analysing 'uzvcJr' on 'PLoTSQ'
#
# Analysing 'v0d2VH' on 'PLoTSQ'
#
# Analysing 'v3owQE' on 'PLoTSQ'
#
# Analysing 'v4Ynvp' on 'PLoTSQ'
#
# Analysing 'v5pizh' on 'PLoTSQ'
#
# Analysing 'V5q5pG' on 'PLoTSQ'
#
# Analysing 'V5twBn' on 'PLoTSQ'
#
# Analysing 'VA2fzz' on 'PLoTSQ'
#
# Analysing 'VAdKNl' on 'PLoTSQ'
#
# Analysing 'VAjfzi' on 'PLoTSQ'
#
# Analysing 'VAPwcw' on 'PLoTSQ'
#
# Analysing 'vAPYjU' on 'PLoTSQ'
#
# Analysing 'VArFPa' on 'PLoTSQ'
#
# Analysing 'vbd8m9' on 'PLoTSQ'
#
# Analysing 'VCMubN' on 'PLoTSQ'
#
# Analysing 'VCYZcU' on 'PLoTSQ'
#
# Analysing 'VD0fKM' on 'PLoTSQ'
#
# Analysing 'VdeuR3' on 'PLoTSQ'
#
# Analysing 'vdnrnh' on 'PLoTSQ'
#
# Analysing 'VdQbSA' on 'PLoTSQ'
#
# Analysing 'vFDOgb' on 'PLoTSQ'
#
# Analysing 'VfFxvW' on 'PLoTSQ'
#
# Analysing 'vfzccO' on 'PLoTSQ'
#
# Analysing 'VgcNZM' on 'PLoTSQ'
#
# Analysing 'vGlmD8' on 'PLoTSQ'
#
# Analysing 'vgLSAj' on 'PLoTSQ'
#
# Analysing 'VH3UvW' on 'PLoTSQ'
#
# Analysing 'VhhUN5' on 'PLoTSQ'
#
# Analysing 'VHVFEQ' on 'PLoTSQ'
#
# Analysing 'viXE8h' on 'PLoTSQ'
#
# Analysing 'vJ421L' on 'PLoTSQ'
#
# Analysing 'VjdgqD' on 'PLoTSQ'
#
# Analysing 'VJgBtA' on 'PLoTSQ'
#
# Analysing 'VjYw6g' on 'PLoTSQ'
#
# Analysing 'vkdLhB' on 'PLoTSQ'
#
# Analysing 'vLdB89' on 'PLoTSQ'
#
# Analysing 'VlMtfE' on 'PLoTSQ'
#
# Analysing 'vmBJUm' on 'PLoTSQ'
#
# Analysing 'vMxf6Q' on 'PLoTSQ'
#
# Analysing 'vnVMbP' on 'PLoTSQ'
#
# Analysing 'VnwJVv' on 'PLoTSQ'
#
# Analysing 'vomPaY' on 'PLoTSQ'
#
# Analysing 'VpcUNS' on 'PLoTSQ'
#
# Analysing 'VQlDf0' on 'PLoTSQ'
#
# Analysing 'VqMdFx' on 'PLoTSQ'
#
# Analysing 'vrD3n1' on 'PLoTSQ'
#
# Analysing 'vRNAg6' on 'PLoTSQ'
#
# Analysing 'VRwuIS' on 'PLoTSQ'
#
# Analysing 'vRzFwW' on 'PLoTSQ'
#
# Analysing 'Vs1dPa' on 'PLoTSQ'
#
# Analysing 'Vt0340' on 'PLoTSQ'
#
# Analysing 'vt1pea' on 'PLoTSQ'
#
# Analysing 'vTASOO' on 'PLoTSQ'
#
# Analysing 'vTcBUJ' on 'PLoTSQ'
#
# Analysing 'vtdTrV' on 'PLoTSQ'
#
# Analysing 'vTqn1H' on 'PLoTSQ'
#
# Analysing 'Vuf7MN' on 'PLoTSQ'
#
# Analysing 'vuGSO0' on 'PLoTSQ'
#
# Analysing 'VujLWV' on 'PLoTSQ'
#
# Analysing 'vvg2Nd' on 'PLoTSQ'
#
# Analysing 'vVm7Wz' on 'PLoTSQ'
#
# Analysing 'VWaVKS' on 'PLoTSQ'
#
# Analysing 'vwrbOZ' on 'PLoTSQ'
#
# Analysing 'vWY8qJ' on 'PLoTSQ'
#
# Analysing 'vx1VtS' on 'PLoTSQ'
#
# Analysing 'vXQyoI' on 'PLoTSQ'
#
# Analysing 'VXTVcm' on 'PLoTSQ'
#
# Analysing 'vXXX2v' on 'PLoTSQ'
#
# Analysing 'vxxX9W' on 'PLoTSQ'
#
# Analysing 'vxZJEH' on 'PLoTSQ'
#
# Analysing 'vYhKcw' on 'PLoTSQ'
#
# Analysing 'VyPVnh' on 'PLoTSQ'
#
# Analysing 'VZKChX' on 'PLoTSQ'
#
# Analysing 'W1TzpI' on 'PLoTSQ'
#
# Analysing 'W1ygrS' on 'PLoTSQ'
#
# Analysing 'w44tzB' on 'PLoTSQ'
#
# Analysing 'w4xVCK' on 'PLoTSQ'
#
# Analysing 'w5lvet' on 'PLoTSQ'
#
# Analysing 'w6FaAv' on 'PLoTSQ'
#
# Analysing 'w8Bc6y' on 'PLoTSQ'
#
# Analysing 'W9UFQu' on 'PLoTSQ'
#
# Analysing 'wa8qwF' on 'PLoTSQ'
#
# Analysing 'wBf0JT' on 'PLoTSQ'
#
# Analysing 'WBP8XW' on 'PLoTSQ'
#
# Analysing 'wbQ8FV' on 'PLoTSQ'
#
# Analysing 'wbu7Bk' on 'PLoTSQ'
#
# Analysing 'WbVkjR' on 'PLoTSQ'
#
# Analysing 'wcSh2A' on 'PLoTSQ'
#
# Analysing 'WDcofO' on 'PLoTSQ'
#
# Analysing 'wDxfJb' on 'PLoTSQ'
#
# Analysing 'we5BkK' on 'PLoTSQ'
#
# Analysing 'WEtAkc' on 'PLoTSQ'
#
# Analysing 'WfMfqh' on 'PLoTSQ'
#
# Analysing 'WG5gDg' on 'PLoTSQ'
#
# Analysing 'wGcML3' on 'PLoTSQ'
#
# Analysing 'whCzsX' on 'PLoTSQ'
#
# Analysing 'wHfVrk' on 'PLoTSQ'
#
# Analysing 'wIOGc6' on 'PLoTSQ'
#
# Analysing 'WIrhhO' on 'PLoTSQ'
#
# Analysing 'WJJIXO' on 'PLoTSQ'
#
# Analysing 'wJqdwg' on 'PLoTSQ'
#
# Analysing 'WKAPkV' on 'PLoTSQ'
#
# Analysing 'wLGe80' on 'PLoTSQ'
#
# Analysing 'wnJHdd' on 'PLoTSQ'
#
# Analysing 'WnlXXT' on 'PLoTSQ'
#
# Analysing 'WOJqNt' on 'PLoTSQ'
#
# Analysing 'wqyoW9' on 'PLoTSQ'
#
# Analysing 'wricjk' on 'PLoTSQ'
#
# Analysing 'WS0Dhz' on 'PLoTSQ'
#
# Analysing 'WsJ50M' on 'PLoTSQ'
#
# Analysing 'wT4d47' on 'PLoTSQ'
#
# Analysing 'WtlMWD' on 'PLoTSQ'
#
# Analysing 'WU9mNS' on 'PLoTSQ'
#
# Analysing 'wuegjA' on 'PLoTSQ'
#
# Analysing 'WUrSmg' on 'PLoTSQ'
#
# Analysing 'WVD77V' on 'PLoTSQ'
#
# Analysing 'WVSS9O' on 'PLoTSQ'
#
# Analysing 'wVyMbU' on 'PLoTSQ'
#
# Analysing 'WwgIS3' on 'PLoTSQ'
#
# Analysing 'WWZV13' on 'PLoTSQ'
#
# Analysing 'wwzYJ9' on 'PLoTSQ'
#
# Analysing 'wxQDMu' on 'PLoTSQ'
#
# Analysing 'WyeOO1' on 'PLoTSQ'
#
# Analysing 'WYg6uO' on 'PLoTSQ'
#
# Analysing 'WyriIY' on 'PLoTSQ'
#
# Analysing 'wYUZr3' on 'PLoTSQ'
#
# Analysing 'WZ6zLx' on 'PLoTSQ'
#
# Analysing 'WZlGGz' on 'PLoTSQ'
#
# Analysing 'WZLKhv' on 'PLoTSQ'
#
# Analysing 'WZozGR' on 'PLoTSQ'
#
# Analysing 'WZRkRJ' on 'PLoTSQ'
#
# Analysing 'x0I562' on 'PLoTSQ'
#
# Analysing 'x39vjx' on 'PLoTSQ'
#
# Analysing 'x3CIan' on 'PLoTSQ'
#
# Analysing 'x3iTHo' on 'PLoTSQ'
#
# Analysing 'X4fLbA' on 'PLoTSQ'
#
# Analysing 'x9tYOM' on 'PLoTSQ'
#
# Analysing 'X9VXAa' on 'PLoTSQ'
#
# Analysing 'xA4XQM' on 'PLoTSQ'
#
# Analysing 'XB6fXc' on 'PLoTSQ'
#
# Analysing 'xbIRSF' on 'PLoTSQ'
#
# Analysing 'Xce8pk' on 'PLoTSQ'
#
# Analysing 'xDceLl' on 'PLoTSQ'
#
# Analysing 'XDjX7P' on 'PLoTSQ'
#
# Analysing 'XDut5Z' on 'PLoTSQ'
#
# Analysing 'XdwKHY' on 'PLoTSQ'
#
# Analysing 'XEhvfV' on 'PLoTSQ'
#
# Analysing 'xEIf9R' on 'PLoTSQ'
#
# Analysing 'xeUgjN' on 'PLoTSQ'
#
# Analysing 'XFA2Fx' on 'PLoTSQ'
#
# Analysing 'xfn53O' on 'PLoTSQ'
#
# Analysing 'xFTtCp' on 'PLoTSQ'
#
# Analysing 'Xg2n6E' on 'PLoTSQ'
#
# Analysing 'XggvXk' on 'PLoTSQ'
#
# Analysing 'xHeWO6' on 'PLoTSQ'
#
# Analysing 'XHhh9n' on 'PLoTSQ'
#
# Analysing 'XHWdf2' on 'PLoTSQ'
#
# Analysing 'XHYwxt' on 'PLoTSQ'
#
# Analysing 'xHZuZc' on 'PLoTSQ'
#
# Analysing 'Xid2LP' on 'PLoTSQ'
#
# Analysing 'Xj21Fo' on 'PLoTSQ'
#
# Analysing 'XjacM6' on 'PLoTSQ'
#
# Analysing 'xJaJKi' on 'PLoTSQ'
#
# Analysing 'XK1fFj' on 'PLoTSQ'
#
# Analysing 'XKS8Fz' on 'PLoTSQ'
#
# Analysing 'XlyNBC' on 'PLoTSQ'
#
# Analysing 'XMGDVn' on 'PLoTSQ'
#
# Analysing 'xmreRt' on 'PLoTSQ'
#
# Analysing 'xNBRip' on 'PLoTSQ'
#
# Analysing 'xNLlYE' on 'PLoTSQ'
#
# Analysing 'XNsErT' on 'PLoTSQ'
#
# Analysing 'xNtgXo' on 'PLoTSQ'
#
# Analysing 'Xo6avZ' on 'PLoTSQ'
#
# Analysing 'xoDCcu' on 'PLoTSQ'
#
# Analysing 'xOGzHj' on 'PLoTSQ'
#
# Analysing 'xOuvw4' on 'PLoTSQ'
#
# Analysing 'xpWolM' on 'PLoTSQ'
#
# Analysing 'XQKp2N' on 'PLoTSQ'
#
# Analysing 'XQMbAq' on 'PLoTSQ'
#
# Analysing 'xRBaZr' on 'PLoTSQ'
#
# Analysing 'XRD7Fd' on 'PLoTSQ'
#
# Analysing 'XRIqHf' on 'PLoTSQ'
#
# Analysing 'xssCVn' on 'PLoTSQ'
#
# Analysing 'xTcUOv' on 'PLoTSQ'
#
# Analysing 'XtOfXA' on 'PLoTSQ'
#
# Analysing 'xtU1YC' on 'PLoTSQ'
#
# Analysing 'xUaPTb' on 'PLoTSQ'
#
# Analysing 'xuDTzw' on 'PLoTSQ'
#
# Analysing 'XvBpLV' on 'PLoTSQ'
#
# Analysing 'xVNqXz' on 'PLoTSQ'
#
# Analysing 'XVQA6O' on 'PLoTSQ'
#
# Analysing 'XvSnls' on 'PLoTSQ'
#
# Analysing 'XWhBaD' on 'PLoTSQ'
#
# Analysing 'xWMHLf' on 'PLoTSQ'
#
# Analysing 'xWZUxQ' on 'PLoTSQ'
#
# Analysing 'XXkb5K' on 'PLoTSQ'
#
# Analysing 'xY5oET' on 'PLoTSQ'
#
# Analysing 'xYTPds' on 'PLoTSQ'
#
# Analysing 'xyupfX' on 'PLoTSQ'
#
# Analysing 'XZ1bHB' on 'PLoTSQ'
#
# Analysing 'XzsIbx' on 'PLoTSQ'
#
# Analysing 'XZtqi3' on 'PLoTSQ'
#
# Analysing 'Y2fr64' on 'PLoTSQ'
#
# Analysing 'Y2klz8' on 'PLoTSQ'
#
# Analysing 'Y2xLbr' on 'PLoTSQ'
#
# Analysing 'y4PMh7' on 'PLoTSQ'
#
# Analysing 'y4q6G7' on 'PLoTSQ'
#
# Analysing 'y56cXb' on 'PLoTSQ'
#
# Analysing 'y6Lv9w' on 'PLoTSQ'
#
# Analysing 'Y6PRpG' on 'PLoTSQ'
#
# Analysing 'y9Pim2' on 'PLoTSQ'
#
# Analysing 'yAr3kt' on 'PLoTSQ'
#
# Analysing 'yaTGKT' on 'PLoTSQ'
#
# Analysing 'YBgoKd' on 'PLoTSQ'
#
# Analysing 'YBlc0g' on 'PLoTSQ'
#
# Analysing 'Ybw2tj' on 'PLoTSQ'
#
# Analysing 'YCgNiI' on 'PLoTSQ'
#
# Analysing 'YCYrdJ' on 'PLoTSQ'
#
# Analysing 'YdExHn' on 'PLoTSQ'
#
# Analysing 'YDRzRv' on 'PLoTSQ'
#
# Analysing 'yE9TZr' on 'PLoTSQ'
#
# Analysing 'YEyWRx' on 'PLoTSQ'
#
# Analysing 'yfB5y7' on 'PLoTSQ'
#
# Analysing 'YFHzQc' on 'PLoTSQ'
#
# Analysing 'yfU0IB' on 'PLoTSQ'
#
# Analysing 'Ygf3Pg' on 'PLoTSQ'
#
# Analysing 'YHp68E' on 'PLoTSQ'
#
# Analysing 'yhT2wl' on 'PLoTSQ'
#
# Analysing 'YicM8x' on 'PLoTSQ'
#
# Analysing 'YIF5EA' on 'PLoTSQ'
#
# Analysing 'yiz06S' on 'PLoTSQ'
#
# Analysing 'Yj9roc' on 'PLoTSQ'
#
# Analysing 'YjCKLC' on 'PLoTSQ'
#
# Analysing 'YJcklm' on 'PLoTSQ'
#
# Analysing 'yjQyb2' on 'PLoTSQ'
#
# Analysing 'yJVCkO' on 'PLoTSQ'
#
# Analysing 'ykjunE' on 'PLoTSQ'
#
# Analysing 'yKp5Yy' on 'PLoTSQ'
#
# Analysing 'YKQy7t' on 'PLoTSQ'
#
# Analysing 'YKZbW0' on 'PLoTSQ'
#
# Analysing 'YMl3jD' on 'PLoTSQ'
#
# Analysing 'Yn8MMf' on 'PLoTSQ'
#
# Analysing 'ynbhtz' on 'PLoTSQ'
#
# Analysing 'yneP7G' on 'PLoTSQ'
#
# Analysing 'YoepGK' on 'PLoTSQ'
#
# Analysing 'yOjFzf' on 'PLoTSQ'
#
# Analysing 'YpmnVN' on 'PLoTSQ'
#
# Analysing 'YQ9434' on 'PLoTSQ'
#
# Analysing 'yTqJiO' on 'PLoTSQ'
#
# Analysing 'yTTkY1' on 'PLoTSQ'
#
# Analysing 'yujlDP' on 'PLoTSQ'
#
# Analysing 'yUvjnj' on 'PLoTSQ'
#
# Analysing 'YuYxux' on 'PLoTSQ'
#
# Analysing 'YWfekl' on 'PLoTSQ'
#
# Analysing 'Ywjaqt' on 'PLoTSQ'
#
# Analysing 'Ywp8Vq' on 'PLoTSQ'
#
# Analysing 'yxbV4e' on 'PLoTSQ'
#
# Analysing 'yXE5ff' on 'PLoTSQ'
#
# Analysing 'yXfU3M' on 'PLoTSQ'
#
# Analysing 'yyVenC' on 'PLoTSQ'
#
# Analysing 'yZg3w9' on 'PLoTSQ'
#
# Analysing 'YZtDxv' on 'PLoTSQ'
#
# Analysing 'YZUZRc' on 'PLoTSQ'
#
# Analysing 'YzXXob' on 'PLoTSQ'
#
# Analysing 'Z0TOpp' on 'PLoTSQ'
#
# Analysing 'Z1BWjM' on 'PLoTSQ'
#
# Analysing 'z1uJP9' on 'PLoTSQ'
#
# Analysing 'z4nlkQ' on 'PLoTSQ'
#
# Analysing 'z5A9cL' on 'PLoTSQ'
#
# Analysing 'z5IZJZ' on 'PLoTSQ'
#
# Analysing 'Z5snjk' on 'PLoTSQ'
#
# Analysing 'z6NOvZ' on 'PLoTSQ'
#
# Analysing 'z78wPi' on 'PLoTSQ'
#
# Analysing 'Z7Nbz3' on 'PLoTSQ'
#
# Analysing 'Z82KQW' on 'PLoTSQ'
#
# Analysing 'Z8TYHt' on 'PLoTSQ'
#
# Analysing 'zamZtr' on 'PLoTSQ'
#
# Analysing 'ZB1MH5' on 'PLoTSQ'
#
# Analysing 'zBAjbB' on 'PLoTSQ'
#
# Analysing 'zBD5mb' on 'PLoTSQ'
#
# Analysing 'ZBfhAa' on 'PLoTSQ'
#
# Analysing 'ZboMaK' on 'PLoTSQ'
#
# Analysing 'zCNl1W' on 'PLoTSQ'
#
# Analysing 'zcXbrx' on 'PLoTSQ'
#
# Analysing 'zDUOCe' on 'PLoTSQ'
#
# Analysing 'ZE3cxL' on 'PLoTSQ'
#
# Analysing 'ZgyHbo' on 'PLoTSQ'
#
# Analysing 'ZGzhtu' on 'PLoTSQ'
#
# Analysing 'Zh1r3W' on 'PLoTSQ'
#
# Analysing 'zHi2iG' on 'PLoTSQ'
#
# Analysing 'zhK6r2' on 'PLoTSQ'
#
# Analysing 'ZhS1P2' on 'PLoTSQ'
#
# Analysing 'ZJ8fqE' on 'PLoTSQ'
#
# Analysing 'ZjCxWk' on 'PLoTSQ'
#
# Analysing 'Zjg0OM' on 'PLoTSQ'
#
# Analysing 'ZJN3LT' on 'PLoTSQ'
#
# Analysing 'ZjT9VS' on 'PLoTSQ'
#
# Analysing 'zJzbeq' on 'PLoTSQ'
#
# Analysing 'ZKlbtV' on 'PLoTSQ'
#
# Analysing 'ZkXJ5t' on 'PLoTSQ'
#
# Analysing 'zLIK6Q' on 'PLoTSQ'
#
# Analysing 'zLQkIW' on 'PLoTSQ'
#
# Analysing 'ZLscj6' on 'PLoTSQ'
#
# Analysing 'ZLV761' on 'PLoTSQ'
#
# Analysing 'ZMFgN9' on 'PLoTSQ'
#
# Analysing 'zMnwde' on 'PLoTSQ'
#
# Analysing 'ZmnzFX' on 'PLoTSQ'
#
# Analysing 'zms3Th' on 'PLoTSQ'
#
# Analysing 'ZnHOAs' on 'PLoTSQ'
#
# Analysing 'zoOmvf' on 'PLoTSQ'
#
# Analysing 'ZP5DMI' on 'PLoTSQ'
#
# Analysing 'zpEzhh' on 'PLoTSQ'
#
# Analysing 'ZpGUKm' on 'PLoTSQ'
#
# Analysing 'zq3jjJ' on 'PLoTSQ'
#
# Analysing 'zQGpe5' on 'PLoTSQ'
#
# Analysing 'zQjWMb' on 'PLoTSQ'
#
# Analysing 'Zrc2SX' on 'PLoTSQ'
#
# Analysing 'ZRJNqm' on 'PLoTSQ'
#
# Analysing 'ZrXlIY' on 'PLoTSQ'
#
# Analysing 'zTRD10' on 'PLoTSQ'
#
# Analysing 'ZuXXBB' on 'PLoTSQ'
#
# Analysing 'ZV8N30' on 'PLoTSQ'
#
# Analysing 'ZVgOej' on 'PLoTSQ'
#
# Analysing 'ZvUuyY' on 'PLoTSQ'
#
# Analysing 'zvYkyq' on 'PLoTSQ'
#
# Analysing 'ZWj7lo' on 'PLoTSQ'
#
# Analysing 'ZXBqUQ' on 'PLoTSQ'
#
# Analysing 'zxDZ8z' on 'PLoTSQ'
#
# Analysing 'zxi3BT' on 'PLoTSQ'
#
# Analysing 'zXpT5G' on 'PLoTSQ'
#
# Analysing 'zydwNA' on 'PLoTSQ'
#
# Analysing 'zyE3X0' on 'PLoTSQ'
#
# Analysing 'zyfGnq' on 'PLoTSQ'
#
# Analysing 'ZZKl9w' on 'PLoTSQ'

# %%
## pleiotropy test
mr_all_pleio <- mr_pleiotropy_test(harmon_nopleio)
# heterogeneity test
mr_all_het <- mr_heterogeneity(harmon_nopleio, method_list = c("mr_ivw"))
# Out:
# Not enough SNPs available for pleiotropy analysis of '0rlQuw' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '0tuqOC' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '11ab6G' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '1kjSq6' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '26S0cE' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '2FbUgr' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '2txnCT' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '2vYbUG' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '3hrREK' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '3i6RDH' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '3pdMaf' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '3TlOcC' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '4Y8AoH' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '4yzHEh' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '53yNiS' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '56M8LH' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '5aeb2d' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '5MfhUv' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '5ulzlM' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '67GpWz' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '6eFJAA' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '6IWlFa' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '6q7soC' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '6uJdXY' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '6UXSlI' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '76p0lP' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '7DrnXF' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '7H8CLk' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '7pyzc9' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '806rh8' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '8IhiOm' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '8temwQ' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '93sEDg' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '9fekE9' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '9JsNzR' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '9q3dCL' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '9rpM1H' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '9UiEW1' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '9wlTAG' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '9xfmfA' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '9Yt0pA' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of '9zUwZs' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'A40C8L' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'A8CZ0I' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'A9LRCP' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'aDNVRd' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'agGIoB' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'AJ6e38' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'akxcFz' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'aNgabn' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'AnNENP' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'ApBZcx' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'aw3JlE' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'B5xZYc' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'BiYeNw' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'BJXXV5' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'bNDHQR' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'bNUAkQ' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'BYUbCE' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'BZ7YRY' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'bZPSIn' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'c780sq' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'c8pkqo' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'cgbcWN' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'cJMLuy' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'cPyA3r' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'CR668A' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Cwlphs' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'CXryLC' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'cXUyKd' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'D8cMv7' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'D8omWN' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'd9fmtC' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'dNYGI4' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'dUgaDZ' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'dwPL1q' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'E1MSOJ' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'e514lC' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'E8xrPm' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'EAQGdd' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'EbYN4s' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'eQwGr5' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'ErgMwz' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'eXBgXn' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'F8c53B' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'FAEizE' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'FDL0cD' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'FJzJC6' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Fklmb1' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'FnhD9x' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'fo4L4d' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'FqeFQh' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'fR2HTf' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'fucJHm' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'FxE55l' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'gANXmT' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'gFSiVR' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'GG94fb' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'gGC6vx' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'gohTqy' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'GpHmzO' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'GqFS7v' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'GUiffj' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'gUvWlF' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'h14Zib' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'H2E17v' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'HBtFzV' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'HcIfCJ' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'hg53hI' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'hIC7Vs' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'HiFAwy' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'HmA7Vk' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'hZA5k9' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'i2eRuM' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'iaKaLX' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Ig1JcA' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'iO0KL2' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'itltlK' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Jg16zo' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'jGtXhJ' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Jh2Qc0' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'JU1m50' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'JxW4u3' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'k19XGv' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'K3P2Dg' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Kbtoae' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'kBYCFu' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'kgWzVK' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'kinL9V' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'KjUcY5' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'kKxbI5' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'km8aiJ' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'KnmAiu' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'KOGLwN' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'kSrIgT' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'KUolTX' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'KXPr8H' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'laiCr2' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'LElig7' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'lhu639' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'liuUub' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'LrgTjI' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'lTckH1' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Ltu1EI' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'LWWGrk' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'LZazv8' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'LzvUdh' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'm49fzx' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'mAwlth' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'mCRetA' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'mDUWDd' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'mFAhLf' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'MoAwNY' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'mPovEK' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'mqtpED' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'ncoJL5' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'nhdSSK' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'nU1v1w' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'NYoDB5' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'NZRjAB' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'o7LU0G' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'oBKt93' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'oeW0Ts' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'OHdjLX' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'oIscmS' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'okEKOX' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'OmApRs' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'oO9tkB' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'oRq7Pv' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'ot4AOG' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'otAepK' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'oTsDmv' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'ovmso6' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'p6gFKy' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'PAGdS9' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'PAmQtX' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'PhF62i' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'pmU15B' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'poQTez' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'PpxSVV' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'pPZeph' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'PRGgQ2' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Prk8oI' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'PwPRw4' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Q1kioD' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Q8g2Oc' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'QeYKES' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'QGYMDG' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'QKmuGe' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'qnWFtp' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'qPwYET' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'R6NVK2' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'RlB4H0' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'rpXeRi' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'rQwV9H' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'rujYv6' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'rVwhLZ' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'sct1Ck' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'sdSyW0' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'sou4WW' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'sRYPVU' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'TcDFC1' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'TsYbCY' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'tV9KG4' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'u3zOez' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'U9T8gs' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'uhaybA' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'UK138u' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'urHP6g' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'urQQd2' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'usIC9e' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'uWP5Xe' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'uWzfpU' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'uzvcJr' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'VA2fzz' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'VArFPa' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'vbd8m9' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'vmBJUm' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'vnVMbP' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'vTASOO' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'vvg2Nd' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'vxZJEH' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'WJJIXO' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'WS0Dhz' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'WZRkRJ' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Xce8pk' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'XHhh9n' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'XKS8Fz' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'xNLlYE' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'xOuvw4' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'xRBaZr' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'XRIqHf' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'XWhBaD' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'XzsIbx' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'yE9TZr' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'YFHzQc' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'Yj9roc' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'YuYxux' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'yyVenC' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'zJzbeq' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'ZKlbtV' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'zLIK6Q' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'ZXBqUQ' on 'PLoTSQ'
#
# Not enough SNPs available for pleiotropy analysis of 'zXpT5G' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '0rlQuw' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '0tuqOC' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '11ab6G' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '1kjSq6' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '26S0cE' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '2FbUgr' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '2txnCT' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '2vYbUG' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '3hrREK' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '3i6RDH' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '3pdMaf' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '3TlOcC' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '4Y8AoH' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '4yzHEh' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '53yNiS' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '56M8LH' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '5aeb2d' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '5MfhUv' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '5ulzlM' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '67GpWz' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '6eFJAA' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '6IWlFa' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '6q7soC' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '6uJdXY' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '6UXSlI' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '76p0lP' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '7DrnXF' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '7H8CLk' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '7pyzc9' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '806rh8' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '8IhiOm' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '8temwQ' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '93sEDg' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '9fekE9' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '9JsNzR' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '9q3dCL' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '9rpM1H' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '9UiEW1' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '9wlTAG' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '9xfmfA' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '9Yt0pA' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of '9zUwZs' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'A40C8L' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'A8CZ0I' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'A9LRCP' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'aDNVRd' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'agGIoB' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'AJ6e38' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'akxcFz' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'aNgabn' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'AnNENP' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'ApBZcx' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'aw3JlE' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'B5xZYc' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'BiYeNw' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'BJXXV5' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'bNDHQR' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'bNUAkQ' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'BYUbCE' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'BZ7YRY' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'bZPSIn' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'c780sq' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'c8pkqo' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'cgbcWN' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'cJMLuy' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'cPyA3r' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'CR668A' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Cwlphs' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'CXryLC' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'cXUyKd' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'D8cMv7' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'D8omWN' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'd9fmtC' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'dNYGI4' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'dUgaDZ' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'dwPL1q' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'E1MSOJ' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'e514lC' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'E8xrPm' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'EAQGdd' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'EbYN4s' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'eQwGr5' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'ErgMwz' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'eXBgXn' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'F8c53B' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'FAEizE' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'FDL0cD' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'FJzJC6' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Fklmb1' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'FnhD9x' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'fo4L4d' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'FqeFQh' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'fR2HTf' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'fucJHm' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'FxE55l' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'gANXmT' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'gFSiVR' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'GG94fb' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'gGC6vx' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'gohTqy' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'GpHmzO' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'GqFS7v' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'GUiffj' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'gUvWlF' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'h14Zib' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'H2E17v' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'HBtFzV' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'HcIfCJ' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'hg53hI' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'hIC7Vs' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'HiFAwy' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'HmA7Vk' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'hZA5k9' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'i2eRuM' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'iaKaLX' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Ig1JcA' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'iO0KL2' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'itltlK' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Jg16zo' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'jGtXhJ' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Jh2Qc0' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'JU1m50' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'JxW4u3' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'k19XGv' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'K3P2Dg' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Kbtoae' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'kBYCFu' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'kgWzVK' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'kinL9V' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'KjUcY5' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'kKxbI5' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'km8aiJ' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'KnmAiu' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'KOGLwN' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'kSrIgT' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'KUolTX' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'KXPr8H' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'laiCr2' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'LElig7' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'lhu639' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'liuUub' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'LrgTjI' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'lTckH1' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Ltu1EI' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'LWWGrk' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'LZazv8' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'LzvUdh' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'm49fzx' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'mAwlth' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'mCRetA' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'mDUWDd' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'mFAhLf' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'MoAwNY' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'mPovEK' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'mqtpED' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'ncoJL5' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'nhdSSK' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'nU1v1w' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'NYoDB5' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'NZRjAB' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'o7LU0G' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'oBKt93' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'oeW0Ts' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'OHdjLX' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'oIscmS' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'okEKOX' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'OmApRs' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'oO9tkB' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'oRq7Pv' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'ot4AOG' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'otAepK' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'oTsDmv' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'ovmso6' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'p6gFKy' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'PAGdS9' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'PAmQtX' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'PhF62i' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'pmU15B' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'poQTez' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'PpxSVV' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'pPZeph' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'PRGgQ2' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Prk8oI' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'PwPRw4' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Q1kioD' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Q8g2Oc' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'QeYKES' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'QGYMDG' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'QKmuGe' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'qnWFtp' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'qPwYET' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'R6NVK2' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'RlB4H0' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'rpXeRi' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'rQwV9H' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'rujYv6' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'rVwhLZ' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'sct1Ck' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'sdSyW0' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'sou4WW' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'sRYPVU' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'TcDFC1' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'TsYbCY' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'tV9KG4' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'u3zOez' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'U9T8gs' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'uhaybA' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'UK138u' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'urHP6g' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'urQQd2' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'usIC9e' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'uWP5Xe' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'uWzfpU' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'uzvcJr' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'VA2fzz' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'VArFPa' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'vbd8m9' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'vmBJUm' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'vnVMbP' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'vTASOO' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'vvg2Nd' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'vxZJEH' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'WJJIXO' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'WS0Dhz' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'WZRkRJ' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Xce8pk' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'XHhh9n' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'XKS8Fz' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'xNLlYE' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'xOuvw4' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'xRBaZr' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'XRIqHf' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'XWhBaD' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'XzsIbx' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'yE9TZr' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'YFHzQc' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'Yj9roc' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'YuYxux' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'yyVenC' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'zJzbeq' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'ZKlbtV' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'zLIK6Q' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'ZXBqUQ' on 'PLoTSQ'
#
# Not enough SNPs available for Heterogeneity analysis of 'zXpT5G' on 'PLoTSQ'

# %%
## make pretty
mr_all2     <- 
    mr_all %>% 
    mutate(method = case_when(method == "Inverse variance weighted" ~ "IVW",
                              method == "Maximum likelihood" ~ "ML",
                              method == "Weighted median" ~ "WM",
                              method == "MR Egger" ~ "MR_Egger",
                              TRUE ~ method)
          ) %>%
    select(-c('id.exposure','id.outcome'))
mr_all_het2 <-
    mr_all_het %>% 
    mutate(method = ifelse(method=="Inverse variance weighted", "IVW", method)) %>%
    select(-c('id.exposure','id.outcome'))

mr_all_pleio2 <-
    mr_all_pleio %>%
    select(-c('id.exposure','id.outcome'))

# %%
ivw_ct <-
mr_all2 %>% 
    filter(method=='IVW') %>%
    mutate(fdr = p.adjust(pval, 'fdr'))
nrow(ivw_ct)
ivw_ct %>% filter(fdr < 0.05) %>% arrange(b)
# Out:
# [1] 1936
#    outcome      exposure method nsnp b           se         pval         fdr
# 1  delirium_ukb APOE     IVW     38  -0.52268374 0.03650178 1.655388e-46 3.204832e-43
# 2  delirium_ukb RILPL2   IVW      4  -0.50202694 0.14973587 8.001291e-04 3.098100e-02
# 3  delirium_ukb NUDT16   IVW      3  -0.47704221 0.11161357 1.919520e-05 2.322620e-03
# 4  delirium_ukb CEACAM19 IVW     17  -0.41535032 0.08891935 2.996051e-06 7.250443e-04
# 5  delirium_ukb RAB44    IVW      6  -0.35639027 0.09516844 1.805113e-04 1.127322e-02
# 6  delirium_ukb CNPY4    IVW     16  -0.35188509 0.06694478 1.469440e-07 5.689670e-05
# 7  delirium_ukb HEPH     IVW     12  -0.29235353 0.08492048 5.759931e-04 2.494098e-02
# 8  delirium_ukb WARS     IVW     17  -0.22935028 0.05204344 1.048603e-05 1.666215e-03
# 9  delirium_ukb DSG2     IVW     20  -0.21334335 0.05515805 1.097969e-04 7.375589e-03
# 10 delirium_ukb BTN1A1   IVW     20  -0.19055437 0.04481139 2.115250e-05 2.408897e-03
# 11 delirium_ukb CHRDL2   IVW     14  -0.16621115 0.05117292 1.162072e-03 4.090494e-02
# 12 delirium_ukb IL1R1    IVW     34  -0.16066552 0.04675672 5.899325e-04 2.494098e-02
# 13 delirium_ukb GAS6     IVW     28  -0.13613510 0.04142368 1.014740e-03 3.777956e-02
# 14 delirium_ukb CRYBB2   IVW     42  -0.13244654 0.03847631 5.768162e-04 2.494098e-02
# 15 delirium_ukb VASN     IVW     20  -0.11648916 0.02869835 4.926461e-05 4.485006e-03
# 16 delirium_ukb ACE      IVW     39  -0.11581461 0.02995459 1.104814e-04 7.375589e-03
# 17 delirium_ukb MEGF9    IVW     39  -0.11416603 0.03578511 1.421140e-03 4.437626e-02
# 18 delirium_ukb PON3     IVW     25  -0.11301414 0.03578253 1.586590e-03 4.875616e-02
# 19 delirium_ukb HNMT     IVW     39  -0.10629979 0.02349761 6.072296e-06 1.306218e-03
# 20 delirium_ukb IL12RB1  IVW     42  -0.10606451 0.02639025 5.842587e-05 4.917934e-03
# 21 delirium_ukb C2       IVW     65  -0.10481365 0.02587255 5.096598e-05 4.485006e-03
# 22 delirium_ukb ENPP6    IVW     51  -0.09760382 0.02643282 2.220392e-04 1.302630e-02
# 23 delirium_ukb VSIG4    IVW     57  -0.09230825 0.02872456 1.310979e-03 4.382968e-02
# 24 delirium_ukb LGALS9   IVW     48  -0.09084310 0.02584073 4.389261e-04 2.230133e-02
# 25 delirium_ukb RNASET2  IVW     53  -0.08739719 0.02356255 2.079510e-04 1.258103e-02
# 26 delirium_ukb FOLR3    IVW     42  -0.08163864 0.01943386 2.659189e-05 2.860106e-03
# 27 delirium_ukb CDSN     IVW    214  -0.04073406 0.01106281 2.313456e-04 1.317309e-02
# 28 delirium_ukb CD33     IVW     45   0.04096865 0.01212487 7.277781e-04 2.935372e-02
# 29 delirium_ukb PON1     IVW     93   0.04312365 0.01345129 1.346352e-03 4.413171e-02
# 30 delirium_ukb IL17RB   IVW     67   0.05733877 0.01669263 5.926060e-04 2.494098e-02
# ⋮  ⋮            ⋮        ⋮      ⋮    ⋮           ⋮          ⋮            ⋮
# 34 delirium_ukb TOR1AIP1 IVW    61   0.07218894  0.01642644 1.109364e-05 1.666215e-03
# 35 delirium_ukb PXN      IVW    48   0.07366412  0.02305072 1.394725e-03 4.426537e-02
# 36 delirium_ukb GNLY     IVW    42   0.07484572  0.02120428 4.159589e-04 2.176477e-02
# 37 delirium_ukb SFTPA2   IVW    41   0.07502135  0.01725734 1.378779e-05 1.906655e-03
# 38 delirium_ukb LECT2    IVW    63   0.07777112  0.01770410 1.118842e-05 1.666215e-03
# 39 delirium_ukb FCGR3B   IVW    83   0.07783280  0.02293933 6.913538e-04 2.847789e-02
# 40 delirium_ukb GGH      IVW    52   0.07847283  0.02421654 1.193353e-03 4.125591e-02
# 41 delirium_ukb APOL1    IVW    92   0.07865873  0.02256237 4.897891e-04 2.312760e-02
# 42 delirium_ukb PVR      IVW    46   0.08486504  0.02439033 5.024368e-04 2.315994e-02
# 43 delirium_ukb SPINK5   IVW    27   0.08696317  0.02607815 8.538707e-04 3.241360e-02
# 44 delirium_ukb HPGDS    IVW    27   0.08853020  0.02445439 2.943552e-04 1.628205e-02
# 45 delirium_ukb KLRD1    IVW    93   0.09258022  0.02369662 9.348985e-05 6.972223e-03
# 46 delirium_ukb ADAM8    IVW    26   0.10176608  0.03127430 1.137987e-03 4.079894e-02
# 47 delirium_ukb IL1R2    IVW    54   0.10576777  0.02540461 3.136389e-05 3.081259e-03
# 48 delirium_ukb LAYN     IVW    33   0.11471599  0.03201456 3.393533e-04 1.824967e-02
# 49 delirium_ukb DPP10    IVW    36   0.12275363  0.03497931 4.492521e-04 2.230133e-02
# 50 delirium_ukb SSC4D    IVW    32   0.14186764  0.03631561 9.363522e-05 6.972223e-03
# 51 delirium_ukb SPINK6   IVW    29   0.16094151  0.03739974 1.682890e-05 2.172050e-03
# 52 delirium_ukb CCL19    IVW    36   0.16668325  0.03521780 2.213056e-06 6.120680e-04
# 53 delirium_ukb GYS1     IVW    86   0.17046019  0.02861765 2.577426e-09 1.663299e-06
# 54 delirium_ukb FOLH1    IVW    25   0.17530491  0.05455933 1.313079e-03 4.382968e-02
# 55 delirium_ukb DSC2     IVW    20   0.19361612  0.04990053 1.044386e-04 7.375589e-03
# 56 delirium_ukb GPNMB    IVW    24   0.20905428  0.04162514 5.105418e-07 1.647348e-04
# 57 delirium_ukb CD84     IVW    11   0.28934018  0.08883175 1.125287e-03 4.079894e-02
# 58 delirium_ukb RNF43    IVW    11   0.33450274  0.09589063 4.859611e-04 2.312760e-02
# 59 delirium_ukb CEACAM20 IVW     8   0.33547354  0.07488302 7.465420e-06 1.445305e-03
# 60 delirium_ukb NT5C1A   IVW     9   0.34062731  0.08914352 1.328516e-04 8.573359e-03
# 61 delirium_ukb MMP13    IVW     8   0.38398685  0.09230556 3.183119e-05 3.081259e-03
# 62 delirium_ukb SH2B3    IVW     4   0.75209340  0.22372911 7.748523e-04 3.061457e-02
# 63 delirium_ukb MENT     IVW    21   0.77208775  0.10212013 4.012662e-14 3.884257e-11

# %%
mr_all2fdr <- left_join(mr_all2, ivw_ct[,c('exposure','method','outcome', 'fdr')], by=c('exposure', 'outcome', 'method'))

# %%
# save results (cis+trans-pqtls)
resultsdir = paste0("pQTL_MR_analysis/results/with_clumped", "/thres", r2, '/ukb_nopleio')
system(paste0("mkdir -p ", resultsdir), intern=T)
fwrite(mr_all2fdr, paste0(resultsdir, "/mr_pQTLs_delirium_1by1_thres", r2, "_main.csv"))     # main table
fwrite(mr_all_pleio2, paste0(resultsdir, "/mr_pQTLs_delirium_1by1_thres", r2, "_pleio.csv")) # plei test
fwrite(mr_all_het2, paste0(resultsdir, "/mr_pQTLs_delirium_1by1_thres", r2, "_het.csv"))     # heterogeneity test
# save dfs (for ploting)
saveRDS(mr_all, paste0(resultsdir, "/mr_all.rds"))                  # original MR df
saveRDS(harmon_nopleio, paste0(resultsdir, "/harmon_nopleio.rds"))  # original harmon df
# Out:
# character(0)

# %% [markdown]
# #### **single cis+trans pQLT MR:**

# %%
# extract proteins with 1 pQTL
singlesnp_cistrans_proteins <- harmon_nopleio %>% group_by(exposure) %>% summarise(n=n()) %>%filter(n==1) %>% pull(exposure)
cat(paste0(length(singlesnp_cistrans_proteins), ' proteins with 1 pQTL'))
# Out:
# 242 proteins with 1 pQTL

# %%
# subset the harmonised data
harmon_nopleio_singlesnp <- harmon_nopleio %>% filter(exposure %in% singlesnp_cistrans_proteins)

# %%
# run MR (Wald ratio method)
mr_all_cistrans_singlesnp <- mr_singlesnp(harmon_nopleio_singlesnp, all_method = 'mr_wald_ratio')

# %%
mr_all_cistrans_singlesnp_f <-
mr_all_cistrans_singlesnp %>% 
    filter(SNP != 'All - Wald ratio') %>%
    mutate(method = 'Wald ratio', nsnp= 1)

# %%
mr_all_cistrans_singlesnp_f %>% filter(p < 0.05) %>% arrange(p)
mr_all_cistrans_singlesnp_f %>% filter(exposure == 'NEFL') %>% arrange(p)
# Out:
#    exposure outcome      id.exposure id.outcome samplesize SNP         b          se        p           method     nsnp
# 1  CSRP3    delirium_ukb 3YK5eU      lQ5Klx     360901     rs2244492   -0.9636291 0.3644168 0.008185896 Wald ratio 1
# 2  SORBS1   delirium_ukb OxFCzQ      lQ5Klx     360901     rs9988729    0.9551838 0.3972096 0.016184206 Wald ratio 1
# 3  HJV      delirium_ukb 5WW7CH      lQ5Klx     360901     rs76144127   0.9596173 0.4006725 0.016619604 Wald ratio 1
# 4  CAPN3    delirium_ukb UXOY4k      lQ5Klx     360901     rs35833641  -0.8960802 0.3749747 0.016861744 Wald ratio 1
# 5  SYAP1    delirium_ukb kt4iqu      lQ5Klx     360901     rs6632882    0.8094111 0.3560582 0.023010814 Wald ratio 1
# 6  NIT2     delirium_ukb AvqoyZ      lQ5Klx     360901     rs2289502   -0.5471806 0.2412286 0.023310468 Wald ratio 1
# 7  DUT      delirium_ukb iqtbFj      lQ5Klx     360901     rs10849410   0.8724674 0.3879784 0.024528241 Wald ratio 1
# 8  TOMM20   delirium_ukb BysVvE      lQ5Klx     360901     rs10849410   0.7630009 0.3392996 0.024528241 Wald ratio 1
# 9  NEO1     delirium_ukb 7QaiDR      lQ5Klx     360901     rs72741432   0.6563915 0.3031007 0.030342612 Wald ratio 1
# 10 EEF1D    delirium_ukb hzlGMS      lQ5Klx     360901     rs58759041   0.6376420 0.2989457 0.032927210 Wald ratio 1
# 11 CLTA     delirium_ukb nnYKr9      lQ5Klx     360901     rs58759041   0.7797113 0.3655520 0.032927210 Wald ratio 1
# 12 CD82     delirium_ukb G0kTbX      lQ5Klx     360901     rs111715739  0.7190755 0.3441407 0.036664418 Wald ratio 1
# 13 IL13     delirium_ukb XPd1kw      lQ5Klx     360901     rs111715739  0.4548912 0.2177053 0.036664418 Wald ratio 1
# 14 FABP5    delirium_ukb oeD64w      lQ5Klx     360901     rs116967130  0.3625771 0.1740737 0.037260840 Wald ratio 1
# 15 IL3RA    delirium_ukb YZlBep      lQ5Klx     360901     rs7112513    0.8199912 0.4107944 0.045921857 Wald ratio 1
# 16 PPIE     delirium_ukb 17FS5s      lQ5Klx     360901     rs230280     0.7469811 0.3754934 0.046664555 Wald ratio 1
# 17 SHD      delirium_ukb irNlVm      lQ5Klx     360901     rs112530749  0.5180594 0.2630685 0.048919263 Wald ratio 1
#   exposure outcome      id.exposure id.outcome samplesize SNP        b          se        p        method     nsnp
# 1 NEFL     delirium_ukb f515vk      lQ5Klx     360901     rs55678516 -0.4794522 0.4320148 0.267083 Wald ratio 1

# %%
fwrite(mr_all_cistrans_singlesnp_f, "pQTL_MR_analysis/results/with_clumped/thres0.2/ukb_nopleio/mr_pQTLs_delirium_1by1_thres0.2_WR.csv")

# %% [markdown]
# #### **single cis-pQLT MR:**

# %%
## load data
harmon_cis_nopleio <- readRDS('pQTL_MR_analysis/results/with_clumped/thres0.2/ukb_nopleio/harmon_cis_nopleio.rds')
mr_all_cis         <- readRDS('pQTL_MR_analysis/results/with_clumped/thres0.2/ukb_nopleio/mr_all_cis.rds')

# %%
# extract proteins with 1 cis-pQTL
singlesnp_proteins <- harmon_cis_nopleio %>% group_by(exposure) %>% summarise(n=n()) %>%filter(n==1) %>% pull(exposure)
cat(paste0(length(singlesnp_proteins), ' proteins with 1 cis-pQTL'))
# Out:
# 251 proteins with 1 cis-pQTL

# %%
# subset the harmonised data
harmon_cis_nopleio_singlesnp <- harmon_cis_nopleio %>% filter(exposure %in% singlesnp_proteins)

# %%
# run MR (Wald ratio method)
mr_all_cis_singlesnp <- mr_singlesnp(harmon_cis_nopleio_singlesnp, all_method = 'mr_wald_ratio')

# %%
mr_all_cis_singlesnp_f <-
mr_all_cis_singlesnp %>% 
    filter(SNP != 'All - Wald ratio') %>%
    mutate(method = 'Wald ratio', nsnp= 1)

# %%
mr_all_cis_singlesnp_f %>% filter(p < 0.05) %>% arrange(p)
# Out:
#    exposure outcome      id.exposure id.outcome samplesize SNP         b          se        p            method     nsnp
# 1  MB       delirium_ukb qucBLo      PLoTSQ     360901     rs2181048   -1.4387315 0.4312990 0.0008505122 Wald ratio 1
# 2  ARHGAP5  delirium_ukb NkYZqH      PLoTSQ     360901     rs2859448    1.1347315 0.4019679 0.0047585425 Wald ratio 1
# 3  SORBS1   delirium_ukb PwPRw4      PLoTSQ     360901     rs9988729    0.9551838 0.3972096 0.0161842063 Wald ratio 1
# 4  NIT2     delirium_ukb urHP6g      PLoTSQ     360901     rs2289502   -0.5471806 0.2412286 0.0233104677 Wald ratio 1
# 5  NEO1     delirium_ukb gFSiVR      PLoTSQ     360901     rs72741432   0.6563915 0.3031007 0.0303426123 Wald ratio 1
# 6  IL12RB2  delirium_ukb xJaJKi      PLoTSQ     360901     rs416352     0.8048733 0.3821810 0.0352043396 Wald ratio 1
# 7  FABP5    delirium_ukb gohTqy      PLoTSQ     360901     rs116967130  0.3625771 0.1740737 0.0372608404 Wald ratio 1
# 8  FKBP4    delirium_ukb tJK98j      PLoTSQ     360901     rs12817815  -0.7437769 0.3657362 0.0419875772 Wald ratio 1
# 9  FARSA    delirium_ukb nyZX9U      PLoTSQ     360901     rs35087277  -0.7984776 0.3944719 0.0429528119 Wald ratio 1
# 10 RBP2     delirium_ukb fxzQGX      PLoTSQ     360901     rs2118981    0.6955950 0.3468463 0.0449112576 Wald ratio 1
# 11 PPIE     delirium_ukb KUolTX      PLoTSQ     360901     rs230280     0.7469811 0.3754934 0.0466645554 Wald ratio 1
# 12 DYNLT3   delirium_ukb SMDD80      PLoTSQ     360901     rs6695104    0.5950074 0.2999577 0.0472962199 Wald ratio 1
# 13 DYNC1H1  delirium_ukb HYviYN      PLoTSQ     360901     rs6695104    0.5708464 0.2877775 0.0472962199 Wald ratio 1

# %%
fwrite(mr_all_cis_singlesnp_f, "pQTL_MR_analysis/results/with_clumped/thres0.2/ukb_nopleio/mr_pQTLs_delirium_1by1_thres0.2_cis_WR.csv")

# %% [markdown]
# ### **Plot MR results:**

# %%
# PWAS proteins with fdr pval < 0.05
a <- fread("proteomics/delirium/output_pwas_models12/del_model1_glm_int_fullset_sumstats.txt") %>% mutate(fdr.pwas=p.adjust(PVALUE, 'fdr')) 
prots <- a %>% filter(fdr.pwas < 0.05) %>% pull(PROTEIN)
length(prots)
# Out:
# [1] 391

# %% [markdown]
# #### *clumped (r^2=0.2)*

# %% [markdown]
# ##### cis+trans pQTLs

# %%
## load data
cistrans <- fread('pQTL_MR_analysis/results/with_clumped/thres0.2/ukb_nopleio/mr_pQTLs_delirium_1by1_thres0.2_main.csv')
cistrans_signif <- 
cistrans %>% 
    filter(fdr < 0.05) %>%
    #filter(pval < 0.05/nrow(.))  %>% 
    arrange(b) %>% 
    mutate(PROTEIN = factor(exposure, levels = exposure)) 
cistrans_signif %>% nrow
cistrans_signif %>% tail(3)
# Out:
# [1] 63
#   outcome      exposure method nsnp b         se         pval         fdr          PROTEIN
# 1 delirium_ukb MMP13    IVW     8   0.3839869 0.09230556 3.183119e-05 3.081259e-03 MMP13
# 2 delirium_ukb SH2B3    IVW     4   0.7520934 0.22372911 7.748523e-04 3.061457e-02 SH2B3
# 3 delirium_ukb MENT     IVW    21   0.7720878 0.10212013 4.012662e-14 3.884257e-11 MENT

# %%
# proteins with MR-pval < 0.05 (fdr) & PWAS pval < 0.05 (fdr)
cistrans_overlap <-
cistrans_signif %>% 
    left_join(., a[,c("PROTEIN","BETA","STDERR","PVALUE","fdr.pwas")], by = "PROTEIN") %>%
    filter(fdr.pwas < 0.05) %>%
    mutate(same_sign = ifelse(BETA*b > 0, 'yes', 'no')) 

printcmd <- paste0(nrow(cistrans_overlap), ' proteins singificant in both MR and PWAS (FDR q < 0.05 ), ', nrow(cistrans_overlap[cistrans_overlap$same_sign == 'yes',]), ' with same direction of effect')
print(printcmd)
cistrans_overlap[cistrans_overlap$same_sign == 'yes',]
# Out:
# [1] "13 proteins singificant in both MR and PWAS (FDR q < 0.05 ), 8 with same direction of effect"
#   outcome      exposure method nsnp b           se         pval         fdr          PROTEIN BETA       STDERR     PVALUE       fdr.pwas     same_sign
# 1 delirium_ukb APOE     IVW    38   -0.52268374 0.03650178 1.655388e-46 3.204832e-43 APOE    -0.1502851 0.04466934 7.671292e-04 0.0092428346 yes
# 2 delirium_ukb LILRB4   IVW    95    0.06638216 0.01698823 9.324177e-05 6.972223e-03 LILRB4   0.1867010 0.04587379 4.703653e-05 0.0009807118 yes
# 3 delirium_ukb PVR      IVW    46    0.08486504 0.02439033 5.024368e-04 2.315994e-02 PVR      0.1739415 0.04472201 1.004948e-04 0.0018222301 yes
# 4 delirium_ukb ADAM8    IVW    26    0.10176608 0.03127430 1.137987e-03 4.079894e-02 ADAM8    0.1752071 0.04474167 9.004042e-05 0.0016956643 yes
# 5 delirium_ukb LAYN     IVW    33    0.11471599 0.03201456 3.393533e-04 1.824967e-02 LAYN     0.1360131 0.04452539 2.252619e-03 0.0215205331 yes
# 6 delirium_ukb DPP10    IVW    36    0.12275363 0.03497931 4.492521e-04 2.230133e-02 DPP10    0.1330704 0.04397378 2.477046e-03 0.0231006299 yes
# 7 delirium_ukb DSC2     IVW    20    0.19361612 0.04990053 1.044386e-04 7.375589e-03 DSC2     0.2154519 0.04557869 2.278272e-06 0.0001007618 yes
# 8 delirium_ukb NT5C1A   IVW     9    0.34062731 0.08914352 1.328516e-04 8.573359e-03 NT5C1A   0.2113186 0.05023325 2.590730e-05 0.0006354909 yes

# %%
## plot significant proteins
cistrans_signif2 <- 
cistrans_signif %>% 
    mutate(PWAS_signif = ifelse(PROTEIN %in% cistrans_overlap$PROTEIN[cistrans_overlap$same_sign=='yes'], "yes", "no"))

ggplot(cistrans_signif2, aes(x=b, y=PROTEIN, colour=PWAS_signif)) + 
    geom_pointrange(aes(xmin=b-1.96*se, xmax=b+1.96*se)) + 
    geom_vline(xintercept = 0, lty="dashed") + 
    scale_color_manual(values=c("black", "red")) + 
    xlab("MR beta") +
    theme_classic()
ggsave('pQTL_MR_analysis/results/plots/MR_cistrans_r0.2_ukb_results.png', dpi = 500)
# Out:
# Saving 7 x 7 in image
# plot without title

# %% [markdown]
# ##### cis pQLTs

# %%
## load data
cis <- fread('pQTL_MR_analysis/results/with_clumped/thres0.2/ukb_nopleio/mr_pQTLs_delirium_1by1_thres0.2_cis_main.csv')
cis_signif <- 
cis %>% 
    filter(fdr < 0.05) %>%
    #filter(pval < 0.05/nrow(.))  %>% 
    arrange(b) %>% 
    mutate(PROTEIN = factor(exposure, levels = exposure)) 
cis_signif %>% nrow
cis_signif %>% tail(3)
# Out:
# [1] 53
#   outcome      exposure method nsnp b         se        pval         fdr          PROTEIN
# 1 delirium_ukb NT5C1A   IVW    3    0.4843686 0.1429601 7.036889e-04 3.135926e-02 NT5C1A
# 2 delirium_ukb SH2B3    IVW    4    0.7520934 0.2237291 7.748523e-04 3.284618e-02 SH2B3
# 3 delirium_ukb MENT     IVW    9    0.9303266 0.1063181 2.125877e-18 1.847387e-15 MENT

# %%
# proteins with MR-pval < 0.05 (fdr) & PWAS pval < 0.05 (fdr)
overlap <-
cis_signif %>% 
    left_join(., a[,c("PROTEIN","BETA","STDERR","PVALUE","fdr.pwas")], by = "PROTEIN") %>%
    filter(fdr.pwas < 0.05) %>%
    mutate(same_sign = ifelse(BETA*b > 0, 'yes', 'no')) 

printcmd <- paste0(nrow(overlap), ' proteins singificant in both MR and PWAS (FDR q < 0.05 ), ', nrow(overlap[overlap$same_sign == 'yes',]), ' with same direction of effect')
print(printcmd)
overlap[overlap$same_sign == 'yes',]
# Out:
# [1] "13 proteins singificant in both MR and PWAS (FDR q < 0.05 ), 8 with same direction of effect"
#   outcome      exposure method nsnp b           se         pval         fdr          PROTEIN BETA       STDERR     PVALUE       fdr.pwas     same_sign
# 1 delirium_ukb APOE     IVW    36   -0.52557330 0.03683868 3.519371e-46 6.116667e-43 APOE    -0.1502851 0.04466934 7.671292e-04 0.0092428346 yes
# 2 delirium_ukb PILRA    IVW    92    0.04356412 0.01353410 1.287097e-03 4.525121e-02 PILRA    0.1853546 0.04463898 3.291455e-05 0.0007527836 yes
# 3 delirium_ukb PVR      IVW    45    0.08540393 0.02461121 5.202209e-04 2.475338e-02 PVR      0.1739415 0.04472201 1.004948e-04 0.0018222301 yes
# 4 delirium_ukb ADAM8    IVW    22    0.10310541 0.03180558 1.188024e-03 4.301636e-02 ADAM8    0.1752071 0.04474167 9.004042e-05 0.0016956643 yes
# 5 delirium_ukb LAYN     IVW    31    0.11837855 0.03231289 2.487843e-04 1.490990e-02 LAYN     0.1360131 0.04452539 2.252619e-03 0.0215205331 yes
# 6 delirium_ukb DPP10    IVW    35    0.13604936 0.03534930 1.187392e-04 7.894290e-03 DPP10    0.1330704 0.04397378 2.477046e-03 0.0231006299 yes
# 7 delirium_ukb DSC2     IVW    18    0.19762806 0.05129216 1.166852e-04 7.894290e-03 DSC2     0.2154519 0.04557869 2.278272e-06 0.0001007618 yes
# 8 delirium_ukb NT5C1A   IVW     3    0.48436858 0.14296012 7.036889e-04 3.135926e-02 NT5C1A   0.2113186 0.05023325 2.590730e-05 0.0006354909 yes

# %%
## plot significant proteins
cis_signif2 <- 
cis_signif %>% 
    mutate(PWAS_signif = ifelse(PROTEIN %in% overlap$PROTEIN[overlap$same_sign=='yes'], "yes", "no"))

ggplot(cis_signif2, aes(x=b, y=PROTEIN, colour=PWAS_signif)) + 
    geom_pointrange(aes(xmin=b-1.96*se, xmax=b+1.96*se)) + 
    geom_vline(xintercept = 0, lty="dashed") + 
    scale_color_manual(values=c("black", "red")) + 
    xlab("MR beta") +
    theme_classic()
ggsave('pQTL_MR_analysis/results/plots/MR_cis_r0.2_ukb_results.png', dpi = 500)
# Out:
# Saving 7 x 7 in image
# plot without title

# %%
cis_signif2 %>% group_by(PWAS_signif) %>% summarise(n=n())
# Out:
#   PWAS_signif n
# 1 no          45
# 2 yes          8

# %% [markdown]
# ### Individual protein plots:

# %%
mr_scatter_plot(mr_all_cis[mr_all_cis$exposure=="APOE",], harmon_cis_nopleio[harmon_cis_nopleio$exposure=="APOE",])[[1]]
# Out:
# plot without title

# %%
# forrest plot
library(patchwork)
mr_apoe <- mr_singlesnp(harmon_cis[harmon_cis$exposure=="APOE",])
p1 <- mr_forest_plot(mr_apoe)[[1]]
# leave one out (MR excluding each pQLT one by one)
mr_loo_apoe <- mr_leaveoneout(harmon_cis[harmon_cis$exposure=="APOE",])
p2 <- mr_leaveoneout_plot(mr_loo_apoe)[[1]]
# funnel plot
p3 <- mr_funnel_plot(mr_apoe)
p1
p2
p3
# Out:
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_errorbarh()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_errorbarh()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_point()`).”
# plot without title
# $DwGW3H.GkofmA
#
# attr(,"split_type")
# [1] "data.frame"
# attr(,"split_labels")
#   id.exposure id.outcome
# 1      DwGW3H     GkofmA
# plot without title
# plot without title

# %% [markdown]
# ### Compare across r^2 thresholds:

# %%
## compare across r2 thresholds (not abrupt se difference)
a <- fread("pQTL_MR_analysis/results/mr_pQTLs_delirium_1by1_thres0.1_cis_main.txt") %>% filter(method=="IVW") %>% mutate(r2 = "0.1")
b <- fread("pQTL_MR_analysis/results/mr_pQTLs_delirium_1by1_thres0.2_cis_main.txt") %>% filter(method=="IVW") %>% mutate(r2 = "0.2")
ab <- inner_join(a, b, by="exposure") 
plot(ab$se.x, ab$se.y)
abline(a=0,b=1)
ab <- bind_rows(a,b)
ggplot(ab, aes(y=se, fill=r2)) +
geom_boxplot()
# Out:
# plot without title
# plot without title

# %%
# Out:
# plot without title
